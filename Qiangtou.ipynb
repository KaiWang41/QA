# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer

OPEN_QUESTION_WORDS = ['what', 'who', 'whose', 'whom', 'where', 'when', 'why', 'how',
                       'which', "what's", "who's", "where's", "how's"]
CLOSED_QUESTION_WORDS = ['is', 'are', 'am', 'was', 'were', 'do', 'does,', 'did', 'can',
                         'could', 'will', 'would', 'shall', 'should', 'have', 'has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)


def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)


def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma


def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += tfs[term]
    return dfs


def query_vsm(query, index, k=10):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'


file = open('Second_method.csv', 'w')
file.write('id,answer\n')

case_count = 0
# test = [test[17]]
for test_case in test:
    question = test_case['question']
    docid = test_case['docid']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)

    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question)
    results = query_vsm(terms, vsm_inverted_index)

    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    target = [] # target dep

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''
    attr = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of question
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            dobj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'attr' and token.head.dep_ == 'ROOT':
            attr = lemmatize(strip_punctuation(token.text))

    # determine answer dependency
    if qword in ['who', "who's", 'whom', 'whose']:
        for chunk in doc.noun_chunks:
            if qword in chunk.text:
                target = [chunk.root.dep_]

    elif qword in ['where', "where's", 'when']:
        target = ['advmod','prep']

    elif qword in ['how', "how's"]:
        if next_token in ['much', 'many','long','far', 'big', 'wide', 'deep', 'tall', 'high', 'fast', 'heavy','old', 'young']:
            target = ['attr']
        
        elif next_token in ['does', 'did', 'do', 'have', 'has', 'had', 'should',
                            'can', 'could', 'will', 'would', 'must']:
            if dobj != '':
                target = ['advmod', 'acomp']
            else:
                target = ['ROOT']

    elif qword in ['what', "what's", 'which']:
        # what...do type question
        tokens.remove(next_token)
        if 'do' in tokens:
            target = ['ROOT']
        else:
            for chunk in doc.noun_chunks:
                if qword in chunk.text:
                    target = [chunk.root.dep_]

    elif qword == 'why':
        target = ['mark','prep']

    elif qword in CLOSED_QUESTION_WORDS:
        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            
            # dep of phrase before and after 'or'
            prev = tokens[index - 1]
            for chunk in doc.noun_chunks:
                if prev in chunk.text:
                    target = [chunk.root.dep_]
            
            if target == '':
                for token in doc:
                    if prev in token.text:
                        target = [token.dep_]

    # find answer with highest score from the 10 most similar sentences
    max_score = -1
    answer = ''

    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        # find sentence structure
        sent_nsubj = ''
        sent_ROOT = ''
        sent_dobj = ''
        sent_attr = ''
        for token in doc:
            if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_nsubj = lemmatize(strip_punctuation(token.text))
            if token.dep_ == 'ROOT':
                sent_ROOT = lemmatize(strip_punctuation(token.text))
            if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_dobj = lemmatize(strip_punctuation(token.text))
            if 'attr' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_attr = lemmatize(strip_punctuation(token.text))

        score = 0
        if nsubj == sent_nsubj:
            score += 1
            if ROOT == sent_ROOT:
                score += 1
                if dobj == sent_dobj:
                    score += 1
                if attr == sent_attr:
                    score += 1

        max_score = -1
        answer = ''
        if target == ['ROOT'] or target == ['attr'] or target == ['advmod','acomp']:
            for token in doc:
                if token.dep_ in target:
                    score += 1
                    
                    if token.text not in question:
                        score += 1
                        
                    if strip_punctuation(token.text).lower() in stop:
                        score = -1
                        
                    if token.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        answer = token.text
                        
        elif target == ['mark','prep'] or target == ['advmod','prep']:
            for token in doc:
                if token.dep_ in target:
                    score += 1
                    
                    if token.text not in question:
                        score += 1
                        
                    if strip_punctuation(token.text).lower() in stop:
                        score = -1
                        
                    if token.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        substr = sent[sent.index(token.text):]
                        tokens = nltk.word_tokenize(substr)
                        del tokens[0]
                        for token in tokens:
                            if token in punc:
                                break
                            answer += token+' '
                        
        else:
            for chunk in doc.noun_chunks:
                if chunk.root.dep_ in target:
                    score += 1
                    
                    if chunk.text not in question:
                        score += 1
                        
                    if strip_punctuation(chunk.text).lower() in stop:
                        score = -1
                        
                    if chunk.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        answer = chunk.text
        
    # default answer
    if answer == '':
        for chunk in doc.noun_chunks:
            if chunk.text not in stop and chunk.text not in question:
                answer = chunk.text
        
        
    file.write(str(case_count))
    file.write(',')
    file.write(strip_punctuation(answer).strip().lower())
    file.write('\n')
    print(case_count, ' ', answer)
    case_count += 1

file.close()
# Out:
# 0   all capabilities
# 1   the World Wide Web Foundation
# 2   the user
# 3   the open source software model
# 4   started his own company
# 5   month
# 6   referred to as a browser
# 7   Java applets
# 8   Internet Explorer
# 9   the World Wide Web
# 10   part
# 11   Sir Tim Berners-Lee
# 12   merely "web browsers
# 13   a web browser
# 14   merely "web browsers
# 15   started his own company
# 16   Commission Safari and Mobile Safari were likewise always included with OS X and iOS respectively always included with OS X and iOS respectively included with OS X and iOS respectively
# 17   local files
# 18   a process
# 19   history
# 20   a web browser
# 21   released in September 2008
# 22   Net Applications
# 23   the World Wide Web
# 24   over 95%
# 25   e-mail
# 26   reduces consumer choice
# 27   their managers
# 28   web browsers
# 29   (HTTP
# 30   CSS
# 31   the browser
# 32   web browsers
# 33   the World Wide Web Foundation
# 34   users
# 35   over 40 million phones
# 36   the average person
# 37   Internet Explorer
# 38   a web browser
# 39   Microsoft's browser
# 40   the user
# 41   a web browser
# 42   the feed
# 43   month
# 44   Google Chrome
# 45   the browser
# 46   the World Wide Web
# 47   Google Chrome
# 48   the World Wide Web
# 49   the entire browser market
# 50   Firefox
# 51   merely "web browsers
# 52   Firefox
# 53   the World Wide Web
# 54   North Korea
# 55   May
# 56   the Olympics
# 57   security concerns
# 58   San Francisco
# 59   the torch relay route
# 60   the torch
# 61   the games
# 62   leader Kim Jong Il
# 63   saboteurs
# 64   Taksim Square
# 65   Tibet
# 66   North Korea
# 67   flight delay
# 68   the police
# 69   dissent
# 70   all bearers
# 71   the South China Sea
# 72   cosmetic products
# 73   pro-secessionist conspiracy and anti-Chinese racism
# 74   the torch relay
# 75   The relay
# 76   the games
# 77   the torch route
# 78   an unannounced route
# 79   an implication
# 80   police chief Heather Fong
# 81   the entire universe
# 82   15 minutes
# 83   Plaza de Mayo
# 84   propane
# 85   the 1989 Tiananmen Square protests
# 86   Tibet
# 87   Pyongyang
# 88   the relay locations
# 89   the torch's Olympic journey
# 90   China
# 91   the Dalai Lama
# 92   The only noted instance
# 93   April
# 94   Western media bias
# 95   the pro-Tibet independent camp
# 96   "Free Tibet
# 97   Jinan
# 98   Taksim Square
# 99   media coverage
# 100   represent the Macanese and that there were too many non-athletes among the torchbearers
# 101   some IOC members
# 102   April
# 103   70 runners
# 104   some IOC members
# 105   the Olympic cause
# 106   its journey
# 107   closed doors
# 108   the torch relays
# 109   narrow streets
# 110   North Korea
# 111   the 1936 Summer Olympics
# 112   rocks
# 113   Tibet
# 114   Carlos Espínola
# 115   the route changes
# 116   Republic Day celebrations
# 117   the Chinese people
# 118   an issue
# 119   the torch
# 120   the Stade Charléty
# 121   at least thirty-five arrests
# 122   the 1936 Summer Olympics
# 123   April
# 124   order
# 125   the citizens of San Francisco
# 126   Jin Jing
# 127   international
# 128   the relay
# 129   the Palace Square
# 130   April
# 131   Commonwealth Park
# 132   the Mayor stating these thugs were from the security services
# 133   the incredible influence
# 134   Chinese 1992 Olympic champion swimmer Lin Li
# 135   an issue
# 136   Macau
# 137   the relay
# 138   Green Party officials
# 139   demonstrators
# 140   China
# 141   North Korea
# 142   the torch
# 143   the torch relay route
# 144   Western media bias
# 145   the relay locations
# 146   the relay
# 147   all times
# 148   other pro-China groups
# 149   the torch relay route
# 150   the torch relay route
# 151   the torch relay
# 152   London
# 153   his blog
# 154   Western media bias
# 155   Ho Chi Minh City
# 156   April
# 157   pro-secessionist conspiracy and anti-Chinese racism
# 158   the Chinese community
# 159   large Chinese flags
# 160   the fact that there was no risk
# 161   the police
# 162   propane
# 163   both sides
# 164   the torch
# 165   its journey
# 166   the route the flame was to take
# 167   Western countries
# 168   the relay
# 169   the media
# 170   the torch relays
# 171   leader Kim Jong Il
# 172   initially
# 173   security concerns
# 174   torchbearers
# 175   Paris
# 176   Macau Fisherman's Wharf
# 177   Tibet
# 178   the city main 's stadium
# 179   Ho Chi Minh City
# 180   readers
# 181   clashes
# 182   Western media coverage
# 183   biased media coverage
# 184   April
# 185   gave a speech criticizing China 's relations with Sudan in Hong Kong
# 186   such a request
# 187   media distortion
# 188   the Olympic cause
# 189   May
# 190   the police
# 191   the protesters
# 192   the relay
# 193   bearers
# 194   the Malaysian capital
# 195   police chief Heather Fong
# 196   all times
# 197   the Chinese media
# 198   Wan Chai
# 199   the Chinese community
# 200   North Korea
# 201   I
# 202   the torch relay route
# 203   a large Chinese national flag
# 204   the ancient Olympic Games
# 205   the relay
# 206   the 1988 Summer Games
# 207   incidents
# 208   the torch relay route
# 209   the Olympic flag
# 210   the flame
# 211   Ho Chi Minh City
# 212   the torch relay was also canceled out of concern about disruptions caused by demonstrators protesting against China 's recent crackdown in Tibet canceled out of concern about disruptions caused by demonstrators protesting against China 's recent crackdown in Tibet
# 213   other pro-China groups
# 214   scheduled to be the starting point for the Olympic torch relay in Nagano
# 215   the torchbearers
# 216   Tibet
# 217   relations
# 218   May
# 219   embassy
# 220   protesters
# 221   the Olympic flame
# 222   officials allowed her to enter
# 223   China
# 224   six continents
# 225   Macau
# 226   on April 16
# 227   the torchbearers
# 228   April
# 229   its journey
# 230   cosmetic products
# 231   San Francisco
# 232   welcomed by Politburo Standing Committee member Zhou Yongkang and State Councilor Liu Yandong
# 233   rocks
# 234   success
# 235   70 runners
# 236   2 pm PDT from the stadium along Van Ness Avenue
# 237   reports
# 238   Western media coverage
# 239   making a point ''
# 240   April
# 241   all times
# 242   Paris
# 243   expression
# 244   more than the number of protesters
# 245   Green Party officials
# 246   its own face
# 247   the 1964 Tokyo edition
# 248   the route the flame was to take
# 249   its route
# 250   large numbers
# 251   the Olympic spirit
# 252   the Olympic cause
# 253   security concerns
# 254   the Chinese embassy
# 255   gave a speech criticizing China 's relations with Sudan in Hong Kong
# 256   Tibet
# 257   Chinese students
# 258   the torchbearers
# 259   the flame's five-continent journey
# 260   the site of a municipal building and now a parking lot
# 261   no objection
# 262   the Chinese over the weekend from April 12
# 263   democracy
# 264   Western media bias
# 265   bus
# 266   officials
# 267   protesters
# 268   China
# 269   the torch relay
# 270   the torch relay
# 271   the 1964 Tokyo edition
# 272   part
# 273   between 2,000 and 10,000 Chinese supporters
# 274   May
# 275   the closing ceremony
# 276   China's actions
# 277   China
# 278   now a parking lot
# 279   the police
# 280   Baichung Bhutia
# 281   China
# 282   Jinnah Stadium
# 283   propane
# 284   Carlos Espínola
# 285   propane
# 286   China
# 287   London
# 288   a large Chinese national flag
# 289   the media
# 290   Tibet
# 291   the Olympic flag
# 292   the Stade Charléty
# 293   her body and later began waving it began waving it
# 294   officials
# 295   the Olympic flag
# 296   the relay
# 297   an attempt by more than one demonstrator to extinguish the flame with water or fire extinguishers
# 298   banners
# 299   arrested
# 300   biased media coverage
# 301   embassy
# 302   the iconic Petronas Twin Towers
# 303   San Francisco
# 304   May
# 305   the torch relay
# 306   supposed to carry the torch around Islamabad Islamabad to security concerns regarding `` militant threats or anti-China protests ''
# 307   the torch relay
# 308   At least five people
# 309   May
# 310   rocks
# 311   his blog
# 312   recent events
# 313   May
# 314   the site
# 315   April
# 316   uniformed police officers
# 317   ended at O2 Arena in the eastern part of the city
# 318   the stadium
# 319   Tibet
# 320   the Olympic torch relay
# 321   an unannounced route
# 322   Macau
# 323   State Councilor Liu Yandong
# 324   China
# 325   the iconic Petronas Twin Towers
# 326   uniformed police officers
# 327   the relay route
# 328   March
# 329   China
# 330   Macau Fisherman's Wharf
# 331   Taksim Square
# 332   media coverage
# 333   the lake
# 334   Buenos Aires
# 335   Tibet
# 336   its own face
# 337   more than the number of protesters
# 338   the United States
# 339   their own "Human Rights Torch
# 340   all times
# 341   the Chinese government's crackdown
# 342   protests
# 343   Tibet
# 344   requested the torch route in San Francisco be shortened
# 345   Jinnah Stadium
# 346   August
# 347   the Chinese media
# 348   a Beijing citizen
# 349   to Asian Times
# 350   the curtailed 3 km route
# 351   propane
# 352   its own face
# 353   a sound
# 354   slower oscillation
# 355   C♯
# 356   frequency
# 357   the waveform
# 358   the number
# 359   frequency
# 360   higher frequencies
# 361   fundamental frequency
# 362   upper partials
# 363   the frequencies
# 364   the pitches
# 365   the basic prerequisite
# 366   higher frequencies
# 367   fundamental frequency
# 368   a pitch
# 369   any specific pitch
# 370   several permanent and travelling exhibitions
# 371   the River Itchen
# 372   apparent crime figures
# 373   ruins
# 374   local public transport
# 375   jobs
# 376   England
# 377   Carnival UK
# 378   boys’ and girls’ teams
# 379   elections
# 380   the Town
# 381   the 13th century
# 382   Southampton Central railway station
# 383   Woodmill Bridge
# 384   the UK
# 385   Southampton
# 386   the UK
# 387   those walls
# 388   other less formal areas
# 389   the United Kingdom
# 390   Swedish home products retailer IKEA
# 391   Bluestar
# 392   Southampton
# 393   Norris
# 394   public transport
# 395   merchant vessels
# 396   the UK
# 397   England
# 398   the web
# 399   a four-year term
# 400   96.1 °
# 401   the previous year
# 402   the WestQuay park
# 403   Friary House
# 404   industry
# 405   Park
# 406   very handsome width
# 407   those walls
# 408   the Premier League
# 409   the High Street
# 410   13 June
# 411   eight years
# 412   the stone age
# 413   plc
# 414   the University
# 415   the world
# 416   Hampshire
# 417   the only geothermal power station
# 418   fun fairs
# 419   1
# 420   then 30–34 years
# 421   The last remains
# 422   the WestQuay shopping centre
# 423   Southampton
# 424   Southampton Central railway station
# 425   the tide
# 426   the town
# 427   ruins
# 428   the previous year
# 429   13 June
# 430   the move
# 431   the tide
# 432   Southampton Choral Society
# 433   the UK
# 434   programme
# 435   Men's Fitness magazine
# 436   all 354 Local Authorities
# 437   the Hill Lane area
# 438   Redbridge
# 439   the city
# 440   city
# 441   England
# 442   the town
# 443   Cunard Line
# 444   estimates
# 445   Southampton
# 446   The city
# 447   13 June
# 448   the WestQuay park
# 449   the UK
# 450   Spencer
# 451   marinas
# 452   the town
# 453   October
# 454   recorded
# 455   the UK
# 456   the city's buildings
# 457   Swedish home products retailer IKEA
# 458   cruise operator Carnival UK
# 459   the City
# 460   the Empire
# 461   Southampton University
# 462   202 crimes
# 463   the city's buildings
# 464   the WestQuay park
# 465   very handsome width
# 466   the Southampton Harbour Board
# 467   Eastleigh
# 468   Men's Fitness magazine
# 469   a single day
# 470   the sea
# 471   Red Funnel
# 472   eight years
# 473   its inner-city industry
# 474   October
# 475   the first purpose-built artillery fortification
# 476   a whole
# 477   the South
# 478   many others
# 479   410
# 480   a student population
# 481   Men's Fitness magazine
# 482   the city's buildings
# 483   six gates
# 484   the city
# 485   its name
# 486   the Southampton Harbour Board
# 487   the Hampshire ceremonial county
# 488   Southampton Central railway station
# 489   west
# 490   girls
# 491   the 1980s Bargate centre
# 492   England
# 493   residents
# 494   September
# 495   Southampton
# 496   the city's buildings
# 497   Southampton's Ocean Village marina
# 498   Clausentum
# 499   Carnival UK
# 500   marinas
# 501   a new, eight storey purpose-built building
# 502   the last Ice Age
# 503   Park Wood Leisure
# 504   the end
# 505   the country
# 506   Southampton
# 507   Portsmouth
# 508   the site
# 509   a toll bridge
# 510   hundreds
# 511   a non-metropolitan district
# 512   constitution
# 513   industry
# 514   May
# 515   Hampshire
# 516   over 600 exhibitors
# 517   a student population
# 518   a £100m development
# 519   the UK
# 520   Southampton
# 521   Eastleigh
# 522   the WestQuay park
# 523   cruise operator Carnival UK
# 524   Southampton Central railway station
# 525   the UK
# 526   girls
# 527   programme
# 528   the WestQuay shopping centre
# 529   the 1992 Local Government Act
# 530   the streets
# 531   Central
# 532   Southampton Central
# 533   very handsome width
# 534   very handsome width
# 535   a non-metropolitan district
# 536   the English Channel
# 537   the country
# 538   the 1960s
# 539   area
# 540   Plymouth
# 541   more local conditions
# 542   its name
# 543   a large casino
# 544   Southampton
# 545   service
# 546   the move
# 547   the University
# 548   Itchen
# 549   all 354 Local Authorities
# 550   the two World Wars
# 551   South Western Railway Company
# 552   England
# 553   then 30–34 years
# 554   advanced
# 555   Southampton Central railway station
# 556   the University
# 557   the 13th century
# 558   girls
# 559   cent of the city 's populace was White—including one per cent White Irish—3.8 per cent were South Asian one per cent White Irish—3.8 per cent were South Asian cent of the city 's populace was White—including one per cent White Irish—3.8 per cent were South Asian cent of the city 's populace was White—including one per cent White Irish—3.8 per cent were South Asian cent of the city 's populace was White—including one per cent White Irish—3.8 per cent were South Asian
# 560   October
# 561   over 22,000 students
# 562   girls
# 563   Southampton
# 564   jobs
# 565   September
# 566   Casablanca
# 567   the WestQuay shopping centre
# 568   six gates
# 569   six gates
# 570   populous
# 571   Luftwaffe bombing raids
# 572   the site
# 573   the friars
# 574   Friary House
# 575   Southampton Choral Society
# 576   the sea
# 577   previously The Coast
# 578   local government
# 579   several permanent and travelling exhibitions
# 580   13 June
# 581   over 600 exhibitors
# 582   the stone age
# 583   the town
# 584   Significant employers
# 585   1
# 586   All Time Low
# 587   celebrations
# 588   the WestQuay shopping centre
# 589   Southampton
# 590   202 crimes
# 591   Richard Taunton Sixth Form College
# 592   the River Itchen
# 593   the Midlands
# 594   the Itchen
# 595   result
# 596   Trojans
# 597   Eastleigh
# 598   96.1 °
# 599   Portsmouth
# 600   a bath house
# 601   the Town
# 602   the city's population
# 603   the WestQuay shopping centre
# 604   202 crimes
# 605   Portsmouth
# 606   the next few decades
# 607   Carnival UK
# 608   its name
# 609   the 16 wards
# 610   the Bargate
# 611   industry
# 612   Southampton Choral Society
# 613   Southampton Central railway station
# 614   the United Kingdom's most populous metropolitan areas
# 615   its name
# 616   lies
# 617   north-west
# 618   Hampshire
# 619   the national rail system
# 620   severe financial difficulties
# 621   plc
# 622   a good example
# 623   marinas
# 624   Luftwaffe bombing raids
# 625   the town
# 626   cent
# 627   Southampton Town
# 628   Town Quay
# 629   land
# 630   a whole
# 631   the sea
# 632   Lymington
# 633   a blue plaque
# 634   a non-metropolitan district
# 635   Spencer
# 636   a marina
# 637   The Southampton Docks company
# 638   October
# 639   the previous year
# 640   the sea
# 641   Carnival UK
# 642   Köppen Cfb
# 643   the move
# 644   Southampton
# 645   the river
# 646   Swedish home products retailer IKEA
# 647   Southampton Choral Society
# 648   its name
# 649   the 16 wards
# 650   Southampton
# 651   the city's largest employers
# 652   Mixed Race
# 653   the town
# 654   the Premier League
# 655   the country
# 656   Richard Taunton Sixth Form College
# 657   Cardiff
# 658   the worst behaved secondary schools
# 659   Xelabus
# 660   the first dock
# 661   the northern side
# 662   plc
# 663   city
# 664   the urban area
# 665   a space
# 666   October
# 667   dance music
# 668
# 669   a toll bridge
# 670   cyclists
# 671   the UK
# 672   Southampton Central
# 673   Eastleigh
# 674   the City
# 675   the city centre
# 676   the River Itchen
# 677   estimates
# 678   13 June
# 679   a good example
# 680   Southampton Central railway station
# 681   a good quality beach
# 682   the world
# 683   eight years
# 684   the city's population
# 685   WestQuay
# 686   Friary House
# 687   the sea
# 688   Southampton
# 689   a population
# 690   Hampshire Constabulary
# 691   the City
# 692   Southampton Central
# 693   Southampton Central
# 694   the South East
# 695   severe financial difficulties
# 696   galleries
# 697   industrial area
# 698   modern Bitterne Manor
# 699   the town
# 700   St. Denys
# 701   Southampton
# 702   cruise operator Carnival UK
# 703   the city's buildings
# 704   the base for any cross-channel ferries
# 705   the River Itchen
# 706   dance music
# 707   the town
# 708   Southampton Town
# 709   England
# 710   the city's waterfront
# 711   the town
# 712   the friars
# 713   Ronald Koeman
# 714   Southampton Central
# 715   an ethnic group
# 716   this reference point
# 717   association
# 718   Jews
# 719   local Christian rulers
# 720   Ashkenazi maternal lineages
# 721   the Caucasus region
# 722   3 million DNA letters
# 723   the general European population
# 724   outnumbered Ashkenazim three to two ''
# 725   the pre-2006 origin hypothesis
# 726   the Bray et al
# 727   the second half
# 728   recent times
# 729   subgroup
# 730   their fellow non-Jewish countrymen
# 731   Israelis
# 732   other parts
# 733   the Bray et al
# 734   together
# 735   differing rates
# 736   the Roman empire
# 737   the practice
# 738   a nun נ
# 739   refers to the nusach Ashkenaz
# 740   the Khazar hypothesis
# 741   Orthodox Judaism
# 742   faiths
# 743   the lands of tribes neighboring the Slavs
# 744   Ashkenazi communities
# 745   Jews
# 746   religious Ashkenazi Jews
# 747   the Holocaust
# 748   the Middle East
# 749   various local occupations
# 750   Nebel et al
# 751   Sephardic
# 752   the general European population
# 753   other nations
# 754   the Ottoman Muslim world
# 755   other Jews
# 756   world Jewry
# 757   a deep European ancestry
# 758   the "southern" group
# 759   refers
# 760   central Europe
# 761   Ashkenazi Jews
# 762   postulate that these results reflect not the population antiquity but a history of mixing between genetically distinct populations in Europe
# 763   other nations
# 764   money lending
# 765   descent (IBD) analysis
# 766   their ultimate provenance
# 767   Ashkenazi Jews
# 768   originally Jewish languages
# 769   recent times
# 770   a vibrant Yiddish culture
# 771   their Siddur (prayer book
# 772   Judaism
# 773   Ashkenazic
# 774   harsher anti-Jewish Church rulings
# 775   Pannonia
# 776   other Jews
# 777   a German-speaking Palestinian Jew
# 778   mutations
# 779   the 1st and 2nd centuries CE
# 780   Khazaria
# 781   mitotypes
# 782   faiths
# 783   its own genetic pattern
# 784   religious Ashkenazi Jews
# 785   Richards
# 786   Hammer et al
# 787   non-Jewish ethnic populations
# 788   diverse political movements
# 789   a deep European ancestry
# 790   the Syrian Jewish community
# 791   have extremely large families large families
# 792   the Dreyfus affair
# 793   relocated
# 794   a nun נ
# 795   Nations
# 796   the Middle East
# 797   formerly German Alsace
# 798   Germany
# 799   about 75%
# 800   Atzmon-Ostrer et al
# 801   Khazaria
# 802   Y-DNA
# 803   European populations
# 804   Ashkenazim
# 805   no further intermarriage
# 806   their halakhic learning
# 807   Ashkenazic
# 808   Ashkenazi Jews
# 809   originally Jewish languages
# 810   faiths
# 811   Central Europe
# 812   a consistent and reproducible distinction
# 813   that ancestry
# 814   Central Europe
# 815   Richards
# 816   this term
# 817   212 CE
# 818   the "southern" group
# 819   Eastern Europe
# 820   these ethnic groups
# 821   Speyer
# 822   world Jewry
# 823   the Ottoman Muslim world
# 824   religious persecution
# 825   Neptune's vivid azure
# 826   the Solar System
# 827   an unknown planet
# 828   the structure
# 829   supersonic flow
# 830   −200
# 831   57,000 km
# 832   14 known moons
# 833   Urbain Le Verrier
# 834   the radius
# 835   François Arago
# 836   Voyager
# 837   storm
# 838   a 1:1 resonance
# 839   the only spacecraft
# 840   radius
# 841   Earth-based telescopes
# 842   the structure
# 843   Neptune,[e
# 844   the only spacecraft
# 845   detected during the 1960s and confirmed by Voyager 2
# 846   its own gravity
# 847   Neptune's trident
# 848   this distinction
# 849   Neptune's gravity
# 850   42,000 km
# 851   roughly 40 Earth years
# 852   the 1989 encounter
# 853   lesser sea gods
# 854   the Neptunian system
# 855   ammonia
# 856   Neptune's rings
# 857   the radius
# 858   C
# 859   1° of where Le Verrier had predicted it to be
# 860   the Solar System
# 861   active and visible weather patterns
# 862   rivalry
# 863   its moon Titan
# 864   comet observations
# 865   has a temporary quasi-satellite
# 866   a fixed star
# 867   57,000 km
# 868   the Solar System
# 869   S/2004 N
# 870   the Kuiper belt
# 871   the planet's blue appearance
# 872   Jupiter
# 873   the Solar System
# 874   the equator to 250 m/s at the poles
# 875   the only spacecraft
# 876   four
# 877   deserved credit
# 878   the structure
# 879   25 August
# 880   their formation
# 881   their orbits
# 882   all other large planetary moons in the Solar System
# 883   the radius
# 884   Adams' prediction
# 885   a 1:1 resonance
# 886   lesser sea gods
# 887   the planets' interiors
# 888   Greenwich
# 889   ammonia
# 890   a 1:1 resonance
# 891   planet
# 892   the polar axis
# 893   Neptune
# 894   detected during the 1960s and confirmed by Voyager 2
# 895   its own gravity
# 896   the Sun
# 897   C
# 898   mass
# 899   a 1:1 resonance
# 900   its 365.26-day orbit
# 901   the observatory's refractor
# 902   known planet in the Solar System
# 903   a dark feature
# 904   several different estimates
# 905   that of Uranus
# 906   planet
# 907   5,100 °C
# 908   Earth-based telescopes
# 909   lesser sea gods
# 910   gravitational interaction
# 911   lesser sea gods
# 912   300 m
# 913   lesser sea gods
# 914   its orbit
# 915   Neptune's colour
# 916   shaped Proteus is notable for being as large as a body of its density can be without being pulled into a spherical shape by its own gravity
# 917   Earth
# 918   cultural studies
# 919   the late 1970s
# 920   Kultursoziologie (cultural sociology
# 921   jewelry
# 922   Paul du Gay et al
# 923   cultural change
# 924   products
# 925   generative action
# 926   Cultural studies
# 927   mass culture
# 928   jewelry
# 929   acculturation
# 930   also
# 931   mass culture
# 932   low culture
# 933   (Weltanschauung
# 934   everyday life
# 935   fandom
# 936   any cultural product
# 937   symbolically encoded experiences
# 938   concerned itself more with understanding the subjective and appropriative side of audience reactions to
# 939   this practice
# 940   products
# 941   the state level
# 942   church and state" doctrine
# 943   as the federal legislature
# 944   England
# 945   the phrase
# 946   the constitutional establishment clause jurisprudence
# 947   public funds
# 948   Newdow
# 949   the Constitution
# 950   U.S.
# 951   America
# 952   God
# 953   public schools
# 954   when students were not compelled to recite it
# 955   a national religion
# 956   proof
# 957   state
# 958   God
# 959   strict separation
# 960   guarded as is the separation between Religion
# 961   strict separation
# 962   America
# 963   a particular religion
# 964   strict separation
# 965   the original constitutional intent
# 966   by the U.S. Supreme Court
# 967   the word religion
# 968   Board of Education
# 969   the original constitutional intent
# 970   point
# 971   the U.S. Supreme Court
# 972   views
# 973   the state governments
# 974   the Dutch Republic
# 975   the eighteenth century
# 976   in the constitution of the United States
# 977   The word 'religion
# 978   the state governments
# 979   rewards
# 980   Board of Education has impacted the subsequent interpretation of the separation of church and state in regard to the state governments
# 981   separationist opinion
# 982   the time
# 983   the Capitol
# 984   the prayers
# 985   the debate
# 986   the substantive constitutional issue
# 987   the United States
# 988   the Anti-Federalists
# 989   the amendment
# 990   the Dutch Republic
# 991   religious establishment
# 992   the constitutional framers
# 993   public schools
# 994   his own Master
# 995   First and Fourteenth Amendment protections
# 996   Anglican
# 997   used by Thomas Jefferson as a description of the First Amendment and its restriction on the legislative branch of the federal government
# 998   the debate
# 999   Board of Education
# 1000   appear in the Constitution nor do they mention any particular religious view of a `` Creator '' or `` Nature 's God
# 1001   the word religion
# 1002   the Establishment Clause
# 1003   the 14th amendment
# 1004   U.S.
# 1005   political appointees
# 1006   favoritism
# 1007   by the U.S. Supreme Court
# 1008   this
# 1009   attended
# 1010   the U.S. Supreme Court
# 1011   First and Fourteenth Amendment protections
# 1012   guarded as is the separation between Religion
# 1013   state
# 1014   Persecution
# 1015   public office
# 1016   Blaine Amendments
# 1017   later date
# 1018   medieval cathedrals
# 1019   the Theotokos
# 1020   Constantinople
# 1021   Georgia
# 1022   Roman prototypes
# 1023   strong Italianate influence
# 1024   the Theotokos
# 1025   The mosaics
# 1026   a beautiful mosaic pavement
# 1027   three medallions
# 1028   a Samaritan synagogue
# 1029   initiated in these arts '' – says the chronicler about the role of the Greeks in the revival of mosaic art in medieval Italy
# 1030   Kiev
# 1031   The most superb example
# 1032   fully coloured work
# 1033   slaves
# 1034   the Lusosphere
# 1035   the city
# 1036   Hungary
# 1037   a robot
# 1038   Empress Zoe
# 1039   the 8th century
# 1040   grains
# 1041   Cipriana
# 1042   bland mosaics
# 1043   figures
# 1044   the Dome
# 1045   the Deacon
# 1046
# 1047   , lesser known sites
# 1048   Georgia
# 1049   initiated in these arts '' – says the chronicler about the role of the Greeks in the revival of mosaic art in medieval Italy
# 1050   the 16th century
# 1051   Thessaloniki
# 1052   the church
# 1053   Bethlehem
# 1054   the 8th century
# 1055   only the floor panels
# 1056   mosaics
# 1057   late Roman mosaic art
# 1058   other high-ranking officials
# 1059   the 12th Century
# 1060   Lebanon
# 1061   more prestigious artform
# 1062   art
# 1063   Santa Maria Maggiore
# 1064   Sant'Apollinare Nuovo
# 1065   Christ
# 1066   The low spandrels
# 1067   a golden background
# 1068   now Sicis The Art Mosaic Factory Srl
# 1069   truly classical Byzantine artworks
# 1070   now Umm ar-Rasas
# 1071   all were destroyed in 1747
# 1072   had the highest concentration of mosaic-covered churches but very few of them survived the subsequent waves of destructions
# 1073   it seems that it was not until the Christian era that figural wall mosaics became a major form of artistic expression
# 1074   the 6th or 9th century
# 1075   suppliants
# 1076   Hungary
# 1077   Arta
# 1078   the 10th and 11th century
# 1079   Peter Chrysologus
# 1080   now Sicis The Art Mosaic Factory Srl
# 1081   the portal
# 1082   this mosaic form
# 1083   now Umm ar-Rasas
# 1084   animals
# 1085   wall mosaics have not survived in the region because of the destruction of buildings but the St. Catherine 's Monastery is exceptional
# 1086   The Crusaders
# 1087   the 9th century
# 1088   decorated their monasteries with mosaic floors
# 1089   follow the classical tradition in that they represent the feast of Bacchus
# 1090   a Roman villa
# 1091   Constantine Monomachos
# 1092   Constantinople
# 1093   the zodiac wheel
# 1094   Pompeii
# 1095   a beautiful mosaic pavement
# 1096   wall mosaics have not survived in the region because of the destruction of buildings but the St. Catherine 's Monastery is exceptional
# 1097   the same town
# 1098   at least 100 million glass and stone tesserae
# 1099   many mosaics
# 1100   a local governor
# 1101   the portal
# 1102   Ravenna section
# 1103   The mosaic covered church
# 1104   proportion
# 1105   the 16th century
# 1106   one
# 1107   the 16th century
# 1108   wall decoration
# 1109   pagans
# 1110   decorated with great mosaics but these were later destroyed
# 1111   the 16th century
# 1112   the 1st or 2nd century AD
# 1113   street art
# 1114   SS
# 1115   only floral and geometric patterns
# 1116   Abdela
# 1117   used as decoration on medieval cathedrals
# 1118   the 13th century
# 1119   Nicaea
# 1120   the 12th–13th centuries
# 1121   the site
# 1122   executed by Cavallini in 1290
# 1123   Georgia
# 1124   were decorated with wall and ceiling mosaics
# 1125   this period
# 1126
# 1127   the 16th century
# 1128   Tunisia
# 1129   , lesser known sites
# 1130   God’s creation
# 1131   Amalfi's Norman Cathedral
# 1132   God’s creation
# 1133   high artistic quality
# 1134   the St. Catherine's Monastery
# 1135   the waters
# 1136   the Beit Alfa synagogue
# 1137   braided hair and rosy cheeks is especially capturing capturing
# 1138   Justinian's reign
# 1139   the Latin Church
# 1140   wall and ceiling mosaics
# 1141   floor mosaics
# 1142   the design software
# 1143   Georgia
# 1144   this period
# 1145   found at Pompeii and neighbouring sites
# 1146   Raphael
# 1147   Nicaea
# 1148   the Latin Church
# 1149   blue background
# 1150   destroyed in 1922
# 1151   the 11th century
# 1152   putty
# 1153   the rebuilt abbey church
# 1154   the 13th century
# 1155   the 17th century
# 1156   present-day Romania
# 1157   Justinian's reign
# 1158   differing thicknesses
# 1159   Venice
# 1160   grains
# 1161   the same town
# 1162   the rebuilt abbey church
# 1163   antique pavements
# 1164   found at Pompeii and neighbouring sites
# 1165   the 6th century
# 1166   the 6th century
# 1167   Empress Zoe
# 1168   Christ
# 1169   the Justinianian age
# 1170   wall mosaics have not survived in the region because of the destruction of buildings but the St. Catherine 's Monastery is exceptional
# 1171   a Roman villa
# 1172   differing thicknesses
# 1173   his Buddhist robes
# 1174   this period
# 1175   Myanmar
# 1176   Many religions
# 1177   the world
# 1178   ASEAN
# 1179   19 million tons
# 1180   some 150,000 men
# 1181   national development
# 1182   these figures
# 1183   37 nats
# 1184   military spending
# 1185   the United Kingdom
# 1186   Shan chiefs
# 1187   both names
# 1188   the 11th century
# 1189   US support
# 1190   many years
# 1191   a highly literate population
# 1192   Yangon (Rangoon
# 1193   other economic sanctions
# 1194   a transitional government
# 1195   South-East Asia
# 1196   Myanmar
# 1197   this area
# 1198   southern Arakan
# 1199   impunity
# 1200   "Myanmar
# 1201   monks
# 1202   the 8888 Uprising
# 1203   the year
# 1204   the country
# 1205   "Myanmar
# 1206   country in South-East Asia
# 1207   Islamophobic persecution
# 1208   Lower Burma
# 1209   time
# 1210   paddybirds
# 1211   the United Kingdom
# 1212   the 18th century
# 1213   several decades
# 1214   Islamophobic persecution
# 1215   more than 80 years
# 1216   the copy
# 1217   adopted the term intellectual property in their new combined title
# 1218   member states
# 1219   copyrighted works
# 1220   member states
# 1221   these monopolies
# 1222   criminal law
# 1223   ideas
# 1224   enforcement
# 1225   digital rights management systems
# 1226   a life-saving drug
# 1227   property rights
# 1228   an estimated 18 million American people
# 1229   ideas
# 1230   knowledge
# 1231   trademarks
# 1232   these lines claim that unlike the situation with tangible property the situation with tangible property
# 1233   trademarks
# 1234   trademarks
# 1235   business method patents
# 1236   the other party
# 1237   the wheat
# 1238   incarceration and fines
# 1239   property rights
# 1240   ideas
# 1241   the copyright holder can only get money damages if the owner registers the copyright
# 1242   an end
# 1243   the invention
# 1244   business method patents
# 1245   copyright
# 1246   member states
# 1247   inventors
# 1248   a life-saving drug
# 1249   adopted the term intellectual property in their new combined title
# 1250   this possibility
# 1251   average readers
# 1252   criminal law
# 1253   human rights laws
# 1254   critics
# 1255   rhetoric
# 1256   America
# 1257   time
# 1258   time
# 1259   a life-saving drug
# 1260   activity
# 1261   digital rights management systems
# 1262   referring to copyright
# 1263   incarceration and fines
# 1264   trademarks
# 1265   property rights
# 1266   a highly publicized case against the file-sharing company Napster publicized case against the file-sharing company Napster
# 1267   copyrighted works
# 1268   adopted the term intellectual property in their new combined title
# 1269   nanotechnology
# 1270   trademarks
# 1271   member states
# 1272   authority
# 1273   than the marginal cost of production in order to recoup the costs of research and development
# 1274   infringement
# 1275   trademarks
# 1276   member states
# 1277   business method patents
# 1278   nanotechnology
# 1279   authorship
# 1280   property rights
# 1281   ideas
# 1282   the 16th century
# 1283   member states
# 1284   example
# 1285   the copyright holder
# 1286   Lebanon
# 1287   the artillery
# 1288   Wallachia
# 1289   disease
# 1290   all the Ottoman naval forces during the Battle of Navarino
# 1291   Russia
# 1292   Sevastopol
# 1293   independence war
# 1294   artillery
# 1295   the Ottomans
# 1296   orders
# 1297   a fleet
# 1298   three months
# 1299   400 Russians
# 1300   orders
# 1301   the artillery
# 1302   the Turks 1500 (29 September
# 1303   Chios massacre
# 1304   the participants at the peace conference at the end of the war
# 1305   western Europe
# 1306   the south coast
# 1307   the Black Sea
# 1308   Malakoff hill
# 1309   its military weakness
# 1310   the Ottoman Empire
# 1311   Eastern Orthodoxy
# 1312   batteries
# 1313   the Crimean peninsula
# 1314   disaster
# 1315   a Franco-British naval force
# 1316   one American officer
# 1317   orders
# 1318   equipment
# 1319   30 March
# 1320   the Greek army
# 1321   part
# 1322   the more sweeping demands
# 1323   Sinop
# 1324   the nearest future
# 1325   his protection
# 1326   equipment
# 1327   the Crimean Peninsula
# 1328   the Crimean peninsula
# 1329   Charlemagne
# 1330   the previous war
# 1331   Alger
# 1332   Alfred Nobel
# 1333   ordered
# 1334   a German satellite
# 1335   Rear Admiral Yevfimy Putyatin
# 1336   problems to the south and the heavy artillery was brought ashore with batteries and connecting trenches built so that by 10 October some batteries were ready and by 17 October—when the bombardment commenced—126 guns were firing
# 1337   the day
# 1338   direct conflict
# 1339   Oltenița
# 1340   Italy
# 1341   the attack
# 1342   27/28 October
# 1343   Gallipoli
# 1344   Russia
# 1345   the Russians
# 1346   the French Emperor
# 1347   William Howard Russell
# 1348   the Kars road
# 1349   the Allies
# 1350   large Greek Christian majorities
# 1351   the Austrian Foreign Minister Count Karl von Buol
# 1352   Åland Islands
# 1353   400 Russians
# 1354   400 Russians
# 1355   a German satellite
# 1356   the British Army forces
# 1357   part
# 1358   Russia
# 1359   the harbor
# 1360   the war
# 1361   late autumn
# 1362   it was March before it was sufficiently advanced to be of any appreciable value advanced to be of any appreciable value
# 1363   the north
# 1364   this time
# 1365   two days
# 1366   such rapid communications
# 1367   the Franco-Prussian War
# 1368   a single line
# 1369   the Russian fleet
# 1370   Russia
# 1371   this point
# 1372   the south
# 1373   Oltenița
# 1374   one American officer
# 1375   World War I.
# 1376   the Danube
# 1377   6 January
# 1378   the Åland war
# 1379   the Åland war
# 1380   the artillery
# 1381   the Black Sea coast
# 1382   after he learned of the failure of Menshikov 's diplomacy toward the end of June 1853
# 1383   heavy casualties
# 1384   Crimea
# 1385   the Black Sea
# 1386   the Mediterranean Sea
# 1387   two days
# 1388   the Åland war
# 1389   Russia
# 1390   the Russians
# 1391   three months
# 1392   its churches
# 1393   a republic
# 1394   their artillery units
# 1395   smaller caliber guns
# 1396   many different interpretations
# 1397   the treaty
# 1398   the Danube
# 1399   the Ottomans
# 1400   the western powers
# 1401   280,000 men
# 1402   Oltenița
# 1403   Caracal
# 1404   the Crimea
# 1405   the whole Russian army
# 1406   smaller caliber guns
# 1407   corvettes
# 1408   a 337-day-long siege
# 1409   a failure
# 1410   batteries
# 1411   posed a naval threat to the Ottomans
# 1412   Bulgaria
# 1413   smaller caliber guns
# 1414   World War I.
# 1415   Bulgaria
# 1416   by disease
# 1417   the siege
# 1418   truncheons
# 1419   this time
# 1420   Crimea
# 1421   the previous war
# 1422   the advance
# 1423   France
# 1424   1,500 people
# 1425
# 1426   a direct attack
# 1427   the Greek Orthodox Church
# 1428   orders
# 1429   one American officer
# 1430   the town
# 1431   a few hours
# 1432   the war
# 1433   400 Russians
# 1434   the Malakoff
# 1435   the Turks
# 1436   the Austrian Foreign Minister Count Karl von Buol
# 1437   3,300 Allied losses
# 1438   the Ottoman Empire
# 1439   authority
# 1440   all their supply train
# 1441   a few hours
# 1442   Orthodox Christians
# 1443   30 January
# 1444   sent
# 1445   by disease
# 1446   the 700-man unit
# 1447   the Crimean peninsula
# 1448   the original battle plan
# 1449   equipment
# 1450   disease
# 1451   the war
# 1452   the Malakoff
# 1453   mismanagement
# 1454   the attack
# 1455   Batum
# 1456   the Kars road
# 1457   the Light Brigade
# 1458   September
# 1459   Sinope
# 1460   its churches
# 1461   one American officer
# 1462   the Russian fleet
# 1463   the village
# 1464   the Russian batteries
# 1465   Thessaly
# 1466   Turks
# 1467   the Ottoman Empire
# 1468   the Russian fleet
# 1469   6000 men
# 1470   Roger Fenton
# 1471   the Turks
# 1472   311 The Crimean campaign
# 1473   the following year
# 1474   the Russo-Turkish War
# 1475   the UK
# 1476   this point
# 1477   Russia
# 1478   the Åland war
# 1479   ground operations
# 1480   stone
# 1481   disease
# 1482   its churches
# 1483   northern Anatolia
# 1484   the Ottoman army
# 1485   orders
# 1486   The Russians
# 1487   the previous war
# 1488   the issue
# 1489   the Crimean peninsula
# 1490   Moldavia
# 1491   Europe
# 1492   William Howard Russell
# 1493   Alexandropol (November
# 1494   duplicitous French and Ottoman diplomacy
# 1495   the Ottoman Empire
# 1496   the Kars road
# 1497   size
# 1498   part
# 1499   Qianlong's purge
# 1500   the Forbidden City
# 1501   his young son
# 1502   Qing rule
# 1503   competitive and stable markets
# 1504   the first order
# 1505   its social, economic and military power
# 1506   his corpse
# 1507   Beijing
# 1508   a watershed
# 1509   the modern Chinese state
# 1510   Kexi
# 1511   their numbers
# 1512   Manchu only lands along the Sungari to Han Chinese at the beginning of the Daoguang Emperor 's reign
# 1513   earlier dynasties
# 1514   of Bannermen
# 1515   an authoritative reference
# 1516   the crown
# 1517   a square emblem
# 1518   the Qing
# 1519   (Brave Camp
# 1520   Britain
# 1521   the later Chinese Rites controversy
# 1522   Qianlong's purge
# 1523   the already hugely unpopular regime
# 1524   Wu
# 1525   the Manchu nation
# 1526   Heilongjiang
# 1527   defected Ming soldiers
# 1528   Beijing
# 1529   200,000 Bannermen
# 1530   the Zongli Yamen
# 1531   Rehe
# 1532   Japan
# 1533   these officials
# 1534   their extensive territories
# 1535   the Qing
# 1536   a nomadic people
# 1537   all Eight Han Banners
# 1538   the Dzungar–Qing War
# 1539   the Zongli Yamen
# 1540   the throne
# 1541   two vice-premiers
# 1542   the Manchus
# 1543   a short-lived Shun dynasty
# 1544   Fujian
# 1545   the rattan shield troops were also inducted into the Eight Banners and used by the Qing against Russian Cossacks at Albazin inducted into the Eight Banners and used by the Qing against Russian Cossacks at Albazin
# 1546   smallpox
# 1547   some 20 million people
# 1548   the already hugely unpopular regime
# 1549   the Qing
# 1550   Indonesia
# 1551   two vice-premiers
# 1552   life
# 1553   Han areas
# 1554   the "Lower Five Banners
# 1555   their numbers
# 1556   the army
# 1557   Beijing
# 1558   welcomed to his court Jesuit missionaries
# 1559   rebels
# 1560   killed in the Dzungar–Qing War
# 1561   Yunnan province
# 1562   all Eight Han Banners
# 1563   size
# 1564   the Qing imperial army
# 1565   China
# 1566   Manchuria
# 1567   100 million to 300 million people
# 1568   the Qing imperial army
# 1569   the Three Feudatories
# 1570   Qing rule
# 1571   Mongols
# 1572   local elites
# 1573   the Summer Palace
# 1574   this city
# 1575   welcomed to his court Jesuit missionaries
# 1576   the Taiping rebels
# 1577   the empire
# 1578   Beijing
# 1579   a treaty
# 1580   200,000 Bannermen
# 1581   the Zongli Yamen
# 1582   Nanjing
# 1583   the throne
# 1584   called the `` Yong Ying ''
# 1585   their own legitimacy
# 1586   a military humiliation
# 1587   all time
# 1588   the arts
# 1589
# 1590   China 's first unified ministry of foreign affairs
# 1591   the Ming
# 1592   83 days
# 1593   its provisional head
# 1594   Chinese culture
# 1595   the Eight Banners
# 1596   Tongzhi
# 1597   each other's influences
# 1598   given to Mongols
# 1599   some 20 million people
# 1600   Manchu culture
# 1601   to a revolt by Han in Liaodong in 1623
# 1602   the previous Jurchen dynasty
# 1603   the ground
# 1604   two or three provinces
# 1605   his corpse
# 1606   he could allow Yuan to step into the position of President of the Republic of China
# 1607   Tibet
# 1608   seaban
# 1609   Fujian
# 1610   troops
# 1611   Mongols
# 1612   the army
# 1613   the empire
# 1614   Bengal
# 1615   petty clan affiliations
# 1616   Beijing
# 1617   local elites
# 1618   greater than he had thought
# 1619   Han Chinese
# 1620   his Han Chinese subjects
# 1621   part
# 1622   the imperial examinations
# 1623   the West
# 1624   Wu Sangui's appeal
# 1625   100 million to 300 million people
# 1626   Wu's concubine Chen Yuanyuan
# 1627   two or three provinces
# 1628   of wooden sailing junks
# 1629   their own legitimacy
# 1630   an authoritative reference
# 1631   the imperial examination
# 1632   the Kangxi Emperor
# 1633   equal rank
# 1634   a brief, abortive restoration
# 1635   the Gapsin Coup
# 1636   his father
# 1637   the capital
# 1638   "China
# 1639   Beijing
# 1640   as viceroys for the Qing after their conquests
# 1641   this period
# 1642   this city
# 1643   all Eight Han Banners
# 1644   foreign control
# 1645   local elites
# 1646   the Chongzhen Emperor
# 1647   Qing Dynasty
# 1648   incorporated them into the Jurchen `` nation '' as full
# 1649   the provinces
# 1650   the 20th century
# 1651   their names
# 1652   the war
# 1653   local elites
# 1654   China
# 1655   the war
# 1656   the early 19th century
# 1657   the Qing
# 1658   Wu Sangui's appeal
# 1659   Vietnam
# 1660   simultaneously
# 1661   Han Chinese civilians
# 1662   Beijing
# 1663   the Eight Banners
# 1664   Liaodong
# 1665   the Foreign Legation Quarter
# 1666   the already hugely unpopular regime
# 1667   inferior status
# 1668   a short, but hard-fought campaign
# 1669   instruction
# 1670   the imperial examination
# 1671   an emergency army
# 1672   these military reforms enabled Hong Taiji to resoundingly defeat Ming forces in a series of battles from 1640 to 1642 for the territories of Songshan and Jinzhou defeat Ming forces in a series of battles from 1640 to 1642 for the territories of Songshan and Jinzhou
# 1673   local-origin-based merchant groups
# 1674   Fujian
# 1675   the Hunan region
# 1676   the mid-16th century
# 1677   the possession
# 1678   small Anglo-French coalition force numbering 25,000
# 1679   Bannermen
# 1680   size
# 1681   another government institution called Imperial Household Department which was unique to the Qing dynasty
# 1682   Qing Dynasty
# 1683   the Manchus
# 1684   the compilation of the Siku Quanshu
# 1685   numerically dominated the Banners up until the mid 18th century dominated the Banners up until the mid 18th century
# 1686   the Qing court
# 1687   warrior
# 1688   bureaucratic government
# 1689   navy
# 1690   a military humiliation
# 1691   Fuzhou
# 1692   a treaty
# 1693   the "Lower Five Banners
# 1694   his corpse
# 1695   the rebels
# 1696   local French diplomats
# 1697   a central government institution
# 1698   the military
# 1699   the Xinhai Revolution
# 1700   the boy emperor
# 1701   breached on 9 October 1645
# 1702   the Three Feudatories
# 1703   smallpox
# 1704   the Bodhisattva Manjusri
# 1705   China
# 1706   autonomous
# 1707   Yangxia
# 1708   resulted
# 1709   Shanhai Pass
# 1710   officially prohibiting Han Chinese settlement on the Manchu and Mongol lands prohibiting Han Chinese settlement on the Manchu and Mongol lands
# 1711   the emperor
# 1712   order
# 1713   the Kangxi Emperor
# 1714   the Qing rulers
# 1715   provinces
# 1716   the Taiping and Nian Rebellions
# 1717   the beleaguered central government
# 1718   power
# 1719   furs
# 1720   life
# 1721   Vietnam
# 1722   May
# 1723   Mongols
# 1724   their numbers
# 1725   any Chinese emperor
# 1726   the early 19th century
# 1727   work
# 1728   DST
# 1729   The first two words
# 1730   the National Bank
# 1731   the dark
# 1732   time zone boundaries need to keep track of multiple DST rules
# 1733   the UK
# 1734   northern regions
# 1735   the spring
# 1736   use
# 1737   New York
# 1738   Many countries
# 1739   Wilson's successor
# 1740   the past
# 1741   12 February
# 1742   Belarus
# 1743   time zone setting
# 1744   clocks
# 1745   October
# 1746   makes
# 1747   15 June
# 1748   saving
# 1749   time
# 1750   suggested
# 1751   this reason
# 1752   some older time stamps
# 1753   normal sunrise times
# 1754   complicate
# 1755   skin cancer
# 1756   Russia
# 1757   contradictory results
# 1758   northern regions
# 1759   summer time
# 1760   Australia's Lord Howe Island
# 1761   a greater increase
# 1762   normal sunrise times
# 1763   country
# 1764   repeals
# 1765   affected by geography
# 1766   Western France
# 1767   some older time stamps
# 1768   ordinary system maintenance
# 1769   use
# 1770   advocated
# 1771   example
# 1772   equatorial Brazil
# 1773   country
# 1774   local time
# 1775   energy use
# 1776   morning sunlight
# 1777   Finland
# 1778   normal sunrise times
# 1779   summer
# 1780   electricity
# 1781   country
# 1782   local time
# 1783   clocks
# 1784   DST
# 1785   the Gregorian calendar
# 1786   Some areas
# 1787   precise schedules
# 1788   summer
# 1789   weekday schedules
# 1790   time zones
# 1791   21 May
# 1792   precise schedules
# 1793   ordinary system maintenance
# 1794   outdoor afternoon sports
# 1795   existing computer installations
# 1796   use
# 1797   normal sunrise times
# 1798   Africa
# 1799   health
# 1800   12 February
# 1801   Arizona
# 1802   reminders
# 1803   confusion
# 1804   summer
# 1805   Central European Time
# 1806   controversy
# 1807   kept
# 1808   daylight saving time year-round
# 1809   DST
# 1810   no standardization
# 1811   some older time stamps
# 1812   peacetime
# 1813   Willett's 1907 proposal
# 1814   differ
# 1815   local time
# 1816   country
# 1817   all locations
# 1818   summer
# 1819   clocks
# 1820   displays
# 1821   reminders
# 1822   morning sunlight
# 1823   the year
# 1824   timings
# 1825   the typical "nine-to-five" workday
# 1826   mechanical clocks
# 1827   DST
# 1828   DST rules
# 1829   weekday schedules
# 1830   the 2007 United States extension
# 1831   Ramadan
# 1832   year
# 1833   DST
# 1834   summer
# 1835   contradictory results
# 1836   no avail
# 1837   daylight hours
# 1838   DST
# 1839   changing dates
# 1840   25 hours
# 1841   ordinary DST
# 1842   the typical "nine-to-five" workday
# 1843   time zone setting
# 1844   Western France
# 1845   sunrise times
# 1846   controversy
# 1847   changes
# 1848   use
# 1849   26 October
# 1850   the Second World War
# 1851   peacetime
# 1852   computer applications
# 1853   care
# 1854   the United States
# 1855   DST
# 1856   effect
# 1857   normal sunrise times
# 1858   the Earth's axial tilt
# 1859   the change
# 1860   display
# 1861   but over the years adjusted transition dates for several reasons
# 1862   their clocks
# 1863   used
# 1864   hours
# 1865   later years
# 1866   the summer months
# 1867   their workday activities
# 1868   home fires
# 1869   the year
# 1870   daylight saving time year-round
# 1871   the Earth's axial tilt
# 1872   Time
# 1873   Double Summer Time
# 1874   a checksum
# 1875   Microsoft Windows
# 1876   Canada
# 1877   12 February
# 1878   argued
# 1879   Hawaii
# 1880   time zone setting
# 1881   Willett
# 1882   Quadrophenia
# 1883   a hard rock act
# 1884   Iron Maiden
# 1885   Van Halen
# 1886   popularity
# 1887   Rock
# 1888   number
# 1889   the mid-1990s
# 1890   a hard rock act
# 1891   music
# 1892   vocals
# 1893   their first number one hit
# 1894   The Spaghetti Incident
# 1895   Double Live Gonzo
# 1896   the world
# 1897   Led Zeppelin
# 1898   vocalist David Coverdale
# 1899   Blue
# 1900   stadium rock
# 1901   the US
# 1902   OU812
# 1903   several other countries
# 1904   the emerging Californian glam metal scene
# 1905   number
# 1906   lead guitars
# 1907   Hard rock
# 1908   several other countries
# 1909   their number one multi-platinum albums
# 1910   previous eras
# 1911   over fifteen years
# 1912   five weeks
# 1913   Van Halen
# 1914   roll
# 1915   highly successful recording careers
# 1916   Eric Clapton
# 1917   number
# 1918   five decades
# 1919   electric guitar
# 1920   The Jeff Beck Group
# 1921   the mid-1980s
# 1922   previous eras
# 1923   the decade
# 1924   punk-influenced music
# 1925   Led Zeppelin
# 1926   traditional hard rock
# 1927   Crashdïet
# 1928   The Spaghetti Incident
# 1929   OU812
# 1930   the decade
# 1931   FireHouse
# 1932   the early 90s with Red Velvet Car in 2010
# ...
# 2967   other personal computers
# 2968   keyboard
# 2969   Claris Impact
# 2970   potential buyers
# 2971   second
# 2972   the iMac G4
# 2973   the problem
# 2974   larger monitors
# 2975   the average consumer
# 2976   a whole
# 2977   security updates
# 2978   from its fast 40 MHz 68030 processor
# 2979   hard drives
# 2980   later appeals
# 2981   version
# 2982   nine months
# 2983   Snow Leopard
# 2984   VirtualBox
# 2985   iteration
# 2986   a price
# 2987   Microsoft's formerly separate MS-DOS and Windows products
# 2988   1998 phased out the Macintosh name in favor of `` Mac ''
# 2989   Microsoft Windows
# 2990   laptops
# 2991   the Legislative Assembly
# 2992   cable
# 2993   the third-fastest growing economy
# 2994   its difficult terrain
# 2995   marketing facilities
# 2996   Pathankot–Jogindernagar
# 2997   various other house hold items
# 2998   in the list of the highest per capita incomes of Indian states
# 2999   the chief minister
# 3000   a traditional ´Pahari' lifestyle
# 3001   the Lt
# 3002   conquered by the Gupta Empire
# 3003   other parts
# 3004   allied disciplines
# 3005   its abundant natural beauty
# 3006   28 to 32 °C
# 3007   a pit-loom
# 3008   every family
# 3009   as multilingual state like other Indian states other Indian states
# 3010   the First Anglo-Sikh War
# 3011   A.O.
# 3012   1 November
# 3013   the members
# 3014   the five river basins
# 3015   Pathankot–Jogindernagar
# 3016   polyethylene and tobacco products
# 3017   some Rajput principalities
# 3018   Himalayas
# 3019   Himachal Pradesh
# 3020   Act
# 3021   the Gupta Empire
# 3022   the state
# 3023   the five river basins
# 3024   the state capital
# 3025   30 December
# 3026   Himachal
# 3027   some Rajput principalities
# 3028   the Indian Administrative Service
# 3029   available cellular phone operators
# 3030   2.18
# 3031   the third-fastest growing economy
# 3032   comprise Kinnars
# 3033   the state
# 3034   has become significant
# 3035   10.5%
# 3036   the third-fastest growing economy in India growing economy in India
# 3037   India
# 3038   far away areas
# 3039   Himachal Pradesh
# 3040   lesser citizens
# 3041   a new September festival
# 3042   the city
# 3043   the camp
# 3044   other gods
# 3045   personal funds
# 3046   sacrifice
# 3047   required observances
# 3048   his duty
# 3049   the innards
# 3050   required observances
# 3051   his part
# 3052   Christianity
# 3053   cult observances
# 3054   the divus Constantine
# 3055   public religion
# 3056   the Capitoline hill
# 3057   miraculous events
# 3058   black-and-white victims
# 3059   to broad seasonal groups that allowed for different local traditions
# 3060   the ruling emperor
# 3061   Roman cultic models
# 3062   the Christians
# 3063   a Roman military aristocrat
# 3064   some individual Romans
# 3065   religious tolerance
# 3066   human sacrifice
# 3067   foreigners
# 3068   the churches
# 3069   Rome's victory
# 3070   a Roman general
# 3071   the Christian Constitutio Apostolica
# 3072   some individual Romans
# 3073   a common Roman identity
# 3074   his career
# 3075   the cremation
# 3076   further expiation
# 3077   his religious reforms
# 3078   the public festivals
# 3079   a centralised legal requirement
# 3080   therefore business
# 3081   Christian heresies
# 3082   her father's authority
# 3083   sacrifice
# 3084   expertise
# 3085   the pomerium
# 3086   divination
# 3087   no stipend
# 3088   whose powers
# 3089   ancient Roman culture
# 3090   its values
# 3091   Nicaea
# 3092   the traditional festivals
# 3093   Christianity
# 3094   offered
# 3095   her father's authority
# 3096   whole
# 3097   extreme penalty
# 3098   Romanitas
# 3099   their new cults
# 3100   the Capitoline hill
# 3101   treason
# 3102   none
# 3103   local elites
# 3104   opinions
# 3105   all social classes
# 3106   events
# 3107   some individual Romans
# 3108   ritual
# 3109   treason
# 3110   class
# 3111   the empire
# 3112   an unacceptable plan
# 3113   images
# 3114   Venus
# 3115   Christian domination
# 3116   the living
# 3117   Roman religious law
# 3118   the palace
# 3119   daily life
# 3120   their gods
# 3121   witnesses
# 3122   Christian control
# 3123   at least some of the traditional festivals
# 3124   the Imperial period
# 3125   intractable conflict
# 3126   the Western and Eastern emperors
# 3127   laws
# 3128   deities
# 3129   each home
# 3130   Persian priests
# 3131   their traditional gods with the usefully open-ended dedication to the diis deabusque omnibus
# 3132   Rome's victory
# 3133   cult practices
# 3134   ancient Rome
# 3135   some individual Romans
# 3136   Roman religion
# 3137   none
# 3138   inscriptions
# 3139   the Christian era
# 3140   class
# 3141   augury
# 3142   belief systems
# 3143   the palace
# 3144   made
# 3145   the collegia
# 3146   most major public ceremonies
# 3147   religious observances
# 3148   office
# 3149   Nicaea
# 3150   none
# 3151   miraculous events
# 3152   wine
# 3153   of which they had no knowledge
# 3154   priesthood
# 3155   a heavenly intercessor
# 3156   divine monarchy
# 3157   the Imperial hierarch
# 3158   the princeps
# 3159   of which they had no knowledge
# 3160   lesser citizens
# 3161   Christians
# 3162   ancient Rome
# 3163   Inscriptions
# 3164   Roman religious law
# 3165   superstitio
# 3166   his rule
# 3167   the Roman people
# 3168   further expiation
# 3169   the Republican pontifices
# 3170   external relations
# 3171   a report
# 3172   "private" diviners
# 3173   earth
# 3174   the community
# 3175   corpses
# 3176   black-and-white victims
# 3177   social stability
# 3178   the Greek goddess Damia
# 3179   The emperor Claudius
# 3180   Rome
# 3181   claimed
# 3182   the more common Latin words
# 3183   superstitio
# 3184   mostly
# 3185   corpses
# 3186   I
# 3187   divine destiny
# 3188   capital punishment
# 3189   her father's authority
# 3190   hero myth
# 3191   Early Italian synagogues
# 3192   a statue
# 3193   a gruesome example
# 3194   an essential public duty
# 3195   Roman women
# 3196   ritual
# 3197   public profile
# 3198   the Greek Dioscuri
# 3199   conspiracy
# 3200   the household hearth
# 3201   its leading Republican
# 3202   occasion
# 3203   his rule
# 3204   his Dacian wars
# 3205   his family
# 3206   the inconvenient delays
# 3207   darkness
# 3208   ancient Rome
# 3209   Most Roman authors
# 3210   the Greek goddess Damia
# 3211   new life
# 3212   whole
# 3213   Rome
# 3214   capital punishment
# 3215   the palace
# 3216   human sacrifice
# 3217   commemorative practices
# 3218   superstitio
# 3219   the household hearth
# 3220   state counterparts
# 3221   blight and red mildew
# 3222   deities
# 3223   others
# 3224   its existence
# 3225   the pomerium
# 3226   subversive activity
# 3227   initiates salvation
# 3228   most major public ceremonies
# 3229   the Lares
# 3230   harm the State
# 3231   such worship
# 3232   deities
# 3233   their chosen philosophy
# 3234   the underside
# 3235   the sea-floor
# 3236   many descendant phyla
# 3237   their fossils
# 3238   these identifications
# 3239   plants
# 3240   all its neurons
# 3241   the sea-floor
# 3242   the cuticle
# 3243   the fertilized egg's development
# 3244   their natural populations
# 3245   vertical mesenteries
# 3246   the fertilized egg's development
# 3247   other phyla
# 3248   have various combinations of ocelli
# 3249   the surface
# 3250   contains
# 3251   the sea-floor
# 3252   the sea-floor
# 3253   leeches
# 3254   the sea-floor
# 3255   their fossils
# 3256   contracting
# 3257   each side
# 3258   arthropods
# 3259   the segment
# 3260   the body
# 3261   hearts
# 3262   some situations
# 3263   inchworms
# 3264   the following segment
# 3265   the same time as flowering plants in the early Cretaceous
# 3266   made
# 3267   the Jurassic
# 3268   bait
# 3269   their fossils
# 3270   this pattern
# 3271   either produces yolk when the eggs are fertilized or nutrients while they are developing
# 3272   the sea-floor
# 3273   arthropods
# 3274   out to extend it
# 3275   a muscular pharynx
# 3276   soil fertility
# 3277   the sea-floor
# 3278   out to extend it
# 3279   vertebrates
# 3280   gut
# 3281   a transverse connection
# 3282   all native earthworms are thought to have been killed by the glaciers and the worms currently found in those areas are all introduced from other areas found in those areas are all introduced from other areas
# 3283   their bodies
# 3284   plants
# 3285   Europe
# 3286   arrangement
# 3287   each side
# 3288   other segments
# 3289   septa
# 3290   appear
# 3291   the Carboniferous
# 3292   locomotion
# 3293   other major annelid groups
# 3294   the modern mobile polychaete groups
# 3295   the underside
# 3296   plants
# 3297   use suckers at their front and rear ends to move like inchworms
# 3298   ammonia
# 3299   trademarks
# 3300   the general and permanent federal statutes
# 3301   wire fraud
# 3302   the Supreme Court
# 3303   the federal judiciary
# 3304   contemporary English cases
# 3305   American reports
# 3306   the Constitution
# 3307   criminal law
# 3308   the rest
# 3309   precedents
# 3310   given
# 3311   stare decisis
# 3312   the territories
# 3313   the Constitution
# 3314   mail
# 3315   mail
# 3316   American tort law
# 3317   the Constitution
# 3318   the territories
# 3319   federal agencies
# 3320   on
# 3321   law enforcement powers
# 3322   abolished
# 3323   state courts
# 3324   the Constitution
# 3325   mail
# 3326   the Uniform Commercial Code
# 3327   criminal law
# 3328   272,795 new cases
# 3329   stare decisis
# 3330   issue
# 3331   a settlement
# 3332   post-Revolution Commonwealth rulings
# 3333   1.9 million juvenile cases
# 3334   state courts
# 3335   West Publishing
# 3336   several ways
# 3337   several ways
# 3338   state courts
# 3339   the federal Senate
# 3340   the Uniform Commercial Code
# 3341   session laws
# 3342   `` received '' into the United States in several ways
# 3343   state law
# 3344   interstate and international situations
# 3345   others
# 3346   the court's jurisdiction
# 3347   numerous exceptions
# 3348   the class
# 3349   local ordinances
# 3350   the federal judiciary
# 3351   the relevant statutes
# 3352   irrational or just bad public policy
# 3353   the United States
# 3354   individual judges
# 3355   English common law
# 3356   one state
# 3357   several ways
# 3358   the McCarran-Ferguson Act
# 3359   the territories
# 3360   influenced by each other 's rulings follow post-Revolution Commonwealth rulings unless there is no American ruling on point
# 3361   a substantial fine
# 3362   local ordinances
# 3363   wire fraud
# 3364   The fifty American states
# 3365   mail
# 3366   relevant to the federal government like evading payment of federal income tax evading payment of federal income tax
# 3367   state law
# 3368   federal agencies
# 3369   June
# 3370   sovereigns
# 3371   result
# 3372   the reasoning
# 3373   state laws
# 3374   a subsequent statute
# 3375   common carriers
# 3376   West Publishing
# 3377   the ground
# 3378   the exact order
# 3379   minor crimes
# 3380   grant
# 3381   individual judges
# 3382   as they are in accordance with the Constitution
# 3383   the Constitution
# 3384   the Constitution
# 3385   state law
# 3386   the general and permanent federal statutes
# 3387   a settlement
# 3388   the presence of reception statutes
# 3389   the start of the 20th century
# 3390   session laws
# 3391   the state level
# 3392   the federal judiciary
# 3393   The law
# 3394   ruling
# 3395   Darijas' use
# 3396   others
# 3397   a historical and political development
# 3398   dialects
# 3399   lower class
# 3400   their own separate languages
# 3401   a yet older language
# 3402   Italian traveling merchants
# 3403   , a more sociolinguistic notion
# 3404   the traditional regional varieties
# 3405   the German dialects
# 3406   a politically motivated "absurdity
# 3407   Russia
# 3408   the dialect continuum
# 3409   that dialect
# 3410   a dialect
# 3411   a hidden or latent language
# 3412   Italy's population
# 3413   their own separate languages
# 3414   not a language
# 3415   the English language
# 3416   their language
# 3417   the Qur'an
# 3418   a politically motivated "absurdity
# 3419   standard Italian
# 3420   the spoken language
# 3421   provincialism
# 3422   these countries
# 3423   an intermediate dialect
# 3424   an Italian national identity
# 3425   the standard languages of Serbia and Croatia
# 3426   their own separate languages
# 3427   its policy
# 3428   the "dialects
# 3429   Spanish
# 3430   the modern situation
# 3431   two dialects
# 3432   Old Norse
# 3433   their own local variants
# 3434   bitter enemies
# 3435   separate languages
# 3436   languages
# 3437   mutual intelligibility
# 3438   even armed conflict
# 3439   the Western language families
# 3440   low social status
# 3441   rather separate (but often related) languages
# 3442   notion
# 3443   a yet older language
# 3444   the term accent
# 3445   the major dialect groups
# 3446   the modern situation
# 3447   provincialism
# 3448   argots
# 3449   social class
# 3450   Latin-based Romance languages the Italo-Dalmatian language family
# 3451   considered more different from other Arabic dialects
# 3452   genetic relationship
# 3453   Italians
# 3454   region
# 3455   other Arabic dialects
# 3456   region
# 3457   the English language
# 3458   a pure Sicilian language variant
# 3459   a yet older language
# 3460   Spanish
# 3461   a regional dialect
# 3462   dialects
# 3463   different languages
# 3464   a dialect
# 3465   distinct languages
# 3466   its pronunciation
# 3467   region
# 3468   the Italo-Dalmatian language family
# 3469   the English language
# 3470   different languages
# 3471   separate languages
# 3472   a pure Sicilian language variant
# 3473   used by linguists
# 3474   purple
# 3475   a few examples
# 3476   intersections
# 3477   the Byzantine emperors
# 3478   a brilliant scarlet
# 3479   the terrible human passions
# 3480   relatively low levels
# 3481   a related insect
# 3482   gold
# 3483   the green chlorophyll
# 3484   danger
# 3485   brides
# 3486   other objects
# 3487   the Nazi flag
# 3488   the Soviet flag
# 3489   Persians
# 3490   his reign
# 3491   color
# 3492   Europe
# 3493   television screen
# 3494   national flags
# 3495   copies
# 3496   the national flower
# 3497   the Christian martyrs
# 3498   color
# 3499   Bouches-du-Rhône
# 3500   the Mediterranean
# 3501   your blood pressure
# 3502   red jerseys
# 3503   Spanish galleons
# 3504   saw
# 3505   his coronation
# 3506   the same distance
# 3507   that color
# 3508   the continent
# 3509   relatively low levels
# 3510   some historically Christian nations
# 3511   its association
# 3512   a Neolithic cave-burial
# 3513   additive primary colors
# 3514   Europe
# 3515   their enemy
# 3516   modern-day Turkey
# 3517   monetary gifts
# 3518   red wood
# 3519   his open coffin
# 3520   the grain
# 3521   Ireland
# 3522   manufacturing pigments
# 3523   their own banners
# 3524   the Nazi flag
# 3525   actual performance
# 3526   testosterone
# 3527   his brother
# 3528   television screen
# 3529   Ireland
# 3530   this law
# 3531   the red
# 3532   that country
# 3533   monetary gifts
# 3534   other objects
# 3535   the Kermes dye
# 3536   the day
# 3537   artists
# 3538   their enemy
# 3539   the Mediterranean
# 3540   certain grasses
# 3541   red wood
# 3542   a brilliant scarlet
# 3543   emotions
# 3544   the Mediterranean
# 3545   party
# 3546   one of the subtractive primary colors
# 3547   emotions
# 3548   the Nazi flag
# 3549   animal species
# 3550   the Ndembu
# 3551   red teams
# 3552   danger
# 3553   purple
# 3554   the same distance
# 3555   his coronation
# 3556   ambition
# 3557   used as a pigment for wall paintings
# 3558   China
# 3559   summer
# 3560   gladiators
# 3561   a white field
# 3562   death
# 3563   a movement
# 3564   all things
# 3565   the Bible
# 3566   all vertebrates
# 3567   many other dangers
# 3568   the Soviet flag
# 3569   red wood
# 3570   brides
# 3571   a related insect
# 3572   artisans
# 3573   of pigment
# 3574   a red shawl
# 3575   the grain
# 3576   the oak tree
# 3577   anthocyanin pigments
# 3578   Tintoretto
# 3579   their culture sees the color as a symbol of life and health
# 3580   this law
# 3581   the Paris Commune
# 3582   the Garde
# 3583   baseball cards
# 3584   mercury
# 3585   the flag
# 3586   red wood
# 3587   Mars
# 3588   iron oxide
# 3589   his Christian faith
# 3590   the plant
# 3591   more than twenty centuries
# 3592   such mansions
# 3593   that country
# 3594   Spain
# 3595   The fabric
# 3596   the "Reds
# 3597   Europe
# 3598   Europe
# 3599   the Mediterranean
# 3600   a black screen
# 3601   Bouches-du-Rhône
# 3602   red wood
# 3603   animal species
# 3604   national flags
# 3605   Jesus
# 3606   five other colors
# 3607   monetary gifts
# 3608   the red scare
# 3609   the Soviet flag
# 3610   relatively low levels
# 3611   Ancient Rome
# 3612   a "red sun
# 3613   ambition
# 3614   a black screen
# 3615   the paintings
# 3616   modern-day Turkey
# 3617   Europe

# %% [markdown]
# # Train set test

# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer

OPEN_QUESTION_WORDS = ['what', 'who', 'whose', 'whom', 'where', 'when', 'why', 'how',
                       'which', "what's", "who's", "where's", "how's"]
CLOSED_QUESTION_WORDS = ['is', 'are', 'am', 'was', 'were', 'do', 'does,', 'did', 'can',
                         'could', 'will', 'would', 'shall', 'should', 'have', 'has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('training.json') as json_data:
    train = json.load(json_data)
    
with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)


def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)


def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma


def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += tfs[term]
    return dfs


def query_vsm(query, index, k=10):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'


# file = open('Second_method.csv', 'w')
# file.write('id,answer\n')

case_count = 0
# test = [test[17]]
for train_case in train:
    question = train_case['question']
    docid = train_case['docid']
    correct_answer = train_case['text']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)

    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question)
    results = query_vsm(terms, vsm_inverted_index)

    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    target = [] # target dep

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''
    attr = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of question
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            dobj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'attr' and token.head.dep_ == 'ROOT':
            attr = lemmatize(strip_punctuation(token.text))

    # determine answer dependency
    if qword in ['who', "who's", 'whom', 'whose']:
        for chunk in doc.noun_chunks:
            if qword in chunk.text:
                target = [chunk.root.dep_]

    elif qword in ['where', "where's", 'when']:
        target = ['advmod','prep']

    elif qword in ['how', "how's"]:
        if next_token in ['much', 'many','long','far', 'big', 'wide', 'deep', 'tall', 'high', 'fast', 'heavy','old', 'young']:
            target = ['attr']
        
        elif next_token in ['does', 'did', 'do', 'have', 'has', 'had', 'should',
                            'can', 'could', 'will', 'would', 'must']:
            if dobj != '':
                target = ['advmod', 'acomp']
            else:
                target = ['ROOT']

    elif qword in ['what', "what's", 'which']:
        # what...do type question
        tokens.remove(next_token)
        if 'do' in tokens:
            target = ['ROOT']
        else:
            for chunk in doc.noun_chunks:
                if qword in chunk.text:
                    target = [chunk.root.dep_]

    elif qword == 'why':
        target = ['mark','prep']

    elif qword in CLOSED_QUESTION_WORDS:
        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            
            # dep of phrase before and after 'or'
            prev = tokens[index - 1]
            for chunk in doc.noun_chunks:
                if prev in chunk.text:
                    target = [chunk.root.dep_]
            
            if target == '':
                for token in doc:
                    if prev in token.text:
                        target = [token.dep_]

    # find answer with highest score from the 10 most similar sentences
    max_score = -1
    answer = ''

    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        # find sentence structure
        sent_nsubj = ''
        sent_ROOT = ''
        sent_dobj = ''
        sent_attr = ''
        for token in doc:
            if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_nsubj = lemmatize(strip_punctuation(token.text))
            if token.dep_ == 'ROOT':
                sent_ROOT = lemmatize(strip_punctuation(token.text))
            if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_dobj = lemmatize(strip_punctuation(token.text))
            if 'attr' in token.dep_ and token.head.dep_ == 'ROOT':
                sent_attr = lemmatize(strip_punctuation(token.text))

        score = 0
        if nsubj == sent_nsubj:
            score += 1
            if ROOT == sent_ROOT:
                score += 1
                if dobj == sent_dobj:
                    score += 1
                if attr == sent_attr:
                    score += 1

        max_score = -1
        answer = ''
        if target == ['ROOT'] or target == ['attr'] or target == ['advmod','acomp']:
            for token in doc:
                if token.dep_ in target:
                    score += 1
                    
                    if token.text not in question:
                        score += 1
                        
                    if strip_punctuation(token.text).lower() in stop:
                        score = -1
                        
                    if token.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        answer = token.text
                        
        elif target == ['mark','prep'] or target == ['advmod','prep']:
            for token in doc:
                if token.dep_ in target:
                    score += 1
                    
                    if token.text not in question:
                        score += 1
                        
                    if strip_punctuation(token.text).lower() in stop:
                        score = -1
                        
                    if token.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        substr = sent[sent.index(token.text):]
                        tokens = nltk.word_tokenize(substr)
                        del tokens[0]
                        for token in tokens:
                            if token in punc:
                                break
                            answer += token+' '
                        
        else:
            for chunk in doc.noun_chunks:
                if chunk.root.dep_ in target:
                    score += 1
                    
                    if chunk.text not in question:
                        score += 1
                        
                    if strip_punctuation(chunk.text).lower() in stop:
                        score = -1
                        
                    if chunk.text.lower() == 'it':
                        score = -1
                    
                    if score > max_score:
                        max_score = score
                        answer = chunk.text
        
    # default answer
    if answer == '':
        for chunk in doc.noun_chunks:
            if chunk.text not in stop and chunk.text not in question:
                answer = chunk.text
        
        
#     file.write(str(case_count))
#     file.write(',')
#     file.write(strip_punctuation(answer).strip().lower())
#     file.write('\n')
    if answer != correct_answer:
        print('Correct: ',correct_answer)
    
        print('Predicted: ',answer)
       
        print('Question: ',question)
        
        for id, _ in results:
            sent = raw_docs[id]
            doc = nlp(sent)
            
        print('\n')
    case_count += 1
# Out:
# Correct:  6966662606895999999♠6.62606896×10−34 j⋅s
# Predicted:  more detailed information
# Question:  A kilogram could be definined as having a Planck constant of what value?
#
#
# Correct:  cylinder
# Predicted:  diagram
# Question:  What is the shape of the object that establishes the base unit of the kilogram?
#
#
# Correct:  time vs. energy
# Predicted:  a given time
# Question:  What example is given as another paired relationship of uncertainly related to standard deviation?
#
#
# Correct:  quantum of action
# Predicted:  angular momentum
# Question:  What does the Planck Constant refer to?
#
#
# Correct:  1913
# Predicted:  calculated in the early twentieth century
# Question:  When was the first quantized model of the atom introduced?
#
#
# Correct:  kirchhoff
# Predicted:  J⋅s
# Question:  What scientist first studied black body radiation?
#
#
# Correct:  schrödinger
# Predicted:  the Bohr model
# Question:  Who helped to give the correct quantization rules for electrons in 1926?
#
#
# Correct:  h
# Predicted:  Rutherford's classical model
# Question:  Classical statistical mechanics requires the existence of what?
#
#
# Correct:  h
# Predicted:  the denominator
# Question:  What is required to exist in classical statistics mechanics?
#
#
# Correct:  7005216000000000000♠216 kj/mol
# Predicted:  time
# Question:  How much energy is contained in the light to which human eyes are most sensitive?
#
#
# Correct:  f
# Predicted:  mass standards
# Question:  What is frequency also known as in science?
#
#
# Correct:  1839
# Predicted:  on the frequency to cause the photoelectric effect
# Question:  When was the photoelectric effect first observed?
#
#
# Correct:  1911
# Predicted:  to a mass on a spring
# Question:  When did Paul Ehrenfest come up with the name "ultraviolet catastrophe"?
#
#
# Correct:  heinrich hertz
# Predicted:  higher kinetic energy
# Question:  Who published the first thorough investigation of the photoelectric effect?
#
#
# Correct:  alexandre edmond becquerel
# Predicted:  higher kinetic energy
# Question:  Who first observed the photoelectric effect?
#
#
# Correct:  paul ehrenfest
# Predicted:  its expected value
# Question:  Who came up with the term, "ultraviolet catastrophe"?
#
#
# Correct:  multiphoton effect
# Predicted:  the variables
# Question:  What is the term used when photoelectrons act virtually at the same time?
#
#
# Correct:  nuclear magneton
# Predicted:  fundamental physical constants
# Question:  What is the unit of magentic properties of atomic nuclei?
#
#
# Correct:  einstein
# Predicted:  his discovery
# Question:  Who discovered an association between the value E and quantum energy?
#
#
# Correct:  555 nanometres
# Predicted:  the wave description
# Question:  At about what wavelength of light are human eyes most sensitive?
#
#
# Correct:  alexandre edmond becquerel
# Predicted:  higher kinetic energy
# Question:  Who first observed the photoelectric effect?
#
#
# Correct:  1911
# Predicted:  developments by Sommerfeld and others
# Question:  When was the first Solvay Conference held?
#
#
# Correct:  hot atoms
# Predicted:  the gyromagnetic ratio
# Question:  What is required for the electromagnetic field to come to thermal equilibrium?
#
#
# Correct:  einstein
# Predicted:  the quantum Hall effect
# Question:  Who received the Nobel Prize in 1921 for his work on the photoelectric effect?
#
#
# Correct:  thermal
# Predicted:  the radiation
# Question:  What assumption that black-body radiation is what leads to an accurate prediction?
#
#
# Correct:  quantum
# Predicted:  the variables
# Question:  What term describes a small amount of element?
#
#
# Correct:  forbidden
# Predicted:  energy
# Question:  Regarding atoms, what are values in between certain energy levels considered by the Planck constant?
#
#
# Correct:  particles
# Predicted:  long wavelength
# Question:  What are common things like furniture and stationary objects actually made of?
#
#
# Correct:  a wave
# Predicted:  the nucleus
# Question:  Before Einstein, electromagnetic radiation was considered to behave as what?
#
#
# Correct:  green
# Predicted:  ♠
# Question:  What color of light is the human eye most sensitive to?
#
#
# Correct:  rayleigh and jeans
# Predicted:  a mere mathematical formalism
# Question:  Einstein and what other two individuals revisited the black-body problem in 1905?
#
#
# Correct:  einstein
# Predicted:  a direct determination
# Question:  Which scientist associated the Planck constant with a quantum five years after Planck's recognition?
#
#
# Correct:  colour
# Predicted:  a certain kinetic energy
# Question:  What type of changes in the light a hot object emits as the object's temperature changes?
#
#
# Correct:  7014540000000000000♠540 thz
# Predicted:  the wave description
# Question:  What is the frequency of the light to which the human eye is most sensitive?
#
#
# Correct:  the `` ultraviolet catastrophe ''
# Predicted:  Robert Andrews Millikan
# Question:  What name did Paul Ehrenfest give to the proofs from Einstein and Rayleigh & Jeans?
#
#
# Correct:  the kilogram
# Predicted:  the substance
# Question:  What measurement is deemed most important to redefine in terms of physical constants?
#
#
# Correct:  intensity
# Predicted:  angular momentum
# Question:  What is the energy transferred by a wave in a given time called?
#
#
# Correct:  watt-balance measurement
# Predicted:  the quantum Hall effect
# Question:  What method was was used to obtain the measurement?
#
#
# Correct:  a circular argument
# Predicted:  SI units
# Question:  Using Planck constant values from these effects would lead to what logical issue?
#
#
# Correct:  7050135639273999999♠135639274×1042 hz
# Predicted:  SI units
# Question:  The mass of a resting body with what energy would be equal to a kilogram?
#
#
# Correct:  value e
# Predicted:  a certain kinetic energy
# Question:  What is considered the minimal energy increment of a hypothetical oscillator?
#
#
# Correct:  the frequency
# Predicted:  J.
# Question:  What does the kinetic energy of a photoelectron depend on?
#
#
# Correct:  the light quantum
# Predicted:  higher kinetic energy
# Question:  What was later termed the photon?
#
#
# Correct:  crystals of silicon
# Predicted:  the equation
# Question:  What element is used typically to establish Avogadro's constant?
#
#
# Correct:  time vs. energy
# Predicted:  the light
# Question:   What measurable value obeys a similar rule of angular momentum?
#
#
# Correct:  sound
# Predicted:  the electromagnetic wave
# Question:  What other types of wave besides light has its own intensity?
#
#
# Correct:  thermal
# Predicted:  a definite rule
# Question:  What do scientists assume black body radiation is?
#
#
# Correct:  7014540000000000000♠540 thz
# Predicted:  the speed
# Question:  What frequency does green light with a wavelength of 555 nanmetres have?
#
#
# Correct:  fourier analysis
# Predicted:  its expected value
# Question:  What type of analysis fits the either-or nature of the uncertainty?
#
#
# Correct:  physical action
# Predicted:  A change
# Question:  After Planck's findings, what was determined could not take on an arbitrary value?
#
#
# Correct:  laws of motion
# Predicted:  a definite rule
# Question:  Electromagnetic fields obey what laws?
#
#
# Correct:  555 nanometres
# Predicted:  the wave description
# Question:  Which light wavelength is the human eye most sensitive to?
#
#
# Correct:  relativity
# Predicted:  a body
# Question:  Einstein's photoelectric effect work was rewards as opposed to his work on what other topic?
#
#
# Correct:  the quantity
# Predicted:  their own intensity
# Question:  What is the reduced Planck constant also known as?
#
#
# Correct:  1918
# Predicted:  action
# Question:  In what year did Planck receive the Nobel Prize in Physics for his discovery of energy quanta?
#
#
# Correct:  black-body
# Predicted:  the Planck
# Question:  What type of radiation was Planck studying in the late 19th century?
#
#
# Correct:  h
# Predicted:  The molar volume
# Question:  In making Planck's law, what was in both the numerator and denominator of the formula that was used?
#
#
# Correct:  quantum of action
# Predicted:  the relation
# Question:  What is the Planck constant formerly known as?
#
#
# Correct:  7005216000000000000♠216 kj/mol
# Predicted:  its thermal light emission
# Question:  How much energy does a green light of wavelength 555 nm contain?
#
#
# Correct:  wilhelm wien
# Predicted:  the light
# Question:  Who discovered the mathematical relationship between peaks and curves of light at different temperatures?
#
#
# Correct:  bohr
# Predicted:  the new definition
# Question:  Who introduced the reduced Planck constant?
#
#
# Correct:  heisenberg
# Predicted:  light
# Question:  What scientist used matrix mechanics to bring electron behavior in line with the Bohr model?
# Correct:  the rayleigh–jeans
# Predicted:  a continuous variable
# Question:  What rule predicted narrow range of energy values at lower temperatures?
#
#
# Correct:  platinum–iridium
# Predicted:  conventional electrical units
# Question:  What alloy is the base unit of the kilogram made from?
#
#
# Correct:  blackbody emissions
# Predicted:  the new definition
# Question:  What does Planck's law correctly predict?
#
#
# Correct:  niels bohr
# Predicted:  angular momentum
# Question:  Who modeled the atom in 1913, challenging Rutherford's model?
#
#
# Correct:  2007
# Predicted:  present
# Question:  The value quoted here for the Planck constant is based on a measurement in what year?
#
#
# Correct:  thermal light emission
# Predicted:  the colour
# Question:  What is maximized as a result of a black object absorbing all the light that hits it?
#
#
# Correct:  6981358000000000000♠3.58×10−19 j
# Predicted:  a certain kinetic energy
# Question:  What is the energy of a photon?
#
#
# Correct:  white hot
# Predicted:  hot atoms
# Question:  What color is hotter than "red hot"?
#
#
# Correct:  black-body radiation
# Predicted:  A change
# Question:  Planck studied what problem posed originally by Kirchhoff?
#
#
# Correct:  intensity
# Predicted:  angular momentum
# Question:  What is the name for the amount of energy transfered by a wave in a given time?
#
#
# Correct:  1921
# Predicted:  the Planck
# Question:  Einstein's paper on the photoelectric effect earned him the Nobel Prize in what year?
#
#
# Correct:  heisenberg
# Predicted:  the Bohr model
# Question:  Who helped to give the correct quantization rules for electrons in 1925?
#
#
# Correct:  the energy account
# Predicted:  the quantum Hall effect
# Question:  What portion of the photoelectric effect was in disagreement with the believed description of light behavior?
#
#
# Correct:  stefan–boltzmann law
# Predicted:  a certain kinetic energy
# Question:  What law describes the changes in light emitted by a hot object?
#
#
# Correct:  niels bohr
# Predicted:  the early twentieth century
# Question:  Who introduced the first quantized model of the atom?
#
#
# Correct:  1905
# Predicted:  Robert Andrews Millikan
# Question:  In what year was the value E associated by Einstein with quantum theories of energy?
#
#
# Correct:  max planck
# Predicted:  the quantum picture
# Question:  Who received the Nobel Prize in Physics in 1918?
#
#
# Correct:  a wave
# Predicted:  higher kinetic energy
# Question:  Prior to Einstein's work, light behavior was modeled as what?
#
#
# Correct:  forty
# Predicted:  the early twentieth century
# Question:  How many years prior to Planck's study had the scientific community first discussed black body radiation?
#
#
# Correct:  1911
# Predicted:  developments by Sommerfeld and others
# Question:  When was the first Solvay Conference held?
#
#
# Correct:  light
# Predicted:  particles
# Question:  What does a hot object in equilibrium absorb as much as it emits?
#
#
# Correct:  hotter
# Predicted:  effect
# Question:  Cooler objects glow less than objects that are what?
#
#
# Correct:  accurate
# Predicted:  temperatures
# Question:  What kind of prediction does the assumption that black body radiation is thermal lead to?
#
#
# Correct:  silicon
# Predicted:  conventional electrical units
# Question:  One other measure involved the molar volume of what element?
#
#
# Correct:  the stefan–boltzmann law
# Predicted:  angular momentum
# Question:  What rule predicts that emitted energy increases with temperature?
#
#
# Correct:  35,800 mw
# Predicted:  reach
# Question:  Global wind power installations increased by how much in 2010?
#
#
# Correct:  international energy agency
# Predicted:  Germany's power plants
# Question:  Which group projected that solar plant may produce most of the world's electricity within 50 years?
#
#
# Correct:  stern review
# Predicted:  ocean energy
# Question:  What made a strong economic case for investing in low carbon technologies?
#
#
# Correct:  renewable energy technologies
# Predicted:  domestic demand
# Question:  What is getting cheaper as a result of technilogical change?
#
#
# Correct:  public policy
# Predicted:  electricity consumption
# Question:  What determines the extent to which renewable energy is to be incorporated into a country's generation mix?
#
#
# Correct:  demonstration egs projects
# Predicted:  coal
# Question:  What is operational in the USA, Australia, Germany, France and The United Kingdom?
#
#
# Correct:  eu member countries
# Predicted:  future generations
# Question:  Who has shown support for ambitious renewable energy goals?
#
#
# Correct:  2006
# Predicted:  the primary energy and/or electricity generation mix
# Question:  In what year did a number of events push renewable energy up the political agenda?
#
#
# Correct:  solyndra
# Predicted:  alternative energy growth
# Question:  What company filed for Chapter 11 bankruptcy?
#
#
# Correct:  $ 140.4 billion
# Predicted:  these technologies
# Question:  How much was the worldwide investment in solar power in 2012?
#
#
# Correct:  global warming
# Predicted:  greater use
# Question:  What motivated the incentive to use 100 percent renewable energy?
#
#
# Correct:  germany
# Predicted:  both developing and developed countries
# Question:  What country is reducing its coal subsidy?
#
#
# Correct:  three
# Predicted:  heat
# Question:  How many hydroelectricity plants are larger than 10 GW?
#
#
# Correct:  mark z. jacobson
# Predicted:  30%
# Question:  Who stated that energy costs with a wind, solar, water system should be similar to today's energy costs?
#
#
# Correct:  half
# Predicted:  installed capacity
# Question:  Photovoltaic and solar-thermal plants may meet how much of the world's energy needs by 2060?
#
#
# Correct:  renewable energy policy
# Predicted:  renewable energy technologies
# Question:  Setting national renewable energy targets can be an important part of what?
#
#
# Correct:  spain
# Predicted:  First Solar
# Question:  Where is the PS20 solar power tower located?
#
#
# Correct:  58 percent
# Predicted:  the USA
# Question:  In 2012, solar electricity consumption increased by what percentage?
#
#
# Correct:  18.1 percent
# Predicted:  conventional energy sources
# Question:  Use of wind power in 2012 increased by what percentage?
#
#
# Correct:  22 percent
# Predicted:  both developing and developed countries
# Question:  Renewables contributed what percentage to our electricity generation?
#
#
# Correct:  achim steiner
# Predicted:  chance
# Question:  Who was the UN under-secretary in 2011?
#
#
# Correct:  first-generation biomass technologies
# Predicted:  a robust promotional policies
# Question:  What can be economically competetive but may still require deployment support?
#
#
# Correct:  renewables
# Predicted:  many developing countries
# Question:  What is becoming increasingly economic in both developing and devloped countries?
#
#
# Correct:  un under-secretary general
# Predicted:  chance
# Question:  Who is Achim Steiner?
#
#
# Correct:  tax shifting
# Predicted:  economists
# Question:  What involves lowering income taxes while raising levies?
#
#
# Correct:  19 %
# Predicted:  solar power
# Question:  In Denmark, wind power accounts for what percentage of electricity generated?
#
#
# Correct:  europe
# Predicted:  77%
# Question:  Where have the majority of photovoltaic power stations been built?
#
#
# Correct:  australia
# Predicted:  ambitious renewable energy goals
# Question:  Name one outher country with defined national or regional target?
#
#
# Correct:  social and political
# Predicted:  many countries
# Question:  What is a barrier to implementing the renewable energy plan?
#
#
# Correct:  sunpower
# Predicted:  over 60%
# Question:  Who is building The Califoria Valley Solar Ranch?
#
#
# Correct:  kandeh yumkella
# Predicted:  energy supply
# Question:  Who is chair of UN Energy?
#
#
# Correct:  2060
# Predicted:  Egypt
# Question:  Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by what year?
#
#
# Correct:  10 percent
# Predicted:  electricity consumption
# Question:  Nearly all gasoline sold in the U.S. is mixed with what percentage of ethanol?
#
#
# Correct:  hydroelectricity
# Predicted:  Ireland
# Question:  Hydroelectricity accounts for what percentage of global electricity generation?
#
#
# Correct:  gm
# Predicted:  11 MW
# Question:  Name one company that sells flexible-fuel cars?
#
#
# Correct:  10 gw
# Predicted:  installed capacity
# Question:  What was the geothermal capacity in 2008?
#
#
# Correct:  renewable energy commercialization
# Predicted:  new generating capacity
# Question:  What involves the deployment of three generations of renewable energy technologies dating back more than 100 years?
# Correct:  lester brown
# Predicted:  the RES Directive
# Question:  Who believes that the market does not value nature's service adequately?
#
#
# Correct:  144
# Predicted:  plants
# Question:  How many countries now have renewable energy policies?
#
#
# Correct:  19 percent
# Predicted:  an indicative renewable energy target
# Question:  Renewables contributed what percentage to our energy consumption?
#
#
# Correct:  dedicated energy crops
# Predicted:  many countries
# Question:  What is a promising cellulose source that can be sustainably produced in many regions?
#
#
# Correct:  coal
# Predicted:  many countries
# Question:  Some countries have phased out all subsidies for what substance?
#
#
# Correct:  the internet
# Predicted:  the renewable energy and energy efficiency industries
# Question:  What was the result of publicly funded links among computers in government labs and reserach institutes?
#
#
# Correct:  2011
# Predicted:  conventional energy sources
# Question:  As of what year have there been substantial reductions in the cost of solar and wind technologies?
#
#
# Correct:  california 's mojave desert
# Predicted:  in Europe
# Question:  Where is the Ivanpah Solar Power Facility located?
#
#
# Correct:  2008
# Predicted:  renewable energy technologies
# Question:  The PV industry has seen drops in module prices since what year?
#
#
# Correct:  renewable energy
# Predicted:  Hydroelectricity
# Question:  As of 2012, what accounts for about half of new nameplate electrical capacity?
#
#
# Correct:  hydroelectricity
# Predicted:  more than 100 years
# Question:  What is the most widely used form of renewable energy?
#
#
# Correct:  9 %
# Predicted:  all new power generation capacity additions
# Question:  In Spain, wind power accounts for what percentage of electricity generated?
#
#
# Correct:  renewable energy
# Predicted:  renewable energy technologies
# Question:  Ban Ki-moon states that renewable energy has the ability to lift the poorest nations to new levels of prosperity?
#
#
# Correct:  17 percent
# Predicted:  the nation's installed wind power capacity
# Question:  In the Phillipines, geothermal represented what percentage of the total power mix at the end of 2008?
#
#
# Correct:  $ 244 billion
# Predicted:  countries
# Question:  How much was the total investment in renewable energy in 2012?
#
#
# Correct:  res directive
# Predicted:  domestic demand
# Question:  What states that EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed?
#
#
# Correct:  market expansion
# Predicted:  the environment
# Question:  What is the main driver of reduced costs?
#
#
# Correct:  2030
# Predicted:  market expansion
# Question:  Analysts expect the market to triple by what year?
#
#
# Correct:  1 gw
# Predicted:  installed capacity
# Question:  What was the geothermal capacity in 1975?
#
#
# Correct:  iea
# Predicted:  the overall target
# Question:  What group stated that "cost reductions in critical technologies, such as wind and solar, are set to continue?"
#
#
# Correct:  150
# Predicted:  the USA
# Question:  Hydropower is produced in how many countries?
#
#
# Correct:  renewable technologies
# Predicted:  both developing and developed countries
# Question:  What are now often the most economic solution for new generating capacity?
#
#
# Correct:  crop residues
# Predicted:  most plants
# Question:  What are potential sources of cellulosic biomass?
#
#
# Correct:  $ 1.00/w installed cost
# Predicted:  energy security
# Question:  What cost is often regarded as marking the achievment of grid parity for PV?
#
#
# Correct:  2030
# Predicted:  wind power
# Question:  Jacobson says producing all new energy with wind power, solar power and hydropower is feasible by what year?
#
#
# Correct:  energy regulators
# Predicted:  more than 100 years
# Question:  Who has the authority to carry out a number of functions that havae implications for the feasiblity of renewable energy projects?
#
#
# Correct:  renewable energy
# Predicted:  both developing and developed countries
# Question:  What is the most economic solution for new grid-connected capacity in areas with good resources?
#
#
# Correct:  renewable energy
# Predicted:  many technologies
# Question:  What plays a major role in the energy mix of many countries?
#
#
# Correct:  usa
# Predicted:  geographical spread
# Question:  Where is the Agua Caliente Solar Project located?
#
#
# Correct:  charles holliday
# Predicted:  16,500 MW
# Question:  Who is chairman of Bank of America?
#
#
# Correct:  tom hanks
# Predicted:  Modern Warfare
# Question:  Who played Donovan in 'Bridge of Spies'?
#
#
# Correct:  falling skies
# Predicted:  his films
# Question:  What show did Spielberg work with Rodat on?
#
#
# Correct:  1958
# Predicted:  baptized by a family servant and then kidnapped from his family by the Papal States
# Question:  When did Spielberg join the Boy Scouts?
#
#
# Correct:  george lucas
# Predicted:  the Coen brothers
# Question:  Who was responsible for Star Wars?
#
#
# Correct:  1997
# Predicted:  at the box office and received a limited release
# Question:  When was 'Men In Black' released?
#
#
# Correct:  1995
# Predicted:  at the box office and received a limited release
# Question:  When was 'The Dig' released?
#
#
# Correct:  amblin
# Predicted:  ER
# Question:  What short film did Spielberg make for theatrical release?
#
#
# Correct:  vice president
# Predicted:  the critics
# Question:  What was Sidney Sheinberg's position with Universal?
#
#
# Correct:  december 21 , 2011
# Predicted:  The Dig
# Question:  When was Adventures of Tintin released in the US?
#
#
# Correct:  1997
# Predicted:  given the opportunity to make a short film for theatrical release
# Question:  When was 'Skullmonkeys' released?
#
#
# Correct:  jaws
# Predicted:  producer Lynda Obst
# Question:  What film did Richard D. Zanuck and David Brown offer Steven Spielberg to direct?
#
#
# Correct:  1,100
# Predicted:  Spielberg's feature films
# Question:  How many Jews did Schindler save?
#
#
# Correct:  2005
# Predicted:  Jaws
# Question:  When was Spielberg added to the Science Fiction Hall of Fame?
#
#
# Correct:  intrusive
# Predicted:  collaborated
# Question:  How does Spielberg feel about cutscenes in games?
#
#
# Correct:  paramount and dreamworks
# Predicted:  Minority Report
# Question:  Which studios produced Spielberg's 'War of the Worlds'?
#
#
# Correct:  1993
# Predicted:  an alien during childhood
# Question:  When did Jurassic Park come out?
#
#
# Correct:  1984
# Predicted:  though it is the darkest and
# Question:  When did 'Temple of Doom' debut?
#
#
# Correct:  world war ii
# Predicted:  the Coen brothers
# Question:  What war was 'Saving Private Ryan' about?
#
#
# Correct:  $ 200 million
# Predicted:  over-runs
# Question:  What was the budget for 'Robopocalypse'?
#
#
# Correct:  # 9
# Predicted:  and was the biggest film of the year at the North American box office
# Question:  Where did the American Film Institute rank 'Schindler's List' in 1997?
#
#
# Correct:  1989
# Predicted:  a movie-making simulation game
# Question:  When was Spielberg's merit badge launched?
#
#
# Correct:  1979
# Predicted:  the most autobiographical aspect of Spielberg 's films
# Question:  When did Spielberg and Irving initially break up?
#
#
# Correct:  the 1930s
# Predicted:  the film audience
# Question:  Until the 1980s, when had an American film last been shot in Shanghai?
#
#
# Correct:  geoff zanelli
# Predicted:  six other Academy Awards nominations
# Question:  Who wrote the music for 'Into the West'?
#
#
# Correct:  dilys powell
# Predicted:  the dramatic genre
# Question:  Which British critic praised 'Duel'?
#
#
# Correct:  life scout
# Predicted:  its cost
# Question:  What was Indy's rank in Boy Scouts when shown in a movie?
#
#
# Correct:  anti-semitic
# Predicted:  younger audiences
# Question:  What kind of prejudice did Spielberg have to deal with in High school?
#
#
# Correct:  his father
# Predicted:  violent invaders
# Question:  Who did Spielberg get money from to film Close Encounters?
#
#
# Correct:  dilys powell
# Predicted:  Best Picture
# Question:  What British critic helped boost Steven Spielberg's career?
#
#
# Correct:  his father
# Predicted:  knowledge
# Question:  Which of Spielberg's parents liked sci-fi?
#
#
# Correct:  1984
# Predicted:  1990 's Back to the Future Part III
# Question:  When did Spielberg and Irving get back together?
#
#
# Correct:  15–20 years
# Predicted:  challenge
# Question:  How far in the future was 'Robopocalypse' set?
#
#
# Correct:  two
# Predicted:  Best Picture
# Question:  How many Emmys did 'Into the West' win?
# Correct:  brussels , belgium
# Predicted:  the Indiana Jones films
# Question:  Where did Adventures of Tintin debut?
#
#
# Correct:  co-producer
# Predicted:  Winfrey
# Question:  What was Spielberg's role on 'Batteries Not Included'?
#
#
# Correct:  five
# Predicted:  the first Monkey Island games
# Question:  How many Oscar nominations did 'Munich' get?
#
#
# Correct:  26-minute
# Predicted:  Broadway
# Question:  How long was 'Amblin'?
#
#
# Correct:  paramount pictures
# Predicted:  the editing department
# Question:  Which studio produced 'Super 8'?
#
#
# Correct:  actress
# Predicted:  their relationship
# Question:  What was Spielberg's future wife's career?
#
#
# Correct:  four
# Predicted:  a major Hollywood studio
# Question:  How many TV movies was Spielberg signed to direct?
#
#
# Correct:  allen daviau
# Predicted:  the Third Kind
# Question:  Which childhood friend worked on Spielberg's films?
#
#
# Correct:  brian de palma
# Predicted:  the film
# Question:  Who introduced Irving to Spielberg?
#
#
# Correct:  sean connery
# Predicted:  the Indiana Jones series
# Question:  Who played Indiana Jones's father?
#
#
# Correct:  seven-year
# Predicted:  film
# Question:  How long of a contract did Sheinberg give Spielberg?
#
#
# Correct:  1989
# Predicted:  cast in his Star Wars films as Han Solo
# Question:  When did the 3rd Indiana Jones film come out?
#
#
# Correct:  cinematography
# Predicted:  an existing working relationship
# Question:  What Boy Scout merit badge did Spielberg help develop?
#
#
# Correct:  e.t . the extra-terrestrial
# Predicted:  the Third Kind
# Question:  Which film did Kathleen Kennedy first work with Spielberg on?
#
#
# Correct:  may
# Predicted:  Lincoln's life
# Question:  In what month is Cannes held?
#
#
# Correct:  schindler 's list
# Predicted:  a Best Director nomination
# Question:  What did Spielberg first win Best Director for?
#
#
# Correct:  october 16 , 2015
# Predicted:  Lincoln
# Question:  When was 'Bridge of Spies' released?
#
#
# Correct:  sally field
# Predicted:  Close Encounters
# Question:  Who played Mary Todd Lincoln in 'Lincoln'?
#
#
# Correct:  four
# Predicted:  Terra Nova
# Question:  How many TV films did Universal sign Spielbergo to direct?
#
#
# Correct:  poorly
# Predicted:  used
# Question:  How did Steven Spielberg's film "The Sugarland Express" do in the box office?
#
#
# Correct:  the last gunfight
# Predicted:  *batteries
# Question:  What film did Spielberg make to earn a merit badge?
#
#
# Correct:  1996
# Predicted:  given the opportunity to make a short film for theatrical release
# Question:  When was The Neverhood released?
#
#
# Correct:  john williams
# Predicted:  the water
# Question:  What composer has Steven Spielberg been associated with since 1974?
#
#
# Correct:  pg
# Predicted:  Best Picture
# Question:  What rating did 'Temple of Doom' receive?
#
#
# Correct:  july 1 , 2016
# Predicted:  July
# Question:  When will 'The BFG' be in most theaters?
#
#
# Correct:  jacques chirac
# Predicted:  his future projects
# Question:  Who made Spielberg a knight?
#
#
# Correct:  frank
# Predicted:
# Question:  Who is naive in 'Catch Me if You Can'?
#
#
# Correct:  pong
# Predicted:  Boom Blox Bash Party
# Question:  What was the first video game Spielberg played?
#
#
# Correct:  1980
# Predicted:  close friends
# Question:  When did Spielberg re-release Close Encounters?
#
#
# Correct:  six
# Predicted:  genres
# Question:  How many Oscar nominations did 'Bridge of Spies' get?
#
#
# Correct:  roald dahl
# Predicted:  Peter Jackson
# Question:  Who wrote 'The BFG'?
#
#
# Correct:  close encounters
# Predicted:  the Third Kind
# Question:  Which film did Kahn first work with Spielberg on?
#
#
# Correct:  ukraine
# Predicted:  the player
# Question:  Where did Spielberg's paternal grandparents immigrate from?
#
#
# Correct:  1982
# Predicted:  announced in 2014
# Question:  When did the 'War Horse' book come out?
#
#
# Correct:  reportedly close friends
# Predicted:
# Question:  What was the relatioship between Joan Crawford and Steven Spielberg?
#
#
# Correct:  terrorism
# Predicted:  E.T.
# Question:  What issue did Spielberg address in his movie Munich?
#
#
# Correct:  cincinnati , ohio
# Predicted:  a co-producer of the 1987 film *batteries not included
# Question:  Where was Steven Spielberg born?
#
#
# Correct:  tnt
# Predicted:  the TNT network
# Question:  Which channel aired 'Falling Skies'?
#
#
# Correct:  martin landau
# Predicted:  the shows
# Question:  Who starred in the TV show "Savage"?
#
#
# Correct:  october 22 , 2011
# Predicted:  the Indiana Jones films
# Question:  When did Adventures of Tintin debut?
#
#
# Correct:  1981
# Predicted:  Night Gallery
# Question:  When did the first Indiana Jones movie come out?
#
#
# Correct:  november 1985
# Predicted:  in 2005
# Question:  When did Spielberg and Irving marry?
#
#
# Correct:  munich
# Predicted:  several recurring themes
# Question:  In what film did Spielberg address terrorism?
#
#
# Correct:  frank abagnale
# Predicted:  his children
# Question:  Whose parents divorced in 'Catch Me If You Can'?
#
#
# Correct:  peterbilt 281 tanker
# Predicted:  the Third Kind
# Question:  What kind of truck was 'Duel' about?
#
#
# Correct:  armageddon
# Predicted:  that end scene
# Question:  Which film beat 'Saving Private Ryan' worldwide?
#
#
# Correct:  editing
# Predicted:  his direction
# Question:  What department did Spielberg have an unpaid internship with?
#
#
# Correct:  amblin
# Predicted:  the Third Kind
# Question:  Which film did Daviau first work with Spielberg on?
#
#
# Correct:  harrison ford
# Predicted:  the Indiana Jones films
# Question:  Who played Indiana Jones?
#
#
# Correct:  john williams
# Predicted:
# Question:  Who composes music for most of Spielberg's movies?
#
#
# Correct:  amistad
# Predicted:  Best Picture
# Question:  In what film did Spielberg cover the slave trade?
#
#
# Correct:  impressed
# Predicted:  earned
# Question:  How did Sidney Sheinberg feel about the film "Amblin'"
#
#
# Correct:  italy
# Predicted:  baptized by a family servant and then kidnapped from his family by the Papal States
# Question:  Where does 'The Kidnapping of Edgardo Mortara' take place?
#
#
# Correct:  daniel day-lewis
# Predicted:  the Coen brothers
# Question:  Who starred in 'Lincoln' as Abraham Lincoln?
#
#
# Correct:  2005
# Predicted:  acclaimed 2005 TV miniseries Into the West which won two Emmy awards
# Question:  When did 'Into the West' air?
#
#
# Correct:  exceeds $ 9 billion
# Predicted:  Steven Spielberg's Director's Chair
# Question:  How much money has all of Steven Spielberg's movies grossed worldwide?
#
#
# Correct:  universal studios
# Predicted:  a movie-making simulation game
# Question:  What job was SPielberg offered when he was a student?
#
#
# Correct:  two
# Predicted:  the Game
# Question:  How many bloody noses did Spielberg get in High School?
#
#
# Correct:  schindler 's list
# Predicted:  several recurring themes
# Question:  In what film did Spielberg address humanistic issues?
#
#
# Correct:  the holy grail
# Predicted:  RCA
# Question:  What artifact did Indy's father focus on?
#
#
# Correct:  martin landau
# Predicted:  Mary Todd Lincoln
# Question:  Who starred in 'Savage'/
#
#
# Correct:  february 2009
# Predicted:  given the opportunity to make a short film for theatrical release
# Question:  When did the Visual Effects Society give Spielberg a Lifetime Achievement Award?
#
#
# Correct:  1989
# Predicted:  a co-producer of the 1987 film *batteries not included
# Question:  When did Spielberg and Irving divorce?
#
#
# Correct:  1974
# Predicted:  an action game and an award winning puzzle game for the Wii called Boom Blox
# Question:  When did Spielberg first play a video game?
#
#
# Correct:  fox
# Predicted:  prehistoric times
# Question:  Which channel aired 'Terra Nova'?
#
#
# Correct:  three
# Predicted:  Best Picture
# Question:  How many Academy Awards did 'Jaws' win?
#
#
# Correct:  eleven
# Predicted:  Best Picture
# Question:  How many Oscar nominations did 'The Color Purple' get?
#
#
# Correct:  england
# Predicted:  entered it into his Great Films archive
# Question:  Where was 'War Horse' filmed?
#
#
# Correct:  science fiction
# Predicted:  the original 1953 film
# Question:  What genre was Steven Spielberg's episode of "The Name of the Game"?
#
#
# Correct:  tom hanks
# Predicted:  *batteries
# Question:  Who narrated a short Spielberg bio at the Kennedy Center?
#
#
# Correct:  robert zemeckis
# Predicted:
# Question:  Who did Spielberg collaborate with in 2006?
#
#
# Correct:  actress
# Predicted:  Eastwood
# Question:  What was Amy Irving's career?
#
#
# Correct:  disney
# Predicted:  Broadway
# Question:  Who distributed 'War Horse'?
# Correct:  oskar schindler
# Predicted:  the Normandy landing
# Question:  Whose life was 'Schindler's List' based on?
#
#
# Correct:  jaws
# Predicted:  the Third Kind
# Question:  What movie was Spielberg working on when he first played Pong?
#
#
# Correct:  two
# Predicted:  his direction
# Question:  How many Oscars did Close Encounters win?
#
#
# Correct:  richmond , virginia
# Predicted:  never worked with the same screenwriter in his films
# Question:  Where was 'Lincoln' filmed?
#
#
# Correct:  1975
# Predicted:  the water scenes in Jaws are filmed from the low-angle perspective of someone swimming
# Question:  When was Jaws released?
#
#
# Correct:  `` bachelor funky ''
# Predicted:  a movie-making simulation game
# Question:  How did Irving describe Spielberg's house?
#
#
# Correct:  firelight
# Predicted:  an actress
# Question:  What film led to Close Encounters?
#
#
# Correct:  capt . miller
# Predicted:  that end scene
# Question:  Who did Tom Hanks play in 'Saving Private Ryan'?
#
#
# Correct:  halo
# Predicted:  Martin Landau
# Question:  What video game did Spielberg say in 2013 he's working on a TV show based on?
#
#
# Correct:  columbia pictures
# Predicted:  close friends
# Question:  Which studio funded Close Encounters?
#
#
# Correct:  phoenix , arizona
# Predicted:  shown divided is often resolved in the ending as well shown divided is often resolved in the ending as well
# Question:  Where did Steven Spielberg's family move to in 1953?
#
#
# Correct:  two
# Predicted:  the Game
# Question:  How many bloody noses did Spielberg get in high school?
#
#
# Correct:  1994
# Predicted:  violent invaders
# Question:  When did Spielberg buy Orson Welles' personal script copy from 'The War of the Worlds'?
#
#
# Correct:  arthur golden
# Predicted:  Amblin
# Question:  Who wrote the book 'Memoirs of a Geisha' is based on?
#
#
# Correct:  sidney sheinberg
# Predicted:  TV productions
# Question:  Who offered Spielberg a contract at Universal Studios?
#
#
# Correct:  1969
# Predicted:  Spielberg's directing trademarks
# Question:  What year was Spielberg hired to direct one of the segments for "Night Gallery"?
#
#
# Correct:  1953
# Predicted:  as the first to win for a performance directed by Spielberg
# Question:  When was the first 'War of the Worlds' movie released?
#
#
# Correct:  2054
# Predicted:  the 225 reviews
# Question:  When is Minority Report set?
#
#
# Correct:  1938
# Predicted:  as a performance of the finale to Leonard Bernstein 's Candide
# Question:  When was 'The War of the Worlds' radio broadcast?
#
#
# Correct:  $ 250 million
# Predicted:  substantial box office revenues
# Question:  How much did 'The Pacific' cost?
#
#
# Correct:  peter benchley
# Predicted:  Close Encounters
# Question:  Who wrote the 'Jaws' book?
#
#
# Correct:  2014
# Predicted:  the Game
# Question:  When was Spielberg named the 'most influential celebrity in America'?
#
#
# Correct:  george jonas
# Predicted:  Broadway
# Question:  Who wrote 'Vengeance'?
#
#
# Correct:  david kertzer
# Predicted:  the Moon
# Question:  Who wrote 'The Kidnapping of Edgardo Mortara'?
#
#
# Correct:  2149
# Predicted:  the Golden Globe Awards
# Question:  In what year does 'Terra Nova' begin?
#
#
# Correct:  $ 500
# Predicted:  an actress
# Question:  How much money did Spielberg spend to film Close Encounters?
#
#
# Correct:  during childhood
# Predicted:  Jaws
# Question:  When in his life did Spielberg 'feel like an alien'?
#
#
# Correct:  daniel h. wilson
# Predicted:  Pope Pius IX
# Question:  Who wrote the book 'Robopocalypse' is based on?
#
#
# Correct:  anti-semitic prejudice
# Predicted:  his direction
# Question:  What was Spielberg bullied because of?
#
#
# Correct:  vengeance
# Predicted:  Lincoln's life
# Question:  What book was 'Munich' based on?
#
#
# Correct:  h. g. wells
# Predicted:  his films
# Question:  Who wrote the 'War of the Worlds' book?
#
#
# Correct:  jonathan nolan
# Predicted:  six other Academy Awards nominations
# Question:  Who wrote the 'Interstellar' script?
#
#
# Correct:  john anderton
# Predicted:  the Moon
# Question:  Whose son disappeared in 'Minority Report'?
#
#
# Correct:  six
# Predicted:  actor Richard Dreyfuss
# Question:  How many Oscars did Close Encounters get nominated for, besides Best Director?
#
#
# Correct:  alice walker
# Predicted:  the Moon
# Question:  Who wrote 'The Color Purple'?
#
#
# Correct:  1999
# Predicted:  given the opportunity to make a short film for theatrical release
# Question:  When was Boombots released?
#
#
# Correct:  cannes film festival
# Predicted:  the Indiana Jones films
# Question:  What film festival will first air 'The BFG'?
#
#
# Correct:  2018
# Predicted:  December
# Question:  When is 'Ready Player One' planned to be released?
#
#
# Correct:  starbright foundation
# Predicted:  his direction
# Question:  What charity did Spielberg's 'Lego Moviemaker' kit fund?
#
#
# Correct:  kennedy center
# Predicted:  in 2005
# Question:  Where was Spielberg honored on Dec 3, 2006?
#
#
# Correct:  minority report
# Predicted:  Jaws
# Question:  What movie did Spielberg collaborate with Cruise for?
#
#
# Correct:  three
# Predicted:  hit
# Question:  How many Academy Awards did the film "Jaws" win?
#
#
# Correct:  harrison ford
# Predicted:  Broadway
# Question:  Who played Han Solo?
#
#
# Correct:  j. g. ballard
# Predicted:  Peter Jackson
# Question:  Who wrote 'Empire of the Sun'?
#
#
# Correct:  $ 470 million worldwide
# Predicted:  substantial box office revenues
# Question:  How much money did the film "Jaws" gross worldwide?
#
#
# Correct:  michael bay
# Predicted:  the Last Crusade
# Question:  Who directed 'Armageddon'?
#
#
# Correct:  tim burton
# Predicted:  the Last Crusade
# Question:  Who directed 'Batman'?
#
#
# Correct:  melissa mathison
# Predicted:  six other Academy Awards nominations
# Question:  Who wrote E.T.'s script?
#
#
# Correct:  92 %
# Predicted:  the MPAA
# Question:  What was the Rotten Tomatoes rating for Minority Report?
#
#
# Correct:  mark rylance
# Predicted:  Broadway
# Question:  Who plays Pope Pius IX in 'The Kidnapping of Edgardo Mortara'?
#
#
# Correct:  85 million years
# Predicted:  Universal Studios
# Question:  How far back in time do people in 'Terra Nova' travel?
#
#
# Correct:  western
# Predicted:  mixed reviews
# Question:  What genre was Spielberg's first film "The Last Gunfight"
#
#
# Correct:  embarrassed
# Predicted:  criticized
# Question:  How did Steven Spielberg feel about being an Orhtodox Jew?
#
#
# Correct:  indiana jones
# Predicted:  the horizon
# Question:  Which major Spielberg movie character was a Boy Scout?
#
#
# Correct:  2010
# Predicted:  Lincoln
# Question:  When was 'The Pacific' released?
#
#
# Correct:  august 2000
# Predicted:  Heaven
# Question:  When did Spielberg give an interview saying he had 'felt like an alien'?
#
#
# Correct:  april 25 , 2014
# Predicted:  IMAX
# Question:  When was 'Robopocalypse' scheduled for release?
#
#
# Correct:  paul rugg
# Predicted:  six other Academy Awards nominations
# Question:  Who wrote the script for 'Someone's in the Kitchen'?
#
#
# Correct:  gremlins
# Predicted:  a media sensation
# Question:  What movie caused 'PG-13' to be created?
#
#
# Correct:  andrew sarris
# Predicted:  Jurassic Park
# Question:  Who thought 'Empire of the Sun' was the best film of the year?
#
#
# Correct:  2009
# Predicted:  a seven-year directing contract
# Question:  When did Spielberg win the Cecil B. DeMille Award?
#
#
# Correct:  three
# Predicted:  a movie-making simulation game
# Question:  How many times did Spielberg work with Richard Dreyfus?
#
#
# Correct:  thirteen
# Predicted:  history
# Question:  At what age did Spielberg make 'Escape to Nowhere'?
#
#
# Correct:  orthodox jewish
# Predicted:  his son
# Question:  What religion was Spielberg's family?
#
#
# Correct:  40-minute
# Predicted:  Clive Barker's Undying
# Question:  How long was Spielberg's film "Escape to Nowhere"?
#
#
# Correct:  ukraine
# Predicted:  the most autobiographical aspect of Spielberg 's films
# Question:  Where were Steven Spielberg's granparents from?
#
#
# Correct:  1858
# Predicted:  baptized by a family servant and then kidnapped from his family by the Papal States
# Question:  When does 'The Kidnapping of Edgardo Mortara' take place?
#
#
# Correct:  2001
# Predicted:  met actress Amy Irving in 1976 at the suggestion of director Brian De Palma
# Question:  When did a Close Encounters DVD come out?
#
#
# Correct:  2002
# Predicted:  December
# Question:  When was Minority Report released?
#
#
# Correct:  orthodox jewish
# Predicted:  RCA
# Question:  What religion was Steven Spielberg's family?
#
#
# Correct:  firelight
# Predicted:  six other Academy Awards nominations
# Question:  What was Spielberg's first indepenent film?
# Correct:  june 2006
# Predicted:  as the first to win for a performance directed by Spielberg
# Question:  When did Spielberg announce what would become 'Interstellar'?
#
#
# Correct:  47 %
# Predicted:  enough money
# Question:  How much of the US believes Spielberg is influential?
#
#
# Correct:  cincinnati , ohio
# Predicted:  the film
# Question:  Where was Spielberg born?
#
#
# Correct:  best picture
# Predicted:  Best Picture
# Question:  What was the film "Jaws" nominated for?
#
#
# Correct:  john williams
# Predicted:  the film audience
# Question:  Who composed music for 'Munich'?
#
#
# Correct:  salt lake city
# Predicted:  the player
# Question:  Where was Spielberg an Olympic flagbearer?
#
#
# Correct:  electrical engineer
# Predicted:  often fathers
# Question:  What job did Steven Spielberg's father have?
#
#
# Correct:  joan crawford
# Predicted:  Universal
# Question:  Who starred in the TV show segment "Eyes"
#
#
# Correct:  john williams
# Predicted:  Jaws
# Question:  Who has composed most of Steven Spielberg's movies?
#
#
# Correct:  the holocaust
# Predicted:  the Century
# Question:  What issue did Spielberg address in his movie Schindler's List?
#
#
# Correct:  schindler 's list
# Predicted:  Best Picture
# Question:  Which film did Kaminski first work with Spielberg on?
#
#
# Correct:  a headteacher
# Predicted:  the first Monkey Island games
# Question:  Who was Ford going to play in E.T., until the scene was removed?
#
#
# Correct:  christopher nolan
# Predicted:  Universal
# Question:  Who took over directing 'Interstellar'?
#
#
# Correct:  as a child
# Predicted:  to his work on these series
# Question:  When did Steven Spielberg have trouble dealing with being an Orthodox Jew?
#
#
# Correct:  the dig
# Predicted:  divorced parents
# Question:  What video game did Spielberg come up with the concept for?
#
#
# Correct:  december 25 , 2011
# Predicted:  an alien during childhood
# Question:  When did 'War Horse' come out?
#
#
# Correct:  1941
# Predicted:  IMAX
# Question:  When was Citizen Kane released?
#
#
# Correct:  michael morpurgo
# Predicted:  a film
# Question:  Who wrote the 'War Horse' book?
#
#
# Correct:  caltech
# Predicted:  the visual effects
# Question:  What university provided scientific consultation for 'Interstellar'?
#
#
# Correct:  guns
# Predicted:  the guns
# Question:  What is being lead to specialty roles?
#
#
# Correct:  1950s
# Predicted:  this formerly front-line weapon is currently being replaced by new missile systems being replaced by new missile systems
# Question:  When were the surface-to-air missile systems introduced?
#
#
# Correct:  anti-aircraft artillery
# Predicted:  London
# Question:  What was placed on the blockhouses by the Germans?
#
#
# Correct:  rocket-propelled grenades
# Predicted:  the smallest mounts
# Question:  What type of weapon can be used against hovering helicopters?
#
#
# Correct:  the railgun
# Predicted:  increasing in size
# Question:  Where can the future of projectile based weapons possibly be found?
#
#
# Correct:  machine guns
# Predicted:  training
# Question:  What was used in AA mountings on both land and water?
#
#
# Correct:  the late 1960s
# Predicted:  the new Sea Wolf short range systems
# Question:  When were interceptors like the F-106 Delta Dart not being built anymore?
#
#
# Correct:  mechanical
# Predicted:  rocket
# Question:  What kind of fuses were needed?
#
#
# Correct:  self-propelled anti-aircraft guns
# Predicted:  Vergeltungswaffe
# Question:  What does SPAAG stand for?
#
#
# Correct:  1918
# Predicted:  Malta
# Question:  When was the successful test of the 3.6-inch HAA gun?
#
#
# Correct:  90 km away
# Predicted:  their targets
# Question:  How far away can the S-400 detect a target?
#
#
# Correct:  gotha g.v bombers
# Predicted:  the United States Air Force's CIM-10 Bomarc
# Question:  In addition to Zeppelins, what attacked London for four years with air attacks?
#
#
# Correct:  bofors of sweden
# Predicted:  at least 150 mm
# Question:  Who designed the 40 mm autocannon?
#
#
# Correct:  air defence
# Predicted:  John M. Browning
# Question:  What do armies tend to have in depth?
#
#
# Correct:  air defence
# Predicted:  the United States Air Force's CIM-10 Bomarc
# Question:  What was one of the quickest areas to evolve in military technology in the 20th century?
#
#
# Correct:  aim-off
# Predicted:  various other methods
# Question:  Deflection settings were also called what?
#
#
# Correct:  non-ballistic factors
# Predicted:  light, medium, and even early heavy tanks
# Question:  What affected the effective ceiling for heavy AA guns?
#
#
# Correct:  for anti-aircraft fire
# Predicted:  airfields
# Question:  Why was Britain mainly interested in solid fuel rockets?
#
#
# Correct:  3-inch
# Predicted:  Further research
# Question:  What size rocket was being developed at the end of the war?
#
#
# Correct:  aimed fire
# Predicted:  locating
# Question:  What was the primary method for HAA fire?
#
#
# Correct:  nato
# Predicted:  based air defences
# Question:  What agency stated that the arrangements were an air defence ground environment?
#
#
# Correct:  zeppelins
# Predicted:  sights
# Question:  What were hydrogen filled balloons called?
#
#
# Correct:  mauser-werke
# Predicted:  a 3.7 cm
# Question:  Which company redesigned the rapid fire 2 cm FlaK 30?
#
#
# Correct:  the backblast
# Predicted:  NATO
# Question:  An RPG fired at a steep angle has what reflecting off the ground?
#
#
# Correct:  1925
# Predicted:  a separate arm
# Question:  When was the Observer Corps formed?
#
#
# Correct:  183
# Predicted:  12 AA divisions
# Question:  How many AA Sections were defending Britain by December 1916?
#
#
# Correct:  americans
# Predicted:  John M. Browning
# Question:  Who started making an unlicensed version of the 40mm at the beginning of the war?
#
#
# Correct:  hochbunker `` high bunkers ''
# Predicted:  their target
# Question:  What were the large blockhouses called that the Germans developed?
#
#
# Correct:  dedicated weapons
# Predicted:  a Royal Air Force command
# Question:  The goal of what is to suppress opposing air defence systems?
#
#
# Correct:  four
# Predicted:  viable weapons systems
# Question:  How many of the M2HB guns were mounted together on the M45 Quadmount weapons system?
#
#
# Correct:  solid fuel rockets
# Predicted:  hostile aircraft
# Question:  What was under development in both the Soviet Union and Britain in the 1930s?
#
#
# Correct:  homeland defence
# Predicted:  its height
# Question:  What is the primary effort been for most countries when it comes to anti-aircraft warfare?
#
#
# Correct:  spain
# Predicted:  enough at close targets and at close targets and
# Question:  Where was the first place the FlaK 36 was used?
#
#
# Correct:  britain
# ...
#
#
# Correct:  405-line system
# Predicted:  second
# Question:  Which system used interlaced scanning to correct the flicker problem of the 240-line?
#
#
# Correct:  free-to-air
# Predicted:  the traditional Vienna New Year's Concert
# Question:  How much did viewers have to pay for the HD1 channel?
#
#
# Correct:  25 frame/s
# Predicted:  the common 1.85 widescreen cinema format
# Question:  To be shown on SDTV in PAL-system countries, at what rate is cinema film scanned?
# Correct:  progressive-scan
# Predicted:  NBC owned and operated station WRC-TV
# Question:  Most computer monitors operate in what mode?
#
#
# Correct:  pal-m
# Predicted:  resolution
# Question:  In addition to the NTSC system, what 525-line system is considered a standard definition television system?
#
#
# Correct:  185 million
# Predicted:  SES's Astra 1H satellite
# Question:  According to the 2010 Satellite Monitor market survey, how many HD capable TV's were sold in Europe?
#
#
# Correct:  euro1080
# Predicted:  kick-start HDTV interest
# Question:  Which European company launched HD1?
#
#
# Correct:  japan
# Predicted:  satellite
# Question:  Which country had successful public analog HDTV broadcasting?
#
#
# Correct:  two
# Predicted:  the newer and more efficient H.264/MPEG-4 AVC compression standards
# Question:  How many frame/field rates were primarily being used in 1983?
#
#
# Correct:  seven
# Predicted:  these files
# Question:  How many broadcasters did Japan have sharing a single channel?
#
#
# Correct:  analog hd
# Predicted:  a broadcast high definition program
# Question:  W-VHS recorders are capable of recording what kinds of signals?
#
#
# Correct:  standard-definition television
# Predicted:  regular DVD
# Question:  What does SDTV stand for?
#
#
# Correct:  dvb
# Predicted:  the monochrome 625 line broadcasts
# Question:  Who created the standard for DVB-2, DVB-C, and DVB-T?
#
#
# Correct:  1440×1152 hdmac
# Predicted:  ITU-R BT.709
# Question:  What scan format is also included in MBAFF?
#
#
# Correct:  etsi
# Predicted:  30/60 Hz
# Question:  Who standardizes HDTV specifications?
#
#
# Correct:  over four times
# Predicted:  context
# Question:  How much more bandwith was required from early HDTV commercial experiments than an SD broadcast?
#
#
# Correct:  2008
# Predicted:  be used to transmit video using the newer and more efficient H.264/MPEG-4 AVC compression standards
# Question:  When was the Hauppauge 1212 Personal Video Recorder introduced?
#
#
# Correct:  1080i format
# Predicted:  several US SMPTE standards
# Question:  What format did the first European HDTV broadcast use?
#
#
# Correct:  september 2003
# Predicted:  the uncompressed source
# Question:  When did test transmissions of HDTV begin in Europe?
#
#
# Correct:  october 2012
# Predicted:  apply only to analogue standard definition television
# Question:  When was the digital switchover process completed in the UK?
#
#
# Correct:  muse
# Predicted:  its 25 Hz frame rate
# Question:  Which system was demonstrated in the US for the first time in 1981?
#
#
# Correct:  about twice
# Predicted:  the secondary market
# Question:  Efforts were made to reduce analog HDTV to how much of the bandwith of SDTV?
#
#
# Correct:  december 2009
# Predicted:  broadcasting
# Question:  When did the UK deploy HD content using the new DVB-T2 transmission standard?
#
#
# Correct:  bandwidth
# Predicted:  the uncompressed source
# Question:  A very high resolution source may require more of what?
#
#
# Correct:  1936
# Predicted:  720p resolution
# Question:  The term "high definition" originally described televisions systems from what year?
#
#
# Correct:  8-bit rgb channels
# Predicted:  GoogleTV Roku boxes and AppleTV or built into `` Smart Televisions ''
# Question:  When transmitted over the internet, colors are typically to what?
#
#
# Correct:  3:2 pulldown
# Predicted:  the source
# Question:  The technique in which with successive pair of film frames, one is held for three video fields, and the next is held for two, is called what?
#
#
# Correct:  27 %
# Predicted:  their heritage systems
# Question:  What percentage of European digital satellite TV homes were watching HD broadcasts in 2010?
#
#
# Correct:  widescreen cinema
# Predicted:  the effective image resolution
# Question:  What was a leading factor in the 16:9 aspect ratio being chosen?
#
#
# Correct:  £60 million
# Predicted:  many years
# Question:  How many pounds were spent in Europe on HD capable TVs in 2010?
#
#
# Correct:  expensive and scarce
# Predicted:  normal television
# Question:  In the secondary market, analog tape recorders are considered what?
#
#
# Correct:  qam
# Predicted:  a CableCARD
# Question:  What kind of built-in tuner will allow a cable-ready TV to display HD content without an external box?
#
#
# Correct:  technical and economic
# Predicted:  SES's Astra 1H satellite
# Question:  What constraints kept HDTV from being widely adopted in the 90's?
#
#
# Correct:  5:3
# Predicted:  Kingswood Warren
# Question:  What was the aspect ratio of the NHK Color?
#
#
# Correct:  525
# Predicted:  standardized algorithms
# Question:  How many lines of resolution did the US NTSC color system have in 1953?
#
#
# Correct:  blu-ray
# Predicted:  the first French TV channel
# Question:  1080i, 1080p, and 720p are often used on what kind of disc.
#
#
# Correct:  ntsc
# Predicted:  standard definition television systems
# Question:  What was the existing system at the time?
#
#
# Correct:  dvb-s2
# Predicted:  1080i/1125 lines
# Question:  What signal did Euro1080 later change to?
#
#
# Correct:  analogue standard
# Predicted:  notation
# Question:  PAL, SECAM, and NTSC frame rates apply to what definition televisions?
#
#
# Correct:  mpeg-2
# Predicted:  most sets
# Question:  Which standard were ATSC and DVB based on?
#
#
# Correct:  the scanning system
# Predicted:  SES's Astra 1H satellite
# Question:  When a parameter is dropped, the remaining numeric parameter is specified first, followed by what?
#
#
# Correct:  us smpte standards
# Predicted:  several US SMPTE standards
# Question:  What were 1920x1080i and 1280x720p defined by?
#
#
# Correct:  10
# Predicted:  many years
# Question:  How many HD channels did the Freeview HD service contain as of December 2013?
#
#
# Correct:  region by region
# Predicted:  demand
# Question:  How was the Freeview HD service rolled out in the UK?
#
#
# Correct:  the frame rate
# Predicted:  Astra satellites
# Question:  What is usually dropped for the commercial naming of an HDTV product?
#
#
# Correct:  dvb-s
# Predicted:  subsequent broadcast channels
# Question:  What signal did the first European HDTV broadcast use?
#
#
# Correct:  the united kingdom
# Predicted:  the newer and more efficient H.264/MPEG-4 AVC compression standards
# Question:  Which European country first deployed HD content using the new DVB-T2 standard?
#
#
# Correct:  16:9
# Predicted:  the 405-line system
# Question:  HDTV handles what aspect ratio without using letterboxing or anamorphic stretching?
#
#
# Correct:  20 million
# Predicted:  several US SMPTE standards
# Question:  According to the 2010 Satellite Monitor market survey, how many European households were watching HD broadcasts?
#
#
# Correct:  the fcc
# Predicted:  the newer and more efficient H.264/MPEG-4 AVC compression standards
# Question:  Who rejected systems such as MUSE as the new standard for the US?
#
#
# Correct:  a research project
# Predicted:  the newer and more efficient H.264/MPEG-4 AVC compression standards
# Question:  In the end what was the Soviet Union's Transformator system used for?
#
#
# Correct:  625
# Predicted:  subsequent broadcast channels
# Question:  How many lines of resolution were the European monochrome broadcasts?
#
#
# Correct:  atsc
# Predicted:  HDTV
# Question:  In the US, what kind of tuner is needed for residents to receive free, over the air programming?
#
#
# Correct:  analog tape
# Predicted:  Astra satellites
# Question:  What kind of recorder is no longer produced for the consumer market?
#
#
# Correct:  by satellite
# Predicted:  normal television
# Question:  Despite the reduced bandwith, HDTV format still had to be distributed how?
#
#
# Correct:  november 25 , 1994
# Predicted:  the 240-line system which was progressive described at the time by the technically correct term `` sequential ''
# Question:  When did regular broadcasting of BS-9ch start?
#
#
# Correct:  monochrome only
# Predicted:  1,080 progressively scanned lines
# Question:  Was France's 819 line system in color?
#
#
# Correct:  25/50 hz
# Predicted:  a speedup
# Question:  In former PAL and SECAM countries, what frame rate does HDTV operate at?
#
#
# Correct:  twice
# Predicted:  their signals
# Question:  At least how many times more linear resolution does HDTV have over SDTV?
#
#
# Correct:  1953 ,
# Predicted:  60 Hz refresh rate
# Question:  What year did color broadcasts start in the US?
#
#
# Correct:  july 23 , 1996
# Predicted:  visiting a demonstration of MUSE in Washington
# Question:  When did the first public HDTV broadcast happen in the US?
# Correct:  1989
# Predicted:  GoogleTV Roku boxes and AppleTV or built into `` Smart Televisions ''
# Question:  When did satellite test broadcasts of Hi-Vision start?
#
#
# Correct:  the soviet union
# Predicted:  military command
# Question:  Who developed Transformator in 1958?
#
#
# Correct:  hd1
# Predicted:  ATSC
# Question:  The New Year's Day broadcast officially launched which channel?
#
#
# Correct:  1979
# Predicted:  the 405-line system
# Question:  In what year did NHK first develop consumer HD television with a 5:3 aspect ratio?
#
#
# Correct:  mbaff
# Predicted:  a USB 2.0 interface
# Question:  Which encoding contains both progressive and interlaced content?
#
#
# Correct:  digital video broadcasting
# Predicted:  standard definition television systems
# Question:  What does DVB stand for?
#
#
# Correct:  1983
# Predicted:  to be inaccurately rechristened 'progressive rechristened 'progressive
# Question:  When was France's 819 line system discontinued?
#
#
# Correct:  8k
# Predicted:  normal television
# Question:  What is the most current HDTV system development?
#
#
# Correct:  20th
# Predicted:  Technology
# Question:  During which entire century were companies and nations trying to achieve true HDTV?
#
#
# Correct:  smpte
# Predicted:  resolution
# Question:  Who tested the four major HDTV systems in the late 1970's?
#
#
# Correct:  high-definition image sources
# Predicted:  both SDTV
# Question:  Terrestrial broadcast and direct broadcast satellite are examples of what?
#
#
# Correct:  2009
# Predicted:  the Belgian company
# Question:  Most television sets sold since what year have an ATSC tuner?
#
#
# Correct:  analog only
# Predicted:  an HDTV-ready HTPC
# Question:  What restriction does W-VHS recordings have?
#
#
# Correct:  720p or 1080i
# Predicted:  the image's characteristics
# Question:  What two formats are typically used to recorde non-cinematic HDTV video intended for broadcast?
#
#
# Correct:  nippon hōsō kyōkai
# Predicted:  commercial and NHK programming
# Question:  What does NHK stand for in Japan?
#
#
# Correct:  5c
# Predicted:  digital HD content
# Question:  Content is now protected by what encryption?
#
#
# Correct:  digital-vhs or data-vhs
# Predicted:
# Question:  What does D-VHS stand for?
#
#
# Correct:  february 1937
# Predicted:  The US NTSC 525-line system
# Question:  When was the Baird system discontinued?
#
#
# Correct:  digital tv group
# Predicted:  digital terrestrial television
# Question:  What does DTG stand for?
#
#
# Correct:  16:9
# Predicted:  the 405-line system
# Question:  What aspect ratio was agreed upon due to the influence of widescreen cinema?
#
#
# Correct:  a resolution
# Predicted:  the source
# Question:  When naming a commercial HDTV product, a frame rate can be specified without what?
#
#
# Correct:  1991
# Predicted:  the 240-line system which was progressive described at the time by the technically correct term `` sequential ''
# Question:  When did regular testing of Hi-Vision start?
#
#
# Correct:  europe
# Predicted:  HDTV
# Question:  The PAL and SECAM were color systems where?
#
#
# Correct:  hd content
# Predicted:  the FCC mandate
# Question:  Without using an external box, cable-ready TVs can display what?
#
#
# Correct:  tulsa
# Predicted:  the state's first permanent major league franchise
# Question:  Where is Cedar Ridge Country Club?
#
#
# Correct:  27th
# Predicted:  the nation
# Question:  How does Oklahoma rank among US states for agriculture?
#
#
# Correct:  $ 3 million
# Predicted:  total education expenditures
# Question:  How much has the Cherokee Preservation Foundation spent on schools?
#
#
# Correct:  bedlam series
# Predicted:  husband Miguel Terekhov
# Question:  What is the rivalry between OSU and University of Oklahoma called?
#
#
# Correct:  77
# Predicted:  sheriff
# Question:  How many counties does Oklahoma have?
#
#
# Correct:  1.7 million
# Predicted:  937,478 residents
# Question:  How many people boarded in Will Rogers World Airport in 2010?
#
#
# Correct:  dallas wings
# Predicted:  one county
# Question:  What was Oklahoma's WNBA team renamed to when it moved?
#
#
# Correct:  roughly one million
# Predicted:  the 2009-10 school year
# Question:  How many people attend the State Fair of Oklahoma each year?
#
#
# Correct:  a day
# Predicted:  Mexico
# Question:  How long did the 1912 tornado outbreak last?
#
#
# Correct:  598
# Predicted:  many years
# Question:  How many incorporated cities are in Oklahoma?
#
#
# Correct:  asgaya gigageyi
# Predicted:  pre-school through eighth grade
# Question:  What is the Cherokee name for Oklahoma?
#
#
# Correct:  six
# Predicted:  two primary newspapers
# Question:  How many states are on the Frontier Strip?
#
#
# Correct:  the sooner state
# Predicted:  the Arts
# Question:  What is Oklahoma's nickname?
#
#
# Correct:  theatre tulsa
# Predicted:  Texas
# Question:  What is the oldest community theater group west of the Mississippi River?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-da578b55f788> in <module>()
#     236     for id, _ in results:
#     237         sent = raw_docs[id]
# --> 238         doc = nlp(sent)
#     239
#     240         # find sentence structure
#
# /anaconda3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in feature_extracter_fwd(docs, drop)
#     335             else:
#     336                 return doc.doc.to_array(attrs)[doc.start:doc.end]
# --> 337         features = [ops.asarray(get_feats(doc), dtype='uint64') for doc in docs]
#     338         def feature_extracter_bwd(d_features, sgd=None):
#     339             return d_features
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in <listcomp>(.0)
#     335             else:
#     336                 return doc.doc.to_array(attrs)[doc.start:doc.end]
# --> 337         features = [ops.asarray(get_feats(doc), dtype='uint64') for doc in docs]
#     338         def feature_extracter_bwd(d_features, sgd=None):
#     339             return d_features
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in get_feats(doc)
#     332         def get_feats(doc):
#     333             if hasattr(doc, 'to_array'):
# --> 334                 return doc.to_array(attrs)
#     335             else:
#     336                 return doc.doc.to_array(attrs)[doc.start:doc.end]
#
# doc.pyx in spacy.tokens.doc.Doc.to_array()
#
# doc.pyx in spacy.tokens.doc.Doc.to_array()
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# KeyboardInterrupt:
