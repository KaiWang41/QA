# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
import re
import csv
from gensim.summarization import bm25

# %% [markdown]
# # Variables

# %%
OPEN_QUESTION_WORDS = ['what','who','whose','whom','where','when','why','how',
                       'which',"what's","who's","where's","how's"]
CLOSED_QUESTION_WORDS = ['is','are','am','was','were','do','does,','did','can',
                         'could','will','would','shall','should','have','has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)

# %%
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)

# %%
def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma

        
def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += 1
    return dfs


def query_vsm(query, index, k=4):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'

# %%
# length of longest same sequences of keywords
def get_overlap(sent1, sent2):
    tokens1 = []
    tokens2 = []

    for token in nltk.word_tokenize(strip_punctuation(sent1.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens1.append(lemma)

    for token in nltk.word_tokenize(strip_punctuation(sent2.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens2.append(lemma)

    max = 0
    for i in range(len(tokens1)):
        for j in range(len(tokens2)):

            if tokens1[i] == tokens2[j]:
                length = 1

                ii = i + 1
                jj = j + 1
                while ii < len(tokens1) and jj < len(tokens2) and \
                        tokens1[ii] == tokens2[jj]:
                    ii += 1
                    jj += 1
                    length += 1

                if length > max:
                    max = length

    return max

# %% [markdown]
# # Write to test file

# %%
csvFile = open("high.csv", "w")
writer = csv.writer(csvFile)
header = ['id','answer']
writer.writerow(header)


case_count = 0
empty_count = 0
# test = [test[17]]
for test_case in test:
    question = test_case['question']
    docid = test_case['docid']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)
    

    # TFIDF
#     doc_term_freqs = {}
#     for (id, raw_doc) in enumerate(raw_docs):
#         term_freqs = extract_term_freqs(raw_doc)
#         doc_term_freqs[id] = term_freqs
#     M = len(doc_term_freqs)

#     doc_freqs = compute_doc_freqs(doc_term_freqs)

#     vsm_inverted_index = defaultdict(list)
#     for docid, term_freqs in doc_term_freqs.items():
#         N = sum(term_freqs.values())
#         length = 0

#         # find tf*idf values and accumulate sum of squares
#         tfidf_values = []
#         for term, count in term_freqs.items():
#             tfidf = float(count) / N * log(M / float(doc_freqs[term]))
#             tfidf_values.append((term, tfidf))
#             length += tfidf ** 2

#         # normalise documents by length and insert into index
#         length = length ** 0.5
#         for term, tfidf in tfidf_values:
#             # inversion of the indexing, term -> (doc_id, score)
#             vsm_inverted_index[term].append([docid, tfidf / length])

#     for term, docids in vsm_inverted_index.items():
#         docids.sort()

#     terms = extract_term_freqs(question) 
#     results = query_vsm(terms, vsm_inverted_index)
    
    
    tokenized_sentence = []
    for each_sentence in raw_docs:
        filter_stop_word = []
        sentence_as_words = nltk.word_tokenize(each_sentence)
        for each_word in sentence_as_words:
            if each_word not in stop:
                filter_stop_word.append(each_word)
        
        tokenized_sentence.append(filter_stop_word)
        
    bm25Model = bm25.BM25(tokenized_sentence)
    average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
    query = []
    for word in nltk.word_tokenize(question):
        if word not in stop:
            query.append(word)
        
    scores = bm25Model.get_scores(query,average_idf)
    bm25_dic = Counter()
    
    sentence_id = 0
    for each_score in scores:
        bm25_dic[sentence_id] = each_score
        sentence_id += 1
    results = bm25_dic.most_common(3)


    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['often']:
            qtype = 'QUANTITY'
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:
        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'
            
        elif 'frequency' in tokens:
            qtype = 'QUANTITY'
            
        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        elif 'name' in tokens:
            qtype = 'NE'

        else:
            # what...do type question
            tokens.remove(next_token)
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC']:
            
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1
                    
        elif qtype == 'NE':
            for ent in doc.ents:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.3 + (scores[id] / max_score * 0.7)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get)
    sent = raw_docs[index]
    doc = nlp(sent)

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if qtype in ['LOC','GPE'] and ent.root.tag_ not in ['NN','NNP','NNS','NNPS']:
                score -= 2
                
            if score > max_score:
                max_score = score
                answer = ent.text
                
                if qtype in ['MONEY']:
                    for token in doc:
                        if token.text == '$':
                            answer = '$ ' + answer
                            
                if qtype in ['PERCENT']:
                    if 'percent' in answer:
                        answer = answer[:answer.index('percent')-1]
                            
                if qtype in ['PERCENT','QUANTITY','CARDINAL','MONEY']:
                    tokens = nltk.word_tokenize(answer)
                    i = 0
                    answer = ''
                    while i < len(tokens):
                        if tokens[i].lower() in ['well','about','around','approximately', 'some','least','close to','than','high as','least']:
                            del tokens[i]
                        else:
                            if i+1 < len(tokens) and tokens[i+1] == "'s":
                                answer += tokens[i]
                            else:
                                answer += tokens[i] + ' '
                            i += 1
                    answer = answer.strip()
                    
    elif qtype == 'NE':
        for ent in doc.ents:
            score = 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = np.text
                
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    answer = answer.strip().lower()
    answer_result = []
    answer_result.append(case_count)
    answer_result.append(answer)
    writer.writerow(answer_result)
    print(case_count,' ',answer)
    case_count += 1
    if answer == '':
        empty_count += 1
    
csvFile.close()
print(empty_count)
# Out:
# 0   combination
# 1   components
# 2   browser's layout engine
# 3   internet explorer
# 4   september 2008
# 5   windows
# 6   1990
# 7   browsers
# 8   andreessen
# 9   first web browser
# 10   competition
# 11   microsoft
# 12   internet relay chat
# 13   january
# 14   every major web browser
# 15   january 2003
# 16   january 2009
# 17   file transfer protocol
# 18   google
# 19   case
# 20   rich user interfaces
# 21   january 2009
# 22   august 2011
# 23   browser software
# 24   chrome's user-base
# 25   form
# 26   december 2011
# 27   september 2008
# 28   netscape
# 29   opera-mini version
# 30   rapid development
# 31   prefix
# 32   mozilla foundation
# 33   private networks
# 34   windows
# 35   comparison
# 36   1994
# 37   user interface
# 38   addition
# 39   major browsers
# 40   information resources
# 41   live bookmarks
# 42   more traditional feed reader
# 43   bookmarks
# 44   september 2008
# 45   prefix
# 46   browser software
# 47   world wide web
# 48   microsoft corp
# 49   mobile safari
# 50   web browsers
# 51   other hand
# 52   user's default e-mail application
# 53   browser extension
# 54   4.5 hour
# 55   call
# 56   chinese media
# 57   protests
# 58   several onlookers
# 59   noted indian social activist
# 60   san francisco's
# 61   chan
# 62   site
# 63   western media
# 64   20 km
# 65   political activist
# 66   several onlookers
# 67   distinction
# 68   relay supporters
# 69   canberra
# 70   team
# 71   20 km
# 72   foreign minister stephen smith
# 73   several onlookers
# 74   interior michèle alliot-marie
# 75   australian police
# 76   april 5
# 77   members
# 78   april 1, 2008
# 79   paris city
# 80   washizawa's aides
# 81   accountability
# 82   april 16
# 83   pro-beijing camp politicians
# 84   10 downing street
# 85   torch
# 86   carrefour
# 87   bbc
# 88   north korea
# 89   750,000
# 90   lhasa riots
# 91   libération
# 92   protests
# 93   seoul
# 94   libération
# 95   giant banner
# 96   torch
# 97   seven
# 98   uyghurs
# 99   chan
# 100   macau
# 101   vietnamese american
# 102   one person
# 103   several onlookers
# 104   several onlookers
# 105   march
# 106   india
# 107   site
# 108   libération
# 109   macao daily news
# 110   costanera sur
# 111   scheduled ceremony
# 112   2,200
# 113   assurances
# 114   man
# 115   foreign minister stephen smith
# 116   major setback
# 117   democracy
# 118   chan
# 119   several onlookers
# 120   20 km
# 121   reports
# 122   several onlookers
# 123   several onlookers
# 124   hollywood
# 125   march 2008
# 126   jon stanhope
# 127   oman
# 128   ted quinlan
# 129   fear
# 130   may 2
# 131   kuala lumpur
# 132   aluminum
# 133   chan
# 134   tsim sha tsui
# 135   new starting point
# 136   tsim sha tsui
# 137   several onlookers
# 138   man
# 139   1000
# 140   event
# 141   may 3
# 142   thupten gyatso
# 143   april 17
# 144   onlookers
# 145   six
# 146   two
# 147   chinese
# 148   show
# 149   china
# 150   several onlookers
# 151   120
# 152   response
# 153   relay
# 154   libération
# 155   vietnamese
# 156   several onlookers
# 157   several onlookers
# 158   minister
# 159   thousands
# 160   1964
# 161   justin herman plaza
# 162   april 5
# 163   francesca martinez
# 164   number
# 165   several onlookers
# 166   olympia
# 167   daily telegraph
# 168   susan prager
# 169   several onlookers
# 170   united nations organization
# 171   jackie chan
# 172   sikkimese
# 173   third torchbearer
# 174   kazakhstan
# 175   march 24
# 176   april
# 177   1964
# 178   invitees
# 179   first
# 180   torch
# 181   two
# 182   jane birkin
# 183   one
# 184   zenkoji monks
# 185   may 2
# 186   ‘caged woman’
# 187   april
# 188   france
# 189   chan
# 190   torch relay route
# 191   china
# 192   70
# 193   one
# 194   85,000
# 195   washizawa's aides
# 196   india
# 197   jane birkin
# 198   several onlookers
# 199   day
# 200   1964
# 201   libération
# 202   nathan road
# 203   response
# 204   chan
# 205   chan
# 206   chan
# 207   chan
# 208   turkey
# 209   japanese family
# 210   taipei
# 211   chan
# 212   japan
# 213   call
# 214   april 3
# 215   chan
# 216   events
# 217   chinese demands
# 218   chan
# 219   days
# 220   china's relations
# 221   oman
# 222   "immigration reasons
# 223   two
# 224   april 17
# 225   members
# 226   chan
# 227   lê minh phiếu
# 228   chan
# 229   jacques rogge
# 230   chan
# 231   several onlookers
# 232   march 24
# 233   sacred torch
# 234   macao daily news
# 235   chan
# 236   medeo
# 237   seven
# 238   call
# 239   aluminum
# 240   carlos espínola
# 241   several onlookers
# 242   argentine
# 243   chinese media
# 244   tibet
# 245   saint petersburg
# 246   government
# 247   may 3
# 248   eiffel tower
# 249   tanzania
# 250   beijing
# 251   olympic torch
# 252   chan
# 253   macao daily news
# 254   1200
# 255   days
# 256   great britain
# 257   april
# 258   two
# 259   own protection
# 260   san jose
# 261   president pervez musharraf
# 262   turn
# 263   pride heavyweight champion fedor emelianenko
# 264   bbc
# 265   chan
# 266   bollywood actress soha ali khan
# 267   telegraph
# 268   chan
# 269   middle east
# 270   india
# 271   macau
# 272   ancient links
# 273   tony goh
# 274   government
# 275   estimated 3,000 french police
# 276   event
# 277   response
# 278   istanbul
# 279   torchbearers
# 280   narisa chakrabongse, green world foundation (gwf) chairwoman
# 281   macao daily news
# 282   paralympic games
# 283   may 4
# 284   supervisors
# 285   chan
# 286   great britain
# 287   bangkok
# 288   several symbolic protests
# 289   several onlookers
# 290   april 16
# 291   telegraph
# 292   buenos aires
# 293   french
# 294   one
# 295   trocadéro
# 296   people's daily
# 297   night
# 298   tibetan flags
# 299   prior
# 300   japan
# 301   chinese officials
# 302   several onlookers
# 303   many as 1,000
# 304   japan
# 305   relay
# 306   justin herman plaza
# 307   tibetan flag
# 308   telegraph
# 309   intended torchbearer lin hatfield dodds
# 310   85,000
# 311   peter ueberroth
# 312   orchidbbs.com and cyberctm.com internet forums
# 313   carrefour
# 314   china
# 315   pyongyang
# 316   thousands
# 317   san jose
# 318   chan
# 319   total
# 320   baichung bhutia
# 321   several onlookers
# 322   diego maradona
# 323   several onlookers
# 324   1988
# 325   tokyo
# 326   30
# 327   arrival
# 328   65 kilometre per hour
# 329   several onlookers
# 330   latin america
# 331   islamabad
# 332   thailand
# 333   kazakhstan
# 334   islamabad
# 335   night
# 336   chinese ambassador
# 337   april 1, 2008
# 338   several onlookers
# 339   world ’ s worst offenders
# 340   jakarta
# 341   many as 1,000
# 342   to 600
# 343   lê minh phiếu
# 344   united states of america
# 345   olympic torch
# 346   francesca martinez
# 347   protests
# 348   kamal nath
# 349   paris city
# 350   tokyo
# 351   torch
# 352   bbc's paul danahar
# 353   same pitch
# 354   total number
# 355   pitch
# 356   12
# 357   indefinite pitch
# 358   100 cents
# 359   frequency
# 360   "high" pitch
# 361   least one model
# 362   overtones
# 363   time
# 364   a4
# 365   the higher frequencies
# 366   12
# 367   perceived interval
# 368   sound
# 369   theories
# 370   southampton
# 371   itv
# 372   annual southampton boat show
# 373   seven
# 374   city
# 375   120,305
# 376   sizeable polish population
# 377   lloyd's register group
# 378   most successful college american football teams
# 379   1996
# 380   great war
# 381   9th century
# 382   london
# 383   new forest
# 384   10th century
# 385   southampton
# 386   southampton city council
# 387   roughly half
# 388   2015 council elections
# 389   2,000
# 390   two
# 391   annual
# 392   92.4 per cent
# 393   one
# 394   walls
# 395   city
# 396   importance
# 397   1888
# 398   november 2014
# 399   annual
# 400   one third
# 401   annual southampton boat show
# 402   university hospital southampton nhs foundation trust
# 403   12th century
# 404   latter half of the 20th century
# 405   october 2014
# 406   hamtun
# 407   2006 and 2013
# 408   banister court stadium
# 409   high street
# 410   anglo-saxons
# 411   house tower
# 412   500,000
# 413   2004
# 414   two
# 415   first half of the 20th century
# 416   1959
# 417   worst behaved secondary schools
# 418   part
# 419   four
# 420   1840
# 421   1862
# 422   city council
# 423   western docks
# 424   space
# 425   1417
# 426   western docks
# 427   1339
# 428   202
# 429   1976
# 430   city
# 431   presence
# 432   centre
# 433   1968
# 434   port
# 435   hampshire
# 436   1066
# 437   british gas
# 438   west quay
# 439   royston smith
# 440   hampshire
# 441   parts
# 442   uk
# 443   princess alexandra dock
# 444   vast majority
# 445   so'ton
# 446   queen mary
# 447   southampton
# 448   early may
# 449   uni-link
# 450   cent
# 451   third ferry
# 452   university of southampton
# 453   13th century
# 454   provide
# 455   1966
# 456   hampshire
# 457   west quay
# 458   adonia
# 459   city
# 460   so'ton
# 461   local train services
# 462   two
# 463   uk
# 464   solent
# 465   p&o cruises
# 466   27 june 1640
# 467   college
# 468   9th century
# 469   1339
# 470   1233
# 471   trust
# 472   biggest operator
# 473   4.2
# 474   1959
# 475   354
# 476   government figures
# 477   m27
# 478   uk
# 479   hanover buildings
# 480   city
# 481   year
# 482   12th century
# 483   traffic congestion
# 484   southampton
# 485   2004
# 486   1233
# 487   hampshire
# 488   three fire stations
# 489   southampton docks
# 490   two
# 491   m27
# 492   southampton's largest retail centre
# 493   13th century
# 494   1066
# 495   clausentum
# 496   two
# 497   plans
# 498   southampton
# 499   port
# 500   over a quarter
# 501   southampton central
# 502   20–24
# 503   council estates
# 504   portswood, banister park
# 505   over a quarter
# 506   king henry's departure
# 507   m3 motorway
# 508   trust
# 509   catherine mcewing
# 510   16.2
# 511   nuffield theatre
# 512   newport
# 513   university of southampton
# 514   france
# 515   swaythling
# 516   1968
# 517   area
# 518   hampshire county council
# 519   duchess
# 520   world's largest cruise ships
# 521   1938
# 522   large shopping centre
# 523   suspension rate
# 524   2009
# 525   southampton university
# 526   three
# 527   duchess of cambridge
# 528   1960s
# 529   september 1940
# 530   1854 book
# 531   48
# 532   plymouth
# 533   walter taylor's
# 534   southampton water
# 535   structural and economic development
# 536   12th century
# 537   banister court stadium
# 538   mansbridge
# 539   stone age
# 540   1996 and 2004
# 541   germany
# 542   charters
# 543   notable former player
# 544   anglo-saxons
# 545   hampshire constabulary
# 546   seacity museum
# 547   university hospital southampton nhs foundation trust
# 548   itchen
# 549   1348
# 550   importance
# 551   1835
# 552   two
# 553   1310
# 554   southampton airport
# 555   england
# 556   great war
# 557   18th-century
# 558   23
# 559   banister court stadium
# 560   southampton
# 561   two local sunday leagues
# 562   part
# 563   banister court stadium
# 564   500,000
# 565   1995
# 566   three
# 567   24
# 568   city
# 569   north
# 570   unitary authority
# 571   1310
# 572   designer
# 573   successive incarnations
# 574   ikea
# 575   cruise ships
# 576   france
# 577   runners-up
# 578   hampshire county
# 579
# 580   floyd
# 581   hampshire constabulary
# 582   southampton
# 583   university of southampton
# 584   today
# 585   january 2007
# 586   floyd
# 587   24 february 1964
# 588   18th century
# 589   so'ton
# 590   march 2007
# 591   university of southampton
# 592   three
# 593   john choules
# 594   henry
# 595   48
# 596   one
# 597   coast
# 598   controversy
# 599   hampshire county council
# 600   1760s
# 601   hampshire county
# 602   hampshire county council
# 603   uk
# 604   500,000
# 605   city
# 606   walls
# 607   today
# 608   city
# 609   11
# 610   bargate
# 611   college
# 612   linda norris
# 613   passenger services
# 614   92.4 per cent
# 615   town and county of the town of southampton '
# 616
# 617   henry vi
# 618   south hampshire
# 619   october 1838
# 620   one
# 621   mud flats
# 622   hampshire county
# 623   1310
# 624   southampton docks
# 625   walls
# 626   london
# 627   march 1644
# 628   so'ton
# 629   woodmill bridge
# 630   three
# 631   test
# 632   country
# 633   southampton docks
# 634   factory
# 635   whitbread
# 636   highest temperature
# 637   town
# 638   latter half
# 639   1944
# 640   last three years
# 641   june
# 642   1310
# 643   england
# 644   southampton
# 645   river test and river itchen
# 646   last remains
# 647   david bowie
# 648   eastleigh
# 649   council
# 650   southampton
# 651   uk
# 652   england
# 653   car manufacture
# 654   two
# 655   1995 and 2004
# 656   battle of agincourt
# 657   2005
# 658   nightclub
# 659   uni-link
# 660   may 1840
# 661   october 2014
# 662   southampton's largest retail centre
# 663   january 2007
# 664   common
# 665   enterprise
# 666   over a week
# 667   south today
# 668   royston smith
# 669   craig david
# 670   southampton city college
# 671   southampton airport
# 672   rest
# 673   coast
# 674   strong
# 675   city hockey club
# 676   swaythling
# 677   1996 and 2004
# 678   junk
# 679   attempt
# 680   today
# 681   major uk port
# 682   supermarine spitfire
# 683   meridian
# 684   city
# 685   northern tip
# 686   king henry's departure
# 687   france
# 688   hampshire
# 689   uk
# 690   hampshire constabulary
# 691   two local sunday leagues
# 692   uk
# 693   hampshire constabulary
# 694   red funnel
# 695   1938
# 696   17,000
# 697   georgian
# 698   previously
# 699   1862
# 700   1888
# 701   shops
# 702   clausentum
# 703   southampton's strong economy
# 704   1879 to 1949
# 705   swaythling
# 706   henry v's
# 707   1740
# 708   fareham
# 709   national lottery
# 710   eastern docks
# 711   royalists
# 712   hampshire
# 713   february 2011
# 714   119,500 males
# 715   nearly 92 %
# 716   nearly 92 %
# 717   eastern
# 718   four women
# 719   poland
# 720   ashkenazi jew's
# 721   40 %
# 722   high frequencies
# 723   however, most people
# 724   1890s
# 725   1990s
# 726   middle east
# 727   last thousand years
# 728   probability
# 729   ashkenazim
# 730   nearly 92 %
# 731   11th century
# 732   last thousand years
# 733   40 %
# 734   often
# 735   middle ages
# 736   212
# 737   certain issues
# 738   midrash
# 739   jews
# 740   several famous people
# 741   holocaust
# 742   20th century
# 743   israeli black panthers
# 744   study
# 745   estimated 8.8 million
# 746   israel
# 747   hebrew
# 748   possible exception
# 749   roman empire
# 750   recent years
# 751   1750
# 752   ashkenazi jews
# 753   16th-century
# 754   1095
# 755   1095
# 756   elevated frequency
# 757   47.5 %
# 758   concept
# 759   uses
# 760   2,500 years ago
# 761   ancient levantine origins
# 762   middle ages
# 763   middle eastern peoples
# 764   conformity
# 765   archeological evidence
# 766   several million
# 767   ashkenazi jew
# 768   hebrew
# 769   pre-christian times
# 770   period
# 771   term
# 772   center
# 773   80
# 774   another trend
# 775   centuries later
# 776   11th century
# 777   jews
# 778   rabbinic leadership
# 779   talmud
# 780   modern-day italians
# 781   30
# 782   five thousand
# 783   nobel
# 784   minhagim
# 785   54 % –60 %
# 786   genome-wide genetic study
# 787   fertile crescent
# 788   quarter
# 789   1095
# 790   second half of the 11th century
# 791   jerusalem
# 792   yiddish
# 793   less 74 %
# 794   yoma
# 795   conformity
# 796   contemporary saadia gaon
# 797   hebrew
# 798   greek historian
# 799   greek historian
# 800   11th century
# 801   first
# 802   first decades
# 803   sergio dellapergola
# 804   nearly 92 %
# 805   jewish
# 806   gomer
# 807   80
# 808   jews
# 809   ashkenazi jew
# 810   2 %
# 811   nearly 92 %
# 812   upper euphrates
# 813   nusach
# 814   latin america
# 815   2002
# 816   conformity
# 817   surname
# 818   herodotus
# 819   many jews
# 820   first half
# 821   nusach sefard
# 822   estimated 8.8 million
# 823   genesis rabbah
# 824   religious jews
# 825   uranus
# 826   11 july neptune
# 827   largest neptunian moon
# 828   objects
# 829   difference
# 830   sun
# 831   le verrier
# 832   result
# 833   earliest recorded observations
# 834   1.0243×1026 kg
# 835   rahab
# 836   troposphere
# 837   2007
# 838   jupiter
# 839   eighth and farthest known planet
# 840   uranus
# 841   johann galle
# 842   same way
# 843   william lassell
# 844   late 2020s or early 2030s
# 845   11 july 2011
# 846   gravity
# 847   le verrier
# 848   first and so far only object
# 849   200
# 850   °
# 851   , persistent methane clouds
# 852   scooter
# 853   yearly retrograde cycle
# 854   last major planet
# 855   high-altitude clouds
# 856   recent proposal
# 857   1:1 resonance
# 858   750
# 859   1843
# 860   winds
# 861   only spacecraft
# 862   1.1
# 863   focus
# 864   unaided eye
# 865   25 august 1989
# 866   credit
# 867   discovery
# 868   1821
# 869   triton
# 870   roughly 40
# 871   upper-level clouds
# 872   17 times the mass
# 873   first and so far only object
# 874   dark spots
# 875   documents
# 876   17
# 877   neptune
# 878   discovery
# 879   neptune
# 880   current most widely accepted explanation
# 881   eighth and farthest known planet
# 882   2019
# 883   1:1
# 884   penultimate known planet
# 885   small apparent size
# 886   irregularly shaped proteus
# 887   2006
# 888   23
# 889   models
# 890   heinrich d'arrest
# 891   earth
# 892   planetary ring system
# 893   most heavily populated resonance
# 894   neptune
# 895   sun
# 896   voyager 2's arrival
# 897   circumferential bands
# 898   neptune's atmospheric methane content
# 899   great dark spot
# 900   discovery
# 901   1979 and 1999
# 902   months
# 903   altitudes
# 904   vortex structures
# 905   neptune's more varied weather
# 906   12,500 years
# 907   17 times the mass
# 908   apparent backward motion
# 909   current models
# 910   1997
# 911   planetary science
# 912   400 m/s
# 913   1981
# 914   images
# 915   12,500 years
# 916   candidates
# 917   neptune's more varied weather
# 918   reaction
# 919   hobbes
# 920   samuel pufendorf
# 921   culture
# 922   citation
# 923   19th-century
# 924   terror management theory
# 925   29
# 926   united states
# 927   germany
# 928   end of the last ice age
# 929   19th-century
# 930   contrasted
# 931   terror management theory
# 932   immanuel kant
# 933   1970s
# 934   european
# 935   united states
# 936   diffusion
# 937   prussian linguist
# 938   1950s and 1960s
# 939   stuart hall
# 940   élite ideal
# 941   present legislation
# 942   jefferson's metaphor
# 943   1971
# 944   nonconformists
# 945   areas
# 946   pervasive secularism
# 947   wall
# 948   may 3, 2006
# 949   still other scholars
# 950   early as the mid-17th century
# 951   religious freedom
# 952   engel
# 953   madison
# 954   december 20, 2005
# 955   william penn
# 956   two
# 957   legal scholars
# 958   still other scholars
# 959   reynolds
# 960   1776
# 961   court's decision
# 962   opponents
# 963   december
# 964   robert s. wood
# 965   u.s.
# 966   1962
# 967   court
# 968   1994
# 969   john f. kennedy
# 970   argue
# 971   patrick henry
# 972   1947
# 973   lone dissenter
# 974   central point
# 975   many early immigrant groups
# 976   third
# 977   north carolina constitution
# 978   jefferson
# 979   states' rights
# 980   1879
# 981   religious bigotry
# 982   one religious society
# 983   1786
# 984   religious beliefs
# 985   national motto
# 986   u.s.
# 987   ohio
# 988   2002
# 989   new england
# 990   phrase
# 991   three
# 992   answer
# 993   pledge
# 994   principle or primary effect
# 995   bill of rights , declaration of rights
# 996   john f. kennedy
# 997   south carolina
# 998   roger williams
# 999   purpose of the display ( educating the public on american legal traditions ) was secular in nature .
# 1000   december 27, 1657
# 1001   jefferson's concept
# 1002   jefferson's statute
# 1003   eighteenth century
# 1004   required beliefs
# 1005   separation
# 1006   consequence
# 1007   1878
# 1008   1961
# 1009   citation
# 1010   proclamations
# 1011   five-justice majority
# 1012   2
# 1013   court's opinion
# 1014   roger williams
# 1015   three
# 1016   jefferson's metaphor
# 1017   umayyad dynasty mosaic making
# 1018   constantinople
# 1019   venetian
# 1020   one solsternus
# 1021   amman
# 1022   fragments
# 1023   end of the 5th century
# 1024   justinian
# 1025   alexander mosaic
# 1026   5th-century
# 1027   17th-century
# 1028   grand prince
# 1029   jerusalem
# 1030   12th century
# 1031   remains
# 1032   whose sail
# 1033   most prominent artist
# 1034   greek masters
# 1035   winemaking putti
# 1036   st. catherine's monastery
# 1037   computer aided design
# 1038   roger ii
# 1039   double indirect method
# 1040   another example
# 1041   affricisco
# 1042   roman church
# 1043   human figure
# 1044   arta
# 1045   decoration
# 1046   abundant variety
# 1047   monastic communities
# 1048   5th-century
# 1049   11th–13th centuries
# 1050   8th–9th centuries
# 1051   east
# 1052   mary
# 1053   golden mosaics
# 1054   bethany
# 1055   1990
# 1056   constantinople
# 1057   southern italy
# 1058   mausoleum
# 1059   1169
# 1060   piazza armerina
# 1061   539
# 1062   royal basilica
# 1063   taddeo zuccari
# 1064   sant'ambrogio
# 1065   ascension
# 1066   another samaritan synagogue
# 1067   vandal
# 1068   normal technique
# 1069   norman kings
# 1070   monastery of euthymius
# 1071   galla placidia
# 1072   1310–14
# 1073   iconoclastic
# 1074   moorish spain
# 1075   portugal
# 1076   2003
# 1077   4th century
# 1078   church of the holy apostles
# 1079   539 ravenna
# 1080   17th century
# 1081   1210
# 1082   present-day
# 1083   pebble mosaics
# 1084   holy land
# 1085   nea moni monastery on chios
# 1086   arabs
# 1087   mosaic panel
# 1088   1043–1056
# 1089   constantinople
# 1090   greek figural mosaics
# 1091   rare example
# 1092   icons
# 1093   constantinople
# 1094   striking technical innovation
# 1095   calçada portuguesa
# 1096   river mureş
# 1097   interesting fusion
# 1098   santa constanza
# 1099   damascus
# 1100   5th-century
# 1101   christ
# 1102   styles
# 1103   martorana church
# 1104   long braided hair and rosy cheeks
# 1105   atrium
# 1106   second
# 1107   large villa rustica
# 1108   works
# 1109   1971–72
# 1110   1607
# 1111   around 1143
# 1112   classe
# 1113   most prominent artist
# 1114   abundant variety
# 1115   kastron mefaa
# 1116   constantinople
# 1117   19th century
# 1118   symbolism
# 1119   rome
# 1120   abbot
# 1121   julii
# 1122   venetian
# 1123   1913
# 1124   royal basilica
# 1125   damascus
# 1126   middle
# 1127   19th century
# 1128   emperor maximian
# 1129   outstanding examples
# 1130   10
# 1131   18th century
# 1132   hand
# 1133   religious umayyad mosaic works
# 1134   constantine monomachos
# 1135   holy land
# 1136   synagogue
# 1137   monomachos
# 1138   accidents
# 1139   1986
# 1140   4th century
# 1141   three
# 1142   mosaic pavement
# 1143   figures
# 1144   monastery of martyrius
# 1145   christian
# 1146   sosus
# 1147   constantine monomachos
# 1148   roger ii
# 1149   mosaics
# 1150   1589
# 1151   constantine monomachos
# 1152   small panels
# 1153   limoges
# 1154   5th-century
# 1155   iconoclastic era
# 1156   3rd millennium bc
# 1157   27
# 1158   double indirect method
# 1159   basilica
# 1160   exotic or mythological animals
# 1161   syria
# 1162   1960s
# 1163   calçada portuguesa
# 1164   64 ad
# 1165   gelati
# 1166   calçada portuguesa
# 1167   constantinople
# 1168   golden gate
# 1169   4th-century bc
# 1170   1043–1056
# 1171   early 4th century
# 1172   north africa
# 1173   taungoo
# 1174   80
# 1175   english
# 1176   capital city
# 1177   myanmar
# 1178   many splendid temples
# 1179   2008 rice production
# 1180   english
# 1181   obama
# 1182   estimated 200,000
# 1183   independent years
# 1184   large and influential community
# 1185   myanmar
# 1186   first
# 1187   myanmar's ethnic minority groups
# 1188   little known fact
# 1189   human rights watch
# 1190   thousands
# 1191   independent researchers
# 1192   largest empire
# 1193   1,930 km
# 1194   2015
# 1195   myanmar
# 1196   myanmar
# 1197   protected areas
# 1198   west
# 1199   myanmar
# 1200   burma's education system
# 1201   lay people
# 1202   colonial architectural influences
# 1203   rohingya muslims
# 1204   english
# 1205   monks
# 1206   400,000 years ago
# 1207   1770
# 1208   english
# 1209   250 years
# 1210   400,000 years ago
# 1211   english
# 1212   naypyidaw
# 1213   major battleground
# 1214   dynasty
# 1215   hanthawaddy monarchs
# 1216   lines
# 1217   1883
# 1218   equitable right
# 1219   civil law
# 1220   absolute protection
# 1221   criticism
# 1222   lines
# 1223   2004
# 1224   estimated 18 million
# 1225   claim
# 1226   napster
# 1227   law professor
# 1228   one year's
# 1229   free software foundation founder richard stallman
# 1230   free software foundation founder richard stallman
# 1231   scope
# 1232   many countries
# 1233   definition
# 1234   scope
# 1235   patent infringement
# 1236   copyleft
# 1237   §
# 1238   1994
# 1239   citation
# 1240   1846
# 1241   many jurisdictions
# 1242   arguments
# 1243   definition
# 1244   three
# 1245   term
# 1246   infringement
# 1247   specific technological problem
# 1248   lines
# 1249   1883
# 1250   trips
# 1251   copyright
# 1252   recording industry association
# 1253   recording industry association
# 1254   referring
# 1255   stephan kinsella
# 1256   united states
# 1257   context
# 1258   equitable right
# 1259   context
# 1260   recent developments
# 1261   1791
# 1262   may 2011
# 1263   1998
# 1264   trade secret misappropriation
# 1265   2001
# 1266   october 1845
# 1267   civil law
# 1268   1883
# 1269   one year's
# 1270   critics
# 1271   17 the stated objective
# 1272   motion picture association of america
# 1273   uk
# 1274   trademark infringement
# 1275   millions
# 1276   high-tech fields
# 1277   native cultures
# 1278   critics
# 1279   intellectual-property rights
# 1280   native cultures
# 1281   disparate laws
# 1282   detriment
# 1283   infringement
# 1284   assumption
# 1285
# 1286   french
# 1287   rossiya
# 1288   ingur river
# 1289   1830
# 1290   kars
# 1291   christians
# 1292   new russia
# 1293   crimean war
# 1294   1854
# 1295   time
# 1296   british
# 1297   black sea
# 1298   danube
# 1299   july 1854
# 1300   26 july
# 1301   baltic was [ when
# 1302   north
# 1303   russians
# 1304   23 june 1854
# 1305   russia
# 1306   russian
# 1307   spring
# 1308   local commanders
# 1309   baltic was [ when
# 1310   august 1855
# 1311   nicholas
# 1312   15,000
# 1313   four
# 1314   center
# 1315   russians
# 1316   william howard russell
# 1317   time
# 1318   1857
# 1319   25 september
# 1320   lord cowley
# 1321   baltic was [ when
# 1322   february
# 1323   morning
# 1324   piedmont
# 1325   nicholas
# 1326   late september
# 1327   year
# 1328   three
# 1329   bulgaria
# 1330   alexander ii
# 1331   french
# 1332   deployment
# 1333   kept
# 1334   evacuation
# 1335   12 july
# 1336   339
# 1337   august 1855
# 1338   black sea
# 1339   31 december 1853
# 1340   alfred nobel
# 1341   george hamilton-gordon
# 1342   baltic was [ when
# 1343   32–40
# 1344   alliance
# 1345   local commanders
# 1346   part
# 1347   russia
# 1348   postponement
# 1349   omar pasha
# 1350   conflict
# 1351   parliament
# 1352   constantinople
# 1353   åland islands
# 1354   alexander ii
# 1355   nicholas
# 1356   cardigan
# 1357   attack
# 1358   :104:19
# 1359   start
# 1360   october 1853
# 1361   french
# 1362   sunday
# 1363   year up to
# 1364   public opinion
# 1365   1855: georgian coast
# 1366   winter of 1854
# 1367   sinop
# 1368   russian cavalry movement
# 1369   part
# 1370   peaceful settlement
# 1371   crimean war
# 1372   baltic was [ when
# 1373   vidin
# 1374   reaction
# 1375   chetatea
# 1376   danube river
# 1377   ottoman forces
# 1378   william howard russell
# 1379   june 24, 1839
# 1380   local commanders
# 1381   105  the tsar
# 1382   28 march 1854
# 1383   432–33
# 1384   roger fenton
# 1385   russian troops
# 1386   far south wrangel
# 1387   10 october
# 1388   461 the resulting battle
# 1389   14 november
# 1390   alfred lord tennyson
# 1391   finally
# 1392   sultan
# 1393   russians
# 1394   439 an electrical telegraph
# 1395   victor emmanuel ii
# 1396   september 1854
# 1397   200 years
# 1398   principalities
# 1399   black sea
# 1400   vidin
# 1401   bleak prospect
# 1402   baltic
# 1403   russians
# 1404   time
# 1405   cardigan
# 1406   baltic was [ when
# 1407   little additional naval action
# 1408   london
# 1409   marani
# 1410   350
# 1411   sevastopol
# 1412   russians
# 1413   february
# 1414   treaty of paris
# 1415   time
# 1416   omar pasha
# 1417   nicholas
# 1418   1840
# 1419   russians
# 1420   times newspaper
# 1421   a. w
# 1422   danube
# 1423   note
# 1424   large body
# 1425   snow
# 1426   march 1854
# 1427   nicholas
# 1428   azov sea
# 1429   sunday
# 1430   taganrog
# 1431   6000
# 1432   april
# 1433   omar pasha
# 1434   giurgiu
# 1435   ottoman empire
# 1436   peace terms
# 1437   ottoman army
# 1438   erzerum
# 1439   austria's efforts
# 1440   russian america
# 1441   5 december 1853
# 1442   muhammad ali
# 1443   ottoman empire
# 1444
# 1445   kerch strait
# 1446   192
# 1447   four
# 1448   late september
# 1449   1848
# 1450   february 1853
# 1451   april 1854
# 1452   201
# 1453   alaska
# 1454   30
# 1455   seven columns
# 1456   spring of 1821
# 1457   :104:19
# 1458   crimean war
# 1459   failure
# 1460   30 march 1856
# 1461   peace terms
# 1462   russian
# 1463   19 october
# 1464   sevastopol
# 1465   greeks
# 1466   20000
# 1467   menshikov
# 1468   russians
# 1469   west
# 1470   battle of sinop
# 1471   late july 1854
# 1472   september 8000
# 1473   april 1855
# 1474   first
# 1475   27 february 1854
# 1476   malakoff
# 1477   chetatea
# 1478   chetatea
# 1479   `` clerical party
# 1480   civilian engineering crew
# 1481   30 march 1856
# 1482   russia
# 1483   30000
# 1484   part
# 1485   paris
# 1486   popularisation
# 1487   view
# 1488   war
# 1489   otto von bismarck
# 1490   industrial explosives
# 1491   british
# 1492   crimean war
# 1493   chetatea
# 1494   february
# 1495   telegraph
# 1496   chetatea
# 1497   mean people
# 1498   two categories
# 1499   eight years old
# 1500   manchus
# 1501   invasion
# 1502   1864
# 1503   pro-japanese koreans
# 1504   ming dynasty
# 1505   eight years old
# 1506   age of 45
# 1507   rebellion
# 1508   zaifeng
# 1509   only remaining part
# 1510   eight
# 1511   early 17th century
# 1512   1900
# 1513   ming dynasty
# 1514   beijing
# 1515   koxinga
# 1516   han migrants
# 1517   instead
# 1518   li zicheng
# 1519   prior military experience
# 1520   first opium war
# 1521   population
# 1522   hooge
# 1523   3,400
# 1524   china
# 1525   peasant rebels
# 1526   britain
# 1527   few ethnic manchus
# 1528   kangxi emperor
# 1529   xiang army
# 1530   1641
# 1531   1850s
# 1532   team
# 1533   zhu zhiliang
# 1534   nurhaci
# 1535   wu sangui
# 1536   manchus
# 1537   zeng guofan
# 1538   watershed
# 1539   nanjing
# 1540   yangzhou
# 1541   late 1700s
# 1542   qing
# 1543   1661
# 1544   move
# 1545   1683
# 1546   dismissal
# 1547   zeng guofan's strategy
# 1548   20 million
# 1549   li
# 1550   18th century
# 1551   manchus
# 1552   chinese
# 1553   late ming dynasty
# 1554   1637
# 1555   manchus
# 1556   qing organization
# 1557   sun yat-sen
# 1558   jianzhou
# 1559   china
# 1560   1860
# 1561   puyi
# 1562   ming general wu sangui
# 1563   yuan shikai
# 1564   taiwan
# 1565   chongzhen emperor
# 1566   liao area
# 1567   18th century
# 1568   tibetan
# 1569   department
# 1570   mongol
# 1571   guangxu emperor
# 1572   hooge
# 1573   sixty-one year reign
# 1574   canton system
# 1575   jianzhou
# 1576   hong xiuquan
# 1577   han chinese
# 1578   zaifeng
# 1579   territories
# 1580   eight
# 1581   daoguang emperor
# 1582   zuo zongtang
# 1583   first
# 1584   1945
# 1585   han bannermen
# 1586   first sino-japanese war
# 1587   western powers
# 1588   calligraphy
# 1589   units
# 1590   jiangnan
# 1591   taiping rebellion
# 1592   manchu generals
# 1593   western powers
# 1594   buddhist
# 1595   several ming princes
# 1596   qing dynasty
# 1597   board
# 1598   koxinga
# 1599   eight years
# 1600   promises
# 1601   galdan
# 1602   manchu state
# 1603   1850s
# 1604   qing organization
# 1605   1661
# 1606   age of 45
# 1607   qianlong emperor
# 1608   yuan
# 1609   less than one-sixth
# 1610   400,000
# 1611   two months
# 1612   three liaodong han bannermen officers
# 1613   ming capital
# 1614   1854
# 1615   most significant fact
# 1616   ming general wu sangui
# 1617   1661
# 1618   1858
# 1619   han bannermen
# 1620   initial reforms
# 1621   18
# 1622   majority
# 1623   ming dynasty
# 1624   9 october 1645
# 1625   100 million to 300 million
# 1626   cabinet
# 1627   early 17th century
# 1628   1842
# 1629   1711
# 1630   oboi's loyalty
# 1631   tongzhi emperor
# 1632   later years
# 1633   nine
# 1634   fulin
# 1635   dungan revolt
# 1636   hong taiji
# 1637   qianlong emperor
# 1638   success
# 1639   qing
# 1640   1673
# 1641   hong taiji's
# 1642   2,000 years
# 1643   80 %
# 1644   first opium war
# 1645   1889
# 1646   ming dynasty
# 1647   yaqub beg
# 1648   hong taiji's
# 1649   capital
# 1650   yongying system
# 1651   1850s
# 1652   1864
# 1653   following year
# 1654   han bannermen
# 1655   1648
# 1656   art
# 1657   bannermen
# 1658   china
# 1659   1854
# 1660   harsher
# 1661   removal
# 1662   treaty
# 1663   yingzhen
# 1664   qianlong emperor's reign
# 1665   kangxi emperor
# 1666   3,400
# 1667   five
# 1668   zeng guofan
# 1669   age of 45
# 1670   wu sangui
# 1671   citation
# 1672   may 27, 1644
# 1673   empire
# 1674   manchus
# 1675   taiwan
# 1676   sino-french war
# 1677   korean
# 1678   beijing
# 1679   ming han chinese armies
# 1680   2,000 years
# 1681   han chinese
# 1682   suiyuan shidan
# 1683   1661
# 1684   1782
# 1685   1637
# 1686   cochinchina campaign
# 1687   qing dynasty
# 1688   nurhaci
# 1689   ming dynasty
# 1690   first sino-japanese war
# 1691   return
# 1692   emperors
# 1693   qianlong
# 1694   dorgon's controversial july 1645 edict
# 1695   prince dorgon
# 1696   response
# 1697   desperation
# 1698   ming capital
# 1699   dynasty
# 1700   pro-japanese koreans
# 1701   1870
# 1702   yaqub beg
# 1703   wu
# 1704   chinese
# 1705   tongzhi emperor
# 1706   ming
# 1707   eight years old
# 1708   allied
# 1709   few ethnic manchus
# 1710   qianlong
# 1711   eight banners
# 1712   early 20th century
# 1713   imperial patronage
# 1714   age of five in 1861
# 1715   ningguta
# 1716   chief
# 1717   nurhaci
# 1718   age of 45
# 1719   beijing
# 1720   1727
# 1721   1860
# 1722   november 1, 1897
# 1723   hong taiji
# 1724   qianlong emperor
# 1725   october 30
# 1726   suiyuan shidan
# 1727   two
# 1728   hours
# 1729   autumn
# 1730   h. h. asquith
# 1731   continental europe
# 1732   canadian
# 1733   energy crisis
# 1734   next year
# 1735   regions
# 1736   iceland
# 1737   years
# 1738   daylight saving time
# 1739   three-year trial
# 1740   example
# 1741   1895
# 1742   2008
# 1743   groups
# 1744   st. paul
# 1745   normal dst
# 1746
# 1747   54.5 %
# 1748   summer
# 1749   forms
# 1750   tended
# 1751   2011 to 2014
# 1752   tz=':america/new_york'
# 1753   france
# 1754   ordered
# 1755   north american
# 1756   1993
# 1757   3.5 %
# 1758   2008 doe report
# 1759   evening
# 1760   october 5
# 1761   early proponents
# 1762   retinitis pigmentosa foundation fighting blindness
# 1763   willett's 1907 proposal
# 1764   `` s
# 1765   dst
# 1766   germany
# 1767   2011
# 1768   windows 98
# 1769   base
# 1770   xinjiang
# 1771   1895
# 1772   george hudson
# 1773   merriam-webster
# 1774   regions
# 1775   united kingdom
# 1776   sunlight exposure
# 1777   unexpected adverse effect
# 1778   winston churchill
# 1779   2009
# 1780   fate
# 1781   merriam-webster's
# 1782   1995
# 1783   dst clock shifts
# 1784   negative dst
# 1785   britain
# 1786   standard time
# 1787   autumn and two hours
# 1788   merriam-webster's
# 1789   two hours
# 1790   dst
# 1791   europe
# 1792   01:00 utc
# 1793   2007
# 1794   fixed work schedules
# 1795   example
# 1796   dst
# 1797   ramadan (the month
# 1798   reduces
# 1799   1970s
# 1800   older form
# 1801   march 2011
# 1802   year
# 1803   us
# 1804   winter
# 1805   north america
# 1806   1895
# 1807   ntfs
# 1808
# 1809   northern summer
# 1810   initial adoption
# 1811   countries
# 1812   dst inherits
# 1813   dst
# 1814   filesystem
# 1815   2007
# 1816   willett
# 1817   us retailing and manufacturing interests
# 1818   st
# 1819   advantages
# 1820   time zone differences
# 1821   early goal
# 1822   one reason
# 1823   times
# 1824   regions
# 1825   kingsford charcoal
# 1826   clock shifts
# 1827   many enactments
# 1828   one
# 1829   gregorian calendar
# 1830   autumn and two hours
# 1831   two
# 1832   dst
# 1833   clocks
# 1834   iceland
# 1835   europe
# 1836   britain
# 1837   2000
# 1838   weekend
# 1839   example
# 1840   clocks
# 1841   united kingdom
# 1842   1784 satire
# 1843   daylight
# 1844   electricity use
# 1845   times
# 1846   1984
# 1847   adopt
# 1848   continental
# 1849   us
# 1850   first three weekdays
# 1851   electricity use
# 1852   standardize
# 1853   14 april
# 1854   2008
# 1855   clock-shift problems
# 1856   us
# 1857   britain
# 1858   little impact
# 1859   limitations
# 1860   example
# 1861   dst year-round
# 1862   two annual clock shifts
# 1863   muslim
# 1864   andrew peters
# 1865   dst
# 1866   much as 11 %
# 1867   02:00 to 01:00
# 1868   similar twice-yearly tasks
# 1869   2005
# 1870   electricity use
# 1871   new zealander george hudson
# 1872   months of the year
# 1873   1996
# 1874   file
# 1875   1987–2006
# 1876   2007 us change
# 1877   britain
# 1878   may
# 1879   repeals
# 1880   may 1965
# 1881   annual
# 1882   2005
# 1883   following year
# 1884   los angeles
# 1885   dick dale
# 1886   end of the decade
# 1887   axl rose
# 1888   1968
# 1889   electric guitar
# 1890   united states
# 1891   axl rose
# 1892   1958
# 1893   track
# 1894   sammy hagar
# 1895   double platinum ballbreaker
# 1896   bigger hit
# 1897   subsequent albums
# 1898   17 million
# 1899   tensions
# 1900   tensions
# 1901   irish
# 1902   david lee roth
# 1903   black crowes
# 1904   poison
# 1905   aerosmith's comeback
# 1906   los angeles music scene
# 1907   tensions
# 1908   fellow australians airbourne's début album
# 1909   alice cooper
# 1910   los angeles
# 1911   early forms
# 1912   single `` bohemian rhapsody
# 1913   2009
# 1914   iron butterfly
# 1915   few hard rock bands
# 1916   dave davies
# 1917   1993
# 1918   new commercial climate glam metal bands
# 1919   roots
# 1920   nirvana
# 1921   axl rose
# 1922   chinese democracy
# 1923   ramones
# 1924   bass guitar
# 1925   guns n' roses' original lineup
# 1926   heavy metal
# 1927   number
# 1928   guns n' roses' original lineup
# 1929   1992
# 1930   somewhat slower sales
# 1931   four
# 1932   1981
# 1933   decade
# 1934   new wave
# 1935   term
# 1936   commercial hit
# 1937   bon jovi's third album
# 1938   kinks
# 1939   others
# 1940   ac/dc
# 1941   guns n' roses
# 1942   brookline
# 1943   transit isps
# 1944   13 april 2015
# 1945   adoption
# 1946   virtual isp ( visp
# 1947   services
# 1948   possible solution
# 1949   4 years
# 1950   1995
# 1951   citation
# 1952   intelligence agencies
# 1953   customers
# 1954   mailbox provider
# 1955   internet
# 1956   internet service
# 1957   many free isps
# 1958   isps
# 1959   adoption
# 1960   isps
# 1961   upstream isp
# 1962   prism
# 1963   many mailbox providers
# 1964   same concept
# 1965   13 april 2015
# 1966   transit isps
# 1967   free isps
# 1968   services
# 1969   university of kansas school of business
# 1970   three
# 1971   ku’s school
# 1972   world war ii
# 1973   lawrence
# 1974   school's sports teams
# 1975   15,000
# 1976   one
# 1977   overland park
# 1978   later that year
# 1979   2009
# 1980   university of kansas school
# 1981   community tool box
# 1982   university daily kansan
# 1983   city management
# 1984   emporia
# 1985   2,100
# 1986   overland park
# 1987   overland park
# 1988   j-school's students
# 1989   four year
# 1990   u.s. news & world report's
# 1991   kansas public radio station kanu
# 1992   23,597
# 1993   university of kansas school of business
# 1994   1890
# 1995   school
# 1996   civil and environmental engineering
# 1997   review
# 1998   thirteen
# 1999   ku bookstore and ku dining services
# 2000   overland park
# 2001   first
# 2002   bs/ms
# 2003   university of kansas school of business
# 2004   ku men's basketball team
# 2005   professional school
# 2006   wichita
# 2007   medical center
# 2008   first union
# 2009   princeton review
# 2010   designintelligence
# 2011   watson library
# 2012   48 months
# 2013   ku's school of business
# 2014   2,100
# 2015   university of kansas school of architecture , design
# 2016   2,100
# 2017   university of kansas school of business
# 2018   america’s first foundation
# 2019   university of kansas
# 2020   site
# 2021   1952
# 2022   medical center and university hospital
# 2023   ku football
# 2024   ku's
# 2025   schools
# 2026   university of kansas school of business
# 2027   ku's academic computing department
# 2028   nike
# 2029   memorial stadium
# 2030   than 7,000
# 2031   1891
# 2032   educational and research sites
# 2033   thirteen
# 2034   citation
# 2035   kansas
# 2036   nike
# 2037   23,597
# 2038   school
# 2039   team
# 2040   school
# 2041   ku school of engineering
# 2042   ku's academic computing department
# 2043   thirteen
# 2044   1891
# 2045   2007
# 2046   w 15th st
# 2047   2,100 students
# 2048   23,597
# 2049   university daily kansan
# 2050   sheahon zenger
# 2051   ku's school of business
# 2052   medical center and university hospital
# 2053   one
# 2054   than 7,000
# 2055   watson library
# 2056   june 8 , 2013
# 2057   sara
# 2058   ku school of engineering
# 2059   university of kansas school of law
# 2060   2
# 2061   western europe
# 2062   dè
# 2063   1974
# 2064   bbc scotland
# 2065   commercial advertising
# 2066   bbc television
# 2067   jana bennett
# 2068   channel
# 2069
# 2070   ceefax
# 2071   bbc
# 2072   baird
# 2073   weeks
# 2074   bbc
# 2075   german
# 2076   following night
# 2077   different remit
# 2078   world war ii
# 2079   1 september
# 2080   30 minutes
# 2081   brookmans park
# 2082
# 2083   uk
# 2084   1933
# 2085   britain
# 2086   bbc scotland
# 2087   own programmes
# 2088   terrestrial channels
# 2089   1967
# 2090
# 2091   programmes
# 2092   uk nations
# 2093   few years
# 2094   simultaneous transmission
# 2095   nearly 1000
# 2096   pioneering bbc television series
# 2097   rights contracts
# 2098   ceefax
# 2099   september 1939
# 2100   daily
# 2101
# 2102   bbc tv
# 2103
# 2104   december 2004
# 2105   different remit
# 2106   station's range
# 2107
# 2108   1967
# 2109   bbc television department
# 2110   daily
# 2111   mechanical camera
# 2112   bbc
# 2113
# 2114   december 2004
# 2115   queen elizabeth
# 2116
# 2117   london
# 2118   18,999
# 2119   [original research
# 2120   dvd
# 2121   new group
# 2122   august
# 2123   june 1932
# 2124   little angels
# 2125   half-century
# 2126   bbc , television
# 2127   john logie baird
# 2128   estimated 25,000–40,000
# 2129
# 2130
# 2131   weeks
# 2132   bbc , television
# 2133   february
# 2134   little angels
# 2135   bbc tv
# 2136
# 2137   1950s
# 2138
# 2139   5 july 2004
# 2140   bbc
# 2141   next five years
# 2142   general entertainment channel
# 2143   february 2016
# 2144   bbc scotland's
# 2145   1967
# 2146   5 july
# 2147   genetic groups
# 2148   rise
# 2149   united states
# 2150   survey
# 2151   empirical and conceptual problems
# 2152   one crucial innovation
# 2153   practice
# 2154   35 %
# 2155   michelle alexander
# 2156   others
# 2157   health disparities
# 2158   fuzzy sets
# 2159   united states
# 2160   mid-20th-century
# 2161   individual
# 2162   abu el-haj
# 2163   common misconception
# 2164   physical anthropologists
# 2165   early human genetic cluster analysis studies
# 2166   thousands
# 2167   early 20th century
# 2168   human populations
# 2169   societies
# 2170   authors
# 2171   race
# 2172   kittles
# 2173   result
# 2174   early human genetic cluster analysis studies
# 2175   federal government policy
# 2176   races
# 2177   large geographic distances
# 2178   42.4%
# 2179   groups
# 2180   increasing number
# 2181   brazil
# 2182   seven
# 2183   whites
# 2184   very good way
# 2185   biological race concept
# 2186   thousands
# 2187   existence
# 2188   scientific classification
# 2189   subspecies
# 2190   sex
# 2191   rigid descent rule
# 2192   forensic physical anthropologist
# 2193   1949
# 2194   skeletal remain
# 2195   two
# 2196   sense
# 2197   falsify
# 2198   recent work
# 2199   generally accepted concept
# 2200   greatest number
# 2201   many
# 2202   survey
# 2203   contrast
# 2204   30 %
# 2205   clustering
# 2206   today
# 2207   today
# 2208   2000
# 2209   brazilian child
# 2210   racism
# 2211   suggest
# 2212   populations
# 2213   population geneticist sewall wright
# 2214   phylogenetic analysis
# 2215   initial hypotheses
# 2216   east asians
# 2217   populations
# 2218   races
# 2219   significant number
# 2220   700.000
# 2221   thousands
# 2222   diagnosis
# 2223   concept
# 2224   eduardo bonilla-silva
# 2225   physical anthropologists
# 2226   adversely
# 2227   mass incarceration
# 2228   racial discrimination
# 2229   france
# 2230   y chromosomes
# 2231   5 %
# 2232   roughly 28–37 %
# 2233   93 %
# 2234   employs
# 2235   international epidemiological data
# 2236   cranial measurements
# 2237   different parts
# 2238   distinction
# 2239   1964
# 2240   another way
# 2241   blumenbach
# 2242   good arguments
# 2243   word
# 2244   earlier work
# 2245   researchers
# 2246   last two decades
# 2247   eduardo bonilla-silva
# 2248   race
# 2249   many people
# 2250   kaplan
# 2251   system
# 2252   five
# 2253   europeans
# 2254   kaplan
# 2255   many biological anthropologists
# 2256   amerindians
# 2257   identification code
# 2258   system
# 2259   2003
# 2260   thousands
# 2261   thus, anthropologist frank livingstone's conclusion
# 2262   values
# 2263   study
# 2264   abu el-haj
# 2265   population
# 2266   mitochondrial dna
# 2267   sewall wright
# 2268   way
# 2269   1978
# 2270   researchers
# 2271   1775 treatise
# 2272   markers
# 2273   wide consensus
# 2274   questioning
# 2275   three
# 2276   anthropologists
# 2277   one result
# 2278   last decades
# 2279   term race
# 2280   william c. boyd
# 2281   examples
# 2282   empirical reasons
# 2283   designation 'subspecies
# 2284   brazilian child
# 2285   early 20th century
# 2286   cladistics
# 2287   dean amadon
# 2288   three
# 2289
# 2290   contradictions
# 2291   similarly
# 2292   greatest number
# 2293   jim crow laws
# 2294   racial groups
# 2295   balanced degree
# 2296   blumenbach
# 2297   concept
# 2298   1992 article
# 2299   dean amadon
# 2300   european union
# 2301   2003
# 2302   eduardo bonilla-silva
# 2303   60-65 %
# 2304   example
# 2305   fixation index
# 2306   widespread popularity
# 2307   species
# 2308   french policies
# 2309   anthropologist norman sauer
# 2310   authors
# 2311   thousands
# 2312   19th century
# 2313   2008
# 2314   2009
# 2315   20th century
# 2316   scientists
# 2317   anthropologists
# 2318   venter
# 2319   subsequent influential classifications
# 2320   non-african groups
# 2321   last two decades of the 18th century
# 2322   clade
# 2323   abu el-haj
# 2324   estimates
# 2325   race
# 2326   united states
# 2327   selected allele
# 2328   18th century
# 2329   77
# 2330   2000 edition
# 2331   small non-representative sample
# 2332   states
# 2333   forensic anthropologists
# 2334   sociological factors
# 2335   trained anthropologist
# 2336   human populations
# 2337   human genetic variation
# 2338   mixture
# 2339   racial discrimination
# 2340   mammalian species
# 2341   authors
# 2342   1996
# 2343   utility
# 2344   loci
# 2345   first post-classical published classification
# 2346   one-drop rule
# 2347   global distributions
# 2348   doctors
# 2349   1970s
# 2350   differences
# 2351   1996
# 2352   2007 review paper
# 2353   least three million people
# 2354   races
# 2355   early 20th century
# 2356   categories
# 2357   smooth gradation
# 2358   visually
# 2359   19th century
# 2360   race
# 2361   english language
# 2362   considerable suffering
# 2363   word
# 2364   england
# 2365   recommendation ecri
# 2366   concept
# 2367   , therefore fst values
# 2368   replaced
# 2369   same geographical location
# 2370   2007 review paper
# 2371   homininae
# 2372   scholars
# 2373   rachel caspari
# 2374   scientists
# 2375   came
# 2376   1.8 million years ago
# 2377   virtually all physical anthropologists
# 2378   figure
# 2379   stanford university school of medicine
# 2380   correctly
# 2381   attempt
# 2382   era
# 2383   ways
# 2384   temple area
# 2385   long houses
# 2386   social inequality
# 2387   large body
# 2388   neolithic societies
# 2389   southwestern united states
# 2390   era
# 2391   rhine
# 2392   era
# 2393   epipaleolithic natufian culture
# 2394   mid-late neolithic
# 2395   elaborate tombs
# 2396   early japanese societies
# 2397   2002
# 2398   control
# 2399   first
# 2400   natufians
# 2401   2012
# 2402   bronze age
# 2403   another significant change
# 2404   era
# 2405   eurasia
# 2406   beginning
# 2407   neolithic pastoralists
# 2408   bronze age
# 2409   anthropomorphic figurines
# 2410   site
# 2411   middle east
# 2412   turkey
# 2413   early farmers
# 2414   near east
# 2415   control
# 2416   era
# 2417   vashtëmi
# 2418   early farmers
# 2419   one
# 2420   neolithic people
# 2421   around 8,800
# 2422   çatal höyük
# 2423   early japanese societies
# 2424   citation
# 2425   ghazal
# 2426   parts
# 2427   10,700
# 2428   ireland
# 2429   treaties
# 2430   same hierarchical position
# 2431   contracting parties ' full names
# 2432   two-thirds
# 2433   relation
# 2434   sovereignty
# 2435   subject matter
# 2436   party
# 2437   citation
# 2438   case
# 2439   congressional-executive agreements
# 2440   office of legal affairs
# 2441   one party
# 2442   600
# 2443   attack
# 2444   material breach
# 2445   cases
# 2446   consent
# 2447   treaties
# 2448   parties
# 2449   cases
# 2450   development
# 2451   state
# 2452   citation
# 2453   al-waqidi
# 2454   article
# 2455   international law
# 2456   binding greenhouse gas emission limits
# 2457   brazil
# 2458   two
# 2459   treaties
# 2460   long treaty
# 2461   subsequent act
# 2462   compacts
# 2463   state legislation
# 2464   state party's withdrawal
# 2465   treaty
# 2466   modern treaties
# 2467   signatures
# 2468   language
# 2469   entered
# 2470   treaties
# 2471   political boundaries
# 2472   unaccepting
# 2473   international law
# 2474   treaty
# 2475   congress
# 2476   official legal procedures
# 2477   party
# 2478   state party's withdrawal
# 2479   prior to 1871
# 2480   united nations
# 2481   government
# 2482   mabo
# 2483   un
# 2484   case
# 2485   subject matter
# 2486   example
# 2487   brazilian federal constitution
# 2488   article
# 2489   european colonization
# 2490   treaties
# 2491   citation
# 2492   contracting parties ' full names
# 2493   division
# 2494   obligations
# 2495   supreme court
# 2496   state party's withdrawal
# 2497   late 20th and early 21st century
# 2498   consent
# 2499   treaty
# 2500   division
# 2501   text
# 2502   first
# 2503   date
# 2504   citation
# 2505   party's consent
# 2506   united states law
# 2507   multilateral treaties
# 2508   norms
# 2509   three
# 2510   international covenant on civil and political rights
# 2511   federal supreme court
# 2512   brazilian federal constitution
# 2513   state's consent
# 2514   coercion
# 2515   ethiopia
# 2516   practice
# 2517   u.s.
# 2518   case
# 2519   consent
# 2520   withdrawal
# 2521   citation
# 2522   vienna convention
# 2523   treaty
# 2524   interest
# 2525   reservations
# 2526   misunderstanding
# 2527   treaties
# 2528   chapter headings
# 2529   deal
# 2530   long-term, complex legal obligations
# 2531   treaty
# 2532   minor corrections
# 2533   executive agreement
# ...
# 2787   vasafua islet
# 2788   tuvalu
# 2789   captain
# 2790   english
# 2791   tuvalu media department
# 2792   10 years
# 2793   eight per cent
# 2794   japan international cooperation agency
# 2795   8,300 days
# 2796   considered
# 2797   pacific acp states
# 2798   pacific war funafuti
# 2799   trader
# 2800   nine
# 2801   funafuti
# 2802   tuvalu advocates ratification
# 2803   major international priority
# 2804   2002 economic growth
# 2805   members
# 2806   part
# 2807   another important building
# 2808   manu
# 2809   tuvalu ship registry
# 2810   10,640
# 2811   july 2012
# 2812   palagi traders
# 2813   hearing
# 2814   macintosh
# 2815   68020-powered macintosh lc
# 2816   macintosh
# 2817   9,900
# 2818   may 1998
# 2819   macintosh
# 2820   then-new imac g5
# 2821   order
# 2822   created
# 2823   macintosh spelling
# 2824   sold
# 2825   grounds
# 2826   current mac product family
# 2827   39 advertising pages
# 2828   sales
# 2829   macintosh
# 2830   mac os x
# 2831   apple's market share
# 2832   pcs
# 2833   mac's market share
# 2834   retrofits
# 2835   use
# 2836   air
# 2837   apple
# 2838   intel
# 2839   original
# 2840   same year
# 2841   1998
# 2842   matters
# 2843   macintosh
# 2844   may
# 2845   well
# 2846   john sculley
# 2847   one
# 2848   may
# 2849   steve jobs
# 2850   1998
# 2851   october
# 2852   macintosh
# 2853   macintosh ii
# 2854   $ $ 2.5 million
# 2855   steve jobs
# 2856   may 1990
# 2857   new imac
# 2858   us $ 1.5 million
# 2859   39 advertising pages
# 2860   estimated 100,000
# 2861   lisa
# 2862   october 2005
# 2863   john dvorak
# 2864   1997
# 2865   jobs
# 2866   macintosh platform
# 2867   august
# 2868   1989
# 2869   second generation
# 2870   released
# 2871   final macintosh design
# 2872   bluetooth
# 2873   apple
# 2874   apple
# 2875   early 2001
# 2876   primary authors
# 2877   installed base
# 2878   imac
# 2879   finally
# 2880   macintosh's minimal memory
# 2881   early 1990s
# 2882   2000
# 2883   complete office suite
# 2884   number five spot
# 2885   third-party platform virtualization software
# 2886   personal computer manufacturers
# 2887   decision
# 2888   1981
# 2889   air
# 2890   open firmware
# 2891   new motorola 68030 processor
# 2892   macintosh's market share
# 2893   contrast
# 2894   steve jobs
# 2895   howard
# 2896   macintosh classic
# 2897   macintosh's market share
# 2898   discontinued power macintosh g3 , to slot between the imac g3 and the power mac g4 .
# 2899   hewlett packard
# 2900   many small companies
# 2901   october 2009
# 2902   several ultrabooks
# 2903   mavericks
# 2904   chief designer
# 2905   allan loren
# 2906   updated motorola cpus
# 2907   1985
# 2908   may 1990
# 2909   october
# 2910   open firmware
# 2911   steve jobs
# 2912   3.36 million
# 2913   macintosh se
# 2914   macbook air
# 2915   2013
# 2916   mid-2011
# 2917   darwin
# 2918   macintosh
# 2919   april 5, 2006
# 2920   c++
# 2921   current mac models
# 2922   cube
# 2923   apple's actions
# 2924   smith
# 2925   14 %
# 2926   c++
# 2927   apple
# 2928   performance advantage
# 2929   20
# 2930   2006
# 2931   time
# 2932   windows 95 operating system
# 2933   windows
# 2934   200,000 people
# 2935   team member andy hertzfeld
# 2936   response
# 2937
# 2938   part
# 2939   third place spot
# 2940   computer
# 2941   apple's industrial design
# 2942   early 2011
# 2943   models
# 2944   materials
# 2945   component shortage
# 2946   seven years
# 2947   6
# 2948   two
# 2949   2006
# 2950   macintosh
# 2951   removal
# 2952   1993 powerbook 165c
# 2953   macintosh iici
# 2954   mid-2011
# 2955   october
# 2956   compaq
# 2957   component shortage
# 2958   lisa and macintosh user interfaces
# 2959   regis mckenna
# 2960   launch
# 2961   performance advantage
# 2962   update
# 2963   mac os x
# 2964   personal computer manufacturers
# 2965   ten
# 2966   macintosh
# 2967   1993
# 2968   crt
# 2969   models
# 2970   one
# 2971   glass
# 2972   9,900
# 2973   microsoft
# 2974   floppy disk drive
# 2975   apple
# 2976   56
# 2977   macintosh programmer's workshop
# 2978   burrel
# 2979   floppy disk drive
# 2980   april 1984
# 2981   apple
# 2982   40
# 2983   ten
# 2984   crt displays
# 2985   3,195
# 2986   mac
# 2987   new imac
# 2988   2011
# 2989   software business
# 2990   2.06
# 2991   virbhadra singh
# 2992   state-owned television broadcaster
# 2993   governor
# 2994   himachal
# 2995   25 %
# 2996   kangra miniature paintings
# 2997   state
# 2998   himachal
# 2999   state
# 3000   himachal pradesh
# 3001   economy
# 3002   10th century
# 3003   hill stations
# 3004   public radio station
# 3005   1 november 1956
# 3006   himachal pradesh
# 3007   handicrafts
# 3008   virbhadra singh
# 3009   21st
# 3010   anglo-gorkha war
# 3011   superintendent
# 3012   leader
# 3013   virbhadra singh
# 3014   buddhism and sikhism
# 3015   himachal pradesh
# 3016   wool
# 3017   year 1768
# 3018   economy
# 3019   hydro electric resources
# 3020   dial-up access
# 3021   mahmud ghaznavi
# 3022   citation
# 3023   citation
# 3024   technological advancements
# 3025   30 december 2007
# 3026   first
# 3027   nepal
# 3028   h.p.
# 3029   private fm stations
# 3030   18 december 1970
# 3031   state
# 3032   1.16%
# 3033   radio
# 3034   2006
# 3035   handicrafts
# 3036   1948
# 3037   muslims
# 3038   first five-year plan
# 3039   extreme variation
# 3040   others
# 3041   senate
# 3042   side
# 3043   imperial era
# 3044   haruspex
# 3045   security
# 3046   edict
# 3047   principate
# 3048   camp
# 3049   constantine
# 3050   roman women
# 3051   valerian's first religious edict
# 3052   famous tirade
# 3053   human sacrifice
# 3054   strong connections
# 3055   same divine agencies
# 3056   vergil
# 3057   return
# 3058   di immortales
# 3059   arvals
# 3060   traditional roman practice
# 3061   ruins
# 3062   abolition
# 3063   ordinary romans
# 3064   public festivals
# 3065   end
# 3066   product
# 3067   customary offers
# 3068   return
# 3069   rome's hegemony
# 3070   relationship
# 3071   veneration
# 3072   cases
# 3073   wake
# 3074   most important camp-offering
# 3075   february
# 3076   color
# 3077   juno regina
# 3078   mistake
# 3079   imperial era
# 3080   opportunities
# 3081   solution
# 3082   cult
# 3083   sporadic and sometimes brutal attempts
# 3084   punic crisis
# 3085   color
# 3086   later imperial provincial dedications
# 3087   particularly
# 3088   office
# 3089   jupiter latiaris
# 3090   religious dimensions
# 3091   augustus
# 3092   roman calendar
# 3093   second edict
# 3094   record
# 3095   lares and penates
# 3096   first punic war
# 3097   even private prayer
# 3098   rites
# 3099   act
# 3100   same token
# 3101   superstitio
# 3102   jupiter feretrius
# 3103   archaeology
# 3104   vestals
# 3105   augustan settlement
# 3106   february
# 3107   point
# 3108   haruspices
# 3109   return
# 3110   robigo
# 3111   original meaning
# 3112   everyday world
# 3113   principate
# 3114   l. junius brutus
# 3115   heretics
# 3116   last emperor
# 3117   roman women
# 3118   christians
# 3119   rome's hegemony
# 3120   rome
# 3121   early stages
# 3122   great crisis
# 3123   february
# 3124   trajan
# 3125   senate
# 3126   military settlement
# 3127   julius caesar
# 3128   very late republic
# 3129   high-status seating
# 3130   archaeology
# 3131   sacrifice
# 3132   day
# 3133   religious calendars
# 3134   synagogues
# 3135   romans
# 3136   individuals
# 3137   empire
# 3138   mortal's death
# 3139   comparison
# 3140   16 bc tiberius
# 3141   julian
# 3142   popular belief deities
# 3143   treason
# 3144   record
# 3145   such spectacular displays
# 3146   color
# 3147   major , set battle
# 3148   gladiator munus
# 3149   laws
# 3150   myth
# 3151   clients
# 3152   second punic war
# 3153   religion
# 3154   equivalent
# 3155   funding
# 3156   julian
# 3157   last century
# 3158   act
# 3159   civil and religious law
# 3160   separate priestly caste
# 3161   year
# 3162   product
# 3163   comparison
# 3164   household cults
# 3165   roman architect vitruvius
# 3166   peace
# 3167   decius mus
# 3168   divine consideration
# 3169   ruins
# 3170   regal era
# 3171   edict
# 3172   ennius
# 3173   state cult
# 3174   paterfamilias
# 3175   clients
# 3176   princeps
# 3177   devotio
# 3178   vestals
# 3179   reign
# 3180   priesthoods
# 3181   justified
# 3182   264–146
# 3183   secretive consultations
# 3184   later
# 3185   glycias
# 3186   color
# 3187   public religion
# 3188   mysteries
# 3189   male priests
# 3190   vergil's aeneid
# 3191   latin word templum
# 3192   popular cult
# 3193   religious disputes
# 3194   constantine
# 3195
# 3196   latin word templum
# 3197   augustus' religious reformations
# 3198   early days
# 3199   servius tullius
# 3200   rome
# 3201   myth
# 3202   participation
# 3203   first and last roman
# 3204   triumph
# 3205   spirit
# 3206   decius
# 3207   excessive devotion
# 3208   color
# 3209   senate
# 3210   hellenization
# 3211   later empire
# 3212   participation
# 3213   context
# 3214   christian emperor gratian
# 3215   male priests
# 3216   law
# 3217   rome
# 3218   archaeology
# 3219   wife
# 3220   non-official but lawful cults
# 3221   customary offers
# 3222   links
# 3223   household cult
# 3224   euhemerus' theory - popular religious observance
# 3225   householder
# 3226   graeco-roman world
# 3227   roman poets
# 3228   rites
# 3229   gods
# 3230   vesta
# 3231   therefore
# 3232   prodigies
# 3233   funeral and commemorative rites
# 3234   clitellates
# 3235   locomotion
# 3236   septa
# 3237   ragworms' jaws
# 3238   mid ordovician
# 3239   ragworms
# 3240   fluid
# 3241   brain
# 3242   "hairs
# 3243   mature clitellates
# 3244   serve
# 3245   circulates
# 3246   3
# 3247   small shelly fossil cloudina
# 3248   north america
# 3249   annelids
# 3250   found
# 3251   guarantee
# 3252   compound eyes
# 3253   cladistic research
# 3254   guarantee
# 3255   two
# 3256   respiratory pigment
# 3257   one
# 3258   difference
# 3259   one-cell deep epidermis
# 3260   fluid
# 3261   second
# 3262   mature clitellates
# 3263   connective tissue layer
# 3264   annelids
# 3265   china
# 3266   produce
# 3267   fertilized eggs
# 3268   thus
# 3269   two families
# 3270   development pattern
# 3271   rest care
# 3272   locomotion
# 3273   oligochaetes
# 3274   1997
# 3275   septa
# 3276   polychaetes
# 3277   guarantee
# 3278   first
# 3279   annelids
# 3280   oligochaetes
# 3281   brain
# 3282   australia
# 3283   leeches' eggs
# 3284   northern hardwood forests
# 3285   china
# 3286   two
# 3287   vertebrates
# 3288   brain
# 3289   15 %
# 3290   enables
# 3291   2008
# 3292   30 ad
# 3293   terrestrial annelids
# 3294   many fossil tubes
# 3295   clitellates
# 3296   charles darwin's book
# 3297   leeches
# 3298   annelids
# 3299   mid-19th century
# 3300   1964
# 3301   states
# 3302   contemporary u.s. courts
# 3303   authority
# 3304   contemporary u.s. courts
# 3305   american federalism
# 3306   contract
# 3307   public laws
# 3308   reason
# 3309   282,000
# 3310   become
# 3311   states
# 3312   constitution
# 3313   law
# 3314   constitution
# 3315   constitution
# 3316   dual-sovereign system
# 3317   act
# 3318   u.s. law
# 3319   mccarran-ferguson act
# 3320   english
# 3321   20th-century american tort law
# 3322   reason
# 3323   constitution
# 3324   u.s. law
# 3325   law
# 3326   traditional common law pleading
# 3327   american law institute
# 3328   principle
# 3329   eighteen
# 3330   ancient judge-made common law principle
# 3331   american civil procedure
# 3332   u.s.
# 3333   18th and 19th centuries
# 3334   united states
# 3335   congress
# 3336   law
# 3337   united states constitution
# 3338   federal courts
# 3339   many statutes
# 3340   felony convictions
# 3341   eighteen
# 3342   eighteenth century
# 3343   constitution
# 3344   handful
# 3345   prosecution
# 3346   difficult question
# 3347   contemporary english cases
# 3348   writ
# 3349   constitution
# 3350   several legal scholars
# 3351   principle
# 3352   federal constitution
# 3353   states
# 3354   transactions
# 3355   appellate decisions
# 3356   18th and 19th centuries
# 3357   law
# 3358   reception statutes
# 3359   president
# 3360   1964
# 3361   law
# 3362   public laws
# 3363   contract law
# 3364   constitution
# 3365   other major implication
# 3366   united states
# 3367   court
# 3368   subsequent statute
# 3369   1963
# 3370   eighteen
# 3371   indeed
# 3372   citations
# 3373   272,795
# 3374   end
# 3375   traditional common law pleading
# 3376   turn
# 3377   constitution
# 3378   reception statutes
# 3379   federal criminal law
# 3380   scope
# 3381   most broadly influential innovation
# 3382   judge
# 3383   u.s.
# 3384   american civil procedure
# 3385   states
# 3386   supreme court
# 3387   crimes
# 3388   19th century
# 3389   chevron
# 3390   eighteen
# 3391   nineteenth century
# 3392   congress
# 3393   federal agencies
# 3394   decades
# 3395   romanian
# 3396   ming dynasty
# 3397   latin
# 3398   german dictionary
# 3399   significance
# 3400   costa rican
# 3401   two
# 3402   examples
# 3403   swedish
# 3404   dialect
# 3405   ukraine
# 3406   1996
# 3407   joseph wright
# 3408   public environment
# 3409   25.1, 1945
# 3410   low german varieties
# 3411   north african
# 3412   20th century
# 3413   latin
# 3414   german empire
# 3415   today
# 3416   theory
# 3417   tunisia
# 3418   ion bărbuţă
# 3419   risorgimento
# 3420   heinz kloss
# 3421   latin
# 3422   1960s
# 3423   world war i
# 3424   spoken varieties
# 3425   opposite example
# 3426   political factors
# 3427   arabic
# 3428   yiddish speaker
# 3429   northern germany
# 3430   situation
# 3431   bulgarian
# 3432   example
# 3433   northern italy's
# 3434   tunisia
# 3435   standardized dialect
# 3436   various terms
# 3437   italy
# 3438   german empire
# 3439   concepts
# 3440   universally accepted criterion
# 3441   significance
# 3442   italo-dalmatian languages
# 3443   english
# 3444   dialect
# 3445   position
# 3446   german dialectology
# 3447   latin
# 3448   middle ages
# 3449   dialect
# 3450   1860s
# 3451   sardinia
# 3452   19th century
# 3453   language—"everybody
# 3454   italian "avere
# 3455   german
# 3456   caribbean coast
# 3457   italy
# 3458   british and american english
# 3459   german
# 3460   northern germany
# 3461   more general term
# 3462   world war i
# 3463   significance
# 3464   latin
# 3465   yiddish
# 3466   1967
# 3467   italian "avere
# 3468   political factors
# 3469   italians
# 3470   ion bărbuţă
# 3471   english
# 3472   english
# 3473   german
# 3474   red clothing
# 3475   christian countries
# 3476   red
# 3477   1921
# 3478   seven
# 3479   karl marx
# 3480   red ochre
# 3481   christian tradition
# 3482   16th century
# 3483   one to two percent
# 3484   1960s
# 3485   danger
# 3486   red ochre
# 3487   2004
# 3488   cincinnati red stockings
# 3489   coccus
# 3490   roman general
# 3491   red
# 3492   1960
# 3493   ray
# 3494   harvard university
# 3495   communist party
# 3496   1950s and 1960s
# 3497   culture
# 3498   painters
# 3499   spain
# 3500   spirit
# 3501   1790
# 3502   increased performance
# 3503   1523
# 3504   gathered
# 3505   ancient rome
# 3506   demonstration
# 3507   color
# 3508   banner
# 3509   red hair
# 3510   harvard university
# 3511   blood pressure
# 3512   jars
# 3513   scarlet academic gowns
# 3514   february 1848
# 3515   international football
# 3516   virgin mary
# 3517   fourth and fifth
# 3518   cincinnati red stockings
# 3519   ivory painter's palette
# 3520   orange-red or brick red color
# 3521   1870 to 1918
# 3522   red dye
# 3523   spanish conquistador
# 3524   1920s
# 3525   contrast
# 3526   ancient rome
# 3527   1962
# 3528   mines
# 3529   four
# 3530   day
# 3531   path
# 3532   1870
# 3533   teams
# 3534   daytime
# 3535   least 1510
# 3536   296 ad
# 3537   principle
# 3538   humans
# 3539   central africa
# 3540   renaissance
# 3541   cincinnati red stockings
# 3542   seven
# 3543   renaissance
# 3544   spirit
# 3545   five
# 3546   nature
# 3547   principle
# 3548   red flag
# 3549   country
# 3550   painters
# 3551   different variety
# 3552   red
# 3553   song dynasty
# 3554   association football
# 3555   benfica
# 3556   colors
# 3557   egyptians
# 3558   french revolution
# 3559   1962
# 3560   255
# 3561   stunning defeat
# 3562   1920s
# 3563   little red book
# 3564   first 20th-century artists
# 3565   renaissance
# 3566   nature
# 3567   39-day
# 3568   christmas
# 3569   rubia plant
# 3570   communist party
# 3571   coccus
# 3572   principle
# 3573   red
# 3574   romans
# 3575   even more money
# 3576   even more money
# 3577   red lac
# 3578   19th century
# 3579   georgia
# 3580   benfica
# 3581   fall
# 3582   famous hymn
# 3583   party leader mao zedong
# 3584   today
# 3585   red coloration
# 3586   1966
# 3587   1295
# 3588   systematic study
# 3589   abbe suger
# 3590   manchu rulers
# 3591   1888
# 3592   first 20th-century
# 3593   1920s
# 3594   red stripes
# 3595   1870
# 3596   face
# 3597   red color
# 3598   high levels
# 3599   five years
# 3600   red sky
# 3601   zhou
# 3602   modern color theory
# 3603   red
# 3604   october
# 3605   vincent van gogh
# 3606   one to two percent
# 3607   silver
# 3608   most famous works
# 3609   chinese cultural traditions
# 3610   egyptians
# 3611   coccus
# 3612   cincinnati red stockings
# 3613   fourth and fifth
# 3614   highways
# 3615   1920
# 3616   one popular color
# 3617   one popular color
# 23

# %% [markdown]
# #  准确率测试

# %%
with open('training.json') as json_data:
    train = json.load(json_data)
    
case_count = 0
empty_count = 0
wrong_count = 0
# test = [test[17]]
for test_case in train:
    question = test_case['question']
    docid = test_case['docid']
    correct_answer = test_case['text']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)
    

    # TFIDF
#     doc_term_freqs = {}
#     for (id, raw_doc) in enumerate(raw_docs):
#         term_freqs = extract_term_freqs(raw_doc)
#         doc_term_freqs[id] = term_freqs
#     M = len(doc_term_freqs)

#     doc_freqs = compute_doc_freqs(doc_term_freqs)

#     vsm_inverted_index = defaultdict(list)
#     for docid, term_freqs in doc_term_freqs.items():
#         N = sum(term_freqs.values())
#         length = 0

#         # find tf*idf values and accumulate sum of squares
#         tfidf_values = []
#         for term, count in term_freqs.items():
#             tfidf = float(count) / N * log(M / float(doc_freqs[term]))
#             tfidf_values.append((term, tfidf))
#             length += tfidf ** 2

#         # normalise documents by length and insert into index
#         length = length ** 0.5
#         for term, tfidf in tfidf_values:
#             # inversion of the indexing, term -> (doc_id, score)
#             vsm_inverted_index[term].append([docid, tfidf / length])

#     for term, docids in vsm_inverted_index.items():
#         docids.sort()

#     terms = extract_term_freqs(question) 
#     results = query_vsm(terms, vsm_inverted_index)
    
    
    tokenized_sentence = []
    for each_sentence in raw_docs:
        filter_stop_word = []
        sentence_as_words = nltk.word_tokenize(each_sentence)
        for each_word in sentence_as_words:
            if each_word not in stop:
                filter_stop_word.append(each_word)
        
        tokenized_sentence.append(filter_stop_word)
        
    bm25Model = bm25.BM25(tokenized_sentence)
    average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
    query = []
    for word in nltk.word_tokenize(question):
        if word not in stop:
            query.append(word)
        
    scores = bm25Model.get_scores(query,average_idf)
    bm25_dic = Counter()
    
    sentence_id = 0
    for each_score in scores:
        bm25_dic[sentence_id] = each_score
        sentence_id += 1
    results = bm25_dic.most_common(3)




    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['often']:
            qtype = 'FREQUENCY'        
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:
        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'

        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        elif 'name' in tokens:
            qtype = 'NE'

        else:
            # what...do type question
            try:
                tokens.remove(next_token)
            except:
                tokens = tokens
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the 20 sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC','FREQUENCY']:
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1
                    
        elif qtype == 'NE':
            for ent in doc.ents:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.5 + (scores[id] / max_score * 0.5)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get,default=0)
    sent = raw_docs[index]
    doc = nlp(sent)

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if qtype in ['LOC','GPE'] and ent.root.tag_ not in ['NN','NNP','NNS','NNPS']:
                score -= 2
                
            if score > max_score:
                max_score = score
                answer = ent.text
                
                if qtype in ['MONEY']:
                    for token in doc:
                        if token.text == '$':
                            answer = '$ ' + answer
                            
                if qtype in ['PERCENT']:
                    if 'percent' in answer:
                        answer = answer[:answer.index('percent')-1]
                            
                if qtype in ['PERCENT','QUANTITY','CARDINAL','MONEY']:
                    tokens = nltk.word_tokenize(answer)
                    i = 0
                    answer = ''
                    while i < len(tokens):
                        if tokens[i].lower() in ['well','about','around','approximately', 'some','least','close to','than','high as','least']:
                            del tokens[i]
                        else:
                            if i+1 < len(tokens) and tokens[i+1] == "'s":
                                answer += tokens[i]
                            else:
                                answer += tokens[i] + ' '
                            i += 1
                    answer = answer.strip()
                    
    elif qtype == 'NE':
        for ent in doc.ents:
            score = 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = np.text
                
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    if correct_answer != answer.strip().lower():
        wrong_count += 1
        print('Support: ',sent)
        print('***')
        print('Question: ',question)
        print('***')
        print('Correct: ',correct_answer)
        print('***')
        print('predicted: ',answer.strip().lower())
        print('\n')
        print('\n')

    case_count += 1
    if answer == '':
        empty_count += 1
    
csvFile.close()
print('Empty: ',empty_count)
print('Wrong: ',wrong_count)
print('Total: ',case_count - 1)
# Out:
# Support:  A change of several tens of micrograms in one kilogram is equivalent to the current uncertainty in the value of the Planck constant in SI units.
# ***
# Question:  A kilogram could be definined as having a Planck constant of what value?
# ***
# Correct:  6966662606895999999♠6.62606896×10−34 j⋅s
# ***
# predicted:  several tens
#
#
#
#
# Support:  The most urgent unit on the list for redefinition is the kilogram, whose value has been fixed for all science (since 1889) by the mass of a small cylinder of platinum–iridium alloy kept in a vault just outside Paris.
# ***
# Question:  What is the shape of the object that establishes the base unit of the kilogram?
# ***
# Correct:  cylinder
# ***
# predicted:  most urgent unit
#
#
#
#
# Support:  In modern terms, if J is the total angular momentum of a system with rotational invariance, and Jz the angular momentum measured along any given direction, these quantities can only take on the values where the uncertainty is given as the standard deviation of the measured value from its expected value.
# ***
# Question:  What example is given as another paired relationship of uncertainly related to standard deviation?
# ***
# Correct:  time vs. energy
# ***
# predicted:  modern terms
#
#
#
#
# Support:  It is defined in terms of the reduced Planck constant, the elementary charge and the electron mass, all of which depend on the Planck constant: the final dependence on h1/2 (r2 > 0.995) can be found by expanding the variables.
# ***
# Question:  What does the Planck Constant refer to?
# ***
# Correct:  quantum of action
# ***
# predicted:  r2
#
#
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# ***
# Question:  What scientist first studied black body radiation?
# ***
# Correct:  kirchhoff
# ***
# predicted:  max planck
#
#
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  Who helped to give the correct quantization rules for electrons in 1926?
# ***
# Correct:  schrödinger
# ***
# predicted:  energy
#
#
#
#
# Support:  Classical statistical mechanics requires the existence of h (but does not define its value).
# ***
# Question:  What is required to exist in classical statistics mechanics?
# ***
# Correct:  h
# ***
# predicted:  classical statistical mechanics
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  How much energy is contained in the light to which human eyes are most sensitive?
# ***
# Correct:  7005216000000000000♠216 kj/mol
# ***
# predicted:  555
#
#
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What is frequency also known as in science?
# ***
# Correct:  f
# ***
# predicted:  colour
#
#
#
#
# Support:  It was first observed by Alexandre Edmond Becquerel in 1839, although credit is usually reserved for Heinrich Hertz, who published the first thorough investigation in 1887.
# ***
# Question:  Who published the first thorough investigation of the photoelectric effect?
# ***
# Correct:  heinrich hertz
# ***
# predicted:  alexandre edmond becquerel
#
#
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# ***
# Question:  What is the term used when photoelectrons act virtually at the same time?
# ***
# Correct:  multiphoton effect
# ***
# predicted:  kinetic energy
#
#
#
#
# Support:  The Bohr magneton and the nuclear magneton are units which are used to describe the magnetic properties of the electron and atomic nuclei respectively.
# ***
# Question:  What is the unit of magentic properties of atomic nuclei?
# ***
# Correct:  nuclear magneton
# ***
# predicted:  bohr magneton
#
#
#
#
# Support:  In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.
# ***
# Question:  Who discovered an association between the value E and quantum energy?
# ***
# Correct:  einstein
# ***
# predicted:  minimal energy increment
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  At about what wavelength of light are human eyes most sensitive?
# ***
# Correct:  555 nanometres
# ***
# predicted:  example
#
#
#
#
# Support:  The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.
# ***
# Question:  What is required for the electromagnetic field to come to thermal equilibrium?
# ***
# Correct:  hot atoms
# ***
# predicted:  electromagnetic field
#
#
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# ***
# Question:  Who received the Nobel Prize in 1921 for his work on the photoelectric effect?
# ***
# Correct:  einstein
# ***
# predicted:  robert andrews millikan
#
#
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What assumption that black-body radiation is what leads to an accurate prediction?
# ***
# Correct:  thermal
# ***
# predicted:  total amount
#
#
#
#
# Support:  That is a very small amount of energy in terms of everyday experience, but everyday experience is not concerned with individual photons any more than with individual atoms or molecules.
# ***
# Question:  What term describes a small amount of element?
# ***
# Correct:  quantum
# ***
# predicted:  very small amount
#
#
#
#
# Support:  In many cases, such as for monochromatic light or for atoms, this quantum of action also implies that only certain energy levels are allowed, and values in between are forbidden.
# ***
# Question:  Regarding atoms, what are values in between certain energy levels considered by the Planck constant?
# ***
# Correct:  forbidden
# ***
# predicted:  quantum
#
#
#
#
# Support:  Equivalently, the smallness of the Planck constant reflects the fact that everyday objects and systems are made of a large number of particles.
# ***
# Question:  What are common things like furniture and stationary objects actually made of?
# ***
# Correct:  particles
# ***
# predicted:  smallness
#
#
#
#
# Support:  Prior to Einstein's paper, electromagnetic radiation such as visible light was considered to behave as a wave: hence the use of the terms "frequency" and "wavelength" to characterise different types of radiation.
# ***
# Question:  Before Einstein, electromagnetic radiation was considered to behave as what?
# ***
# Correct:  a wave
# ***
# predicted:  visible light
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What color of light is the human eye most sensitive to?
# ***
# Correct:  green
# ***
# predicted:  example
#
#
#
#
# Support:  The black-body problem was revisited in 1905, when Rayleigh and Jeans (on the one hand) and Einstein (on the other hand) independently proved that classical electromagnetism could never account for the observed spectrum.
# ***
# Question:  Einstein and what other two individuals revisited the black-body problem in 1905?
# ***
# Correct:  rayleigh and jeans
# ***
# predicted:  jeans
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  Which scientist associated the Planck constant with a quantum five years after Planck's recognition?
# ***
# Correct:  einstein
# ***
# predicted:  last years
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What is the frequency of the light to which the human eye is most sensitive?
# ***
# Correct:  7014540000000000000♠540 thz
# ***
# predicted:  example
#
#
#
#
# Support:  These proofs are commonly known as the "ultraviolet catastrophe", a name coined by Paul Ehrenfest in 1911.
# ***
# Question:  What name did Paul Ehrenfest give to the proofs from Einstein and Rayleigh & Jeans?
# ***
# Correct:  the `` ultraviolet catastrophe ''
# ***
# predicted:  1911
#
#
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# ***
# Question:  What measurement is deemed most important to redefine in terms of physical constants?
# ***
# Correct:  the kilogram
# ***
# predicted:  planck constant
#
#
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What is the energy transferred by a wave in a given time called?
# ***
# Correct:  intensity
# ***
# predicted:  energy
#
#
#
#
# Support:  The most likely reason is that the measurement uncertainty for one (or both) of the methods has been estimated too low – it is (or they are) not as precise as is currently believed – but for the time being there is no indication which method is at fault.
# ***
# Question:  What method was was used to obtain the measurement?
# ***
# Correct:  watt-balance measurement
# ***
# predicted:  most likely reason
#
#
#
#
# Support:  If these theories are slightly inaccurate – though there is no evidence at present to suggest they are – the methods would not give accurate values for the Planck constant.
# ***
# Question:  Using Planck constant values from these effects would lead to what logical issue?
# ***
# Correct:  a circular argument
# ***
# predicted:  present
#
#
#
#
# Support:  Possible new definitions include "the mass of a body at rest whose equivalent energy equals the energy of photons whose frequencies sum to 7050135639273999999♠135639274×1042 Hz", or simply "the kilogram is defined so that the Planck constant equals 6966662606895999999♠6.62606896×10−34 J⋅s".
# ***
# Question:  The mass of a resting body with what energy would be equal to a kilogram?
# ***
# Correct:  7050135639273999999♠135639274×1042 hz
# ***
# predicted:  body
#
#
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# ***
# Question:  What does the kinetic energy of a photoelectron depend on?
# ***
# Correct:  the frequency
# ***
# predicted:  kinetic energy
#
#
#
#
# Support:  It was eventually called the photon.
# ***
# Question:  What was later termed the photon?
# ***
# Correct:  the light quantum
# ***
# predicted:
#
#
#
#
# Support:  The X-ray crystal density method is primarily a method for determining the Avogadro constant NA but as the Avogadro constant is related to the Planck constant it also determines a value for h. The principle behind the method is to determine NA as the ratio between the volume of the unit cell of a crystal, measured by X-ray crystallography, and the molar volume of the substance.
# ***
# Question:  What element is used typically to establish Avogadro's constant?
# ***
# Correct:  crystals of silicon
# ***
# predicted:  x-ray crystal density method
#
#
#
#
# Support:  There are a number of other such pairs of physically measurable values which obey a similar rule.
# ***
# Question:   What measurable value obeys a similar rule of angular momentum?
# ***
# Correct:  time vs. energy
# ***
# predicted:  number
#
#
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What other types of wave besides light has its own intensity?
# ***
# Correct:  sound
# ***
# predicted:  energy
#
#
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# ***
# Question:  What do scientists assume black body radiation is?
# ***
# Correct:  thermal
# ***
# predicted:  max planck
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What frequency does green light with a wavelength of 555 nanmetres have?
# ***
# Correct:  7014540000000000000♠540 thz
# ***
# predicted:  example
#
#
#
#
# Support:  The either-or nature of uncertainty forces measurement attempts to choose between trade offs, and given that they are quanta, the trade offs often take the form of either-or (as in Fourier analysis), rather than the compromises and gray areas of time series analysis.
# ***
# Question:  What type of analysis fits the either-or nature of the uncertainty?
# ***
# Correct:  fourier analysis
# ***
# predicted:  uncertainty forces measurement
#
#
#
#
# Support:  Eventually, following upon Planck's discovery, it was recognized that physical action cannot take on an arbitrary value.
# ***
# Question:  After Planck's findings, what was determined could not take on an arbitrary value?
# ***
# Correct:  physical action
# ***
# predicted:  planck
#
#
#
#
# Support:  There are a number of other such pairs of physically measurable values which obey a similar rule.
# ***
# Question:  Electromagnetic fields obey what laws?
# ***
# Correct:  laws of motion
# ***
# predicted:  number
#
#
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  Which light wavelength is the human eye most sensitive to?
# ***
# Correct:  555 nanometres
# ***
# predicted:  example
#
#
#
#
# Support:  They contributed greatly (along with Einstein's work on the photoelectric effect) to convincing physicists that Planck's postulate of quantized energy levels was more than a mere mathematical formalism.
# ***
# Question:  Einstein's photoelectric effect work was rewards as opposed to his work on what other topic?
# ***
# Correct:  relativity
# ***
# predicted:  photoelectric effect
#
#
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  What is the reduced Planck constant also known as?
# ***
# Correct:  the quantity
# ***
# predicted:  bohr
#
#
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  What type of radiation was Planck studying in the late 19th century?
# ***
# Correct:  black-body
# ***
# predicted:  last years of the nineteenth century
#
#
#
#
# Support:  To make Planck's law, which correctly predicts blackbody emissions, it was necessary to multiply the classical expression by a complex factor that involves h in both the numerator and the denominator.
# ***
# Question:  In making Planck's law, what was in both the numerator and denominator of the formula that was used?
# ***
# Correct:  h
# ***
# predicted:
#
#
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  What is the Planck constant formerly known as?
# ***
# Correct:  quantum of action
# ***
# predicted:  bohr
# Support:  The result is that green light of wavelength 555 nm has an energy of 7005216000000000000♠216 kJ/mol, a typical energy of everyday life.
# ***
# Question:  How much energy does a green light of wavelength 555 nm contain?
# ***
# Correct:  7005216000000000000♠216 kj/mol
# ***
# predicted:  7005216000000000000
#
#
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  What scientist used matrix mechanics to bring electron behavior in line with the Bohr model?
# ***
# Correct:  heisenberg
# ***
# predicted:  electrons
#
#
#
#
# Support:  The Rayleigh–Jeans law makes close predictions for a narrow range of values at one limit of temperatures, but the results diverge more and more strongly as temperatures increase.
# ***
# Question:  What rule predicted narrow range of energy values at lower temperatures?
# ***
# Correct:  the rayleigh–jeans
# ***
# predicted:  rayleigh–jeans law
#
#
#
#
# Support:  The most urgent unit on the list for redefinition is the kilogram, whose value has been fixed for all science (since 1889) by the mass of a small cylinder of platinum–iridium alloy kept in a vault just outside Paris.
# ***
# Question:  What alloy is the base unit of the kilogram made from?
# ***
# Correct:  platinum–iridium
# ***
# predicted:  most urgent unit
#
#
#
#
# Support:  If the object is black, meaning it absorbs all the light that hits it, then its thermal light emission is maximized.
# ***
# Question:  What is maximized as a result of a black object absorbing all the light that hits it?
# ***
# Correct:  thermal light emission
# ***
# predicted:  object
#
#
#
#
# Support:  Each photon has an energy E = hf = 6981358000000000000♠3.58×10−19 J.
# ***
# Question:  What is the energy of a photon?
# ***
# Correct:  6981358000000000000♠3.58×10−19 j
# ***
# predicted:  photon
#
#
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What color is hotter than "red hot"?
# ***
# Correct:  white hot
# ***
# predicted:  colour
#
#
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  Planck studied what problem posed originally by Kirchhoff?
# ***
# Correct:  black-body radiation
# ***
# predicted:  last years
#
#
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What is the name for the amount of energy transfered by a wave in a given time?
# ***
# Correct:  intensity
# ***
# predicted:  energy
#
#
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# ***
# Question:  Einstein's paper on the photoelectric effect earned him the Nobel Prize in what year?
# ***
# Correct:  1921
# ***
# predicted:  1905
#
#
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  Who helped to give the correct quantization rules for electrons in 1925?
# ***
# Correct:  heisenberg
# ***
# predicted:  energy
#
#
#
#
# Support:  However, the energy account of the photoelectric effect didn't seem to agree with the wave description of light.
# ***
# Question:  What portion of the photoelectric effect was in disagreement with the believed description of light behavior?
# ***
# Correct:  the energy account
# ***
# predicted:  energy account
#
#
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What law describes the changes in light emitted by a hot object?
# ***
# Correct:  stefan–boltzmann law
# ***
# predicted:  colour
#
#
#
#
# Support:  Prior to Planck's work, it had been assumed that the energy of a body could take on any value whatsoever – that it was a continuous variable.
# ***
# Question:  Prior to Einstein's work, light behavior was modeled as what?
# ***
# Correct:  a wave
# ***
# predicted:  planck's work
#
#
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  How many years prior to Planck's study had the scientific community first discussed black body radiation?
# ***
# Correct:  forty
# ***
# predicted:  last years of the nineteenth century
#
#
#
#
# Support:  The hot object in equilibrium with light absorbs just as much light as it emits.
# ***
# Question:  What does a hot object in equilibrium absorb as much as it emits?
# ***
# Correct:  light
# ***
# predicted:  hot object
#
#
#
#
# Support:  It is well known that hot objects glow, and that hotter objects glow brighter than cooler ones.
# ***
# Question:  Cooler objects glow less than objects that are what?
# ***
# Correct:  hotter
# ***
# predicted:
#
#
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What kind of prediction does the assumption that black body radiation is thermal lead to?
# ***
# Correct:  accurate
# ***
# predicted:  assumption
#
#
#
#
# Support:  The molar volume Vm(Si) requires a knowledge of the density of the crystal and the atomic weight of the silicon used.
# ***
# Question:  One other measure involved the molar volume of what element?
# ***
# Correct:  silicon
# ***
# predicted:  density
#
#
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What rule predicts that emitted energy increases with temperature?
# ***
# Correct:  the stefan–boltzmann law
# ***
# predicted:  stefan
#
#
#
#
# Support:  Global wind power installations increased by 35,800 MW in 2010, bringing total installed capacity up to 194,400 MW, a 22.5% increase on the 158,700 MW installed at the end of 2009.
# ***
# Question:  Global wind power installations increased by how much in 2010?
# ***
# Correct:  35,800 mw
# ***
# predicted:  35,800
#
#
#
#
# Support:  According to a 2011 projection by the International Energy Agency, solar power plants may produce most of the world's electricity within 50 years, significantly reducing the emissions of greenhouse gases that harm the environment.
# ***
# Question:  Which group projected that solar plant may produce most of the world's electricity within 50 years?
# ***
# Correct:  international energy agency
# ***
# predicted:  2011 projection
#
#
#
#
# Support:  The company ceased all business activity, filed for Chapter 11 bankruptcy, and laid-off nearly all of its employees in early September 2011.
# ***
# Question:  What company filed for Chapter 11 bankruptcy?
# ***
# Correct:  solyndra
# ***
# predicted:  early september 2011
#
#
#
#
# Support:  Worldwide investment in solar power in 2012 was $140.4 billion, an 11 percent decline from 2011, and wind power investment was down 10.1 percent, to $80.3 billion.
# ***
# Question:  How much was the worldwide investment in solar power in 2012?
# ***
# Correct:  $ 140.4 billion
# ***
# predicted:  $ $ $ 140.4 billion
#
#
#
#
# Support:  The incentive to use 100% renewable energy, for electricity, transport, or even total primary energy supply globally, has been motivated by global warming and other ecological as well as economic concerns.
# ***
# Question:  What motivated the incentive to use 100 percent renewable energy?
# ***
# Correct:  global warming
# ***
# predicted:  100 %
#
#
#
#
# Support:  Jacobson says that energy costs with a wind, solar, water system should be similar to today's energy costs.
# ***
# Question:  Who stated that energy costs with a wind, solar, water system should be similar to today's energy costs?
# ***
# Correct:  mark z. jacobson
# ***
# predicted:  jacobson
#
#
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# ***
# Question:  Photovoltaic and solar-thermal plants may meet how much of the world's energy needs by 2060?
# ***
# Correct:  half
# ***
# predicted:  2060 – and half
# Support:  Solar thermal power stations include the 354 megawatt (MW) Solar Energy Generating Systems power plant in the USA, Solnova Solar Power Station (Spain, 150 MW), Andasol solar power station (Spain, 100 MW), Nevada Solar One (USA, 64 MW), PS20 solar power tower (Spain, 20 MW), and the PS10 solar power tower (Spain, 11 MW).
# ***
# Question:  Where is the PS20 solar power tower located?
# ***
# Correct:  spain
# ***
# predicted:  usa
#
#
#
#
# Support:  Solar electricity consumption increased by 58 percent, to 93 terawatt-hours (TWh).
# ***
# Question:  In 2012, solar electricity consumption increased by what percentage?
# ***
# Correct:  58 percent
# ***
# predicted:  58
#
#
#
#
# Support:  Use of wind power in 2012 increased by 18.1 percent, to 521.3 TWh.
# ***
# Question:  Use of wind power in 2012 increased by what percentage?
# ***
# Correct:  18.1 percent
# ***
# predicted:  18.1
#
#
#
#
# Support:  Based on REN21's 2014 report, renewables contributed 19 percent to our energy consumption and 22 percent to our electricity generation in 2012 and 2013, respectively.
# ***
# Question:  Renewables contributed what percentage to our electricity generation?
# ***
# Correct:  22 percent
# ***
# predicted:  19
#
#
#
#
# Support:  In 2011, UN under-secretary general Achim Steiner said: "The continuing growth in this core segment of the green economy is not happening by chance.
# ***
# Question:  Who was the UN under-secretary in 2011?
# ***
# Correct:  achim steiner
# ***
# predicted:  un under-secretary general achim steiner
#
#
#
#
# Support:  In 2011, UN under-secretary general Achim Steiner said: "The continuing growth in this core segment of the green economy is not happening by chance.
# ***
# Question:  Who is Achim Steiner?
# ***
# Correct:  un under-secretary general
# ***
# predicted:  un under-secretary general achim steiner
#
#
#
#
# Support:  It involves lowering income taxes while raising levies on environmentally destructive activities, in order to create a more responsive market.
# ***
# Question:  What involves lowering income taxes while raising levies?
# ***
# Correct:  tax shifting
# ***
# predicted:  environmentally destructive activities
#
#
#
#
# Support:  Other developed countries with defined national or regional targets include Australia, Canada, Israel, Japan, Korea, New Zealand, Norway, Singapore, Switzerland, and some US States.
# ***
# Question:  Name one outher country with defined national or regional target?
# ***
# Correct:  australia
# ***
# predicted:  developed countries
#
#
#
#
# Support:  Barriers to implementing the renewable energy plan are seen to be "primarily social and political, not technological or economic".
# ***
# Question:  What is a barrier to implementing the renewable energy plan?
# ***
# Correct:  social and political
# ***
# predicted:  barriers
#
#
#
#
# Support:  The 230 MW Antelope Valley Solar Ranch is a First Solar photovoltaic project which is under construction in the Antelope Valley area of the Western Mojave Desert, and due to be completed in 2013.
# ***
# Question:  Who is building The Califoria Valley Solar Ranch?
# ***
# Correct:  sunpower
# ***
# predicted:  230 mw antelope valley solar ranch
#
#
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# ***
# Question:  Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by what year?
# ***
# Correct:  2060
# ***
# predicted:  2060 – and half
#
#
#
#
# Support:  Nearly all the gasoline sold in the United States today is mixed with 10 percent ethanol, a mix known as E10, and motor vehicle manufacturers already produce vehicles designed to run on much higher ethanol blends.
# ***
# Question:  Nearly all gasoline sold in the U.S. is mixed with what percentage of ethanol?
# ***
# Correct:  10 percent
# ***
# predicted:  10
#
#
#
#
# Support:  Setting national renewable energy targets can be an important part of a renewable energy policy and these targets are usually defined as a percentage of the primary energy and/or electricity generation mix.
# ***
# Question:  Hydroelectricity accounts for what percentage of global electricity generation?
# ***
# Correct:  hydroelectricity
# ***
# predicted:  renewable energy policy
#
#
#
#
# Support:  Ford, DaimlerChrysler, and GM are among the automobile companies that sell flexible-fuel cars, trucks, and minivans that can use gasoline and ethanol blends ranging from pure gasoline up to 85% ethanol (E85).
# ***
# Question:  Name one company that sells flexible-fuel cars?
# ***
# Correct:  gm
# ***
# predicted:  ford
#
#
#
#
# Support:  In some countries, geothermal power accounts for a significant share of the total electricity supply, such as in the Philippines, where geothermal represented 17 percent of the total power mix at the end of 2008.
# ***
# Question:  What was the geothermal capacity in 2008?
# ***
# Correct:  10 gw
# ***
# predicted:  countries
#
#
#
#
# Support:  As of 2012, renewable energy plays a major role in the energy mix of many countries globally.
# ***
# Question:  How many countries now have renewable energy policies?
# ***
# Correct:  144
# ***
# predicted:  2012
#
#
#
#
# Support:  Based on REN21's 2014 report, renewables contributed 19 percent to our energy consumption and 22 percent to our electricity generation in 2012 and 2013, respectively.
# ***
# Question:  Renewables contributed what percentage to our energy consumption?
# ***
# Correct:  19 percent
# ***
# predicted:  19
#
#
#
#
# Support:  In terms of specific examples, the Internet was the result of publicly funded links among computers in government laboratories and research institutes.
# ***
# Question:  What was the result of publicly funded links among computers in government labs and reserach institutes?
# ***
# Correct:  the internet
# ***
# predicted:  terms
#
#
#
#
# Support:  As of 2011[update], there have been substantial reductions in the cost of solar and wind technologies: Renewable energy is also the most economic solution for new grid-connected capacity in areas with good resources.
# ***
# Question:  As of what year have there been substantial reductions in the cost of solar and wind technologies?
# ***
# Correct:  2011
# ***
# predicted:  solar and wind technologies
#
#
#
#
# Support:  The 370 MW Ivanpah Solar Power Facility, located in California's Mojave Desert, is the world's largest solar-thermal power plant project currently under construction.
# ***
# Question:  Where is the Ivanpah Solar Power Facility located?
# ***
# Correct:  california 's mojave desert
# ***
# predicted:  california
#
#
#
#
# Support:  The PV industry has seen drops in module prices since 2008.
# ***
# Question:  The PV industry has seen drops in module prices since what year?
# ***
# Correct:  2008
# ***
# predicted:  since 2008
#
#
#
#
# Support:  As of 2012, renewable energy accounts for about half of new nameplate electrical capacity installed and costs are continuing to fall.
# ***
# Question:  As of 2012, what accounts for about half of new nameplate electrical capacity?
# ***
# Correct:  renewable energy
# ***
# predicted:  renewable energy accounts
#
#
#
#
# Support:  It is the most widely used form of renewable energy, accounting for 16 percent of global electricity generation – 3,427 terawatt-hours of electricity production in 2010, and is expected to increase about 3.1% each year for the next 25 years.
# ***
# Question:  What is the most widely used form of renewable energy?
# ***
# Correct:  hydroelectricity
# ***
# predicted:  16 percent
#
#
#
#
# Support:  Wind power accounts for approximately 19% of electricity generated in Denmark, 9% in Spain and Portugal, and 6% in Germany and the Republic of Ireland.
# ***
# Question:  In Spain, wind power accounts for what percentage of electricity generated?
# ***
# Correct:  9 %
# ***
# predicted:  19 %
#
#
#
#
# Support:  United Nations' Secretary-General Ban Ki-moon has said that "renewable energy has the ability to lift the poorest nations to new levels of prosperity".
# ***
# Question:  Ban Ki-moon states that renewable energy has the ability to lift the poorest nations to new levels of prosperity?
# ***
# Correct:  renewable energy
# ***
# predicted:  united nations' secretary-general ban ki-moon
#
#
#
#
# Support:  In some countries, geothermal power accounts for a significant share of the total electricity supply, such as in the Philippines, where geothermal represented 17 percent of the total power mix at the end of 2008.
# ***
# Question:  In the Phillipines, geothermal represented what percentage of the total power mix at the end of 2008?
# ***
# Correct:  17 percent
# ***
# predicted:  17
#
#
#
#
# Support:  As a share of total investment in power plants, wind and solar PV grew from 14% in 2000 to over 60% in 2012.
# ***
# Question:  How much was the total investment in renewable energy in 2012?
# ***
# Correct:  $ 244 billion
# ***
# predicted:  pv
#
#
#
#
# Support:  According to the directive the EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed and therefore a "guarantee of origin" must be issued (article 15).
# ***
# Question:  What states that EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed?
# ***
# Correct:  res directive
# ***
# predicted:  directive
# Support:  Innovation has helped, but the main driver of reduced costs has been market expansion.
# ***
# Question:  What is the main driver of reduced costs?
# ***
# Correct:  market expansion
# ***
# predicted:  innovation
#
#
#
#
# Support:  Geothermal power capacity grew from around 1 GW in 1975 to almost 10 GW in 2008.
# ***
# Question:  What was the geothermal capacity in 1975?
# ***
# Correct:  1 gw
# ***
# predicted:  geothermal power capacity
#
#
#
#
# Support:  A 2011 IEA report said: "A portfolio of renewable energy technologies is becoming cost-competitive in an increasingly broad range of circumstances, in some cases providing investment opportunities without the need for specific economic support," and added that "cost reductions in critical technologies, such as wind and solar, are set to continue."
# ***
# Question:  What group stated that "cost reductions in critical technologies, such as wind and solar, are set to continue?"
# ***
# Correct:  iea
# ***
# predicted:  2011 iea report
#
#
#
#
# Support:  As of 2011[update], there have been substantial reductions in the cost of solar and wind technologies: Renewable energy is also the most economic solution for new grid-connected capacity in areas with good resources.
# ***
# Question:  What is the most economic solution for new grid-connected capacity in areas with good resources?
# ***
# Correct:  renewable energy
# ***
# predicted:  substantial reductions
#
#
#
#
# Support:  The Blythe Solar Power Project is a 500 MW photovoltaic station under construction in Riverside County, California.
# ***
# Question:  Where is the Agua Caliente Solar Project located?
# ***
# Correct:  usa
# ***
# predicted:  riverside county
#
#
#
#
# Support:  The group is to be co-chaired by Kandeh Yumkella, the chair of UN Energy and director general of the UN Industrial Development Organisation, and Charles Holliday, chairman of Bank of America".
# ***
# Question:  Who is chairman of Bank of America?
# ***
# Correct:  charles holliday
# ***
# predicted:  kandeh yumkella
#
#
#
#
# Support:  Spielberg directed 2015's Bridge of Spies, a Cold War thriller based on the 1960 U-2 incident, and focusing on James B. Donovan's negotiations with the Soviets for the release of pilot Gary Powers after his aircraft was shot down over Soviet territory.
# ***
# Question:  Who played Donovan in 'Bridge of Spies'?
# ***
# Correct:  tom hanks
# ***
# predicted:  spielberg
#
#
#
#
# Support:  He developed the series with Robert Rodat and is credited as an executive producer.
# ***
# Question:  What show did Spielberg work with Rodat on?
# ***
# Correct:  falling skies
# ***
# predicted:  series
#
#
#
#
# Support:  Drawing from his own experiences in Scouting, Spielberg helped the Boy Scouts of America develop a merit badge in cinematography in order to help promote filmmaking as a marketable skill.
# ***
# Question:  When did Spielberg join the Boy Scouts?
# ***
# Correct:  1958
# ***
# predicted:  boy scouts of america
#
#
#
#
# Support:  The archaeologist and adventurer hero Indiana Jones was played by Harrison Ford (whom Lucas had previously cast in his Star Wars films as Han Solo).
# ***
# Question:  Who was responsible for Star Wars?
# ***
# Correct:  george lucas
# ***
# predicted:  harrison ford
#
#
#
#
# Support:  In 1989, he brought the concept of The Dig to LucasArts.
# ***
# Question:  When was 'The Dig' released?
# ***
# Correct:  1995
# ***
# predicted:  1989
#
#
#
#
# Support:  He was later given the opportunity to make a short film for theatrical release, the 26-minute, 35mm, Amblin', which he wrote and directed.
# ***
# Question:  What short film did Spielberg make for theatrical release?
# ***
# Correct:  amblin
# ***
# predicted:  opportunity
#
#
#
#
# Support:  Studio vice president Sidney Sheinberg was impressed by the film, which had won a number of awards, and offered Spielberg a seven-year directing contract.
# ***
# Question:  What was Sidney Sheinberg's position with Universal?
# ***
# Correct:  vice president
# ***
# predicted:  studio vice president sidney sheinberg
#
#
#
#
# Support:  It was released just four days after The Adventures of Tintin, on December 25, 2011.
# ***
# Question:  When was Adventures of Tintin released in the US?
# ***
# Correct:  december 21 , 2011
# ***
# predicted:  four days
#
#
#
#
# Support:  According to Forbes' Most Influential Celebrities 2014 list, Spielberg was listed as the most influential celebrity in America.
# ***
# Question:  When was 'Skullmonkeys' released?
# ***
# Correct:  1997
# ***
# predicted:  2014
#
#
#
#
# Support:  Studio producers Richard D. Zanuck and David Brown offered Spielberg the director's chair for Jaws, a thriller-horror film based on the Peter Benchley novel about an enormous killer shark.
# ***
# Question:  What film did Richard D. Zanuck and David Brown offer Steven Spielberg to direct?
# ***
# Correct:  jaws
# ***
# predicted:  studio producers
#
#
#
#
# Support:  Spielberg played many of LucasArts adventure games, including the first Monkey Island games.
# ***
# Question:  How does Spielberg feel about cutscenes in games?
# ***
# Correct:  intrusive
# ***
# predicted:  played
#
#
#
#
# Support:  He bought Orson Welles's own directorial copy of the script for the radio broadcast The War of the Worlds (1938) in 1994.
# ***
# Question:  Which studios produced Spielberg's 'War of the Worlds'?
# ***
# Correct:  paramount and dreamworks
# ***
# predicted:  orson welles's own directorial copy
#
#
#
#
# Support:  the Extra-Terrestrial, Empire of the Sun, Jurassic Park, etc.
# ***
# Question:  When did Jurassic Park come out?
# ***
# Correct:  1993
# ***
# predicted:  extra-terrestrial
#
#
#
#
# Support:  His next directorial feature was the Raiders prequel Indiana Jones and the Temple of Doom.
# ***
# Question:  When did 'Temple of Doom' debut?
# ***
# Correct:  1984
# ***
# predicted:  raiders
#
#
#
#
# Support:  Despite the film's ultimate, enormous success, it was nearly shut down due to delays and budget over-runs.
# ***
# Question:  What was the budget for 'Robopocalypse'?
# ***
# Correct:  $ 200 million
# ***
# predicted:  film's ultimate , enormous success
#
#
#
#
# Support:  In 1997, the American Film Institute listed it among the 10 Greatest American Films ever Made (#9) which moved up to (#8) when the list was remade in 2007.
# ***
# Question:  Where did the American Film Institute rank 'Schindler's List' in 1997?
# ***
# Correct:  # 9
# ***
# predicted:  10
#
#
#
#
# Support:  I made it and got my merit badge.
# ***
# Question:  When was Spielberg's merit badge launched?
# ***
# Correct:  1989
# ***
# predicted:  merit badge
#
#
#
#
# Support:  Spielberg first met actress Amy Irving in 1976 at the suggestion of director Brian De Palma, who knew he was looking for an actress to play in Close Encounters.
# ***
# Question:  When did Spielberg and Irving initially break up?
# ***
# Correct:  1979
# ***
# predicted:  1976
#
#
#
#
# Support:  In 1987, as China began opening to Western capital investment, Spielberg shot the first American film in Shanghai since the 1930s, an adaptation of J. G. Ballard's autobiographical novel Empire of the Sun, starring John Malkovich and a young Christian Bale.
# ***
# Question:  Until the 1980s, when had an American film last been shot in Shanghai?
# ***
# Correct:  the 1930s
# ***
# predicted:  1987
#
#
#
#
# Support:  He was later given the opportunity to make a short film for theatrical release, the 26-minute, 35mm, Amblin', which he wrote and directed.
# ***
# Question:  Who wrote the music for 'Into the West'?
# ***
# Correct:  geoff zanelli
# ***
# predicted:  opportunity
#
#
#
#
# Support:  Special praise of this film by the influential British critic Dilys Powell was highly significant to Spielberg's career.
# ***
# Question:  Which British critic praised 'Duel'?
# ***
# Correct:  dilys powell
# ***
# predicted:  special praise
#
#
#
#
# Support:  Drawing from his own experiences in Scouting, Spielberg helped the Boy Scouts of America develop a merit badge in cinematography in order to help promote filmmaking as a marketable skill.
# ***
# Question:  What was Indy's rank in Boy Scouts when shown in a movie?
# ***
# Correct:  life scout
# ***
# predicted:  own experiences
#
#
#
#
# Support:  Spielberg also said he suffered from acts of anti-Semitic prejudice and bullying: "In high school, I got smacked and kicked around.
# ***
# Question:  What kind of prejudice did Spielberg have to deal with in High school?
# ***
# Correct:  anti-semitic
# ***
# predicted:  acts
#
#
#
#
# Support:  Spielberg then revisited his Close Encounters project and, with financial backing from Columbia Pictures, released Close Encounters: The Special Edition in 1980.
# ***
# Question:  Who did Spielberg get money from to film Close Encounters?
# ***
# Correct:  his father
# ***
# predicted:  spielberg
# Support:  Special praise of this film by the influential British critic Dilys Powell was highly significant to Spielberg's career.
# ***
# Question:  What British critic helped boost Steven Spielberg's career?
# ***
# Correct:  dilys powell
# ***
# predicted:  special praise
#
#
#
#
# Support:  This theme is arguably the most autobiographical aspect of Spielberg's films, since Spielberg himself was affected by his parents' divorce as a child and by the absence of his father.
# ***
# Question:  Which of Spielberg's parents liked sci-fi?
# ***
# Correct:  his father
# ***
# predicted:  theme
#
#
#
#
# Support:  However, much to the surprise of many, Spielberg did not get a Best Director nomination.
# ***
# Question:  When did Spielberg and Irving get back together?
# ***
# Correct:  1984
# ***
# predicted:  spielberg
#
#
#
#
# Support:  It was set for release on April 25, 2014, with Anne Hathaway and Chris Hemsworth set to star, but Spielberg postponed production indefinitely in January 2013, just before it had been set to begin.
# ***
# Question:  How far in the future was 'Robopocalypse' set?
# ***
# Correct:  15–20 years
# ***
# predicted:  april 25 , 2014
#
#
#
#
# Support:  The series won a number of awards at the Golden Globes and the Emmys.
# ***
# Question:  How many Emmys did 'Into the West' win?
# ***
# Correct:  two
# ***
# predicted:  golden globes
#
#
#
#
# Support:  The Adventures of Tintin won the award for Best Animated Feature Film at the Golden Globe Awards that year.
# ***
# Question:  Where did Adventures of Tintin debut?
# ***
# Correct:  brussels , belgium
# ***
# predicted:  golden globe awards
#
#
#
#
# Support:  Once again teaming up with Lucas and Ford, Spielberg also cast actor Sean Connery in a supporting role as Indy's father.
# ***
# Question:  What was Spielberg's role on 'Batteries Not Included'?
# ***
# Correct:  co-producer
# ***
# predicted:  lucas
#
#
#
#
# Support:  However, much to the surprise of many, Spielberg did not get a Best Director nomination.
# ***
# Question:  How many Oscar nominations did 'Munich' get?
# ***
# Correct:  five
# ***
# predicted:  spielberg
#
#
#
#
# Support:  Apart from being an ardent gamer Spielberg has had a long history of involvement in video games.
# ***
# Question:  How long was 'Amblin'?
# ***
# Correct:  26-minute
# ***
# predicted:  spielberg
#
#
#
#
# Support:  In 2011, he produced the J. J. Abrams science fiction thriller film Super 8 for Paramount Pictures.
# ***
# Question:  Which studio produced 'Super 8'?
# ***
# Correct:  paramount pictures
# ***
# predicted:  j. j. abrams science fiction thriller film
#
#
#
#
# Support:  It was on this project that Spielberg also met his future wife, actress Kate Capshaw.
# ***
# Question:  What was Spielberg's future wife's career?
# ***
# Correct:  actress
# ***
# predicted:  project
#
#
#
#
# Support:  Spielberg has often never worked with the same screenwriter in his films, beside Tony Kushner and David Koepp, who have written a few of his films more than once.
# ***
# Question:  Which childhood friend worked on Spielberg's films?
# ***
# Correct:  allen daviau
# ***
# predicted:  same screenwriter
#
#
#
#
# Support:  It is the first non-Pixar film to win the award since the category was first introduced.
# ***
# Question:  Who introduced Irving to Spielberg?
# ***
# Correct:  brian de palma
# ***
# predicted:  first non-pixar film
#
#
#
#
# Support:  The archaeologist and adventurer hero Indiana Jones was played by Harrison Ford (whom Lucas had previously cast in his Star Wars films as Han Solo).
# ***
# Question:  Who played Indiana Jones's father?
# ***
# Correct:  sean connery
# ***
# predicted:  harrison ford
#
#
#
#
# Support:  Drawing from his own experiences in Scouting, Spielberg helped the Boy Scouts of America develop a merit badge in cinematography in order to help promote filmmaking as a marketable skill.
# ***
# Question:  What Boy Scout merit badge did Spielberg help develop?
# ***
# Correct:  cinematography
# ***
# predicted:  own experiences
#
#
#
#
# Support:  An example of this is his production relationship with Kathleen Kennedy who has served as producer on all his major films from E.T.
# ***
# Question:  Which film did Kathleen Kennedy first work with Spielberg on?
# ***
# Correct:  e.t . the extra-terrestrial
# ***
# predicted:  example
#
#
#
#
# Support:  The BFG is set to premiere out of competition at the Cannes Film Festival in May 2016, before its wide release in the US on July 1, 2016.
# ***
# Question:  In what month is Cannes held?
# ***
# Correct:  may
# ***
# predicted:  may 2016
#
#
#
#
# ...
# ***
# predicted:  four-year
#
#
#
#
# Support:  On the pretext of restoring order, the Russians occupied Northern Iran in 1911, and maintained a military presence in the region for years to come.
# ***
# Question:  In 1911, Russians occupied Northern Iran under what pretext?
# ***
# Correct:  restoring order
# ***
# predicted:  pretext
#
#
#
#
# Support:  According to 2014 census, around 40% of the population of Iran are Internet users.
# ***
# Question:  What percentage of Iran's population were internet users in 2014?
# ***
# Correct:  around 40 %
# ***
# predicted:  40 %
#
#
#
#
# Support:  Shiraz, with a population of around 1.4 million (2011 census), is the sixth major city of Iran.
# ***
# Question:  What is Shiraz' population by the 2011 Census?
# ***
# Correct:  1.4 million
# ***
# predicted:  population
#
#
#
#
# Support:  Under king Cyaxares, the Medes and Persians entered into an alliance with Nabopolassar of Babylon, as well as the Scythians and the Cimmerians, and together they attacked the Assyrian Empire.
# ***
# Question:  Who lead the Persians into a coalition with the Medes, Babylon, Scythians, and Cimmerians to fight against the Assyrians?
# ***
# Correct:  king cyaxares
# ***
# predicted:  alliance
#
#
#
#
# Support:  The Expediency Council has the authority to mediate disputes between Parliament and the Guardian Council, and serves as an advisory body to the Supreme Leader, making it one of the most powerful governing bodies in the country.
# ***
# Question:  What Council acts as a mediator when there are disputes between the Parliament and the Guardian Council?
# ***
# Correct:  the expediency council
# ***
# predicted:  expediency council
#
#
#
#
# Support:  In 2007, Iran's military spending represented 2.6% of the GDP or $102 per capita, the lowest figure of the Persian Gulf nations.
# ***
# Question:  In 2007 what was Iran spending 2.6% of its GDP on?
# ***
# Correct:  military spending
# ***
# predicted:  iran's military spending
#
#
#
#
# Support:  Under the new Arab elite of the Rashidun and later the Umayyad caliphates, both converted (mawali) and non-converted (dhimmi) Iranians were discriminated against, being excluded from the government and military, and having to pay a special tax called Jizya.
# ***
# Question:  What special tax did the discriminated Iranians - both converted and nonconverted - have to pay?
# ***
# Correct:  jizya
# ***
# predicted:  new arab elite
#
#
#
#
# Support:  Due to the 1973 spike in oil prices, the economy of Iran was flooded with foreign currency, which caused inflation.
# ***
# Question:  Iran's inflation led to what in 1975-1976?
# ***
# Correct:  an economic recession
# ***
# predicted:  1973 spike
#
#
#
#
# Support:  As a result of the 19th century Russo-Persian wars, the Russians took over the Caucasus, and Iran irrevocably lost control over its integral territories in the region (comprising modern-day Dagestan, Georgia, Armenia, and Azerbaijan), which got confirmed per the treaties of Gulistan and Turkmenchay.
# ***
# Question:  What region consisting of Dagestan, Georgia, Armenia, & Azerbaijan did Iran lose control of to the Russians?
# ***
# Correct:  the caucasus
# ***
# predicted:  19th century
#
#
#
#
# Support:  In 2010, Iran was ranked 69, out of 139 nations, in the Global Competitiveness Report.
# ***
# Question:  The Global COmpetitiveness Report in 2010 ranked Iran where out of 139 countries?
# ***
# Correct:  ranked 69
# ***
# predicted:  global competitiveness report
#
#
#
#
# Support:  The first Iranian Constitution and the first national parliament of Iran were founded in 1906, through the ongoing revolution.
# ***
# Question:  The first national parliament of Iran was founded in what year?
# ***
# Correct:  in 1906
# ***
# predicted:  1906
#
#
#
#
# Support:  Kiarostami, an admired Iranian director, planted Iran firmly on the map of world cinema when he won the Palme d'Or for Taste of Cherry in 1997.
# ***
# Question:  Which Iranian director won the Palm d'Or at Cannes in 1997?
# ***
# Correct:  abbas kiarostami
# ***
# predicted:  kiarostami
#
#
#
#
# Support:  Today, both Persia and Iran are used in cultural contexts; although, Iran is the name used officially in political contexts.
# ***
# Question:  Which name is officially used politically?
# ***
# Correct:  iran
# ***
# predicted:  today
#
#
#
#
# Support:  The Median and Achaemenid empires left a significant classical art scene which remained as basic influences for the art of the later eras.
# ***
# Question:  The Achaemind Empire along with what other group became the foundation for the art in later Iranian history?
# ***
# Correct:  the median
# ***
# predicted:  median and achaemenid empires
# Support:  In August 2014, Maryam Mirzakhani became the first-ever woman, as well as the first-ever Iranian, to receive the Fields Medal, the highest prize in mathematics.
# ***
# Question:  In 2014, Maryam Mirzakhani became the first women ever and first Iranian to win what prestigious mathematics award?
# ***
# Correct:  the fields medal
# ***
# predicted:  fields medal
#
#
#
#
# Support:  According to many of them, the number of ethnic Azerbaijanis in Iran comprises between 21.6–30% of the total population, with the majority holding it on 25%.cd In any case, the largest population of Azerbaijanis in the world live in Iran.
# ***
# Question:  What is the percentage range of Iran's total population is seemingly comprised of Azerbaijanis?
# ***
# Correct:  between 21.6–30 %
# ***
# predicted:  21.6–30 %
#
#
#
#
# Support:  The Persian Campaign commenced furthermore during World War I in Northwestern Iran after an Ottoman invasion, as part of the Middle Eastern Theatre of World War I.
# ***
# Question:  When did the Iran-Iraq War finally end?
# ***
# Correct:  1988
# ***
# predicted:  persian
#
#
#
#
# Support:  Since 2005, Iran's nuclear program has become the subject of contention with the international community following earlier quotes of Iranian leadership favoring the use of an atomic bomb against Iran's enemies and in particular Israel.
# ***
# Question:  Iran's nuclear program has caused discord within the international community since when?
# ***
# Correct:  since 2005
# ***
# predicted:  2005
#
#
#
#
# Support:  Iran's climate ranges from arid or semiarid, to subtropical along the Caspian coast and the northern forests.
# ***
# Question:  During what season does Iran's northern region's temperatures never go higher than 29c?
# ***
# Correct:  summer
# ***
# predicted:  caspian
#
#
#
#
# Support:  Following a gradual decline in the late 1600s and early 1700s, which was caused by the internal conflicts, the continuous wars with the Ottomans, and the foreign interference (most notably the Russian interference), the Safavid rule was ended by the Pashtun rebels who besieged Isfahan and defeated Soltan Hosein in 1722.
# ***
# Question:  Who ended Safavid power in Iran in 1722?
# ***
# Correct:  pashtun rebels
# ***
# predicted:  isfahan
#
#
#
#
# Support:  Iran was predominantly Sunni, but Ismail instigated a forced conversion to the Shia branch of Islam, by which the Shia Islam spread throughout the Safavid territories in the Caucasus, Iran, Anatolia, and Mesopotamia.
# ***
# Question:  Ismail I forced a conversion to what Islamic branch?
# ***
# Correct:  shia islam
# ***
# predicted:  shia branch
#
#
#
#
# Support:  By the late 1970s, many of these people opposed the Shah's regime and began to organize and join the protests against it.
# ***
# Question:  How many people live in Iran?
# ***
# Correct:  78.4 million
# ***
# predicted:  late 1970s
#
#
#
#
# Support:  According to UNESCO and the deputy head of research for Iran Travel and Tourism Organization (ITTO), Iran is rated 4th among the top 10 destinations in the Middle East.
# ***
# Question:  What was Iran's rank in the top 10 Middle East destinations according to UNESCO?
# ***
# Correct:  rated 4th
# ***
# predicted:  deputy head
#
#
#
#
# Support:  The unification of the Median tribes under a single ruler in 728 BC led to the foundation of the Median Empire which, by 612 BC, controlled the whole Iran and the eastern Anatolia.
# ***
# Question:  When did the Median tribes unify under a single ruler to form the Median Empire?
# ***
# Correct:  728 bc
# ***
# predicted:  728
#
#
#
#
# Support:  The ruins of Persepolis and Pasargadae, two of the four capitals of the Achaemenid Empire, are located around the modern-day city of Shiraz.
# ***
# Question:  The Achaemenid Empire expanded into what part of Asia?
# ***
# Correct:  central asia
# ***
# predicted:  persepolis
#
#
#
#
# Support:  The presence of so many foreign troops in the nation also culminated in the Soviet-backed establishment of two puppet regimes in the nation; the Azerbaijan People's Government, and the Republic of Mahabad.
# ***
# Question:  Who backed two puppet regimes in/around Iran during WWII?
# ***
# Correct:  the soviet union
# ***
# predicted:  presence
#
#
#
#
# Support:  In 550 BC, Cyrus the Great, son of Mandane and Cambyses I, took over the Median Empire, and founded the Achaemenid Empire by unifying other city states.
# ***
# Question:  Who found the Archaemenid Empire in 550 BC?
# ***
# Correct:  cyrus the great
# ***
# predicted:  cyrus
#
#
#
#
# Support:  Many countries have expressed concern that Iran's nuclear program could divert civilian nuclear technology into a weapons program.
# ***
# Question:  Who imposed sanctions against Iran as a result of Iran's nuclear program?
# ***
# Correct:  un security council
# ***
# predicted:  many countries
#
#
#
#
# Support:  The area was greatly influenced by the Babylonian civilization, and after the emergence of the ancient Persians, soon came to be known as Persis.
# ***
# Question:  What is Persis known as today?
# ***
# Correct:  fars province
# ***
# predicted:  area
#
#
#
#
# Support:  The struggle related to the constitutional movement continued until 1911, when Mohammad Ali Shah was defeated and forced to abdicate.
# ***
# Question:  The constitutional movement in Iran lasted from 1906 until what year?
# ***
# Correct:  until 1911
# ***
# predicted:  1911
#
#
#
#
# Support:  According to many of them, the number of ethnic Azerbaijanis in Iran comprises between 21.6–30% of the total population, with the majority holding it on 25%.cd In any case, the largest population of Azerbaijanis in the world live in Iran.
# ***
# Question:  What is the majority of organizational estimations of Azerbaijanis' percentage of Iran's population?
# ***
# Correct:  25 %
# ***
# predicted:  21.6–30 %
#
#
#
#
# Support:  The 10th century saw a mass migration of Turkic tribes from Central Asia into the Iranian plateau.
# ***
# Question:  What tribes migranted en masse to the Iranian plateau in the 10th Century?
# ***
# Correct:  turkic tribes
# ***
# predicted:  10th century
#
#
#
#
# Support:  As of 2007[update], Iran had earned $70 billion in foreign exchange reserves mostly (80%) from crude oil exports.
# ***
# Question:  By 2007, Iran's crude oil exports resulted in how much of its foreign exchange currency?
# ***
# Correct:  $ 70 billion
# ***
# predicted:  $ $ 70 billion
#
#
#
#
# Support:  Around 90% of Iran's e-commerce takes place on the Iranian online store of Digikala, which has around 750,000 visitors per day and more than 2.3 million subscribers.
# ***
# Question:  What site is responsible for around 90% of Iran's online e-commerce?
# ***
# Correct:  digikala
# ***
# predicted:  around 90%
#
#
#
#
# Support:  From the late 10th to late 7th centuries BC, the Iranian peoples, together with the pre-Iranian kingdoms, fell under the domination of the Assyrian Empire, based in northern Mesopotamia.
# ***
# Question:  Who dominated the area of Irea between the 10th Century BC to the late 7th Century BC?
# ***
# Correct:  the assyrian empire
# ***
# predicted:  late 10th
#
#
#
#
# Support:  During the 19th century, Iran irrevocably lost swaths of its territories in the Caucasus which made part of the concept of Iran for centuries, to neighboring Imperial Russia.
# ***
# Question:  What century did Iran lose the Caucasus to Russia?
# ***
# Correct:  the 19th century
# ***
# predicted:  19th century
#
#
#
#
# Support:  In 633 AD, Rashidun Arabs invaded Iran and conquered it by 651 AD, largely converting Iranian people from their indigenous faiths of Manichaeism and Zoroastrianism to Sunni Islam.
# ***
# Question:  What year did the Rashidun Arabs invade Iran?
# ***
# Correct:  633 ad
# ***
# predicted:  651 ad
#
#
#
#
# Support:  Over 80% of the users of Telegram, a cloud-based instant messaging service, are from Iran.
# ***
# Question:  What percentage of cloud-based instant messaging platform Telegram's users are from Iran?
# ***
# Correct:  over 80 %
# ***
# predicted:  80 %
#
#
#
#
# Support:  Eight Vice-Presidents serve under the President, as well as a cabinet of twenty-two ministers, who must all be approved by the legislature.
# ***
# Question:  The legislature approves the 8 vice presidents and how many cabinet members?
# ***
# Correct:  twenty-two
# ***
# predicted:  eight
#
#
#
#
# Support:  In 633 AD, Rashidun Arabs invaded Iran and conquered it by 651 AD, largely converting Iranian people from their indigenous faiths of Manichaeism and Zoroastrianism to Sunni Islam.
# ***
# Question:  What religion did the Rashidun Arabs convert the indigenous conquered peoples to?
# ***
# Correct:  sunni islam
# ***
# predicted:  633 ad
# Support:  Attempts to organize a film festival that had begun in 1954 within the framework of the Golrizan Festival, bore fruits in the form of the Sepas Festival in 1969.
# ***
# Question:  What Iranian film festival in 1954 was the progenitor of future film festivals in 1969 and 1973?
# ***
# Correct:  the golrizan festival
# ***
# predicted:  attempts
#
#
#
#
# Support:  However, nationalized industries such as the bonyads have often been managed badly, making them ineffective and uncompetitive with years.
# ***
# Question:  What Iranian nationalized industry has been noncompetitive and managed badly?
# ***
# Correct:  the bonyads
# ***
# predicted:  nationalized industries
#
#
#
#
# Support:  The empire at its peak ruled over 44% of the world's population, the highest such figure for any empire in history.
# ***
# Question:  Iran has the highest population of what group in the world?
# ***
# Correct:  azerbaijanis
# ***
# predicted:  world's population
#
#
#
#
# Support:  The coastal plains of the Persian Gulf and Gulf of Oman in southern Iran have mild winters, and very humid and hot summers.
# ***
# Question:  Where does Iran border the Persian Gulf and the Gulf of Oman?
# ***
# Correct:  to the south
# ***
# predicted:  persian gulf
#
#
#
#
# Support:  The area was greatly influenced by the Babylonian civilization, and after the emergence of the ancient Persians, soon came to be known as Persis.
# ***
# Question:  Which ancient civilization in Iran during the 4th Millenium was the most prominent?
# ***
# Correct:  elam
# ***
# predicted:  area
#
#
#
#
# Support:  The Iranian visual arts reached a pinnacle by the Sassanid Era.
# ***
# Question:  In what era did Iranian visual art reach its peak?
# ***
# Correct:  the sassanid era
# ***
# predicted:  sassanid era
#
#
#
#
# Support:  But the Bahá'í Faith, which is said to be the largest non-Muslim religious minority in Iran, is not officially recognized, and has been persecuted during its existence in Iran since the 19th century.
# ***
# Question:  Which religious minority since the 1979 Revolution has been persecuted and in some cases executed by the Iranian government?
# ***
# Correct:  the bahá'í faith
# ***
# predicted:  bahá'í faith
#
#
#
#
# Support:  On September 22, 1980, the Iraqi army invaded the Iranian Khuzestan, and the Iran–Iraq War began.
# ***
# Question:  Who invaded Iran in 1980?
# ***
# Correct:  the iraqi army
# ***
# predicted:  september
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-8990abb21dc4> in <module>()
#     254     for id, _ in results:
#     255         sent = raw_docs[id]
# --> 256         doc = nlp(sent)
#     257
#     258         score = get_overlap(sent, question)
#
# /anaconda3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# KeyboardInterrupt:
