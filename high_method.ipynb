# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
import re
import csv

# %% [markdown]
# # Variables

# %%
OPEN_QUESTION_WORDS = ['what','who','whose','whom','where','when','why','how',
                       'which',"what's","who's","where's","how's"]
CLOSED_QUESTION_WORDS = ['is','are','am','was','were','do','does,','did','can',
                         'could','will','would','shall','should','have','has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)

# %%
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)

# %%
def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma

        
def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += 1
    return dfs


def query_vsm(query, index, k=12):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'

# %%
# length of longest same sequences of keywords
def get_overlap(sent1, sent2):
    tokens1 = []
    tokens2 = []

    for token in nltk.word_tokenize(strip_punctuation(sent1.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens1.append(lemma)

    for token in nltk.word_tokenize(strip_punctuation(sent2.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens2.append(lemma)

    max = 0
    for i in range(len(tokens1)):
        for j in range(len(tokens2)):

            if tokens1[i] == tokens2[j]:
                length = 1

                ii = i + 1
                jj = j + 1
                while ii < len(tokens1) and jj < len(tokens2) and \
                        tokens1[ii] == tokens2[jj]:
                    ii += 1
                    jj += 1
                    length += 1

                if length > max:
                    max = length

    return max

# %% [markdown]
# # Write to test file

# %%
csvFile = open("high.csv", "w")
writer = csv.writer(csvFile)
header = ['id','answer']
writer.writerow(header)


case_count = 0
# test = [test[17]]
for test_case in test:
    question = test_case['question']
    docid = test_case['docid']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)
    
#     fn_docs = raw_docs
#     bm25 = BM25(fn_docs, delimiter=' ')
#     Query = question
#     Query = Query.split()
#     scores = bm25.BM25Score(Query)
#     tfidf = bm25.TFIDF()
#     print bm25.Items()
    
#     for i, tfidfscore in enumerate(tfidf):
#         print i, tfidfscore
    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question)
    results = query_vsm(terms, vsm_inverted_index)


    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:

        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'

        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        else:
            # what...do type question
            tokens.remove(next_token)
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the 20 sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC']:
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.5 + (scores[id] / max_score * 0.5)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get)
    sent = raw_docs[index]
    doc = nlp(sent)

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = 0

            if score > max_score:
                max_score = score
                answer = np.text
                
                
    a = nltk.word_tokenize(answer)
    try:
        if a[0].lower() == 'the' or a[0].lower() == 'a' or a[0].lower() == 'an' or a[0].lower() == 'this':
            answer = ''
            del a[0]
            for word in a:
                answer += word + ' '
    except:
        answer = answer
        
    answer = answer.strip().lower()
    result = []
    result.append(case_count)
    result.append(answer)
    writer.writerow(result)
    print(case_count,' ',answer)
    case_count += 1
    
csvFile.close()
# Out:
# 0   combination
# 1   addition
# 2   browser 's layout engine
# 3   its opera-mini version
# 4   late 2004
# 5   windows
# 6   1995
# 7   most browsers
# 8   marc andreessen
# 9   first web browser
# 10   competition
# 11   dominance
# 12   internet relay chat
# 13   january
# 14   every major web browser
# 15   january 2003
# 16   january 2009
# 17   file transfer protocol
# 18   google
# 19   case
# 20   rich user interfaces
# 21   2002
# 22   august 2011
# 23   all major web browsers
# 24   chrome's user-base
# 25   development
# 26   december 2011
# 27   january 2003
# 28   netscape
# 29   apple's safari
# 30   rapid development
# 31   prefix
# 32   mozilla foundation
# 33   private networks
# 34   mac
# 35   comparison
# 36   1994
# 37   user interface
# 38   addition
# 39   major browsers
# 40   information resources
# 41   live bookmarks
# 42   more traditional feed reader
# 43   bookmarks
# 44   year
# 45   prefix
# 46   browser software
# 47   file transfer protocol
# 48   microsoft corp
# 49   mobile safari
# 50   most web browsers
# 51   windows
# 52   user 's default e-mail application
# 53   browser extension
# 54   4.5 hour
# 55   carrefour boycott
# 56   relay
# 57   protests
# 58   several protests
# 59   noted indian social activist
# 60   vietnam
# 61   several protests
# 62   site
# 63   some western media
# 64   uk
# 65   political activist
# 66   russia
# 67   distinction
# 68   relay supporters
# 69   its arrival
# 70   team
# 71   turkey
# 72   foreign minister stephen smith
# 73   french members
# 74   interior michèle alliot-marie
# 75   carlos espínola
# 76   april 5
# 77   members
# 78   april 1, 2008
# 79   april 16
# 80   nagano
# 81   accountability
# 82   april 1, 2008
# 83   sachin tendulkar
# 84   10 downing street
# 85   torch
# 86   carrefour
# 87   2012
# 88   north korea
# 89   750,000
# 90   libération
# 91   lhasa riots
# 92   these protests
# 93   seoul
# 94   libération
# 95   francesca martinez
# 96   route
# 97   seven
# 98   uyghurs
# 99   reporters without borders'
# 100   macau
# 101   vietnamese american
# 102   great britain
# 103   event
# 104   chinese media
# 105   asian times
# 106   tibet
# 107   site
# 108   libération
# 109   several hundred
# 110   costanera sur
# 111   relay
# 112   1200
# 113   assurances
# 114   man
# 115   foreign minister stephen smith
# 116   major setback
# 117   democracy
# 118   80
# 119   kazakhstan
# 120   turkey
# 121   reports
# 122   praise
# 123   air china
# 124   hollywood
# 125   march 2008
# 126   jon stanhope
# 127   oman
# 128   ted quinlan
# 129   several protests
# 130   may 2
# 131   kuala lumpur
# 132   i
# 133   china
# 134   tsim sha tsui
# 135   new starting point
# 136   event
# 137   coverage
# 138   chaotic torch relays
# 139   as many as 1,000
# 140   event
# 141   may 3
# 142   thupten gyatso
# 143   april 17
# 144   some western media
# 145   one
# 146   two
# 147   more than one
# 148   ladbroke grove
# 149   april 1, 2008
# 150   about 2,200 police
# 151   120
# 152   response
# 153   relay
# 154   libération
# 155   vietnamese american
# 156   2008 summer olympics torch relay
# 157   intended torchbearers choi seung-kook
# 158   minister
# 159   thousands
# 160   1964
# 161   justin herman plaza
# 162   april 5
# 163   francesca martinez
# 164   justin herman plaza
# 165   first time
# 166   tibet
# 167   daily telegraph
# 168   susan prager
# 169   home secretary jacqui smith
# 170   united nations organization
# 171   jackie chan
# 172   also
# 173   francesca martinez
# 174   kazakhstan
# 175   great britain
# 176   april
# 177   1964
# 178   only invitees
# 179   distinction
# 180   torch
# 181   two
# 182   jane birkin
# 183   one
# 184   city
# 185   may 2
# 186   torch
# 187   april
# 188   france
# 189   event
# 190   torch relay route
# 191   china
# 192   70
# 193   one
# 194   85,000
# 195   nagano
# 196   tibet
# 197   jane birkin
# 198   torch
# 199   day
# 200   1964
# 201   libération
# 202   nathan road
# 203   intended torchbearers choi seung-kook
# 204   air china
# 205   protests
# 206   last time
# 207   paris city officials
# 208   great britain
# 209   japanese family
# 210   taipei
# 211   athletes
# 212   malaysia
# 213   call
# 214   april 3
# 215   no politicians
# 216   several protests
# 217   chinese demands
# 218   carrefour
# 219   days
# 220   china's relations
# 221   oman
# 222   "immigration reasons
# 223   only two
# 224   april 17
# 225   members
# 226   india
# 227   lê minh phiếu
# 228   kazakhstan
# 229   jacques rogge
# 230   park won-sun
# 231   several protests
# 232   april
# 233   our sacred torch
# 234   120
# 235   15 minutes
# 236   medeo
# 237   seven
# 238   call
# 239   republic of china
# 240   carlos espínola
# 241   relay
# 242   argentine activists
# 243   chinese media
# 244   vietnam
# 245   saint petersburg
# 246   government
# 247   may 3
# 248   eiffel tower
# 249   tanzania
# 250   beijing
# 251   air china
# 252   tibetan flags
# 253   some 60
# 254   1200
# 255   days
# 256   great britain
# 257   april
# 258   three
# 259   first time
# 260   great britain
# 261   president pervez musharraf
# 262   macau
# 263   150,000-strong
# 264   carrefour
# 265   protests
# 266   bollywood actress soha ali khan
# 267   chinese media coverage
# 268   great britain
# 269   middle east
# 270   india
# 271   macau
# 272   ancient links
# 273   tony goh
# 274   government
# 275   reporters
# 276   people
# 277   response
# 278   istanbul
# 279   torchbearers
# 280   narisa chakrabongse, green world foundation (gwf) chairwoman
# 281   macao daily news
# 282   paralympic games
# 283   may 4
# 284   carlos espínola
# 285   parliament
# 286   great britain
# 287   bangkok
# 288   several symbolic protests
# 289   libération
# 290   april 16
# 291   chinese government
# 292   buenos aires
# 293   trocadéro
# 294   torchbearers
# 295   china
# 296   people 's daily
# 297   april 9
# 298   tibetan flags
# 299   prior
# 300   japan
# 301   chinese officials
# 302   several times
# 303   torch relay route
# 304   japan
# 305   relay
# 306   islamabad
# 307   several hundred pro-tibet protesters
# 308   carlos espínola
# 309   bedi
# 310   85,000
# 311   mccovey cove
# 312   three activists
# 313   carrefour
# 314   original 20 km relay
# 315   pyongyang
# 316   more than 100
# 317   great britain
# 318   chan cheong
# 319   total
# 320   baichung bhutia
# 321   relay
# 322   march 2008
# 323   torch
# 324   1988
# 325   tokyo
# 326   30
# 327   its arrival
# 328   65 kilometre per hour
# 329   san francisco
# 330   australia
# 331   islamabad
# 332   torch
# 333   tsim sha tsui
# 334   islamabad
# 335   129 days
# 336   fu ying
# 337   april 1, 2008
# 338   torch relay leg
# 339   world ’ s worst offenders
# 340   argentina
# 341   up to 600
# 342   up to 600
# 343   lê minh phiếu
# 344   united states of america
# 345   nagano
# 346   francesca martinez
# 347   protests
# 348   kamal nath
# 349   april 16
# 350   tokyo
# 351   torch
# 352   bbc 's paul danahar
# 353   same pitch
# 354   total number
# 355   pitch
# 356   12
# 357   indefinite pitch
# 358   100 cents
# 359   frequency
# 360   "high" pitch
# 361   at least one model
# 362   overtones
# 363   time
# 364   a4
# 365   not the higher frequencies
# 366   12
# 367   perceived interval
# 368   sound
# 369   some theories
# 370   southampton
# 371   uk
# 372   annual southampton boat show
# 373   seven
# 374   city
# 375   120,305
# 376   as high as 20,000
# 377   lloyd 's register group
# 378   most successful college american football teams
# 379   1996
# 380   great war
# 381   9th century
# 382   london
# 383   new forest
# 384   10th century
# 385   southampton
# 386   southampton city council
# 387   roughly half
# 388   2015 council elections
# 389   more than 2,000
# 390   centre
# 391   just over a week
# 392   portsmouth
# 393   one
# 394   those walls
# 395   city
# 396   importance
# 397   about 1888
# 398   november 2014
# 399   annual
# 400   one third
# 401   annual southampton boat show
# 402   population
# 403   evidence
# 404   latter half of the 20th century
# 405   october 2014
# 406   settlement
# 407   1920s
# 408   banister court stadium
# 409   southampton's largest retail centre
# 410   town
# 411   city walls
# 412   24
# 413   2004
# 414   two
# 415   port
# 416   1964
# 417   worst behaved secondary schools
# 418   part
# 419   four
# 420   1840
# 421   1862
# 422   city council
# 423   western docks
# 424   space
# 425   1417
# 426   western docks
# 427   1339
# 428   202
# 429   1976
# 430   city
# 431   presence
# 432   centre
# 433   1968
# 434   port
# 435   hampshire
# 436   1066
# 437   british gas
# 438   west quay
# 439   2015
# 440   only about
# 441   parts
# 442   eastleigh
# 443   princess alexandra dock
# 444   vast majority
# 445   classical concerts
# 446   queen mary
# 447   southampton
# 448   early may
# 449   uni-link
# 450   cent
# 451   third ferry
# 452   university of southampton
# 453   13th century
# 454   provide
# 455   1966
# 456   hampshire
# 457   west quay
# 458   headquarters
# 459   city
# 460   additional police stations
# 461   local train services
# 462   two
# 463   uk
# 464   solent
# 465   p&o cruises
# 466   27 june 1640
# 467   college
# 468   840
# 469   centuries
# 470   1233
# 471   university hospital southampton nhs foundation trust
# 472   biggest operator
# 473   4.2
# 474   1959
# 475   354
# 476   government figures
# 477   m27
# 478   talking heads
# 479   hanover buildings
# 480   city
# 481   december 2007
# 482   12th century
# 483   traffic congestion
# 484   southampton
# 485   2004
# 486   1233
# 487   built-up area
# 488   three fire stations
# 489   southampton docks
# 490   24
# 491   western docks
# 492   southampton's largest retail centre
# 493   1920s
# 494   1976
# 495   clausentum
# 496   two
# 497   plans
# 498   southampton
# 499   port
# 500   just over a quarter
# 501   main station
# 502   20–24
# 503   council estates
# 504   south west trains
# 505   16.2 percent
# 506   king henry's departure
# 507   route
# 508   trust
# 509   town
# 510   16.2 percent
# 511   two large live music venues
# 512   three
# 513   university of southampton
# 514   france
# 515   northam area
# 516   1968
# 517   area
# 518   hampshire county council
# 519   duchess
# 520   world 's largest cruise ships
# 521   1938
# 522   large shopping centre
# 523   uk
# 524   2009
# 525   southampton university
# 526   three
# 527   southampton
# 528   1960s
# 529   september 1940
# 530   his 1854 book
# 531   48
# 532   plymouth
# 533   town
# 534   southampton water
# 535   city
# 536   12th century
# 537   banister court stadium
# 538   river test and river itchen
# 539   stone age
# 540   between 1996 and 2004
# 541   germany
# 542   these charters
# 543   notable former player
# 544   anglo-saxons
# 545   hampshire constabulary
# 546   seacity museum
# 547   university hospital southampton nhs foundation trust
# 548   south west trains
# 549   1966
# 550   importance
# 551   1835
# 552   two
# 553   1310
# 554   southampton airport
# 555   city
# 556   great war
# 557   18th-century
# 558   23
# 559   ocean race
# 560   city-link
# 561   two local sunday leagues
# 562   part
# 563   banister court stadium
# 564   25–29
# 565   crimean war
# 566   three
# 567   24
# 568   city
# 569   north
# 570   253,651
# 571   1310
# 572   its designer
# 573   successive incarnations
# 574   ikea
# 575   docks
# 576   france
# 577   runners-up
# 578   hampshire county
# 579   stage award
# 580   variety
# 581   hampshire constabulary
# 582   southampton
# 583   southampton solent university
# 584   today
# 585   january 2007
# 586   northam area
# 587   24 february 1964
# 588   18th-century
# 589   university of southampton
# 590   march 2007
# 591   university of southampton
# 592   three
# 593   john choules
# 594   king henry's departure
# 595   48
# 596   one
# 597   coast
# 598   some controversy
# 599   hampshire county council
# 600   1760s
# 601   hampshire county
# 602   university of southampton
# 603   24
# 604   500,000
# 605   city
# 606   plans
# 607   today
# 608   city
# 609   11
# 610   bargate
# 611   southampton city college
# 612   linda norris
# 613   passenger services
# 614   southampton
# 615   port
# 616   has
# 617   towns
# 618   south hampshire
# 619   october 1838
# 620   one
# 621   mud flats
# 622   hampshire county
# 623   1310
# 624   southampton docks
# 625   walls
# 626   london
# 627   march 1644
# 628   three
# 629   woodmill bridge
# 630   three
# 631   river test and river itchen
# 632   southampton pupils
# 633   estimated 236,900 people
# 634   site
# 635   whitbread
# 636   princess alexandra dock
# 637   town
# 638   council
# 639   1944
# 640   1976
# 641   june
# 642   1310
# 643   city
# 644   southampton
# 645   river test and river itchen
# 646   last remains
# 647   shirley
# 648   eastleigh
# 649   council
# 650   importance
# 651   uk
# 652   england
# 653   car manufacture
# 654   october 2014
# 655   between 1995 and 2004
# 656   battle of agincourt
# 657   2005
# 658   nightclub
# 659   uni-link
# 660   may 1840
# 661   october 2014
# 662   southampton's largest retail centre
# 663   january 2007
# 664   common
# 665   enterprise
# 666   sunday
# 667   bbc
# 668   royston smith
# 669   city
# 670   barton peveril college
# 671   southampton airport
# 672   rest
# 673   saints
# 674   city
# 675   city hockey club
# 676   northam area
# 677   between 1996 and 2004
# 678   talking heads
# 679   attempt
# 680   further remains
# 681   major uk port
# 682   supermarine spitfire
# 683   local itv franchise
# 684   city
# 685   northern tip
# 686   king henry's departure
# 687   france
# 688   town
# 689   uk
# 690   swaythling
# 691   premier league
# 692   london
# 693   redbridge
# 694   red funnel
# 695   1938
# 696   over 40,000
# 697   crimean war
# 698   previously
# 699   1862
# 700   1888
# 701   steam yacht north star
# 702   clausentum
# 703   ferry port
# 704   1879 to 1949
# 705   itchen
# 706   henry v's famous warship hms grace dieu
# 707   1740
# 708   southampton
# 709   national lottery
# 710   eastern docks
# 711   royalists
# 712   hampshire
# 713   2015
# 714   119,500 males
# 715   nearly 92%
# 716   nearly 92%
# 717   eastern
# 718   just four women
# 719   german
# 720   ashkenazi jew's
# 721   about 40%
# 722   high frequencies
# 723   however, most people
# 724   1890s
# 725   1990s
# 726   middle east
# 727   last thousand years
# 728   probability
# 729   ashkenazim
# 730   nearly 92%
# 731   11th century
# 732   last thousand years
# 733   about 40%
# 734   often
# 735   middle ages
# 736   212
# 737   certain issues
# 738   midrash compilation
# 739   jews
# 740   several famous people
# 741   holocaust
# 742   20th century
# 743   israeli black panthers
# 744   study
# 745   estimated 8.8 million
# 746   israel
# 747   hebrew
# 748   possible exception
# 749   roman empire
# 750   recent years
# 751   1750
# 752   ashkenazi jews
# 753   16th-century
# 754   1095
# 755   1095
# 756   elevated frequency
# 757   around 47.5%
# 758   concept
# 759   uses
# 760   2,500 years ago
# 761   ancient levantine origins
# 762   middle ages
# 763   middle eastern peoples
# 764   conformity
# 765   archeological evidence
# 766   several million
# 767   ashkenazi jew
# 768   hebrew
# 769   pre-christian times
# 770   period
# 771   term
# 772   center
# 773   80 percent
# 774   another trend
# 775   some centuries later
# 776   11th century
# 777   those jews
# 778   rabbinic leadership
# 779   talmud
# 780   modern-day italians
# 781   30
# 782   five thousand
# 783   brigetio
# 784   minhagim
# 785   54%–60%
# 786   genome-wide genetic study
# 787   fertile crescent
# 788   quarter
# 789   1095
# 790   second half of the 11th century
# 791   jerusalem
# 792   yiddish
# 793   about 75%
# 794   yoma tractate
# 795   conformity
# 796   his contemporary saadia gaon
# 797   hebrew
# 798   greek historian
# 799   greek historian
# 800   1095
# 801   biblical figure
# 802   first decades
# 803   sergio dellapergola
# 804   nearly 92%
# 805   jewish
# 806   gomer
# 807   80 percent
# 808   jews
# 809   ashkenazi jew
# 810   about 2%
# 811   91%
# 812   upper euphrates
# 813   nusach
# 814   latin america
# 815   2002
# 816   conformity
# 817   surname hail
# 818   herodotus
# 819   many jews
# 820   first half
# 821   nusach sefard
# 822   estimated 8.8 million
# 823   genesis rabbah
# 824   religious jews
# 825   uranus
# 826   11 july neptune
# 827   largest neptunian moon
# 828   objects
# 829   difference
# 830   sun
# 831   right
# 832   result
# 833   planet 's distance
# 834   1.0243×1026 kg
# 835   rahab
# 836   troposphere
# 837   2007
# 838   jupiter
# 839   modern greek
# 840   uranus
# 841   johann galle
# 842   same way
# 843   william lassell
# 844   late 2020s or early 2030s
# 845   11 july 2011
# 846   its gravity
# 847   nahuatl
# 848   formation
# 849   200
# 850   °
# 851   , persistent methane clouds
# 852   scooter
# 853   small dark spot
# 854   voyager
# 855   high-altitude clouds
# 856   voyager
# 857   1:1 resonance
# 858   100 kpa
# 859   1843
# 860   winds
# 861   occultation
# 862   over 50%
# 863   focus
# 864   first scientifically useful observation
# 865   25 august 1989
# 866   that credit
# 867   his discovery
# 868   1821
# 869   only 0.25%
# 870   roughly 40
# 871   upper-level clouds
# 872   sun
# 873   first and so far only object
# 874   dark spots
# 875   adams
# 876   17
# 877   le verrier ring
# 878   discovery
# 879   neptune
# 880   current most widely accepted explanation
# 881   nahuatl
# 882   2019
# 883   1:1
# 884   penultimate known planet
# 885   uranus
# 886   neptune
# 887   2006
# 888   23
# 889   high-altitude clouds
# 890   first and so far only object
# 891   14
# 892   jupiter
# 893   most heavily populated resonance
# 894   le verrier ring
# 895   sun
# 896   voyager 2's arrival
# 897   high-altitude cloud bands
# 898   neptune's atmospheric methane content
# 899   months
# 900   discovery
# 901   evening
# 902   december 1612
# 903   these altitudes
# 904   vortex structures
# 905   neptune's more varied weather
# 906   30.1
# 907   pluto
# 908   apparent backward motion
# 909   current models
# 910   1997
# 911   planetary science
# 912   400 m/s
# 913   2004
# 914   images
# 915   1017
# 916   other candidates
# 917   neptune's more varied weather
# 918   reaction
# 919   hobbes
# 920   modern term `` culture
# 921   non-material culture
# 922   citation
# 923   19th-century
# 924   terror management theory
# 925   29
# 926   united states
# 927   germany
# 928   end of the last ice age
# 929   other 19th-century critics
# 930   contrasted
# 931   terror management theory
# 932   anthropologists
# 933   1970s
# 934   around 50,000 years ago
# 935   united states
# 936   diffusion
# 937   prussian linguist
# 938   1950s and 1960s
# 939   stuart hall
# 940   élite ideal
# 941   present legislation
# 942   jefferson's metaphor
# 943   1971
# 944   nonconformists
# 945   all areas
# 946   pervasive secularism
# 947   that wall
# 948   may 3, 2006
# 949   still other scholars
# 950   as early as the mid-17th century
# 951   religious freedom
# 952   engel
# 953   madison
# 954   december 20, 2005
# 955   william penn
# 956   two
# 957   some legal scholars
# 958   still other scholars
# 959   reynolds
# 960   1776
# 961   court 's decision
# 962   opponents
# 963   december
# 964   robert s. wood
# 965   u.s.
# 966   1962
# 967   court
# 968   1994
# 969   kurtzman
# 970   argue
# 971   thomas jefferson's influential virginia statute
# 972   1947
# 973   lone dissenter
# 974   central point
# 975   many early immigrant groups
# 976   third
# 977   may
# 978   jefferson
# 979   states' rights
# 980   1879
# 981   religious bigotry
# 982   no one religious society
# 983   1786
# 984   religious beliefs
# 985   national motto
# 986   u.s.
# 987   ohio
# 988   2002
# 989   new england
# 990   phrase
# 991   three
# 992   answer
# 993   pledge
# 994   principle or primary effect
# 995   kurtzman
# 996   john f. kennedy
# 997   south carolina
# 998   roger williams
# 999   purpose of the display ( educating the public on american legal traditions ) was secular in nature .
# 1000   december 27, 1657
# 1001   jefferson's concept
# 1002   jefferson's statute
# 1003   eighteenth century
# 1004   required beliefs
# 1005   separation
# 1006   consequence
# 1007   1878
# 1008   1835-1876
# 1009   citation
# 1010   proclamations
# 1011   five-justice majority
# 1012   2
# 1013   epperson
# 1014   roger williams
# 1015   three
# 1016   jefferson's metaphor
# 1017   umayyad dynasty mosaic making
# 1018   constantinople
# 1019   rome
# 1020   one solsternus
# 1021   earliest examples
# 1022   only fragments
# 1023   end of the 5th century
# 1024   justinian
# 1025   one
# 1026   5th-century
# 1027   17th-century
# 1028   grand prince
# 1029   jerusalem
# 1030   12th century
# 1031   remains
# 1032   whose sail
# 1033   most prominent artist
# 1034
# 1035   roman church
# 1036   important justinian
# 1037   mosaics
# 1038   roger ii
# 1039   double indirect method
# 1040   another example
# 1041   affricisco
# 1042   hand
# 1043   human figure
# 1044   arta
# 1045   decoration
# 1046   abundant variety
# 1047   monastic communities
# 1048   5th-century
# 1049   6th to the 15th centuries
# 1050   8th–9th centuries
# 1051   east
# 1052   mary
# 1053   another example
# 1054   1949
# 1055   17th–19th centuries
# 1056   constantinople
# 1057   southern italy
# 1058   mausoleum
# 1059   1169
# 1060   piazza armerina
# 1061   539
# 1062   royal basilica
# 1063   taddeo zuccari
# 1064   sant'ambrogio
# 1065   ascension
# 1066   another samaritan synagogue
# 1067   thessaloniki
# 1068   normal technique
# 1069   norman kings
# 1070   mosaics
# 1071   galla placidia
# 1072   1310–14
# 1073   iconoclastic
# 1074   moorish spain
# 1075   portugal
# 1076   2003
# 1077   seasons
# 1078   church of the holy apostles
# 1079   islamic architecture
# 1080   raphael
# 1081   1210
# 1082   present-day
# 1083   pebble mosaics
# 1084   1894
# 1085   nea moni monastery on chios
# 1086   arabs
# 1087   constantinople
# 1088   1043–1056
# 1089   10th-century
# 1090   rome
# 1091   rare example
# 1092   striking technical innovation
# 1093   12th-century
# 1094   striking technical innovation
# 1095   calçada portuguesa
# 1096   river mureş
# 1097   5th century mosaics
# 1098   santa constanza
# 1099   damascus
# 1100   5th-century
# 1101   outstanding examples
# 1102   styles
# 1103   roger ii
# 1104   only surviving 12th-century mosaic work
# 1105   atrium
# 1106   greek
# 1107   large villa rustica
# 1108   works
# 1109   1971–72
# 1110   1607
# 1111   around 1143
# 1112   17th–19th centuries
# 1113   most prominent artist
# 1114   abundant variety
# 1115   kastron mefaa
# 1116   constantinople
# 1117   12th century
# 1118   symbolism
# 1119   rome
# 1120   abbot
# 1121   julii
# 1122   venetian
# 1123   1913
# 1124   royal basilica
# 1125   damascus
# 1126   middle
# 1127   1310–14
# 1128   emperor maximian
# 1129   outstanding examples
# 1130   10
# 1131   18th century
# 1132   hand
# 1133   religious umayyad mosaic works
# 1134   constantine monomachos
# 1135   lebanon
# 1136   synagogue
# 1137   18th-century
# 1138   accidents
# 1139   1986
# 1140   late 4th century
# 1141   three
# 1142   cathedral
# 1143   more figures
# 1144   monastery of martyrius
# 1145   christian
# 1146   nile delta
# 1147   constantine monomachos
# 1148   roger ii
# 1149   map
# 1150   1589
# 1151   constantine monomachos
# 1152   venetian craftsmen
# 1153   limoges
# 1154   5th-century
# 1155   iconoclastic era
# 1156   2000
# 1157   seasons
# 1158   double indirect method
# 1159   17th–19th centuries
# 1160   exotic or mythological animals
# 1161   ravenna
# 1162   1960s
# 1163   two-tone stone mosaic paving
# 1164   64 ad
# 1165   albania
# 1166   calçada portuguesa
# 1167   three
# 1168   golden gate
# 1169   4th-century bc
# 1170   1043–1056
# 1171   early 4th century
# 1172   nile delta
# 1173   taungoo
# 1174   about 80
# 1175   official united states policy
# 1176   its capital city
# 1177   both these names
# 1178   hanthawaddy monarchs
# 1179   2008 rice production
# 1180   name
# 1181   obama
# 1182   650
# 1183   its independent years
# 1184   early civilisations
# 1185   myanmar
# 1186   first
# 1187   myanmar's ethnic minority groups
# 1188   little known fact
# 1189   obama
# 1190   thousands
# 1191   10%
# 1192   mong mao
# 1193   1,930 km
# 1194   us
# 1195   official united states
# 1196   myanmar
# 1197   majority burmese bamar ethnic group
# 1198   mong mao
# 1199   name
# 1200   burma's education system
# 1201   august
# 1202   colonial architectural influences
# 1203   2008
# 1204   official united states policy
# 1205   monks
# 1206   past myanmar
# 1207   1770
# 1208   time
# 1209   250 years
# 1210   1988
# 1211   name
# 1212   myanmar
# 1213   major battleground
# 1214   250 years
# 1215   hanthawaddy monarchs
# 1216   these lines
# 1217   1883
# 1218   equitable right
# 1219   civil law
# 1220   uk
# 1221   criticism
# 1222   these lines
# 1223   2004
# 1224   estimated 18 million
# 1225   claim
# 1226   napster
# 1227   law professor
# 1228   one year's
# 1229   free software foundation founder richard stallman
# 1230   free software foundation founder richard stallman
# 1231   scope
# 1232   many countries
# 1233   definition
# 1234   scope
# 1235   patent infringement
# 1236   lawrence lessig
# 1237   united states
# 1238   1994
# 1239   citation
# 1240   1846
# 1241   many jurisdictions
# 1242   other arguments
# 1243   definition
# 1244   three
# 1245   term
# 1246   infringement
# 1247   specific technological problem
# 1248   these lines
# 1249   1883
# 1250   trips
# 1251   copyright
# 1252   copyright infringement
# 1253   recording industry association
# 1254   referring
# 1255   stephan kinsella
# 1256   united states
# 1257   context
# 1258   equitable right
# 1259   context
# 1260   other recent developments
# 1261   1791
# 1262   may 2011
# 1263   1998
# 1264   trade secret misappropriation
# 1265   2001
# 1266   october 1845
# 1267   civil law
# 1268   1883
# 1269   one year's
# 1270   some critics
# 1271   17 the stated objective
# 1272   motion picture association of america
# 1273   uk
# 1274   trademark infringement
# 1275   millions
# 1276   high-tech fields
# 1277   native cultures
# 1278   some critics
# 1279   intellectual-property rights
# 1280   native cultures
# 1281   berne
# 1282   detriment
# 1283   infringement
# 1284   assumption
# 1285   he
# 1286   french
# 1287   rossiya
# 1288   ingur river
# 1289   1830
# 1290   kars
# 1291   christians
# 1292   ottoman empire
# 1293   crimean war
# 1294   1854
# 1295   time
# 1296   constantinople
# 1297   black sea
# 1298   danube
# 1299   july 1854
# 1300   26 july
# 1301   omar pasha
# 1302   north
# 1303   russians
# 1304   14 april
# 1305   russia
# 1306   fewer than half
# 1307   spring
# 1308   local commanders
# 1309   hill
# 1310   august 1855
# 1311   nicholas
# 1312   15,000
# 1313   four
# 1314   russians
# 1315   both sides
# 1316   william howard russell
# 1317   time
# 1318   1857
# 1319   25 september
# 1320   constantinople
# 1321   war
# 1322   february
# 1323   morning
# 1324   piedmont
# 1325   nicholas
# 1326   late september
# 1327   year
# 1328   three
# 1329   bulgaria
# 1330   alexander ii
# 1331   french
# 1332   cronstadt
# 1333   second
# 1334   walachia
# 1335   minor naval skirmishes
# 1336   ukraine
# 1337   19–31
# 1338   black sea
# 1339   31 december
# 1340   cronstadt
# 1341   george hamilton-gordon
# 1342   omar pasha
# 1343   32–40
# 1344   its alliance
# 1345   local commanders
# 1346   russians
# 1347   william howard russell
# 1348   constantinople
# 1349   omar pasha
# 1350   omar pasha
# 1351   parliament
# 1352   constantinople
# 1353   åland islands
# 1354   alexander ii
# 1355   nicholas
# 1356   cardigan
# 1357   treaty of paris
# 1358   austria
# 1359   ridge
# 1360   october 1853
# 1361   french
# 1362   united kingdom
# 1363   centuries-old
# 1364   public opinion
# 1365   second counterattack
# 1366   winter of 1854
# 1367   sinop
# 1368   russian cavalry movement
# 1369   catholic support
# 1370   peaceful settlement
# 1371   1830
# 1372   alfred nobel
# 1373   vidin
# 1374   reaction
# 1375   september 1853
# 1376   danube river
# 1377   ottoman forces
# 1378   william howard russell
# 1379   june 24, 1839
# 1380   local commanders
# 1381   105  the tsar
# 1382   28 march 1854
# 1383   432–33
# 1384   roger fenton
# 1385   russian troops
# 1386   far south wrangel
# 1387   may
# 1388   461 the resulting battle
# 1389   14 november
# 1390   alfred lord tennyson
# 1391   however
# 1392   sultan
# 1393   russians
# 1394   439 an electrical telegraph
# 1395   victor emmanuel ii
# 1396   september 1854
# 1397   over 200 years
# 1398   principalities
# 1399   black sea
# 1400   vidin
# 1401   gallipoli
# 1402   may
# 1403   calafat
# 1404   time
# 1405   cardigan
# 1406   19 october
# 1407   little additional naval action
# 1408   london
# 1409   marani
# 1410   about 1000
# 1411   sevastopol
# 1412   victor emmanuel ii
# 1413   february
# 1414   chetatea
# 1415   time
# 1416   130–43
# 1417   nicholas
# 1418   1840
# 1419   balkans
# 1420   times newspaper
# 1421   a. w
# 1422   danube
# 1423   note
# 1424   large body
# 1425   snow
# 1426   march 1854
# 1427   nicholas
# 1428   azov sea
# 1429   sunday
# 1430   taganrog
# 1431   8000
# 1432   april
# 1433   omar pasha
# 1434   5 september
# 1435   crimean war
# 1436   february
# 1437   ottoman army
# 1438   alaska
# 1439   411 nicholas
# 1440   russian america
# 1441   5 december 1853
# 1442   28 may
# 1443   aberdeen
# 1444   however
# 1445   kerch strait
# 1446   192
# 1447   four
# 1448   september 8000
# 1449   1848
# 1450   february 1853
# 1451   april 1854
# 1452   201 the ships
# 1453   france
# 1454   30
# 1455   seven columns
# 1456   spring of 1821
# 1457   :104:19
# 1458   crimean war
# 1459   failure
# 1460   30 march 1856
# 1461   peace terms
# 1462   russians
# 1463   19 october
# 1464   black sea
# 1465   greeks
# 1466   about 20000
# 1467   menshikov
# 1468   war
# 1469   west
# 1470   battle of sinop
# 1471   late july 1854
# 1472   8000
# 1473   september 1854
# 1474   first
# 1475   27
# 1476   malakoff
# 1477   chetatea
# 1478   1830
# 1479   `` clerical party
# 1480   civilian engineering crew
# 1481   30 march 1856
# 1482   russia
# 1483   4000
# 1484   sevastopol
# 1485   paris
# 1486   popularisation
# 1487   little advance
# 1488   war
# 1489   otto von bismarck
# 1490   industrial explosives
# 1491   british
# 1492   1830
# 1493   chetatea
# 1494   february
# 1495   telegraph
# 1496   25 october
# 1497   another seventeen years
# 1498   emperors
# 1499   1648
# 1500   1720s
# 1501   yongzheng
# 1502   1623
# 1503   pro-japanese koreans
# 1504   xinjiang
# 1505   sixty-one year
# 1506   1648
# 1507   dorgon
# 1508   sun yat-sen
# 1509   qing emperors
# 1510   eight
# 1511   qing dynasty
# 1512   1900
# 1513   empire of the great qing
# 1514   beijing
# 1515   yongzheng
# 1516   diplomatic and strategic problems
# 1517   instead
# 1518   name
# 1519   qing armies
# 1520   first opium war
# 1521   yuan shikai
# 1522   puyi
# 1523   over 3,400
# 1524   china
# 1525   peasant rebels
# 1526   britain
# 1527   empire
# 1528   kangxi emperor
# 1529   xiang army
# 1530   1641
# 1531   1850s
# 1532   team
# 1533   yingzhen
# 1534   shunzhi emperor
# 1535   two
# 1536   manchus
# 1537   zeng guofan
# 1538   watershed
# 1539   korea
# 1540   kangxi emperor
# 1541   government
# 1542   mid-19th century
# 1543   april 1644
# 1544   many han
# 1545   1683
# 1546   fall
# 1547   zeng guofan's strategy
# 1548   some 20 million
# 1549   li
# 1550   18th century
# 1551   manchus
# 1552   chinese
# 1553   late ming dynasty
# 1554   1641
# 1555   manchus
# 1556   qing organization
# 1557   yuan shikai
# 1558   jianzhou
# 1559   china
# 1560   1860
# 1561   qīng cháo
# 1562   ming general wu sangui
# 1563   yuan shikai
# 1564   manchuria
# 1565   prince gui
# 1566   liao area
# 1567   18th century
# 1568   1930s
# 1569   department
# 1570   liaodong
# 1571   puyi
# 1572   shunzhi emperor
# 1573   sixty-one year reign
# 1574   india
# 1575   jianzhou
# 1576   hong xiuquan
# 1577   han chinese
# 1578   xinjiang
# 1579   british
# 1580   400,000
# 1581   beijing
# 1582   zeng guofan
# 1583   chinese
# 1584   1930s
# 1585   yingzhen
# 1586   late 19th century
# 1587   dorgon
# 1588   calligraphy
# 1589   such problems
# 1590   jiangnan
# 1591   qing surrender
# 1592   manchu generals
# 1593   western powers
# 1594   name
# 1595   several ming princes
# 1596   53
# 1597   board
# 1598   koxinga
# 1599   eight years
# 1600   promises
# 1601   nanjing
# 1602   qing
# 1603   1850s
# 1604   xinjiang
# 1605   1661
# 1606   day
# 1607   early rulers
# 1608   yuan
# 1609   turnover
# 1610   400,000
# 1611   1889
# 1612   qing emperors
# 1613   early manchu rulers
# 1614   qing court
# 1615   his death
# 1616   beijing
# 1617   1648
# 1618   1858
# 1619   han bannermen
# 1620   emperors
# 1621   three
# 1622   majority
# 1623   ming dynasty
# 1624   china
# 1625   two
# 1626   cabinet
# 1627   qing dynasty
# 1628   1683
# 1629   1711
# 1630   yingzhen
# 1631   ci'an
# 1632   november 14, 1908
# 1633   nine
# 1634   qīng cháo
# 1635   dungan revolt
# 1636   qīng cháo
# 1637   qianlong emperor
# 1638   manchu generals
# 1639   manchus
# 1640   1673
# 1641   eighteen
# 1642   2,000 years
# 1643   80%
# 1644   first opium war
# 1645   november 14, 1908
# 1646   qing dynasty
# 1647   yaqub beg
# 1648   september 1643
# 1649   li zicheng
# 1650   yongying system
# 1651   imperial palace
# 1652   1864
# 1653   november 14, 1908
# 1654   han bannermen
# 1655   only 16%
# 1656   art
# 1657   yongzheng
# 1658   xinjiang
# 1659   1854
# 1660   far
# 1661   china
# 1662   remaining banners
# 1663   yingzhen
# 1664   qianlong emperor 's reign
# 1665   christianity
# 1666   over 3,400
# 1667   five
# 1668   zeng guofan
# 1669   qing
# 1670   wu sangui
# 1671   remaining banners
# 1672   1681
# 1673   multi-ethnic force
# 1674   manchus
# 1675   xinjiang
# 1676   terms
# 1677   1683
# 1678   beijing
# 1679   these military reforms
# 1680   qing dynasty
# 1681   qing
# 1682   suiyuan shidan
# 1683   1661
# 1684   1782
# 1685   1637
# 1686   full control
# 1687   qing dynasty
# 1688   nurhaci
# 1689   new but not exactly modern chinese armies
# 1690   late 19th century
# 1691   addition
# 1692   emperors
# 1693   1641
# 1694   dorgon's controversial july 1645 edict
# 1695   manchu generals
# 1696   november
# 1697   these units
# 1698   early manchu rulers
# 1699   qīng cháo
# 1700   pro-japanese koreans
# 1701   1870
# 1702   yaqub beg
# 1703   wu
# 1704   short story form
# 1705   move
# 1706   manchuria
# 1707   1711
# 1708   guangxu
# 1709   too few ethnic manchus
# 1710   china
# 1711   remaining banners
# 1712   300 million
# 1713   early manchu rulers
# 1714   1850s
# 1715   ningguta
# 1716   chief
# 1717   jiangyin
# 1718   1648
# 1719   guangxu
# 1720   1727
# 1721   1860
# 1722   1637
# 1723   qīng cháo
# 1724   qianlong emperor
# 1725   october 30
# 1726   suiyuan shidan
# 1727   only two
# 1728   dst
# 1729   evening
# 1730   opposition
# 1731   continental europe
# 1732   canadian
# 1733   time
# 1734   2007
# 1735   all clocks
# 1736   iceland
# 1737   all years
# 1738   daylight
# 1739   three-year trial
# 1740   example
# 1741   1895
# 1742   2008
# 1743   groups
# 1744   us
# 1745   normal dst
# 1746   are
# 1747   54.5%
# 1748   summer
# 1749   forms
# 1750   argue
# 1751   2011 to 2014
# 1752   tz=':america/new_york'
# 1753   broadly
# 1754   standardize
# 1755   north american
# 1756   1993
# 1757   about 3.5%
# 1758   2008 doe report
# 1759   july
# 1760   october 5
# 1761   some early proponents
# 1762   retinitis pigmentosa foundation fighting blindness
# 1763   willett's 1907 proposal
# 1764   1907
# 1765   2008
# 1766   us
# 1767   2007
# 1768   2005
# 1769   keeps
# 1770   xinjiang
# 1771   1907
# 1772   us
# 1773   merriam-webster
# 1774   regions
# 1775   united kingdom
# 1776   sunlight exposure
# 1777   unexpected adverse effect
# 1778   winston churchill
# 1779   people
# 1780   proposal
# 1781   1907
# 1782   1995
# 1783   microsoft windows
# 1784   negative dst
# 1785   britain
# 1786   standard time
# 1787   autumn and two hours
# 1788   merriam-webster's
# 1789   two hours
# 1790   dst
# 1791   correlation
# 1792   (cet
# 1793   all years
# 1794   fixed work schedules
# 1795   example
# 1796   dst
# 1797   november
# 1798   several studies
# 1799   1970s
# 1800   older form
# 1801   march 2011
# 1802   2007
# 1803   us
# 1804   winter
# 1805   north america
# 1806   1895
# 1807   ntfs
# 1808   is
# 1809   northern summer
# 1810   some farmers' groups
# 1811   some countries
# 1812   dst inherits
# 1813   dst
# 1814   filesystem
# 1815   2007
# 1816   merriam-webster
# 1817   some farmers' groups
# 1818   st
# 1819   people
# 1820   time zone differences
# 1821   early goal
# 1822   one reason
# 1823   daylight
# 1824   common agreement
# 1825   kingsford charcoal
# 1826   1999 study
# 1827   many enactments
# 1828   one
# 1829   year-independent way
# 1830   2007
# 1831   at least two
# 1832   us
# 1833   clocks
# 1834   iceland
# 1835   europe
# 1836   britain
# 1837   2000
# 1838   daily
# 1839   name
# 1840   all clocks
# 1841   united kingdom
# 1842   1784 satire
# 1843   compatibility
# 1844   electricity use
# 1845   times
# 1846   1984
# 1847   adopt
# 1848   britain
# 1849   us
# 1850   first three weekdays
# 1851   plan
# 1852   standardize
# 1853   14 april
# 1854   2008
# 1855   people
# 1856   us
# 1857   summer hours
# 1858   little impact
# 1859   accidents
# 1860   example
# 1861   summer
# 1862   taxing shutters
# 1863   starting
# 1864   andrew peters
# 1865   dst
# 1866   as much as 11%
# 1867   summer
# 1868   similar twice-yearly tasks
# 1869   2005
# 1870   dairy farmers
# 1871   modern dst
# 1872   months of the year
# 1873   1996
# 1874   file
# 1875   1987–2006
# 1876   2007 us change
# 1877   britain
# 1878   may
# 1879   repeals
# 1880   may 1965
# 1881   annual
# 1882   2005
# 1883   1983
# 1884   los angeles
# 1885   van halen
# 1886   end of the decade
# 1887   scottish
# 1888   1988
# 1889   1980s
# 1890   van halen
# 1891   canadian
# 1892   1958
# 1893   elements
# 1894   led zeppelin
# 1895   double platinum ballbreaker
# 1896   bigger hit
# 1897   bon scott
# 1898   one
# 1899   1980s
# 1900   breakup
# 1901   irish
# 1902   david lee roth
# 1903   black crowes
# 1904   poison
# 1905   aerosmith's comeback
# 1906   los angeles music scene
# 1907   bon scott
# 1908   fellow australians airbourne's début album
# 1909   alice cooper
# 1910   los angeles
# 1911   early forms
# 1912   rock anthem
# 1913   2009
# 1914   san francisco
# 1915   their hard rock roots
# 1916   joe hill louis
# 1917   1993
# 1918   1980s
# 1919   1980s
# 1920   black sabbath's
# 1921   us
# 1922   guns n' roses
# 1923   ramones
# 1924   1980s
# 1925   bon jovi
# 1926   heavy metal
# 1927   number
# 1928   audioslave
# 1929   1992
# 1930   david lee roth
# 1931   four
# 1932   1981
# 1933   1987
# 1934   new wave
# 1935   term
# 1936   bon jovi's 1995 album
# 1937   bon jovi's third album
# 1938   kinks
# 1939   others
# 1940   ac/dc
# 1941   guns n' roses
# 1942   first commercial isp
# 1943   transit isps
# 1944   13 april 2015
# 1945   adoption
# 1946   virtual isp ( visp
# 1947   other services
# 1948   possible solution
# 1949   4 years
# 1950   1995
# 1951   citation
# 1952   intelligence agencies
# 1953   their customers
# 1954   mailbox provider
# 1955   internet
# 1956   fcc chairman
# 1957   free isps
# 1958   isps
# 1959   isps
# 1960   isps
# 1961   upstream isp
# 1962   prism
# 1963   many mailbox providers
# 1964   same concept
# 1965   26 february 2015
# 1966   transit isps
# 1967   free isps
# 1968   other services
# 1969   university of kansas school of business
# 1970   three
# 1971   top law school
# 1972   more than 345
# 1973   lawrence
# 1974   addition
# 1975   university of kansas school of business
# 1976   one
# 1977   overland park
# 1978   march 21, 1865
# 1979   march 21, 1865
# 1980   university of kansas school
# 1981   community tool box
# 1982   university daily kansan
# 1983   marvin hall
# 1984   wichita
# 1985   about 2,100
# 1986   kansas union
# 1987   wichita
# 1988   j-school 's students
# 1989   1954
# 1990   first
# 1991   kansas public radio station kanu
# 1992   23,597
# 1993   university of kansas school of business
# 1994   1954
# 1995   number
# 1996   ku school of engineering
# 1997   kansas
# 1998   thirteen
# 1999   university
# 2000   university of kansas school of business
# 2001   kansas union
# 2002   bs/ms
# 2003   university of kansas school of business
# 2004   kansas
# 2005   professional school
# 2006   wichita
# 2007   medical center
# 2008   first union
# 2009   princeton review
# 2010   designintelligence
# 2011   watson library
# 2012   48 months
# 2013   college of liberal arts & sciences
# 2014   about 2,100
# 2015   university of kansas school of architecture , design
# 2016   about 2,100
# 2017   university of kansas school of business
# 2018   lawrence
# 2019   university of kansas school of business
# 2020   university
# 2021   september 12, 1866
# 2022   medical center and university hospital
# 2023   mark mangino
# 2024   ku men 's basketball team
# 2025   journal
# 2026   10,000
# 2027   ku's academic computing department
# 2028   university of kansas school of business
# 2029   team
# 2030   university of kansas school of business
# 2031   1891
# 2032   lynx
# 2033   ku cross country
# 2034   citation
# 2035   additional funds
# 2036   bs/ms
# 2037   23,597
# 2038   school newspaper
# 2039   their most recent championship
# 2040   university of kansas school
# 2041   1891
# 2042   ku department
# 2043   thirteen
# 2044   1891
# 2045   2007
# 2046   w 15th st
# 2047   enrollment
# 2048   23,597
# 2049   university
# 2050   sheahon zenger
# 2051   ku's school of business
# 2052   designintelligence
# 2053   more than 345
# 2054   free , online resource
# 2055   kansas
# 2056   5
# 2057   lawrence
# 2058   college of liberal arts & sciences
# 2059   university of kansas school of law
# 2060   around 2
# 2061   western europe
# 2062   jana bennett
# 2063   1974
# 2064   event
# 2065   dedicated tv channel
# 2066   bbc television
# 2067   service
# 2068   bbc one
# 2069   two
# 2070   mechanically scanned, 30-line television broadcasts
# 2071   bbc
# 2072   broadcasting act 1990
# 2073   weeks
# 2074   bbc domestic television channels
# 2075   march 2003
# 2076   uk
# 2077   queen elizabeth
# 2078   world war ii
# 2079   basement
# 2080   bbc television
# 2081   britain
# 2082   english
# 2083   uk
# 2084   late 1930
# 2085   britain
# 2086   bbc television service
# 2087   other uk nations
# 2088   bbc
# 2089   1967
# 2090   two
# 2091   few years
# 2092   bbc television service
# 2093   few years
# 2094   studio
# 2095   nearly 1000
# 2096   pioneering bbc television series
# 2097   drama
# 2098   uk
# 2099   september 1939
# 2100   1927
# 2101   30
# 2102   commissioning
# 2103   40 kilometres
# 2104   between december 2004
# 2105   different remit
# 2106   bbc television
# 2107   existing vhf 405-line system
# 2108   world war ii
# 2109   bbc television department
# 2110   daily
# 2111   mechanical camera
# 2112   bbc
# 2113   larger quarters
# 2114   between december 2004
# 2115   queen elizabeth
# 2116   £85 million
# 2117   london
# 2118   estimated 25,000–40,000
# 2119   [original research
# 2120   dvd
# 2121   david attenborough
# 2122   series
# 2123   1967
# 2124   united states
# 2125   2008
# 2126   division
# 2127   united kingdom
# 2128   estimated 25,000–40,000
# 2129   bbc television
# 2130   london
# 2131   weeks
# 2132   division
# 2133   february
# 2134   england's bbc one output
# 2135   bbc tv
# 2136   1967
# 2137   1950s
# 2138   625-line
# 2139   5 july 2004
# 2140   1927
# 2141   1927
# 2142   general entertainment channel
# 2143   united states
# 2144   bbc scotland's
# 2145   1967
# 2146   dvd
# 2147   genetic groups
# 2148   rise
# 2149   united states
# 2150   survey
# 2151   empirical and conceptual problems
# 2152   one crucial innovation
# 2153   practice
# 2154   only 35%
# 2155   michelle alexander
# 2156   others
# 2157   health disparities
# 2158   fuzzy sets
# 2159   united states
# 2160   races
# 2161   individual
# 2162   abu el-haj
# 2163   common misconception
# 2164   physical anthropologists
# 2165   early human genetic cluster analysis studies
# 2166   only seven
# 2167   early 20th century
# 2168   human populations
# 2169   some societies
# 2170   authors
# 2171   race
# 2172   kittles
# 2173   result
# 2174   early human genetic cluster analysis studies
# 2175   federal government policy
# 2176   these socioeconomic factors
# 2177   such large geographic distances
# 2178   42.4%
# 2179   brutal conflicts
# 2180   increasing number
# 2181   brazil
# 2182   only seven
# 2183   whites
# 2184   categories
# 2185   biological race concept
# 2186   population
# 2187   existence
# 2188   scientific classification
# 2189   subspecies
# 2190   sex
# 2191   rigid descent rule
# 2192   forensic physical anthropologist
# 2193   1949
# 2194   skeletal remain
# 2195   at least two
# 2196   sense
# 2197   falsify
# 2198   recent work
# 2199   no generally accepted concept
# 2200   greatest number
# 2201   many
# 2202   survey
# 2203   races
# 2204   about 30%
# 2205   clustering
# 2206   today
# 2207   20th century
# 2208   2000
# 2209   brazilian child
# 2210   racism
# 2211   suggest
# 2212   populations
# 2213   cladistics
# 2214   phylogenetic analysis
# 2215   initial hypotheses
# 2216   east asians
# 2217   populations
# 2218   practice
# 2219   significant number
# 2220   700.000
# 2221   clade
# 2222   diagnosis
# 2223   concept
# 2224   eduardo bonilla-silva
# 2225   physical anthropologists
# 2226   adversely
# 2227   mass incarceration
# 2228   many thousands
# 2229   france
# 2230   y chromosomes
# 2231   about 5%
# 2232   roughly 28–37%
# 2233   93%
# 2234   uses
# 2235   international epidemiological data
# 2236   cranial measurements
# 2237   european concept
# 2238   arbitrary matter
# 2239   1964
# 2240   another way
# 2241   blumenbach
# 2242   good arguments
# 2243   word
# 2244   earlier work
# 2245   some researchers
# 2246   last two decades
# 2247   eduardo bonilla-silva
# 2248   race
# 2249   many people
# 2250   his 2003 paper
# 2251   system
# 2252   approximately five percent
# 2253   europeans
# 2254   kaplan
# 2255   many biological anthropologists
# 2256   amerindians
# 2257   identification code
# 2258   system
# 2259   use
# 2260   five
# 2261   thus, anthropologist frank livingstone's conclusion
# 2262   that values
# 2263   study
# 2264   abu el-haj
# 2265   any population
# 2266   mitochondrial dna
# 2267   sewall wright
# 2268   way
# 2269   1978
# 2270   researchers
# 2271   1775 treatise
# 2272   markers
# 2273   sense
# 2274   questioning
# 2275   three
# 2276   anthropologists
# 2277   one result
# 2278   last decades
# 2279   term race
# 2280   william c. boyd
# 2281   examples
# 2282   empirical reasons
# 2283   designation 'subspecies
# 2284   brazilian child
# 2285   early 20th century
# 2286   cladistics
# 2287   dean amadon
# 2288   three
# 2289   who
# 2290   contradictions
# 2291   similarly
# 2292   rise
# 2293   jim crow laws
# 2294   racial groups
# 2295   balanced degree
# 2296   blumenbach
# 2297   concept
# 2298   many others
# 2299   dean amadon
# 2300   european union
# 2301   more than 1.8 million years ago
# 2302   eduardo bonilla-silva
# 2303   60-65%
# 2304   example
# 2305   fixation index
# 2306   widespread popularity
# 2307   racial groups
# 2308   rather than 85%
# 2309   anthropologist norman sauer
# 2310   authors
# 2311   thousands
# 2312   19th century
# 2313   2008
# 2314   selected allele
# 2315   20th century
# 2316   scientists
# 2317   anthropologists
# 2318   scientific one
# 2319   subsequent influential classifications
# 2320   all non-african groups
# 2321   last two decades of the 18th century
# 2322   clade
# 2323   racial groups
# 2324   material
# 2325   race
# 2326   united states
# 2327   selected allele
# 2328   18th century
# 2329   77
# 2330   2000 edition
# 2331   small non-representative sample
# 2332   some states
# 2333   definitions
# 2334   sociological factors
# 2335   trained anthropologist
# 2336   human populations
# 2337   historically recent acceleration
# 2338   mixture
# 2339   racial discrimination
# 2340   other mammalian species
# 2341   authors
# 2342   graves
# 2343   utility
# 2344   loci
# 2345   first post-classical published classification
# 2346   one-drop rule
# 2347   global distributions
# 2348   doctors
# 2349   1970s
# 2350   differences
# 2351   1996
# 2352   2007 review paper
# 2353   at least three million people
# 2354   races
# 2355   early 20th century
# 2356   2001
# 2357   more realistic portrayal
# 2358   visually
# 2359   19th century
# 2360   race
# 2361   english language
# 2362   considerable suffering
# 2363   term
# 2364   england
# 2365   cladistics
# 2366   concept
# 2367   , therefore fst values
# 2368   replaced
# 2369   same geographical location
# 2370   2007 review paper
# 2371   homininae
# 2372   some scholars
# 2373   rachel caspari
# 2374   scientists
# 2375   came
# 2376   more than 1.8 million years ago
# 2377   virtually all physical anthropologists
# 2378   figure
# 2379   stanford university school of medicine
# 2380   correctly
# 2381   attempt
# 2382   era
# 2383   farm
# 2384   temple area
# 2385   evidence
# 2386   social inequality
# 2387   settlements
# 2388   most neolithic societies
# 2389   southwestern united states
# 2390   era
# 2391   rhine
# 2392   era
# 2393   british isles
# 2394   mid-late neolithic
# 2395   elaborate tombs
# 2396   these cultural elements
# 2397   2002
# 2398   control
# 2399   first
# 2400   farm
# 2401   2012
# 2402   copper age
# 2403   southeast europe agrarian societies
# 2404   era
# 2405   eurasia
# 2406   neolithic peoples
# 2407   neolithic pastoralists
# 2408   bronze age
# 2409   anthropomorphic figurines
# 2410   europe
# 2411   middle east
# 2412   turkey
# 2413   early farmers
# 2414   near east
# 2415   control
# 2416   era
# 2417   vashtëmi
# 2418   early farmers
# 2419   9000 bc
# 2420   neolithic people
# 2421   era
# 2422   çatal höyük
# 2423   early japanese societies
# 2424   9000 bc
# 2425   largest prehistoric settlements
# 2426   other parts
# 2427   around 10,700
# 2428   ireland
# 2429   treaties
# 2430   same hierarchical position
# 2431   contracting parties ' full names
# 2432   two-thirds
# 2433   relation
# 2434   sovereignty
# 2435   treaty
# 2436   party
# 2437   citation
# 2438   case
# 2439   congressional-executive agreements
# 2440   office of legal affairs
# 2441   no one party
# 2442   600
# 2443   attack
# 2444   material breach
# 2445   treaties
# 2446   consent
# 2447   treaties
# 2448   all parties
# 2449   other cases
# 2450   development
# 2451   first
# 2452   citation
# 2453   al-waqidi
# 2454   each article
# 2455   international law
# 2456   binding greenhouse gas emission limits
# 2457   brazil
# 2458   two
# 2459   some treaties
# 2460   long treaty
# 2461   any subsequent act
# 2462   compacts
# 2463   state legislation
# 2464   one
# 2465   treaty
# 2466   modern treaties
# 2467   signatures
# 2468   brazilian federal constitution
# 2469   entered
# 2470   state
# 2471   political boundaries
# 2472   unaccepting
# 2473   international law
# 2474   treaty
# 2475   congress
# 2476   official legal procedures
# 2477   party
# 2478   one
# 2479   prior to 1871
# 2480   united nations
# 2481   government
# 2482   mabo
# 2483   un
# 2484   case
# 2485   preamble
# 2486   example
# 2487   brazilian federal constitution
# 2488   verb
# 2489   european colonization
# 2490   treaties
# 2491   citation
# 2492   contracting parties ' full names
# 2493   division
# 2494   its obligations
# 2495   supreme court
# 2496   state party 's withdrawal
# 2497   late 20th and early 21st century
# 2498   consent
# 2499   treaty
# 2500   division
# 2501   text
# 2502   end
# 2503   date
# 2504   citation
# 2505   party 's consent
# 2506   nations
# 2507   multilateral treaties
# 2508   these norms
# 2509   three
# 2510   international covenant on civil and political rights
# 2511   federal supreme court
# 2512   brazilian federal constitution
# 2513   state 's consent
# 2514   coercion
# 2515   ethiopia
# 2516   practice
# 2517   u.s.
# 2518   case
# 2519   consent
# ...
# 2805   independence
# 2806   part
# 2807   another important building
# 2808   manu
# 2809   ellice islands
# 2810   10,640
# 2811   july 2012
# 2812   palagi traders
# 2813   hearing
# 2814   its new imac
# 2815   68020-powered macintosh lc
# 2816   macintosh
# 2817   2900
# 2818   may 1998
# 2819   their first portable computer
# 2820   then-new imac g5
# 2821   order
# 2822   created
# 2823   macintosh project
# 2824   sold
# 2825   four years
# 2826   current mac product family
# 2827   all 39 advertising pages
# 2828   sales
# 2829   macintosh
# 2830   mac os x
# 2831   apple's market share
# 2832   most pcs
# 2833   mac 's market share
# 2834   retrofits
# 2835   use
# 2836   air
# 2837   apple
# 2838   intel
# 2839   original
# 2840   same year
# 2841   response
# 2842   matters
# 2843   macintosh
# 2844   may
# 2845   well
# 2846   john sculley
# 2847   only one
# 2848   may
# 2849   steve jobs
# 2850   1998
# 2851   october
# 2852   macintosh
# 2853   macintosh ii
# 2854   $2.5 million
# 2855   steve jobs
# 2856   may 1990
# 2857   its new imac
# 2858   us$1.5 million
# 2859   all 39 advertising pages
# 2860   estimated 100,000
# 2861   jobs
# 2862   october 2005
# 2863   john dvorak
# 2864   1997
# 2865   40
# 2866   macintosh platform
# 2867   august
# 2868   1989
# 2869   second generation
# 2870   change
# 2871   final macintosh design
# 2872   mice
# 2873   apple
# 2874   apple
# 2875   early 2001
# 2876   primary authors
# 2877   installed base
# 2878   imac
# 2879   finally
# 2880   macintosh 's minimal memory
# 2881   clarisworks
# 2882   2000
# 2883   complete office suite
# 2884   number five spot
# 2885   third-party platform virtualization software
# 2886   other personal computer manufacturers
# 2887   steve jobs
# 2888   quarterly
# 2889   air
# 2890   open firmware
# 2891   new motorola 68030 processor
# 2892   steve jobs
# 2893   contrast
# 2894   steve jobs
# 2895   bill atkinson
# 2896   macintosh classic
# 2897   macintosh 's market share
# 2898   discontinued power macintosh g3 , to slot between the imac g3 and the power mac g4 .
# 2899   hewlett packard
# 2900   suggestions
# 2901   october 2009
# 2902   several ultrabooks
# 2903   mavericks
# 2904   chief designer
# 2905   allan loren
# 2906   updated motorola cpus
# 2907   late 1991
# 2908   may 1990
# 2909   october
# 2910   open firmware
# 2911   apple
# 2912   3.36 million
# 2913   macintosh se
# 2914   macbook air
# 2915   2013
# 2916   mid-2011
# 2917   darwin
# 2918   macintosh
# 2919   march
# 2920   c++
# 2921   all current mac models
# 2922   cube
# 2923   apple's actions
# 2924   one megabyte
# 2925   over 14%
# 2926   c++
# 2927   apple
# 2928   performance advantage
# 2929   20
# 2930   2006
# 2931   time
# 2932   windows 95 operating system
# 2933   windows
# 2934   apple
# 2935   final mac design
# 2936   its new imac
# 2937   adventurous mac users
# 2938   part
# 2939   third place spot
# 2940   macintosh
# 2941   imac , macbook pro , macbook air , and mac mini lines
# 2942   early 2011
# 2943   these models
# 2944   these materials
# 2945   component shortage
# 2946   seven years
# 2947   around 6 percent
# 2948   two
# 2949   2006
# 2950   macintosh
# 2951   removal
# 2952   1993 powerbook 165c
# 2953   macintosh iici
# 2954   mid-2011
# 2955   october
# 2956   compaq
# 2957   jean-louis gassée
# 2958   lisa and macintosh user interfaces
# 2959   regis mckenna
# 2960   launch
# 2961   performance advantage
# 2962   update
# 2963   mac os x
# 2964   other personal computer manufacturers
# 2965   only about ten
# 2966   macintosh
# 2967   1993
# 2968   crt
# 2969   these models
# 2970   only one
# 2971   glass
# 2972   9,900
# 2973   march 2006
# 2974   floppy disk drive
# 2975   apple
# 2976   56 percent
# 2977   macintosh programmer 's workshop
# 2978   1994
# 2979   floppy disk drive
# 2980   april 1984
# 2981   apple
# 2982   macs
# 2983   only about ten
# 2984   every macintosh
# 2985   3,195
# 2986   mac
# 2987   launch
# 2988   2011
# 2989   its software business
# 2990   2.06 percent
# 2991   virbhadra singh
# 2992   state-owned television broadcaster
# 2993   governor
# 2994   himachal
# 2995   sikhs
# 2996   kangra miniature paintings
# 2997   state
# 2998   himachal
# 2999   state
# 3000   himachal pradesh
# 3001   economy
# 3002   10th century
# 3003   hill stations
# 3004   public radio station
# 3005   1 november 1956
# 3006   himachal
# 3007   handicrafts
# 3008   virbhadra singh
# 3009   21st
# 3010   anglo-gorkha war
# 3011   superintendent
# 3012   pit-loom
# 3013   virbhadra singh
# 3014   buddhism and sikhism
# 3015   himachal pradesh
# 3016   wool
# 3017   year 1768
# 3018   hima
# 3019   hydro electric resources
# 3020   dial-up access
# 3021   mahmud ghaznavi
# 3022   citation
# 3023   citation
# 3024   technological advancements
# 3025   30 december 2007
# 3026   first
# 3027   nepal
# 3028   h.p.
# 3029   private fm stations
# 3030   18 december 1970
# 3031   state
# 3032   1.16%
# 3033   radio
# 3034   2006
# 3035   handicrafts
# 3036   1948
# 3037   muslims
# 3038   first five-year plan
# 3039   extreme variation
# 3040   most others
# 3041   military settlement
# 3042   roman women
# 3043   imperial era
# 3044   human sacrifice
# 3045   security
# 3046   edict
# 3047   historian livy
# 3048   each camp
# 3049   constantine
# 3050   roman women
# 3051   second edict
# 3052   famous tirade
# 3053   mysteries
# 3054   all sacrifices
# 3055   ordinary romans
# 3056   vergil
# 3057   valerian's first religious edict
# 3058   di immortales
# 3059   rome
# 3060   independent means
# 3061   ruins
# 3062   (509–27 bc
# 3063   excessive devotion
# 3064   rome's hegemony
# 3065   end
# 3066   product
# 3067   customary offers
# 3068   product
# 3069   rome's hegemony
# 3070   relationship
# 3071   little or no civil authority
# 3072   edict
# 3073   edict
# 3074   most important camp-offering
# 3075   several days
# 3076   women
# 3077   minerva
# 3078   mistake
# 3079   edict
# 3080   such opportunities
# 3081   solution
# 3082   cult
# 3083   sporadic and sometimes brutal attempts
# 3084   punic crisis
# 3085   human sacrifice
# 3086   roman oaths
# 3087   hitherto
# 3088   office
# 3089   jupiter latiaris
# 3090   its religious dimensions
# 3091   augustus
# 3092   roman calendar
# 3093   second edict
# 3094   record
# 3095   lares and penates
# 3096   first punic war
# 3097   non-official but lawful cults
# 3098   rites
# 3099   act
# 3100   same token
# 3101   superstitio
# 3102   l. junius brutus
# 3103   others
# 3104   vestals
# 3105   augustan settlement
# 3106   february
# 3107   hitherto unlikely source
# 3108   haruspices
# 3109   constantine
# 3110   gaul
# 3111   original meaning
# 3112   egypt
# 3113   early severan era
# 3114   roman bellona
# 3115   heretics
# 3116   last emperor
# 3117   roman calendar
# 3118   twelve tables
# 3119   rome's hegemony
# 3120   rome
# 3121   infernal gods
# 3122   great crisis
# 3123   ad 567
# 3124   imperial
# 3125   (509–27 bc
# 3126   emperor julian
# 3127   end of the republic
# 3128   very late republic
# 3129   high-status seating
# 3130   archaeology
# 3131   sacrifice
# 3132   several days
# 3133   gauls
# 3134   their synagogues
# 3135   romans
# 3136   individuals
# 3137   empire
# 3138   mortal 's death
# 3139   later empire
# 3140   16 bc tiberius
# 3141   julian
# 3142   popular belief deities
# 3143   treason
# 3144   record
# 3145   all such spectacular displays
# 3146   ofﬁcial recognition
# 3147   harmony
# 3148   first ( 303 ad
# 3149   empire-wide ban
# 3150   successful general
# 3151   her clients
# 3152   second punic war
# 3153   prayer
# 3154   addition
# 3155   funding
# 3156   his attempt
# 3157   last century
# 3158   magistrates
# 3159   civil and religious law
# 3160   no separate priestly caste
# 3161   303 ad
# 3162   product
# 3163   comparison
# 3164   valerian's first religious edict
# 3165   roman architect vitruvius
# 3166   rome
# 3167   decius mus
# 3168   divine consideration
# 3169   presence
# 3170   regal era
# 3171   edict
# 3172   ovid
# 3173   state cult
# 3174   public priests
# 3175   her clients
# 3176   roman religion
# 3177   devotio
# 3178   vestals
# 3179   his reign
# 3180   western emperor gratian
# 3181   ordinary
# 3182   264–146
# 3183   senate
# 3184   least
# 3185   thessaly
# 3186   some periods
# 3187   aventine temple
# 3188   mystery cult
# 3189   male priests
# 3190   roman "domestic" deities
# 3191   latin word templum
# 3192   popular cult
# 3193   other public festivals
# 3194   constantine
# 3195   they
# 3196   ruins
# 3197   exceptional honor
# 3198   early days
# 3199   servius tullius
# 3200   rome
# 3201   myth
# 3202   participation
# 3203   first and last roman
# 3204   sacrifice
# 3205   rome's hegemony
# 3206   decius
# 3207   excessive devotion
# 3208   magistrates
# 3209   haruspicy
# 3210   hellenization
# 3211   later empire
# 3212   times
# 3213   context
# 3214   everyday world
# 3215   male priests
# 3216   law
# 3217   rome
# 3218   around the 7th century ad
# 3219   his wife
# 3220   new plebeian nobility
# 3221   customary offers
# 3222   fulfillment
# 3223   household cult
# 3224   popular belief deities
# 3225   some public rituals
# 3226   graeco-roman world
# 3227   roman poets
# 3228   rites
# 3229   gods
# 3230   vesta
# 3231   hitherto
# 3232   prodigies
# 3233   funeral and commemorative rites
# 3234   clitellates
# 3235   locomotion
# 3236   septa
# 3237   ragworms' jaws
# 3238   65 million years ago
# 3239   ragworms
# 3240   fluid
# 3241   brain
# 3242   "hairs
# 3243   clitellates
# 3244   find
# 3245   circulates
# 3246   3
# 3247   small shelly fossil cloudina
# 3248   north america
# 3249   most annelids
# 3250   found
# 3251   frontmost section
# 3252   some polychaetes
# 3253   cladistic research
# 3254   frontmost section
# 3255   two
# 3256   respiratory pigment
# 3257   two
# 3258   difference
# 3259   one-cell deep epidermis
# 3260   mesothelium
# 3261   two
# 3262   sea-floor
# 3263   mesothelium
# 3264   annelids
# 3265   leeches
# 3266   produce
# 3267   fertilized eggs
# 3268   thus
# 3269   two families
# 3270   their cells
# 3271   leeches
# 3272   locomotion
# 3273   oligochaetes
# 3274   1997
# 3275   most annelids
# 3276   most polychaetes
# 3277   frontmost section
# 3278   some very mobile and active polychaetes
# 3279   protostomes
# 3280   oligochaetes
# 3281   brain
# 3282   australia
# 3283   rest care
# 3284   northern hardwood forests
# 3285   ediacaran
# 3286   two
# 3287   vertebrates
# 3288   brain
# 3289   15%
# 3290   enables
# 3291   2008
# 3292   30 ad
# 3293   their fossils
# 3294   some marine polychaetes' predation
# 3295   clitellates
# 3296   charles darwin's book
# 3297   leeches
# 3298   vertebrates
# 3299   mid-19th century
# 3300   1964
# 3301   some states
# 3302   contemporary u.s. courts
# 3303   authority
# 3304   contemporary u.s. courts
# 3305   american federalism
# 3306   contract
# 3307   public laws
# 3308   reason
# 3309   only about 282,000
# 3310   contract
# 3311   all states
# 3312   constitution
# 3313   chevron deference
# 3314   all states
# 3315   constitution
# 3316   dual-sovereign system
# 3317   federal courts
# 3318   criminal law
# 3319   mccarran-ferguson act
# 3320   english
# 3321   20th-century american tort law
# 3322   reason
# 3323   constitution
# 3324   most u.s. law
# 3325   law
# 3326   traditional common law pleading
# 3327   american law institute
# 3328   principle
# 3329   eighteen
# 3330   english common law
# 3331   american civil procedure
# 3332   u.s.
# 3333   18th and 19th centuries
# 3334   united states
# 3335   only about 282,000
# 3336   law
# 3337   united states constitution
# 3338   federal courts
# 3339   many statutes
# 3340   most felony convictions
# 3341   eighteen
# 3342   eighteenth century
# 3343   constitution
# 3344   handful
# 3345   prosecution
# 3346   difficult question
# 3347   contemporary english cases
# 3348   writ
# 3349   constitution
# 3350   several legal scholars
# 3351   principle
# 3352   federal constitution
# 3353   all states
# 3354   transactions
# 3355   actual substance
# 3356   18th and 19th centuries
# 3357   law
# 3358   u.s.
# 3359   president
# 3360   1964
# 3361   some states
# 3362   public laws
# 3363   tort law
# 3364   constitution
# 3365   constitution
# 3366   united states
# 3367   turn
# 3368   subsequent statute
# 3369   1963
# 3370   eighteen
# 3371   indeed
# 3372   actual substance
# 3373   only about 282,000
# 3374   end
# 3375   traditional common law pleading
# 3376   turn
# 3377   congress
# 3378   some reception statutes
# 3379   federal criminal law
# 3380   scope
# 3381   roger j. traynor
# 3382   u.s.
# 3383   u.s.
# 3384   american civil procedure
# 3385   all states
# 3386   supreme court
# 3387   crimes
# 3388   19th century
# 3389   chevron
# 3390   eighteen
# 3391   nineteenth century
# 3392   congress
# 3393   federal agencies
# 3394   decades
# 3395   romanian
# 3396   ming dynasty
# 3397   latin
# 3398   , a more sociolinguistic notion
# 3399   multiple standard dialects
# 3400   latin
# 3401   latin
# 3402   italians
# 3403   swedish
# 3404   dialect
# 3405   serbia
# 3406   1996
# 3407   tok pisin
# 3408   public environment
# 3409   25.1, 1945
# 3410   low german varieties
# 3411   north african
# 3412   first
# 3413   spanish
# 3414   rest
# 3415   only 2.5%
# 3416   english
# 3417   tunisia
# 3418   ion bărbuţă
# 3419   risorgimento
# 3420   heinz kloss
# 3421   italian
# 3422   south
# 3423   world war i
# 3424   modern nationalism
# 3425   opposite example
# 3426   arabic
# 3427   arabic
# 3428   yiddish speaker
# 3429   northern germany
# 3430   terms `` language
# 3431   them
# 3432   example
# 3433   northern italy's
# 3434   hong kong
# 3435   standardized dialect
# 3436   various terms
# 3437   italy
# 3438   german empire
# 3439   german language
# 3440   that interpretation
# 3441   secondary sense
# 3442   dialect
# 3443   english
# 3444   dialect
# 3445   standard dialect
# 3446   german dialectology
# 3447   italian
# 3448   middle ages
# 3449   standard italian
# 3450   1860s
# 3451   sardinia
# 3452   19th century
# 3453   language—"everybody
# 3454   example
# 3455   english
# 3456   caribbean coast
# 3457   italy
# 3458   british and american english
# 3459   german
# 3460   northern germany
# 3461   varieties
# 3462   world war i
# 3463   standard dialect
# 3464   latin
# 3465   yiddish
# 3466   1967
# 3467   example
# 3468   cantonese
# 3469   italians
# 3470   ion bărbuţă
# 3471   english
# 3472   english
# 3473   german
# 3474   medieval painting red
# 3475   christian countries
# 3476   red
# 3477   1921
# 3478   seven
# 3479   karl marx
# 3480   red ochre
# 3481   british flag
# 3482   16th century
# 3483   one to two percent
# 3484   red flag
# 3485   danger
# 3486   red ochre
# 3487   most common colors
# 3488   cincinnati red stockings
# 3489   ancient rome
# 3490   roman general
# 3491   red
# 3492   1960
# 3493   ray
# 3494   harvard university
# 3495   communist party
# 3496   1950s and 1960s
# 3497   middle ages
# 3498   painters
# 3499   central and south america
# 3500   spirit
# 3501   1790
# 3502   increased performance
# 3503   1523
# 3504   gathered
# 3505   ancient rome
# 3506   demonstration
# 3507   color
# 3508   banner
# 3509   red hair
# 3510   harvard university
# 3511   your blood pressure
# 3512   jars
# 3513   scarlet academic gowns
# 3514   february 1848
# 3515   international football
# 3516   virgin mary
# 3517   fourth and fifth
# 3518   cincinnati red stockings
# 3519   ivory painter 's palette
# 3520   new red dyes
# 3521   1870 to 1918
# 3522   dye
# 3523   spanish conquistador
# 3524   16th century
# 3525   naphtol
# 3526   ancient rome
# 3527   1962
# 3528   mines
# 3529   four
# 3530   day
# 3531   path
# 3532   1870
# 3533   other teams
# 3534   daytime
# 3535   five years
# 3536   about 296 ad
# 3537   principle
# 3538   tae kwon
# 3539   central africa
# 3540   renaissance
# 3541   cincinnati red stockings
# 3542   seven
# 3543   1792
# 3544   spirit
# 3545   five
# 3546   nature
# 3547   red, green and blue light
# 3548   red flag
# 3549   country
# 3550   vermilion
# 3551   rubia plant
# 3552   red
# 3553   song dynasty
# 3554   association football
# 3555   romans
# 3556   colors
# 3557   1792
# 3558   french revolution
# 3559   1962
# 3560   255
# 3561   vladimir lenin
# 3562   1920s
# 3563   little red book
# 3564   first 20th-century artists
# 3565   renaissance
# 3566   nature
# 3567   2000
# 3568   christmas
# 3569   rubia plant
# 3570   communist party
# 3571   neolithic period
# 3572   example
# 3573   red
# 3574   romans
# 3575   even more money
# 3576   even more money
# 3577   red lac
# 3578   19th century
# 3579   red hair
# 3580   red stripes
# 3581   fall
# 3582   his famous hymn
# 3583   national symbols
# 3584   five years
# 3585   red coloration
# 3586   1966
# 3587   middle ages
# 3588   he
# 3589   abbe suger
# 3590   manchu rulers
# 3591   1888
# 3592   first 20th-century
# 3593   1920s
# 3594   red stripes
# 3595   1870
# 3596   face
# 3597   red color
# 3598   color
# 3599   murals
# 3600   red sky
# 3601   zhou
# 3602   red
# 3603   red
# 3604   october
# 3605   these studies
# 3606   one to two percent
# 3607   silver
# 3608   most famous works
# 3609   chinese cultural traditions
# 3610   egyptians
# 3611   coccus
# 3612   cincinnati red stockings
# 3613   fourth and fifth
# 3614   highways
# 3615   1920
# 3616   one popular color
# 3617   one popular color

# %% [markdown]
# #  准确率测试

# %%
with open('training.json') as json_data:
    train = json.load(json_data)
    
case_count = 0

for train_case in train:
    question = train_case['question']
    docid = train_case['docid']
    correct_answer = train_case['text']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)

    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question)
    results = query_vsm(terms, vsm_inverted_index)


    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:

        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'

        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        else:
            # what...do type question
            tokens.remove(next_token)
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the 20 sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC']:
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.5 + (scores[id] / max_score * 0.5)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get,default=0)
    sent = raw_docs[index]
    doc = nlp(sent)

    
    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = 0

            if score > max_score:
                max_score = score
                answer = np.text
                
    if answer != correct_answer:
        print(case_count)
        print('Question: ',question)
        print('Predicted: ',strip_punctuation(answer).strip().lower())
        print('Correct Answer: ',correct_answer)
#         print('Support sentence: ')
#         for id, _ in results:
#             sent = raw_docs[id]   
#             print(sent+'\n')
        print('\n')
    
    case_count += 1
# Out:
# 0
# Question:  A kilogram could be definined as having a Planck constant of what value?
# Predicted:  several tens
# Correct Answer:  6966662606895999999♠6.62606896×10−34 j⋅s
#
#
# 1
# Question:  What is the shape of the object that establishes the base unit of the kilogram?
# Predicted:  the planck constant
# Correct Answer:  cylinder
#
#
# 2
# Question:  What example is given as another paired relationship of uncertainly related to standard deviation?
# Predicted:  modern terms
# Correct Answer:  time vs. energy
#
#
# 3
# Question:  What does the Planck Constant refer to?
# Predicted:  r2
# Correct Answer:  quantum of action
#
#
# 5
# Question:  What scientist first studied black body radiation?
# Predicted:  max planck
# Correct Answer:  kirchhoff
#
#
# 6
# Question:  Who helped to give the correct quantization rules for electrons in 1926?
# Predicted:  the energy
# Correct Answer:  schrödinger
#
#
# 8
# Question:  What is required to exist in classical statistics mechanics?
# Predicted:  classical statistical mechanics
# Correct Answer:  h
#
#
# 9
# Question:  How much energy is contained in the light to which human eyes are most sensitive?
# Predicted:  555
# Correct Answer:  7005216000000000000♠216 kj/mol
#
#
# 10
# Question:  What is frequency also known as in science?
# Predicted:  the colour
# Correct Answer:  f
#
#
# 13
# Question:  Who published the first thorough investigation of the photoelectric effect?
# Predicted:  alexandre edmond becquerel
# Correct Answer:  heinrich hertz
#
#
# 14
# Question:  Who first observed the photoelectric effect?
# Predicted:  alexandre edmond becquerel
# Correct Answer:  alexandre edmond becquerel
#
#
# 15
# Question:  Who came up with the term, "ultraviolet catastrophe"?
# Predicted:  paul ehrenfest
# Correct Answer:  paul ehrenfest
#
#
# 16
# Question:  What is the term used when photoelectrons act virtually at the same time?
# Predicted:  this kinetic energy
# Correct Answer:  multiphoton effect
#
#
# 17
# Question:  What is the unit of magentic properties of atomic nuclei?
# Predicted:  the bohr magneton
# Correct Answer:  nuclear magneton
#
#
# 18
# Question:  Who discovered an association between the value E and quantum energy?
# Predicted:  bohr
# Correct Answer:  einstein
#
#
# 19
# Question:  At about what wavelength of light are human eyes most sensitive?
# Predicted:  example
# Correct Answer:  555 nanometres
#
#
# 20
# Question:  Who first observed the photoelectric effect?
# Predicted:  alexandre edmond becquerel
# Correct Answer:  alexandre edmond becquerel
#
#
# 22
# Question:  What is required for the electromagnetic field to come to thermal equilibrium?
# Predicted:  the electromagnetic field
# Correct Answer:  hot atoms
#
#
# 23
# Question:  Who received the Nobel Prize in 1921 for his work on the photoelectric effect?
# Predicted:  robert andrews millikan
# Correct Answer:  einstein
#
#
# 24
# Question:  What assumption that black-body radiation is what leads to an accurate prediction?
# Predicted:  the total amount
# Correct Answer:  thermal
#
#
# 25
# Question:  What term describes a small amount of element?
# Predicted:  a very small amount
# Correct Answer:  quantum
#
#
# 26
# Question:  Regarding atoms, what are values in between certain energy levels considered by the Planck constant?
# Predicted:  this quantum
# Correct Answer:  forbidden
#
#
# 27
# Question:  What are common things like furniture and stationary objects actually made of?
# Predicted:  the smallness
# Correct Answer:  particles
#
#
# 28
# Question:  Before Einstein, electromagnetic radiation was considered to behave as what?
# Predicted:  visible light
# Correct Answer:  a wave
#
#
# 29
# Question:  What color of light is the human eye most sensitive to?
# Predicted:  example
# Correct Answer:  green
#
#
# 30
# Question:  Einstein and what other two individuals revisited the black-body problem in 1905?
# Predicted:  jeans
# Correct Answer:  rayleigh and jeans
#
#
# 31
# Question:  Which scientist associated the Planck constant with a quantum five years after Planck's recognition?
# Predicted:  bohr
# Correct Answer:  einstein
#
#
# 32
# Question:  What type of changes in the light a hot object emits as the object's temperature changes?
# Predicted:  the colour
# Correct Answer:  colour
#
#
# 33
# Question:  What is the frequency of the light to which the human eye is most sensitive?
# Predicted:  example
# Correct Answer:  7014540000000000000♠540 thz
#
#
# 34
# Question:  What name did Paul Ehrenfest give to the proofs from Einstein and Rayleigh & Jeans?
# Predicted:  these proofs
# Correct Answer:  the `` ultraviolet catastrophe ''
#
#
# 35
# Question:  What measurement is deemed most important to redefine in terms of physical constants?
# Predicted:  the planck constant
# Correct Answer:  the kilogram
#
#
# 36
# Question:  What is the energy transferred by a wave in a given time called?
# Predicted:  the energy
# Correct Answer:  intensity
#
#
# 37
# Question:  What method was was used to obtain the measurement?
# Predicted:  addition
# Correct Answer:  watt-balance measurement
#
#
# 38
# Question:  Using Planck constant values from these effects would lead to what logical issue?
# Predicted:  the new definition
# Correct Answer:  a circular argument
#
#
# 39
# Question:  The mass of a resting body with what energy would be equal to a kilogram?
# Predicted:  a body
# Correct Answer:  7050135639273999999♠135639274×1042 hz
#
#
# 40
# Question:  What is considered the minimal energy increment of a hypothetical oscillator?
# Predicted:  the value e
# Correct Answer:  value e
#
#
# 41
# Question:  What does the kinetic energy of a photoelectron depend on?
# Predicted:  this kinetic energy
# Correct Answer:  the frequency
#
#
# 42
# Question:  What was later termed the photon?
# Predicted:  it
# Correct Answer:  the light quantum
#
#
# 43
# Question:  What element is used typically to establish Avogadro's constant?
# Predicted:  the xray crystal density method
# Correct Answer:  crystals of silicon
#
#
# 44
# Question:   What measurable value obeys a similar rule of angular momentum?
# Predicted:  a number
# Correct Answer:  time vs. energy
#
#
# 45
# Question:  What other types of wave besides light has its own intensity?
# Predicted:  other waves
# Correct Answer:  sound
#
#
# 46
# Question:  What do scientists assume black body radiation is?
# Predicted:  max planck
# Correct Answer:  thermal
#
#
# 47
# Question:  What frequency does green light with a wavelength of 555 nanmetres have?
# Predicted:  example
# Correct Answer:  7014540000000000000♠540 thz
#
#
# 48
# Question:  What type of analysis fits the either-or nature of the uncertainty?
# Predicted:  uncertainty forces measurement
# Correct Answer:  fourier analysis
#
#
# 49
# Question:  After Planck's findings, what was determined could not take on an arbitrary value?
# Predicted:  planck
# Correct Answer:  physical action
#
#
# 50
# Question:  Electromagnetic fields obey what laws?
# Predicted:  the electromagnetic field
# Correct Answer:  laws of motion
#
#
# 51
# Question:  Which light wavelength is the human eye most sensitive to?
# Predicted:  example
# Correct Answer:  555 nanometres
#
#
# 52
# Question:  Einstein's photoelectric effect work was rewards as opposed to his work on what other topic?
# Predicted:  the photoelectric effect
# Correct Answer:  relativity
#
#
# 53
# Question:  What is the reduced Planck constant also known as?
# Predicted:  bohr
# Correct Answer:  the quantity
#
#
# 55
# Question:  What type of radiation was Planck studying in the late 19th century?
# Predicted:  the last years of the nineteenth century
# Correct Answer:  black-body
#
#
# 56
# Question:  In making Planck's law, what was in both the numerator and denominator of the formula that was used?
# Predicted:  blackbody emissions
# Correct Answer:  h
#
#
# 57
# Question:  What is the Planck constant formerly known as?
# Predicted:  r2
# Correct Answer:  quantum of action
#
#
# 58
# Question:  How much energy does a green light of wavelength 555 nm contain?
# Predicted:  7005216000000000000
# Correct Answer:  7005216000000000000♠216 kj/mol
#
#
# 59
# Question:  Who discovered the mathematical relationship between peaks and curves of light at different temperatures?
# Predicted:  wilhelm wien
# Correct Answer:  wilhelm wien
#
#
# 60
# Question:  Who introduced the reduced Planck constant?
# Predicted:  h12
# Correct Answer:  bohr
#
#
# 61
# Question:  What scientist used matrix mechanics to bring electron behavior in line with the Bohr model?
# Predicted:  electrons
# Correct Answer:  heisenberg
#
#
# 62
# Question:  What rule predicted narrow range of energy values at lower temperatures?
# Predicted:  the rayleigh–jeans law
# Correct Answer:  the rayleigh–jeans
# 63
# Question:  What alloy is the base unit of the kilogram made from?
# Predicted:  the planck constant
# Correct Answer:  platinum–iridium
#
#
# 65
# Question:  Who modeled the atom in 1913, challenging Rutherford's model?
# Predicted:  niels bohr
# Correct Answer:  niels bohr
#
#
# 67
# Question:  What is maximized as a result of a black object absorbing all the light that hits it?
# Predicted:  the object
# Correct Answer:  thermal light emission
#
#
# 68
# Question:  What is the energy of a photon?
# Predicted:  possible new definitions
# Correct Answer:  6981358000000000000♠3.58×10−19 j
#
#
# 69
# Question:  What color is hotter than "red hot"?
# Predicted:  the colour
# Correct Answer:  white hot
#
#
# 70
# Question:  Planck studied what problem posed originally by Kirchhoff?
# Predicted:  the last years
# Correct Answer:  black-body radiation
#
#
# 71
# Question:  What is the name for the amount of energy transfered by a wave in a given time?
# Predicted:  the energy
# Correct Answer:  intensity
#
#
# 72
# Question:  Einstein's paper on the photoelectric effect earned him the Nobel Prize in what year?
# Predicted:  1905
# Correct Answer:  1921
#
#
# 73
# Question:  Who helped to give the correct quantization rules for electrons in 1925?
# Predicted:  the energy
# Correct Answer:  heisenberg
#
#
# 75
# Question:  What law describes the changes in light emitted by a hot object?
# Predicted:  the hot object
# Correct Answer:  stefan–boltzmann law
#
#
# 76
# Question:  Who introduced the first quantized model of the atom?
# Predicted:  niels bohr
# Correct Answer:  niels bohr
#
#
# 78
# Question:  Who received the Nobel Prize in Physics in 1918?
# Predicted:  max planck
# Correct Answer:  max planck
#
#
# 79
# Question:  Prior to Einstein's work, light behavior was modeled as what?
# Predicted:  visible light
# Correct Answer:  a wave
#
#
# 80
# Question:  How many years prior to Planck's study had the scientific community first discussed black body radiation?
# Predicted:  first
# Correct Answer:  forty
#
#
# 82
# Question:  What does a hot object in equilibrium absorb as much as it emits?
# Predicted:  the hot object
# Correct Answer:  light
#
#
# 83
# Question:  Cooler objects glow less than objects that are what?
# Predicted:  hot objects
# Correct Answer:  hotter
#
#
# 84
# Question:  What kind of prediction does the assumption that black body radiation is thermal lead to?
# Predicted:  the assumption
# Correct Answer:  accurate
#
#
# 85
# Question:  One other measure involved the molar volume of what element?
# Predicted:  three watt
# Correct Answer:  silicon
#
#
# 86
# Question:  What rule predicts that emitted energy increases with temperature?
# Predicted:  stefan
# Correct Answer:  the stefan–boltzmann law
#
#
# 87
# Question:  Global wind power installations increased by how much in 2010?
# Predicted:  35800
# Correct Answer:  35,800 mw
#
#
# 88
# Question:  Which group projected that solar plant may produce most of the world's electricity within 50 years?
# Predicted:  a 2011 projection
# Correct Answer:  international energy agency
#
#
# 89
# Question:  What made a strong economic case for investing in low carbon technologies?
# Predicted:  the stern review
# Correct Answer:  stern review
#
#
# 90
# Question:  What is getting cheaper as a result of technilogical change?
# Predicted:  renewable energy technologies
# Correct Answer:  renewable energy technologies
#
#
# 91
# Question:  What determines the extent to which renewable energy is to be incorporated into a country's generation mix?
# Predicted:  public policy
# Correct Answer:  public policy
#
#
# 92
# Question:  What is operational in the USA, Australia, Germany, France and The United Kingdom?
# Predicted:  demonstration egs projects
# Correct Answer:  demonstration egs projects
#
#
# 93
# Question:  Who has shown support for ambitious renewable energy goals?
# Predicted:  eu member countries
# Correct Answer:  eu member countries
#
#
# 95
# Question:  What company filed for Chapter 11 bankruptcy?
# Predicted:  early september 2011
# Correct Answer:  solyndra
#
#
# 96
# Question:  How much was the worldwide investment in solar power in 2012?
# Predicted:  1404 billion
# Correct Answer:  $ 140.4 billion
#
#
# 97
# Question:  What motivated the incentive to use 100 percent renewable energy?
# Predicted:  100
# Correct Answer:  global warming
#
#
# 98
# Question:  What country is reducing its coal subsidy?
# Predicted:  germany
# Correct Answer:  germany
#
#
# 99
# Question:  How many hydroelectricity plants are larger than 10 GW?
# Predicted:  41
# Correct Answer:  three
#
#
# 100
# Question:  Who stated that energy costs with a wind, solar, water system should be similar to today's energy costs?
# Predicted:  jacobson
# Correct Answer:  mark z. jacobson
#
#
# 101
# Question:  Photovoltaic and solar-thermal plants may meet how much of the world's energy needs by 2060?
# Predicted:  2060 – and half
# Correct Answer:  half
#
#
# 102
# Question:  Setting national renewable energy targets can be an important part of what?
# Predicted:  a renewable energy policy
# Correct Answer:  renewable energy policy
#
#
# 103
# Question:  Where is the PS20 solar power tower located?
# Predicted:  usa
# Correct Answer:  spain
#
#
# 106
# Question:  Renewables contributed what percentage to our electricity generation?
# Predicted:  19 percent
# Correct Answer:  22 percent
#
#
# 107
# Question:  Who was the UN under-secretary in 2011?
# Predicted:  kandeh yumkella
# Correct Answer:  achim steiner
#
#
# 108
# Question:  What can be economically competetive but may still require deployment support?
# Predicted:  firstgeneration biomass technologies
# Correct Answer:  first-generation biomass technologies
#
#
# 109
# Question:  What is becoming increasingly economic in both developing and devloped countries?
# Predicted:  renewables
# Correct Answer:  renewables
#
#
# 110
# Question:  Who is Achim Steiner?
# Predicted:  un undersecretary general achim steiner
# Correct Answer:  un under-secretary general
#
#
# 111
# Question:  What involves lowering income taxes while raising levies?
# Predicted:  environmentally destructive activities
# Correct Answer:  tax shifting
#
#
# 112
# Question:  In Denmark, wind power accounts for what percentage of electricity generated?
# Predicted:  approximately 19
# Correct Answer:  19 %
#
#
# 113
# Question:  Where have the majority of photovoltaic power stations been built?
# Predicted:  europe
# Correct Answer:  europe
#
#
# 114
# Question:  Name one outher country with defined national or regional target?
# Predicted:  other developed countries
# Correct Answer:  australia
#
#
# 115
# Question:  What is a barrier to implementing the renewable energy plan?
# Predicted:  barriers
# Correct Answer:  social and political
#
#
# 116
# Question:  Who is building The Califoria Valley Solar Ranch?
# Predicted:  the california valley solar ranch
# Correct Answer:  sunpower
#
#
# 117
# Question:  Who is chair of UN Energy?
# Predicted:  kandeh yumkella
# Correct Answer:  kandeh yumkella
#
#
# 118
# Question:  Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by what year?
# Predicted:  2060 – and half
# Correct Answer:  2060
#
#
# 120
# Question:  Hydroelectricity accounts for what percentage of global electricity generation?
# Predicted:  16 percent
# Correct Answer:  hydroelectricity
#
#
# 121
# Question:  Name one company that sells flexible-fuel cars?
# Predicted:  ford
# Correct Answer:  gm
#
#
# 122
# Question:  What was the geothermal capacity in 2008?
# Predicted:  geothermal power capacity
# Correct Answer:  10 gw
#
#
# 123
# Question:  What involves the deployment of three generations of renewable energy technologies dating back more than 100 years?
# Predicted:  renewable energy commercialization
# Correct Answer:  renewable energy commercialization
#
#
# 124
# Question:  Who believes that the market does not value nature's service adequately?
# Predicted:  lester brown
# Correct Answer:  lester brown
#
#
# 127
# Question:  What is a promising cellulose source that can be sustainably produced in many regions?
# Predicted:  dedicated energy crops
# Correct Answer:  dedicated energy crops
#
#
# 129
# Question:  What was the result of publicly funded links among computers in government labs and reserach institutes?
# Predicted:  terms
# Correct Answer:  the internet
#
#
# 130
# Question:  As of what year have there been substantial reductions in the cost of solar and wind technologies?
# Predicted:  solar and wind technologies
# Correct Answer:  2011
#
#
# 131
# Question:  Where is the Ivanpah Solar Power Facility located?
# Predicted:  california
# Correct Answer:  california 's mojave desert
# 132
# Question:  The PV industry has seen drops in module prices since what year?
# Predicted:  since 2008
# Correct Answer:  2008
#
#
# 133
# Question:  As of 2012, what accounts for about half of new nameplate electrical capacity?
# Predicted:  renewable energy accounts
# Correct Answer:  renewable energy
#
#
# 134
# Question:  What is the most widely used form of renewable energy?
# Predicted:  16 percent
# Correct Answer:  hydroelectricity
#
#
# 135
# Question:  In Spain, wind power accounts for what percentage of electricity generated?
# Predicted:  approximately 19
# Correct Answer:  9 %
#
#
# 136
# Question:  Ban Ki-moon states that renewable energy has the ability to lift the poorest nations to new levels of prosperity?
# Predicted:  united nations secretarygeneral ban kimoon
# Correct Answer:  renewable energy
#
#
# 138
# Question:  How much was the total investment in renewable energy in 2012?
# Predicted:  244 billion
# Correct Answer:  $ 244 billion
#
#
# 139
# Question:  What states that EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed?
# Predicted:  the directive
# Correct Answer:  res directive
#
#
# 140
# Question:  What is the main driver of reduced costs?
# Predicted:  innovation
# Correct Answer:  market expansion
#
#
# 142
# Question:  What was the geothermal capacity in 1975?
# Predicted:  geothermal power capacity
# Correct Answer:  1 gw
#
#
# 143
# Question:  What group stated that "cost reductions in critical technologies, such as wind and solar, are set to continue?"
# Predicted:  a 2011 iea report
# Correct Answer:  iea
#
#
# 145
# Question:  What are now often the most economic solution for new generating capacity?
# Predicted:  renewable technologies
# Correct Answer:  renewable technologies
#
#
# 146
# Question:  What are potential sources of cellulosic biomass?
# Predicted:  crop residues
# Correct Answer:  crop residues
#
#
# 147
# Question:  What cost is often regarded as marking the achievment of grid parity for PV?
# Predicted:  the 100w installed cost
# Correct Answer:  $ 1.00/w installed cost
#
#
# 149
# Question:  Who has the authority to carry out a number of functions that havae implications for the feasiblity of renewable energy projects?
# Predicted:  energy regulators
# Correct Answer:  energy regulators
#
#
# 150
# Question:  What is the most economic solution for new grid-connected capacity in areas with good resources?
# Predicted:  substantial reductions
# Correct Answer:  renewable energy
#
#
# 152
# Question:  Where is the Agua Caliente Solar Project located?
# Predicted:  india
# Correct Answer:  usa
#
#
# 153
# Question:  Who is chairman of Bank of America?
# Predicted:  kandeh yumkella
# Correct Answer:  charles holliday
#
#
# 154
# Question:  Who played Donovan in 'Bridge of Spies'?
# Predicted:  tom hanks
# Correct Answer:  tom hanks
#
#
# 155
# Question:  What show did Spielberg work with Rodat on?
# Predicted:  original footage
# Correct Answer:  falling skies
#
#
# 156
# Question:  When did Spielberg join the Boy Scouts?
# Predicted:  indiana jones
# Correct Answer:  1958
#
#
# 157
# Question:  Who was responsible for Star Wars?
# Predicted:  harrison ford
# Correct Answer:  george lucas
#
#
# 158
# Question:  When was 'Men In Black' released?
# Predicted:  early 2017
# Correct Answer:  1997
#
#
# 159
# Question:  When was 'The Dig' released?
# Predicted:  early 2017
# Correct Answer:  1995
#
#
# 160
# Question:  What short film did Spielberg make for theatrical release?
# Predicted:  the opportunity
# Correct Answer:  amblin
#
#
# 161
# Question:  What was Sidney Sheinberg's position with Universal?
# Predicted:  studio vice president sidney sheinberg
# Correct Answer:  vice president
#
#
# 162
# Question:  When was Adventures of Tintin released in the US?
# Predicted:  just four days
# Correct Answer:  december 21 , 2011
#
#
# 163
# Question:  When was 'Skullmonkeys' released?
# Predicted:  early 2017
# Correct Answer:  1997
#
#
# 164
# Question:  What film did Richard D. Zanuck and David Brown offer Steven Spielberg to direct?
# Predicted:  studio producers
# Correct Answer:  jaws
#
#
# 167
# Question:  How does Spielberg feel about cutscenes in games?
# Predicted:  three
# Correct Answer:  intrusive
#
#
# 168
# Question:  Which studios produced Spielberg's 'War of the Worlds'?
# Predicted:  a modern adaptation
# Correct Answer:  paramount and dreamworks
#
#
# 169
# Question:  When did Jurassic Park come out?
# Predicted:  1982
# Correct Answer:  1993
#
#
# 170
# Question:  When did 'Temple of Doom' debut?
# Predicted:  raiders
# Correct Answer:  1984
#
#
# 171
# Question:  What war was 'Saving Private Ryan' about?
# Predicted:  the world war ii
# Correct Answer:  world war ii
#
#
# 172
# Question:  What was the budget for 'Robopocalypse'?
# Predicted:  the films ultimate enormous success
# Correct Answer:  $ 200 million
#
#
# 173
# Question:  Where did the American Film Institute rank 'Schindler's List' in 1997?
# Predicted:  10
# Correct Answer:  # 9
#
#
# 174
# Question:  When was Spielberg's merit badge launched?
# Predicted:  my merit badge
# Correct Answer:  1989
#
#
# 176
# Question:  Until the 1980s, when had an American film last been shot in Shanghai?
# Predicted:  1987
# Correct Answer:  the 1930s
#
#
# 177
# Question:  Who wrote the music for 'Into the West'?
# Predicted:  et
# Correct Answer:  geoff zanelli
#
#
# 178
# Question:  Which British critic praised 'Duel'?
# Predicted:  special praise
# Correct Answer:  dilys powell
#
#
# 179
# Question:  What was Indy's rank in Boy Scouts when shown in a movie?
# Predicted:  spielberg
# Correct Answer:  life scout
#
#
# 180
# Question:  What kind of prejudice did Spielberg have to deal with in High school?
# Predicted:  acts
# Correct Answer:  anti-semitic
#
#
# 181
# Question:  Who did Spielberg get money from to film Close Encounters?
# Predicted:  spielberg
# Correct Answer:  his father
#
#
# 182
# Question:  What British critic helped boost Steven Spielberg's career?
# Predicted:  special praise
# Correct Answer:  dilys powell
#
#
# 183
# Question:  Which of Spielberg's parents liked sci-fi?
# Predicted:  this theme
# Correct Answer:  his father
#
#
# 184
# Question:  When did Spielberg and Irving get back together?
# Predicted:  2006
# Correct Answer:  1984
#
#
# 185
# Question:  How far in the future was 'Robopocalypse' set?
# Predicted:  april 25 2014
# Correct Answer:  15–20 years
#
#
# 187
# Question:  Where did Adventures of Tintin debut?
# Predicted:  just four days
# Correct Answer:  brussels , belgium
#
#
# 188
# Question:  What was Spielberg's role on 'Batteries Not Included'?
# Predicted:  a coproducer of the 1987 film
# Correct Answer:  co-producer
#
#
# 189
# Question:  How many Oscar nominations did 'Munich' get?
# Predicted:  one
# Correct Answer:  five
#
#
# 190
# Question:  How long was 'Amblin'?
# Predicted:  1982
# Correct Answer:  26-minute
#
#
# 191
# Question:  Which studio produced 'Super 8'?
# Predicted:  the j j abrams science fiction thriller film
# Correct Answer:  paramount pictures
#
#
# 192
# Question:  What was Spielberg's future wife's career?
# Predicted:  this project
# Correct Answer:  actress
#
#
# 194
# Question:  Which childhood friend worked on Spielberg's films?
# Predicted:  cinematography
# Correct Answer:  allen daviau
#
#
# 195
# Question:  Who introduced Irving to Spielberg?
# Predicted:  spielberg
# Correct Answer:  brian de palma
#
#
# 196
# Question:  Who played Indiana Jones's father?
# Predicted:  harrison ford
# Correct Answer:  sean connery
#
#
# 197
# Question:  How long of a contract did Sheinberg give Spielberg?
# Predicted:  1996
# Correct Answer:  seven-year
#
#
# 199
# Question:  What Boy Scout merit badge did Spielberg help develop?
# Predicted:  his own experiences
# Correct Answer:  cinematography
#
#
# 200
# Question:  Which film did Kathleen Kennedy first work with Spielberg on?
# Predicted:  an example
# Correct Answer:  e.t . the extra-terrestrial
#
#
# 201
# Question:  In what month is Cannes held?
# Predicted:  may 2016
# Correct Answer:  may
#
#
# 202
# Question:  What did Spielberg first win Best Director for?
# Predicted:  schindlers list
# Correct Answer:  schindler 's list
#
#
# 203
# Question:  When was 'Bridge of Spies' released?
# Predicted:  early 2017
# Correct Answer:  october 16 , 2015
#
#
# 204
# Question:  Who played Mary Todd Lincoln in 'Lincoln'?
# Predicted:  spielberg
# Correct Answer:  sally field
#
#
# 206
# Question:  How did Steven Spielberg's film "The Sugarland Express" do in the box office?
# Predicted:  debut
# Correct Answer:  poorly
#
#
# 207
# Question:  What film did Spielberg make to earn a merit badge?
# Predicted:  my merit badge
# Correct Answer:  the last gunfight
#
#
# 209
# Question:  What composer has Steven Spielberg been associated with since 1974?
# Predicted:  composer john williams
# Correct Answer:  john williams
# 210
# Question:  What rating did 'Temple of Doom' receive?
# Predicted:  spite
# Correct Answer:  pg
#
#
# 211
# Question:  When will 'The BFG' be in most theaters?
# Predicted:  may 2016
# Correct Answer:  july 1 , 2016
#
#
# 212
# Question:  Who made Spielberg a knight?
# Predicted:  spielberg
# Correct Answer:  jacques chirac
#
#
# 213
# Question:  Who is naive in 'Catch Me if You Can'?
# Predicted:  a career
# Correct Answer:  frank
#
#
# 214
# Question:  What was the first video game Spielberg played?
# Predicted:  lucasarts
# Correct Answer:  pong
#
#
# 216
# Question:  How many Oscar nominations did 'Bridge of Spies' get?
# Predicted:  one
# Correct Answer:  six
#
#
# 217
# Question:  Who wrote 'The BFG'?
# Predicted:  et
# Correct Answer:  roald dahl
#
#
# 218
# Question:  Which film did Kahn first work with Spielberg on?
# Predicted:  the first nonpixar film
# Correct Answer:  close encounters
#
#
# 219
# Question:  Where did Spielberg's paternal grandparents immigrate from?
# Predicted:  ukraine
# Correct Answer:  ukraine
#
#
# 220
# Question:  When did the 'War Horse' book come out?
# Predicted:  2005
# Correct Answer:  1982
#
#
# 221
# Question:  What was the relatioship between Joan Crawford and Steven Spielberg?
# Predicted:  eyes starred joan crawford
# Correct Answer:  reportedly close friends
#
#
# 222
# Question:  What issue did Spielberg address in his movie Munich?
# Predicted:  later years
# Correct Answer:  terrorism
#
#
# 223
# Question:  Where was Steven Spielberg born?
# Predicted:  cincinnati
# Correct Answer:  cincinnati , ohio
#
#
# 224
# Question:  Which channel aired 'Falling Skies'?
# Predicted:  spielberg
# Correct Answer:  tnt
#
#
# 225
# Question:  Who starred in the TV show "Savage"?
# Predicted:  martin landau
# Correct Answer:  martin landau
#
#
# 226
# Question:  When did Adventures of Tintin debut?
# Predicted:  just four days
# Correct Answer:  october 22 , 2011
#
#
# 227
# Question:  When did the first Indiana Jones movie come out?
# Predicted:  1989
# Correct Answer:  1981
#
#
# 228
# Question:  When did Spielberg and Irving marry?
# Predicted:  1984
# Correct Answer:  november 1985
#
#
# 229
# Question:  In what film did Spielberg address terrorism?
# Predicted:  two forays
# Correct Answer:  munich
#
#
# 230
# Question:  Whose parents divorced in 'Catch Me If You Can'?
# Predicted:  tim
# Correct Answer:  frank abagnale
#
#
# 231
# Question:  What kind of truck was 'Duel' about?
# Predicted:  his other films
# Correct Answer:  peterbilt 281 tanker
#
#
# 232
# Question:  Which film beat 'Saving Private Ryan' worldwide?
# Predicted:  spielberg
# Correct Answer:  armageddon
#
#
# 233
# Question:  What department did Spielberg have an unpaid internship with?
# Predicted:  a small unpaid intern job
# Correct Answer:  editing
#
#
# 234
# Question:  Which film did Daviau first work with Spielberg on?
# Predicted:  the first nonpixar film
# Correct Answer:  amblin
#
#
# 235
# Question:  Who played Indiana Jones?
# Predicted:  harrison ford
# Correct Answer:  harrison ford
#
#
# 236
# Question:  Who composes music for most of Spielberg's movies?
# Predicted:  composer john williams
# Correct Answer:  john williams
#
#
# 237
# Question:  In what film did Spielberg cover the slave trade?
# Predicted:  later years
# Correct Answer:  amistad
#
#
# 239
# Question:  Where does 'The Kidnapping of Edgardo Mortara' take place?
# Predicted:  brussels
# Correct Answer:  italy
#
#
# 240
# Question:  Who starred in 'Lincoln' as Abraham Lincoln?
# Predicted:  spielberg
# Correct Answer:  daniel day-lewis
#
#
# 242
# Question:  How much money has all of Steven Spielberg's movies grossed worldwide?
# Predicted:  591 million
# Correct Answer:  exceeds $ 9 billion
#
#
# 243
# Question:  What job was SPielberg offered when he was a student?
# Predicted:  a small unpaid intern job
# Correct Answer:  universal studios
#
#
# 244
# Question:  How many bloody noses did Spielberg get in High School?
# Predicted:  two
# Correct Answer:  two
#
#
# 245
# Question:  In what film did Spielberg address humanistic issues?
# Predicted:  later years
# Correct Answer:  schindler 's list
#
#
# 246
# Question:  What artifact did Indy's father focus on?
# Predicted:  lucas
# Correct Answer:  the holy grail
#
#
# 247
# Question:  Who starred in 'Savage'/
# Predicted:  tom hanks
# Correct Answer:  martin landau
#
#
# 248
# Question:  When did the Visual Effects Society give Spielberg a Lifetime Achievement Award?
# Predicted:  november 2007
# Correct Answer:  february 2009
#
#
# 249
# Question:  When did Spielberg and Irving divorce?
# Predicted:  three and a half years
# Correct Answer:  1989
#
#
# 250
# Question:  When did Spielberg first play a video game?
# Predicted:  1998
# Correct Answer:  1974
#
#
# 251
# Question:  Which channel aired 'Terra Nova'?
# Predicted:  spielberg
# Correct Answer:  fox
#
#
# 253
# Question:  How many Oscar nominations did 'The Color Purple' get?
# Predicted:  one
# Correct Answer:  eleven
#
#
# 254
# Question:  Where was 'War Horse' filmed?
# Predicted:  schindler
# Correct Answer:  england
#
#
# 255
# Question:  What genre was Steven Spielberg's episode of "The Name of the Game"?
# Predicted:  marcus welby
# Correct Answer:  science fiction
#
#
# 256
# Question:  Who narrated a short Spielberg bio at the Kennedy Center?
# Predicted:  spielberg
# Correct Answer:  tom hanks
#
#
# 257
# Question:  Who did Spielberg collaborate with in 2006?
# Predicted:  spielberg
# Correct Answer:  robert zemeckis
#
#
# 258
# Question:  What was Amy Irving's career?
# Predicted:  spielberg
# Correct Answer:  actress
#
#
# 259
# Question:  Who distributed 'War Horse'?
# Predicted:  spielberg
# Correct Answer:  disney
#
#
# 260
# Question:  Whose life was 'Schindler's List' based on?
# Predicted:  spielberg
# Correct Answer:  oskar schindler
#
#
# 261
# Question:  What movie was Spielberg working on when he first played Pong?
# Predicted:  jaws
# Correct Answer:  jaws
#
#
# 262
# Question:  How many Oscars did Close Encounters win?
# Predicted:  548
# Correct Answer:  two
#
#
# 263
# Question:  Where was 'Lincoln' filmed?
# Predicted:  empire
# Correct Answer:  richmond , virginia
#
#
# 264
# Question:  When was Jaws released?
# Predicted:  early 2017
# Correct Answer:  1975
#
#
# 265
# Question:  How did Irving describe Spielberg's house?
# Predicted:  young
# Correct Answer:  `` bachelor funky ''
#
#
# 266
# Question:  What film led to Close Encounters?
# Predicted:  his other films
# Correct Answer:  firelight
#
#
# 267
# Question:  Who did Tom Hanks play in 'Saving Private Ryan'?
# Predicted:  spielberg
# Correct Answer:  capt . miller
#
#
# 268
# Question:  What video game did Spielberg say in 2013 he's working on a TV show based on?
# Predicted:  343 industries
# Correct Answer:  halo
#
#
# 269
# Question:  Which studio funded Close Encounters?
# Predicted:  spielberg
# Correct Answer:  columbia pictures
#
#
# 270
# Question:  Where did Steven Spielberg's family move to in 1953?
# Predicted:  phoenix
# Correct Answer:  phoenix , arizona
#
#
# 271
# Question:  How many bloody noses did Spielberg get in high school?
# Predicted:  two
# Correct Answer:  two
#
#
# 272
# Question:  When did Spielberg buy Orson Welles' personal script copy from 'The War of the Worlds'?
# Predicted:  1938
# Correct Answer:  1994
#
#
# 273
# Question:  Who wrote the book 'Memoirs of a Geisha' is based on?
# Predicted:  spielberg
# Correct Answer:  arthur golden
#
#
# 274
# Question:  Who offered Spielberg a contract at Universal Studios?
# Predicted:  spielberg
# Correct Answer:  sidney sheinberg
#
#
# 276
# Question:  When was the first 'War of the Worlds' movie released?
# Predicted:  early 2017
# Correct Answer:  1953
#
#
# 277
# Question:  When is Minority Report set?
# Predicted:  april 25 2014
# Correct Answer:  2054
#
#
# 279
# Question:  How much did 'The Pacific' cost?
# Predicted:  250 million
# Correct Answer:  $ 250 million
#
#
# 280
# Question:  Who wrote the 'Jaws' book?
# Predicted:  spielberg
# Correct Answer:  peter benchley
#
#
# 282
# Question:  Who wrote 'Vengeance'?
# Predicted:  et
# Correct Answer:  george jonas
#
#
# 283
# Question:  Who wrote 'The Kidnapping of Edgardo Mortara'?
# Predicted:  ready player one
# Correct Answer:  david kertzer
#
#
# 284
# Question:  In what year does 'Terra Nova' begin?
# Predicted:  the year 2149
# Correct Answer:  2149
#
#
# 285
# Question:  How much money did Spielberg spend to film Close Encounters?
# Predicted:  indiana jones
# Correct Answer:  $ 500
#
#
# 286
# Question:  When in his life did Spielberg 'feel like an alien'?
# Predicted:  spielberg
# Correct Answer:  during childhood
#
#
# 287
# Question:  Who wrote the book 'Robopocalypse' is based on?
# Predicted:  spielberg
# Correct Answer:  daniel h. wilson
#
#
# 288
# Question:  What was Spielberg bullied because of?
# Predicted:  acts
# Correct Answer:  anti-semitic prejudice
# 289
# Question:  What book was 'Munich' based on?
# Predicted:  2005
# Correct Answer:  vengeance
#
#
# 290
# Question:  Who wrote the 'War of the Worlds' book?
# Predicted:  spielberg
# Correct Answer:  h. g. wells
#
#
# 291
# Question:  Who wrote the 'Interstellar' script?
# Predicted:  tom hanks
# Correct Answer:  jonathan nolan
#
#
# 292
# Question:  Whose son disappeared in 'Minority Report'?
# Predicted:  spielberg
# Correct Answer:  john anderton
#
#
# 293
# Question:  How many Oscars did Close Encounters get nominated for, besides Best Director?
# Predicted:  one
# Correct Answer:  six
#
#
# 294
# Question:  Who wrote 'The Color Purple'?
# Predicted:  spielberg
# Correct Answer:  alice walker
#
#
# 295
# Question:  When was Boombots released?
# Predicted:  1996
# Correct Answer:  1999
#
#
# 296
# Question:  What film festival will first air 'The BFG'?
# Predicted:  competition
# Correct Answer:  cannes film festival
#
#
# 297
# Question:  When is 'Ready Player One' planned to be released?
# Predicted:  early 2017
# Correct Answer:  2018
#
#
# 298
# Question:  What charity did Spielberg's 'Lego Moviemaker' kit fund?
# Predicted:  the spielberg name
# Correct Answer:  starbright foundation
#
#
# 299
# Question:  Where was Spielberg honored on Dec 3, 2006?
# Predicted:  empire
# Correct Answer:  kennedy center
#
#
# 300
# Question:  What movie did Spielberg collaborate with Cruise for?
# Predicted:  tom cruise
# Correct Answer:  minority report
#
#
# 302
# Question:  Who played Han Solo?
# Predicted:  harrison ford
# Correct Answer:  harrison ford
#
#
# 303
# Question:  Who wrote 'Empire of the Sun'?
# Predicted:  et
# Correct Answer:  j. g. ballard
#
#
# 304
# Question:  How much money did the film "Jaws" gross worldwide?
# Predicted:  591 million
# Correct Answer:  $ 470 million worldwide
#
#
# 305
# Question:  Who directed 'Armageddon'?
# Predicted:  michael bay
# Correct Answer:  michael bay
#
#
# 306
# Question:  Who directed 'Batman'?
# Predicted:  michael bay
# Correct Answer:  tim burton
#
#
# 307
# Question:  Who wrote E.T.'s script?
# Predicted:  tom hanks
# Correct Answer:  melissa mathison
#
#
# 308
# Question:  What was the Rotten Tomatoes rating for Minority Report?
# Predicted:  the film
# Correct Answer:  92 %
#
#
# 309
# Question:  Who plays Pope Pius IX in 'The Kidnapping of Edgardo Mortara'?
# Predicted:  tony kushner
# Correct Answer:  mark rylance
#
#
# 310
# Question:  How far back in time do people in 'Terra Nova' travel?
# Predicted:  the year 2149
# Correct Answer:  85 million years
#
#
# 311
# Question:  What genre was Spielberg's first film "The Last Gunfight"
# Predicted:  a boy scout
# Correct Answer:  western
#
#
# 312
# Question:  How did Steven Spielberg feel about being an Orhtodox Jew?
# Predicted:  worked
# Correct Answer:  embarrassed
#
#
# 313
# Question:  Which major Spielberg movie character was a Boy Scout?
# Predicted:  indiana jones
# Correct Answer:  indiana jones
#
#
# 314
# Question:  When was 'The Pacific' released?
# Predicted:  early 2017
# Correct Answer:  2010
#
#
# 315
# Question:  When did Spielberg give an interview saying he had 'felt like an alien'?
# Predicted:  spielberg
# Correct Answer:  august 2000
#
#
# 316
# Question:  When was 'Robopocalypse' scheduled for release?
# Predicted:  early 2017
# Correct Answer:  april 25 , 2014
#
#
# 317
# Question:  Who wrote the script for 'Someone's in the Kitchen'?
# Predicted:  boombots
# Correct Answer:  paul rugg
#
#
# 318
# Question:  What movie caused 'PG-13' to be created?
# Predicted:  the scenario
# Correct Answer:  gremlins
#
#
# 319
# Question:  Who thought 'Empire of the Sun' was the best film of the year?
# Predicted:  spielberg
# Correct Answer:  andrew sarris
#
#
# 320
# Question:  When did Spielberg win the Cecil B. DeMille Award?
# Predicted:  january 2008
# Correct Answer:  2009
#
#
# 321
# Question:  How many times did Spielberg work with Richard Dreyfus?
# Predicted:  250
# Correct Answer:  three
#
#
# 322
# Question:  At what age did Spielberg make 'Escape to Nowhere'?
# Predicted:  1963
# Correct Answer:  thirteen
#
#
# 323
# Question:  What religion was Spielberg's family?
# Predicted:  cincinnati
# Correct Answer:  orthodox jewish
#
#
# 324
# Question:  How long was Spielberg's film "Escape to Nowhere"?
# Predicted:  1996
# Correct Answer:  40-minute
#
#
# 325
# Question:  Where were Steven Spielberg's granparents from?
# Predicted:  1996
# Correct Answer:  ukraine
#
#
# 326
# Question:  When does 'The Kidnapping of Edgardo Mortara' take place?
# Predicted:  ready player one
# Correct Answer:  1858
#
#
# 327
# Question:  When did a Close Encounters DVD come out?
# Predicted:  1980
# Correct Answer:  2001
#
#
# 328
# Question:  When was Minority Report released?
# Predicted:  early 2017
# Correct Answer:  2002
#
#
# 329
# Question:  What religion was Steven Spielberg's family?
# Predicted:  original footage
# Correct Answer:  orthodox jewish
#
#
# 330
# Question:  What was Spielberg's first indepenent film?
# Predicted:  the film
# Correct Answer:  firelight
#
#
# 331
# Question:  When did Spielberg announce what would become 'Interstellar'?
# Predicted:  june 2006
# Correct Answer:  june 2006
#
#
# 332
# Question:  How much of the US believes Spielberg is influential?
# Predicted:  47
# Correct Answer:  47 %
#
#
# 333
# Question:  Where was Spielberg born?
# Predicted:  cincinnati
# Correct Answer:  cincinnati , ohio
#
#
# 334
# Question:  What was the film "Jaws" nominated for?
# Predicted:  pong
# Correct Answer:  best picture
#
#
# 335
# Question:  Who composed music for 'Munich'?
# Predicted:  composer john williams
# Correct Answer:  john williams
#
#
# 336
# Question:  Where was Spielberg an Olympic flagbearer?
# Predicted:  salt lake city
# Correct Answer:  salt lake city
#
#
# 337
# Question:  What job did Steven Spielberg's father have?
# Predicted:  original footage
# Correct Answer:  electrical engineer
#
#
# 338
# Question:  Who starred in the TV show segment "Eyes"
# Predicted:  spielberg
# Correct Answer:  joan crawford
#
#
# 339
# Question:  Who has composed most of Steven Spielberg's movies?
# Predicted:  francis ford coppola
# Correct Answer:  john williams
#
#
# 340
# Question:  What issue did Spielberg address in his movie Schindler's List?
# Predicted:  even oskar schindler
# Correct Answer:  the holocaust
#
#
# 341
# Question:  Which film did Kaminski first work with Spielberg on?
# Predicted:  the first nonpixar film
# Correct Answer:  schindler 's list
#
#
# 342
# Question:  Who was Ford going to play in E.T., until the scene was removed?
# Predicted:  spielberg
# Correct Answer:  a headteacher
#
#
# 343
# Question:  Who took over directing 'Interstellar'?
# Predicted:  spielberg
# Correct Answer:  christopher nolan
#
#
# 344
# Question:  When did Steven Spielberg have trouble dealing with being an Orthodox Jew?
# Predicted:  seven eight nine years old
# Correct Answer:  as a child
#
#
# 345
# Question:  What video game did Spielberg come up with the concept for?
# Predicted:  the special thanks section
# Correct Answer:  the dig
#
#
# 346
# Question:  When did 'War Horse' come out?
# Predicted:  the summer of 2010
# Correct Answer:  december 25 , 2011
#
#
# 348
# Question:  Who wrote the 'War Horse' book?
# Predicted:  spielberg
# Correct Answer:  michael morpurgo
#
#
# 349
# Question:  What university provided scientific consultation for 'Interstellar'?
# Predicted:  dakota fanning
# Correct Answer:  caltech
#
#
# 350
# Question:  What is being lead to specialty roles?
# Predicted:  the 1920s
# Correct Answer:  guns
#
#
# 351
# Question:  When were the surface-to-air missile systems introduced?
# Predicted:  the 1950s
# Correct Answer:  1950s
#
#
# 352
# Question:  What was placed on the blockhouses by the Germans?
# Predicted:  the germans
# Correct Answer:  anti-aircraft artillery
#
#
# 353
# Question:  What type of weapon can be used against hovering helicopters?
# Predicted:  rocketpropelled grenades
# Correct Answer:  rocket-propelled grenades
#
#
# 354
# Question:  Where can the future of projectile based weapons possibly be found?
# Predicted:  the future
# Correct Answer:  the railgun
#
#
# 355
# Question:  What was used in AA mountings on both land and water?
# Predicted:  machine guns
# Correct Answer:  machine guns
#
#
# 357
# Question:  What kind of fuses were needed?
# Predicted:  verification
# Correct Answer:  mechanical
#
#
# 358
# Question:  What does SPAAG stand for?
# Predicted:  at least supplanting
# Correct Answer:  self-propelled anti-aircraft guns
#
#
# 360
# Question:  How far away can the S-400 detect a target?
# Predicted:  005 meter
# Correct Answer:  90 km away
#
#
# 361
# Question:  In addition to Zeppelins, what attacked London for four years with air attacks?
# Predicted:  the experience
# Correct Answer:  gotha g.v bombers
#
#
# 362
# Question:  Who designed the 40 mm autocannon?
# Predicted:  krupps designs
# Correct Answer:  bofors of sweden
# 363
# Question:  What do armies tend to have in depth?
# Predicted:  most countries
# Correct Answer:  air defence
#
#
# 364
# Question:  What was one of the quickest areas to evolve in military technology in the 20th century?
# Predicted:  the 1930s
# Correct Answer:  air defence
#
#
# 365
# Question:  Deflection settings were also called what?
# Predicted:  the problem
# Correct Answer:  aim-off
#
#
# 367
# Question:  Why was Britain mainly interested in solid fuel rockets?
# Predicted:  development
# Correct Answer:  for anti-aircraft fire
#
#
# 368
# Question:  What size rocket was being developed at the end of the war?
# Predicted:  world war i
# Correct Answer:  3-inch
#
#
# 369
# Question:  What was the primary method for HAA fire?
# Predicted:  two assumptions
# Correct Answer:  aimed fire
#
#
# 370
# Question:  What agency stated that the arrangements were an air defence ground environment?
# Predicted:  nato
# Correct Answer:  nato
#
#
# 371
# Question:  What were hydrogen filled balloons called?
# Predicted:  zeppelins
# Correct Answer:  zeppelins
#
#
# 372
# Question:  Which company redesigned the rapid fire 2 cm FlaK 30?
# Predicted:  oerlikon
# Correct Answer:  mauser-werke
#
#
# 376
# Question:  Who started making an unlicensed version of the 40mm at the beginning of the war?
# Predicted:  john m browning
# Correct Answer:  americans
#
#
# 377
# Question:  What were the large blockhouses called that the Germans developed?
# Predicted:  the germans
# Correct Answer:  hochbunker `` high bunkers ''
#
#
# 378
# Question:  The goal of what is to suppress opposing air defence systems?
# Predicted:  most modern air defence systems
# Correct Answer:  dedicated weapons
#
#
# 380
# Question:  What was under development in both the Soviet Union and Britain in the 1930s?
# Predicted:  the 1930s
# Correct Answer:  solid fuel rockets
#
#
# 381
# Question:  What is the primary effort been for most countries when it comes to anti-aircraft warfare?
# Predicted:  nato
# Correct Answer:  homeland defence
#
#
# 382
# Question:  Where was the first place the FlaK 36 was used?
# Predicted:  germany
# Correct Answer:  spain
#
#
# 383
# Question:  Which country probably coined the term air defence?
# Predicted:  britain
# Correct Answer:  britain
#
#
# 384
# Question:  Targets could be how many feet for the HAA to engage them?
# Predicted:  up to 24000 feet
# Correct Answer:  24,000 feet
#
#
# 386
# Question:  Which country's research was ahead of all other countries for missiles?
# Predicted:  britain
# Correct Answer:  germans missile research
#
#
# 387
# Question:  What replaced the Browning 37nn because of jamming issues?
# Predicted:  the browning 37mm
# Correct Answer:  bofors 40 mm
#
#
# 388
# Question:  After guns firing ballistic munitions lost their appeal, what weapon took their place?
# Predicted:  aa
# Correct Answer:  guided missiles
#
#
# 389
# Question:  How many rounds did this cannon fire per second?
# Predicted:  2
# Correct Answer:  125
#
#
# 390
# Question:  What structure did the British build in the North Sea?
# Predicted:  the north sea
# Correct Answer:  maunsell forts
#
#
# 391
# Question:  Damaged aircraft can be out of action for days or what?
# Predicted:  targets
# Correct Answer:  permanently
#
#
# 392
# Question:  The evolution of air defence was in answer to the evolution of what?
# Predicted:  some armies
# Correct Answer:  aircraft
#
#
# 393
# Question:  What was also utilized to control ground targets?
# Predicted:  aaa battalions
# Correct Answer:  aaa battalions
#
#
# 394
# Question:  In the 1920s, which company developed the automatic 20 mm?
# Predicted:  oerlikon
# Correct Answer:  rheinmetall
#
#
# 395
# Question:  What war was the FlaK first used in?
# Predicted:  the spanish civil war
# Correct Answer:  spanish civil war
#
#
# 396
# Question:  What was the name of the mechanical computer that used automation?
# Predicted:  the solution
# Correct Answer:  the kerrison predictor
#
#
# 398
# Question:  What particular aircraft did the interceptor target most?
# Predicted:  the interceptor aircraft
# Correct Answer:  bombers
#
#
# 399
# Question:  How many guns or missile launchers are typically in a battery?
# Predicted:  2
# Correct Answer:  2 to 12
#
#
# 400
# Question:  What was the HRF used with to set fuses?
# Predicted:  a machine fuse setter
# Correct Answer:  height/fuse indicator ( hfi )
#
#
# 401
# Question:  What are man-portable missiles better known as?
# Predicted:  manportable missiles
# Correct Answer:  manpads
#
#
# 402
# Question:  The HRF measured target distance and what else?
# Predicted:  no means
# Correct Answer:  elevation angle
#
#
# 404
# Question:  What was the arm that was the Air Defence of the Ground Forces?
# Predicted:  two arms
# Correct Answer:  pvo sv
#
#
# 405
# Question:  What can detect stealth aircraft?
# Predicted:  multiple transmitter
# Correct Answer:  multiple transmitter radars
#
#
# 406
# Question:  Along with speed of the modern jet, what else limits target opportunities?
# Predicted:  speed
# Correct Answer:  altitude
#
#
# 407
# Question:  What year did the PVO Strany become independent?
# Predicted:  1941
# Correct Answer:  1954
#
#
# 408
# Question:  What are the SAMs called that are launched by individuals in the US?
# Predicted:  the sams
# Correct Answer:  manpads
#
#
# 409
# Question:  What term is used to describe the altitude for a gun to shoot shells against a target that is moving?
# Predicted:  the british
# Correct Answer:  `` effective ceiling ''
#
#
# 410
# Question:  When did the British see the need to add anti-aircraft capability?
# Predicted:  a few weeks
# Correct Answer:  8 july 1914
#
#
# 411
# Question:  Along with predicting the gun data from tracking the target, what else needed to be known about the target to enable the aimed fire?
# Predicted:  two assumptions
# Correct Answer:  its height
#
#
# 412
# Question:  Which company wanted to introduce missile systems during the second World War but was not successful?
# Predicted:  nato
# Correct Answer:  germany
#
#
# 413
# Question:  The use of lasers in anti-aircraft warfare is currently considered what?
# Predicted:  another potential weapon system
# Correct Answer:  experimental usefulness
#
#
# 414
# Question:  What type of ships are particularly well defended?
# Predicted:  carrier battle groups
# Correct Answer:  carrier battle groups
#
#
# 415
# Question:  Who had a separate military force for controlling nuclear ICBMs?
# Predicted:  the ussr
# Correct Answer:  ussr
#
#
# 416
# Question:  What gun size was relined to take 13-pounder shells?
# Predicted:  60000 ft
# Correct Answer:  18-pdr guns
#
#
# 417
# Question:  Where were most of the nations who had the strongest military after World War I?
# Predicted:  world war ii
# Correct Answer:  europe
#
#
# 418
# Question:  How are batteries typically grouped?
# Predicted:  batteries
# Correct Answer:  into battalions
#
#
# 419
# Question:  What does SHORAD stand for?
# Predicted:  the field army
# Correct Answer:  short range ad
#
#
# 420
# ...
#
#
# 3051
# Question:  What percent of Oklahomans have graduated high school?
# Predicted:  31 to 25 percent
# Correct Answer:  85.2 percent
#
#
# 3052
# Question:  When was the exact hundredth anniversary of Oklahoma's statehood?
# Predicted:  2007
# Correct Answer:  november 16 , 2007
#
#
# 3053
# Question:  Where is the Storm Prediction Center located?
# Predicted:  norman
# Correct Answer:  norman
#
#
# 3054
# Question:  What Arkansas city's metro area extends into Oklahoma?
# Predicted:  oklahoma city
# Correct Answer:  fort smith
#
#
# 3055
# Question:  What is the average annual temperature in southeast Oklahoma?
# Predicted:  over 40 inches
# Correct Answer:  62 °f
#
#
# 3056
# Question:  How many different airlines operate in Oklahoma?
# Predicted:  two
# Correct Answer:  six
#
#
# 3057
# Question:  How much of Oklahoma is covered in forests?
# Predicted:  midsummer july and august
# Correct Answer:  24 percent
#
#
# 3060
# Question:  When was Oklahoma's border determined?
# Predicted:  2008
# Correct Answer:  1890s
#
#
# 3061
# Question:  What is the largest company in Oklahoma?
# Predicted:  forbes
# Correct Answer:  oneok
#
#
# 3062
# Question:  What is Oklahoma's western climate type?
# Predicted:  a transition zone
# Correct Answer:  semi-arid
#
#
# 3063
# Question:  Where does Oklahoma rank by land area?
# Predicted:  kansas
# Correct Answer:  20th
#
#
# 3064
# Question:  What was Oklahoma's high school dropout rate in 2008?
# Predicted:  high school dropout rate
# Correct Answer:  2.5 percent
#
#
# 3065
# Question:  What is the second-oldest university west of the MS River?
# Predicted:  the university of tulsa
# Correct Answer:  northeastern state university
#
#
# 3066
# Question:  What is the oldest resident professional theater company in Oklahoma?
# Predicted:  american theatre company
# Correct Answer:  american theatre company
#
#
# 3067
# Question:  What is the average snowfall in Oklahoma near the Colorado border?
# Predicted:  snowfall
# Correct Answer:  over 20 inches
#
#
# 3068
# Question:  What is the conservative Evangelical Christian region called?
# Predicted:  oklahoma
# Correct Answer:  the `` bible belt ''
#
#
# 3069
# Question:  What kind of museum is the Philbrook?
# Predicted:  the philbrook museum
# Correct Answer:  fine art
#
#
# 3070
# Question:  What percent of Cherokee people are desired to be fluent in Cherokee?
# Predicted:  80
# Correct Answer:  80 % or more
#
#
# 3071
# Question:  What is the world's tallest hill?
# Predicted:  a portion
# Correct Answer:  cavanal hill
#
#
# 3072
# Question:  How much did Oklahoma's population decline from 1930 to 1950?
# Predicted:  midsummer july and august
# Correct Answer:  6.9 percent
#
#
# 3073
# Question:  When did the University of Oklahoma's dance program begin?
# Predicted:  city ballet
# Correct Answer:  1962
#
#
# 3074
# Question:  How many people died in the Oklahoma City Bombing?
# Predicted:  579999
# Correct Answer:  168
#
#
# 3075
# Question:  Where is Heller Theatre?
# Predicted:  oklahoma
# Correct Answer:  tulsa
#
#
# 3076
# Question:  How many tons of cargo does the Tulsa Port of Catoosa ship annually?
# Predicted:  two million tons
# Correct Answer:  over two million
#
#
# 3077
# Question:  What part of Oklahoma is Cross Timbers in?
# Predicted:  the cross timbers
# Correct Answer:  central
#
#
# 3079
# Question:  When is the second-driest season in Oklahoma?
# Predicted:  september
# Correct Answer:  mid-summer
#
#
# 3080
# Question:  What part of Oklahoma is the Antelope Hills in?
# Predicted:  partial plains
# Correct Answer:  southwestern
#
#
# 3081
# Question:  How many Fortune 500 companies are based in Oklahoma?
# Predicted:  four
# Correct Answer:  four
#
#
# 3082
# Question:  What is the largest metro area in Oklahoma as of 2010?
# Predicted:  ten
# Correct Answer:  oklahoma city
#
#
# 3083
# Question:  What part of Oklahoma does the American alligator live in?
# Predicted:  southeastern oklahoma
# Correct Answer:  southeastern
#
#
# 3084
# Question:  How many of Oklahoma's 2007 grad students completed their degree?
# Predicted:  181973
# Correct Answer:  5,386
#
#
# 3085
# Question:  What state House bill would change Oklahoma's motto to 'Oklahoma - In God We Trust'?
# Predicted:  hcr
# Correct Answer:  hcr 1024
#
#
# 3086
# Question:  Where do Oklahoma's winds bring moisture from?
# Predicted:  the gulf of mexico
# Correct Answer:  gulf of mexico
#
#
# 3087
# Question:  How many public schools does Oklahoma have?
# Predicted:  638817
# Correct Answer:  1,845
#
#
# 3088
# Question:  Which Native American group is involved in a language preservation project?
# Predicted:  english
# Correct Answer:  cherokee nation
#
#
# 3089
# Question:  What is Oklahoma's fifth most popular language?
# Predicted:  arabic
# Correct Answer:  vietnamese
#
#
# 3090
# Question:  Where is the State Fair of Oklahoma?
# Predicted:  oklahoma city
# Correct Answer:  oklahoma city
#
#
# 3091
# Question:  Who was the last Democratic presidential candidate to win any counties in Oklahoma?
# Predicted:  al gore
# Correct Answer:  al gore
#
#
# 3092
# Question:  Where does Oklahoma rank by population?
# Predicted:  oklahoma city
# Correct Answer:  28th
#
#
# 3093
# Question:  How many museums are in Oklahoma?
# Predicted:  one
# Correct Answer:  more than 300
#
#
# 3094
# Question:  How many of the 50 largest US cities are in Oklahoma?
# Predicted:  579999
# Correct Answer:  oklahoma
#
#
# 3095
# Question:  What is Oklahoma's record high temperature for Nov 11?
# Predicted:  66 degrees
# Correct Answer:  83 °f
#
#
# 3096
# Question:  What watershed is Oklahoma in?
# Predicted:  the great plains
# Correct Answer:  gulf of mexico
#
#
# 3097
# Question:  What was Oklahoma's high school dropout rate in 2007?
# Predicted:  high school dropout rate
# Correct Answer:  3.1
#
#
# 3099
# Question:  What league is the Thunder in?
# Predicted:  the oklahoma city thunder
# Correct Answer:  national basketball association
#
#
# 3101
# Question:  When was the Oklahoma City Bombing?
# Predicted:  2010
# Correct Answer:  april 19 , 1995
#
#
# 3102
# Question:  What is Oklahoma's rank among states by active drilling rigs?
# Predicted:  the nations thirdlargest producer
# Correct Answer:  second
# 3103
# Question:  Who commands the Oklahoma National Guard?
# Predicted:  the principal head
# Correct Answer:  the governor
#
#
# 3104
# Question:  What was Spiro, Oklahoma named for?
# Predicted:  the westernmost center
# Correct Answer:  spiro mounds
#
#
# 3105
# Question:  What percent of Oklahomans speak only English at home, as of 2000?
# Predicted:  english
# Correct Answer:  92.6 %
#
#
# 3106
# Question:  How many square miles is Oklahoma?
# Predicted:  181035
# Correct Answer:  69,898
#
#
# 3107
# Question:  How many ports does Oklahoma have?
# Predicted:  two
# Correct Answer:  two
#
#
# 3108
# Question:  Where is 'Discoveryland!'?
# Predicted:  oklahoma
# Correct Answer:  sand springs
#
#
# 3109
# Question:  What parts of Oklahoma rarely see below-zero temperatures?
# Predicted:  the state
# Correct Answer:  south-central and southeastern
#
#
# 3110
# Question:  How many tornadoes hit Oklahoma each year?
# Predicted:  about one
# Correct Answer:  average 62
#
#
# 3112
# Question:  What does Oklahoma spend per student in public schools as of 2008?
# Predicted:  an educational system
# Correct Answer:  $ 7,755
#
#
# 3113
# Question:  How many school districts are in Oklahoma?
# Predicted:  638817
# Correct Answer:  533
#
#
# 3115
# Question:  Who is responsible for submitting a state budget in Oklahoma?
# Predicted:  the responsibilities
# Correct Answer:  the executive branch
#
#
# 3116
# Question:  How many PGA championships has Southern Hills held?
# Predicted:  one
# Correct Answer:  four
#
#
# 3117
# Question:  When does Oklahoma get the most rain?
# Predicted:  2008
# Correct Answer:  may
#
#
# 3118
# Question:  What mistake led to the Dust Bowl?
# Predicted:  a twentyyear period
# Correct Answer:  poor farming practices
#
#
# 3119
# Question:  What is Oklahoma's main climate region?
# Predicted:  the gulf of mexico
# Correct Answer:  humid subtropical
#
#
# 3120
# Question:  What part of Oklahoma has low rainfall?
# Predicted:  a geographical region
# Correct Answer:  western
#
#
# 3121
# Question:  Within what university is Oklahoma's only optometry college?
# Predicted:  northeastern state university
# Correct Answer:  northeastern state university
#
#
# 3122
# Question:  How many Native American languages are used in Oklahoma?
# Predicted:  8258
# Correct Answer:  more than 25
#
#
# 3123
# Question:  How much did Oklahoma City's population grow from 2000 to 2010?
# Predicted:  579999
# Correct Answer:  14.6 %
#
#
# 3124
# Question:  Where is ONEOK based?
# Predicted:  amarillo
# Correct Answer:  tulsa
#
#
# 3125
# Question:  What is the one election since 1952 where a Republican presidential candidate didn't win in Oklahoma?
# Predicted:  registered republicans
# Correct Answer:  1964
#
#
# 3126
# Question:  What is the 2nd-largest company in Oklahoma?
# Predicted:  forbes
# Correct Answer:  williams companies
#
#
# 3127
# Question:  What part of Oklahoma is the Tallgrass Prairie Preserve in?
# Predicted:  39000 acres
# Correct Answer:  north-central
#
#
# 3129
# Question:  How many US House reps did Oklahoma have before the 2000 census?
# Predicted:  six to five
# Correct Answer:  six
#
#
# 3130
# Question:  Oklahoma has the longest drivable stretch of what famous highway?
# Predicted:  more than 12000 miles
# Correct Answer:  route 66
#
#
# 3132
# Question:  Ancestors of which tribes lived in Oklahoma?
# Predicted:  the wichita
# Correct Answer:  wichita and caddo
#
#
# 3133
# Question:  When did France sell Oklahoma's land to the US?
# Predicted:  2008
# Correct Answer:  1803
#
#
# 3134
# Question:  What was the Thunder's previous name?
# Predicted:  the name
# Correct Answer:  seattle supersonics
#
#
# 3135
# Question:  In which direction do the Ozark mountains get higher?
# Predicted:  oklahoma
# Correct Answer:  eastward
#
#
# 3136
# Question:  What does Oklahoma mean?
# Predicted:  the state
# Correct Answer:  red people
#
#
# 3137
# Question:  Who starred in the Broadway production of 'Oklahoma!'?
# Predicted:  ridge bond
# Correct Answer:  ridge bond
#
#
# 3138
# Question:  When did the Dust Bowl begin?
# Predicted:  twentyyear
# Correct Answer:  1930s
#
#
# 3139
# Question:  How much of Oklahoma's electricity comes from non-renewable sources?
# Predicted:  eighth
# Correct Answer:  94 percent
#
#
# 3140
# Question:  How many district courts does Oklahoma have?
# Predicted:  one
# Correct Answer:  77
#
#
# 3141
# Question:  How many feet above sea level is Oklahoma's lowest point?
# Predicted:  the little river
# Correct Answer:  289
#
#
# 3142
# Question:  Which season is the most dry in Oklahoma?
# Predicted:  midsummer july
# Correct Answer:  winter
#
#
# 3143
# Question:  When was the name Oklahoma suggested?
# Predicted:  1890
# Correct Answer:  1866
#
#
# 3144
# Question:  The Tallgrass Prairie Preserve is the largest protected tallgrass prairie in what area?
# Predicted:  39000 acres
# Correct Answer:  the world
#
#
# 3146
# Question:  What type of investments were important in early Oklahoma?
# Predicted:  tulsa
# Correct Answer:  oil
#
#
# 3147
# Question:  What is the only major league sports team in Oklahoma?
# Predicted:  the oklahoma city thunder
# Correct Answer:  oklahoma city thunder
#
#
# 3148
# Question:  How many US House reps did Oklahoma have after the 2000 census?
# Predicted:  six to five
# Correct Answer:  five
#
#
# 3149
# Question:  Where is the American Theatre Company based?
# Predicted:  tulsa
# Correct Answer:  tulsa
#
#
# 3151
# Question:  What kind of tournaments does Cedar Ridge Country Club host?
# Predicted:  tulsa
# Correct Answer:  lpga
#
#
# 3152
# Question:  How many public universities does Oklahoma have?
# Predicted:  638817
# Correct Answer:  eleven
#
#
# 3153
# Question:  Where was Oklahoma's first medieval fair?
# Predicted:  oklahoma
# Correct Answer:  norman
#
#
# 3154
# Question:  What language does the name Oklahoma come from?
# Predicted:  oklahoma
# Correct Answer:  choctaw
#
#
# 3156
# Question:  How many county commissioners does each Oklahoma county have?
# Predicted:  77
# Correct Answer:  three
#
#
# 3158
# Question:  What part of Oklahoma has oak savannahs?
# Predicted:  partial plains
# Correct Answer:  central
#
#
# 3159
# Question:  What was Oklahoma's record high temperature?
# Predicted:  66 degrees
# Correct Answer:  120 °f
#
#
# 3160
# Question:  What was the "Oil Capital of the World"?
# Predicted:  tulsa
# Correct Answer:  tulsa
#
#
# 3161
# Question:  How many people read the Sunday issue of The Oklahoman?
# Predicted:  138493
# Correct Answer:  202,690
#
#
# 3162
# Question:  What is the Pawnee name for Oklahoma?
# Predicted:  the name
# Correct Answer:  uukuhuúwa
#
#
# 3164
# Question:  How many national highway bridges in Oklahoma were found to be deficient in 2010?
# Predicted:  nearly 5212
# Correct Answer:  235
#
#
# 3166
# Question:  What is Oklahoma's 2nd-largest city?
# Predicted:  oklahoma city
# Correct Answer:  tulsa
#
#
# 3167
# Question:  How much of Oklahoma's electricity comes from coal?
# Predicted:  midsummer july and august
# Correct Answer:  25 percent
#
#
# 3168
# Question:  When was Oklahoma's centennial year?
# Predicted:  early june
# Correct Answer:  2007
#
#
# 3170
# Question:  When did the Medieval Fair of Norman begin?
# Predicted:  annually
# Correct Answer:  1976
#
#
# 3172
# Question:  What was Oklahoma's state motto, before the state House bill might change it?
# Predicted:  hcr
# Correct Answer:  labor omnia vincit
#
#
# 3173
# Question:  What is Oklahoma's fourth most popular language?
# Predicted:  arabic
# Correct Answer:  german
#
#
# 3174
# Question:  How does Oklahoma's crude oil reserves rank among states?
# Predicted:  is
# Correct Answer:  fifth
#
#
# 3176
# Question:  What is an example of a mesa range?
# Predicted:  the semiarid high plains
# Correct Answer:  glass mountains
#
#
# 3178
# Question:  What is the Cayuga name for Oklahoma?
# Predicted:  the name
# Correct Answer:  gahnawiyoˀgeh
#
#
# 3179
# Question:  Oklahoma was the only state where which presidential candidate won no counties twice?
# Predicted:  oklahoma
# Correct Answer:  barack obama
#
#
# 3180
# Question:  What political party has the most members in Oklahoma?
# Predicted:  the southern and eastern parts
# Correct Answer:  democratic
#
#
# 3181
# Question:  What organization said Oklahoma's centennial was the top event in the US that year?
# Predicted:  2007
# Correct Answer:  american bus association
#
#
# 3183
# Question:  Where is the Philbrook Museum?
# Predicted:  tulsa
# Correct Answer:  tulsa
#
#
# 3184
# Question:  What kind of art did Dale Chinuly make?
# Predicted:  the oklahoma city museum
# Correct Answer:  glass sculptures
#
#
# 3185
# Question:  What natural-disaster-based nickname does Oklahoma's region have?
# Predicted:  the glass mountains
# Correct Answer:  tornado alley
#
#
# 3186
# Question:  How many people lived in Stillwater in 2010?
# Predicted:  579999
# Correct Answer:  45,688
# 3188
# Question:  An activist in the Arab spring said they were using youtube to do what?
# Predicted:  quoted
# Correct Answer:  tell the world
#
#
# 3189
# Question:  What was the highest earning youtube partner video producer?
# Predicted:  preroll advertisements
# Correct Answer:  $ 12 million
#
#
# 3190
# Question:  What was the original title of youtube red?
# Predicted:  the announcement
# Correct Answer:  music key
#
#
# 3191
# Question:  How much content on youtube comes from outside the US?
# Predicted:  2014
# Correct Answer:  around three quarters
#
#
# 3192
# Question:  As of 2010 what is the maximum length of a video a user can upload given the proper authority?
# Predicted:  youtube
# Correct Answer:  unlimited
#
#
# 3193
# Question:  How many independent labels did the Merlin Network represent?
# Predicted:  over 20000
# Correct Answer:  20,000
#
#
# 3194
# Question:  How many copyright infringements must an account have before the account is deleted?
# Predicted:  three
# Correct Answer:  three
#
#
# 3195
# Question:  What type of videos did youtube officially start supporting in July 2009?
# Predicted:  the default settings
# Correct Answer:  3d
#
#
# 3196
# Question:  What happened to the sites rules in Dec. 2010?
# Predicted:  youtube
# Correct Answer:  were modified
#
#
# 3197
# Question:  Youtube depends on who to flag inappropriate videos?
# Predicted:  youtube
# Correct Answer:  users
#
#
# 3198
# Question:  When was youtube red originally announced?
# Predicted:  november 12 2014
# Correct Answer:  november 12 , 2014
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4993e4f1edf9> in <module>()
#     176         else:
#     177             # what...do type question
# --> 178             tokens.remove(next_token)
#     179             if 'do' in tokens:
#     180                 qtype = 'verb'
#
# ValueError: list.remove(x): x not in list
