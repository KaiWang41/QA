# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer
import gensim
import re
import csv
from gensim.summarization import bm25

# %% [markdown]
# # Variables

# %%
OPEN_QUESTION_WORDS = ['what','who','whose','whom','where','when','why','how',
                       'which',"what's","who's","where's","how's"]
CLOSED_QUESTION_WORDS = ['is','are','am','was','were','do','does,','did','can',
                         'could','will','would','shall','should','have','has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)

# %%
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)

# %%
def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma

        
def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += 1
    return dfs


def query_vsm(query, index, k=4):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'

# %%
# length of longest same sequences of keywords
def get_overlap(sent1, sent2):
    tokens1 = []
    tokens2 = []

    for token in nltk.word_tokenize(strip_punctuation(sent1.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens1.append(lemma)

    for token in nltk.word_tokenize(strip_punctuation(sent2.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens2.append(lemma)

    max = 0
    for i in range(len(tokens1)):
        for j in range(len(tokens2)):

            if tokens1[i] == tokens2[j]:
                length = 1

                ii = i + 1
                jj = j + 1
                while ii < len(tokens1) and jj < len(tokens2) and \
                        tokens1[ii] == tokens2[jj]:
                    ii += 1
                    jj += 1
                    length += 1

                if length > max:
                    max = length

    return max

# %% [markdown]
# # Write to test file

# %%
csvFile = open("high.csv", "w")
writer = csv.writer(csvFile)
header = ['id','answer']
writer.writerow(header)


case_count = 0
empty_count = 0
# test = [test[17]]
for test_case in test:
    question = test_case['question']
    docid = test_case['docid']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)
    

    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question) 
    results = query_vsm(terms, vsm_inverted_index)
    
    
#     tokenized_sentence = []
#     for each_sentence in raw_docs:
#         filter_stop_word = []
#         sentence_as_words = nltk.word_tokenize(each_sentence)
#         for each_word in sentence_as_words:
#             if each_word not in stop:
#                 filter_stop_word.append(each_word)
        
#         tokenized_sentence.append(filter_stop_word)
        
#     bm25Model = bm25.BM25(tokenized_sentence)
#     average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
#     query = []
#     for word in nltk.word_tokenize(question):
#         if word not in stop:
#             query.append(word)
        
#     scores = bm25Model.get_scores(query,average_idf)
#     bm25_dic = Counter()
    
#     sentence_id = 0
#     for each_score in scores:
#         bm25_dic[sentence_id] = each_score
#         sentence_id += 1
#     results = bm25_dic.most_common(4)


    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:
        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'

        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        elif 'name' in tokens:
            qtype = 'NE'

        else:
            # what...do type question
            tokens.remove(next_token)
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the 20 sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC']:
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1
                    
        elif qtype == 'NE':
            for ent in doc.ents:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.5 + (scores[id] / max_score * 0.5)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get)
    sent = raw_docs[index]
    doc = nlp(sent)

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if qtype in ['LOC','GPE'] and ent.root.tag_ not in ['NN','NNP','NNS','NNPS']:
                score -= 2
                
            if score > max_score:
                max_score = score
                answer = ent.text
                
#                 if qtype in ['MONEY']:
#                     for token in doc:
#                         if token.text == '$':
#                             answer = '$ ' + answer
                            
                if qtype in ['PERCENT']:
                    if 'percent' in answer:
                        answer = answer[:answer.index('percent')-1]
                            
                if qtype in ['PERCENT','QUANTITY','CARDINAL','MONEY']:
                    tokens = nltk.word_tokenize(answer)
                    i = 0
                    answer = ''
                    while i < len(tokens):
                        if tokens[i].lower() in ['well','about','around','approximately', 'some']:
                            del tokens[i]
                        else:
                            if i+1 < len(tokens) and tokens[i+1] == "'s":
                                answer += tokens[i]
                            else:
                                answer += tokens[i] + ' '
                            i += 1
                    answer = answer.strip()
                    
    elif qtype == 'NE':
        for ent in doc.ents:
            score = 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = np.text
                
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    answer = answer.strip().lower()
    answer_result = []
    answer_result.append(case_count)
    answer_result.append(answer)
    writer.writerow(answer_result)
    print(case_count,' ',answer)
    case_count += 1
    if answer == '':
        empty_count += 1
    
csvFile.close()
print(empty_count)
# Out:
# 0   combination
# 1   addition
# 2   browser's layout engine
# 3   internet explorer
# 4   late 2004
# 5   windows
# 6   1995
# 7   browsers
# 8   marc andreessen
# 9   first web browser
# 10   competition
# 11   dominance
# 12   internet relay chat
# 13   january
# 14   every major web browser
# 15   january 2003
# 16   january 2009
# 17   file transfer protocol
# 18   google
# 19   case
# 20   rich user interfaces
# 21   2002
# 22   august 2011
# 23   major web browsers
# 24   chrome's user-base
# 25   development
# 26   december 2011
# 27   1993
# 28   netscape
# 29   apple's safari
# 30   rapid development
# 31   prefix
# 32   mozilla foundation
# 33   private networks
# 34   mac
# 35   comparison
# 36   1994
# 37   user interface
# 38   addition
# 39   major browsers
# 40   information resources
# 41   live bookmarks
# 42   more traditional feed reader
# 43   bookmarks
# 44   january 2003
# 45   prefix
# 46   browser software
# 47   file transfer protocol
# 48   microsoft corp
# 49   mobile safari
# 50   web browsers
# 51   windows
# 52   user's default e-mail application
# 53   browser extension
# 54   4.5 hour
# 55   carrefour boycott
# 56   chinese media
# 57   protests
# 58   several protests
# 59   noted indian social activist
# 60   united states of america
# 61   several protests
# 62   site
# 63   western media
# 64   uk
# 65   political activist
# 66   russia
# 67   distinction
# 68   relay supporters
# 69   canberra
# 70   team
# 71   turkey
# 72   foreign minister stephen smith
# 73   french members
# 74   interior michèle alliot-marie
# 75   australian police
# 76   april 5
# 77   members
# 78   april 1, 2008
# 79   april 16
# 80   nagano
# 81   accountability
# 82   april 5
# 83   total
# 84   10 downing street
# 85   torch
# 86   carrefour
# 87   2012
# 88   north korea
# 89   750,000
# 90   libération
# 91   lhasa riots
# 92   protests
# 93   seoul
# 94   libération
# 95   francesca martinez
# 96   route
# 97   seven
# 98   uyghurs
# 99   reporters without borders'
# 100   macau
# 101   vietnamese american
# 102   great britain
# 103   event
# 104   chinese media
# 105   asian times
# 106   india
# 107   site
# 108   libération
# 109   indian
# 110   costanera sur
# 111   original 20 km relay
# 112   1200
# 113   assurances
# 114   man
# 115   foreign minister stephen smith
# 116   major setback
# 117   democracy
# 118   tokyo
# 119   kazakhstan
# 120   paris
# 121   reports
# 122   praise
# 123   air china
# 124   hollywood
# 125   march 2008
# 126   jon stanhope
# 127   oman
# 128   ted quinlan
# 129   several protests
# 130   may 2
# 131   kuala lumpur
# 132
# 133   china
# 134   tsim sha tsui
# 135   new starting point
# 136   event
# 137   coverage
# 138   chaotic torch relays
# 139   many as 1,000
# 140   event
# 141   may 3
# 142   thupten gyatso
# 143   april 17
# 144   protests
# 145   one
# 146   two
# 147   chinese
# 148   ladbroke grove
# 149   april 5
# 150   2,200 police
# 151   120
# 152   response
# 153   relay
# 154   libération
# 155   vietnamese
# 156   2008 summer olympics torch relay
# 157   intended torchbearers choi seung-kook
# 158   minister
# 159   thousands
# 160   1964
# 161   justin herman plaza
# 162   april 5
# 163   francesca martinez
# 164   number
# 165   first time
# 166   ali mohamed shein
# 167   daily telegraph
# 168   susan prager
# 169   torch
# 170   united nations organization
# 171   jackie chan
# 172   times
# 173   francesca martinez
# 174   kazakhstan
# 175   great britain
# 176   april
# 177   1964
# 178   invitees
# 179   first
# 180   torch
# 181   two
# 182   jane birkin
# 183   one
# 184   event
# 185   may 2
# 186   torch
# 187   april
# 188   france
# 189   event
# 190   torch relay route
# 191   china
# 192   70
# 193   one
# 194   85,000
# 195   nagano
# 196   india
# 197   jane birkin
# 198   torch
# 199   day
# 200   1964
# 201   libération
# 202   nathan road
# 203   intended torchbearers choi seung-kook
# 204   sanya
# 205   protests
# 206   tazara railway
# 207   paris city
# 208   turkey
# 209   japanese family
# 210   taipei
# 211   indian
# 212   malaysia
# 213   call
# 214   april 3
# 215   politicians
# 216   several protests
# 217   chinese demands
# 218   carrefour
# 219   days
# 220   china's relations
# 221   oman
# 222   "immigration reasons
# 223   two
# 224   april 17
# 225   members
# 226   north korea's
# 227   lê minh phiếu
# 228   maria nafpliotou
# 229   jacques rogge
# 230   several protests
# 231   several protests
# 232   april
# 233   sacred torch
# 234   120
# 235   olympic games
# 236   medeo
# 237   seven
# 238   call
# 239   aluminum
# 240   kazakhstan
# 241   relay
# 242   argentine
# 243   chinese media
# 244   vietnam
# 245   saint petersburg
# 246   government
# 247   may 3
# 248   eiffel tower
# 249   tanzania
# 250   beijing
# 251   air china
# 252   tibetan flags
# 253   two
# 254   1200
# 255   days
# 256   great britain
# 257   april
# 258   two
# 259   several protests
# 260   paris
# 261   president pervez musharraf
# 262   macau
# 263   150,000-strong
# 264   carrefour
# 265   protests
# 266   bollywood actress soha ali khan
# 267   chinese media coverage
# 268   great britain
# 269   middle east
# 270   india
# 271   macau
# 272   ancient links
# 273   tony goh
# 274   government
# 275   reporters
# 276   people
# 277   response
# 278   istanbul
# 279   torchbearers
# 280   narisa chakrabongse, green world foundation (gwf) chairwoman
# 281   macao daily news
# 282   paralympic games
# 283   may 4
# 284   call
# 285   sanya
# 286   great britain
# 287   bangkok
# 288   several symbolic protests
# 289   libération
# 290   april 16
# 291   chinese government
# 292   buenos aires
# 293   trocadéro
# 294   one
# 295   trocadéro
# 296   people's daily
# 297   april 9
# 298   tibetan flags
# 299   prior
# 300   japan
# 301   chinese officials
# 302   several times
# 303   torch relay route
# 304   japan
# 305   relay
# 306   china
# 307   several hundred pro-tibet protesters
# 308   several protests
# 309   intended torchbearer lin hatfield dodds
# 310   85,000
# 311   peter ueberroth
# 312   three activists
# 313   carrefour
# 314   original 20 km relay
# 315   pyongyang
# 316   than 100
# 317   south korea
# 318   chan
# 319   total
# 320   baichung bhutia
# 321   relay
# 322   march 2008
# 323   torch
# 324   1988
# 325   tokyo
# 326   30
# 327   arrival
# 328   65 kilometre per hour
# 329   san francisco
# 330   australia
# 331   islamabad
# 332   torch
# 333   tsim sha tsui
# 334   islamabad
# 335   129 days
# 336   fu ying
# 337   april 1, 2008
# 338   torch relay leg
# 339   world ’ s worst offenders
# 340   france
# 341   to 600
# 342   to 600
# 343   lê minh phiếu
# 344   united states of america
# 345   torch
# 346   event
# 347   protests
# 348   kamal nath
# 349   april 16
# 350   tokyo
# 351   torch
# 352   bbc's paul danahar
# 353   same pitch
# 354   total number
# 355   pitch
# 356   12
# 357   indefinite pitch
# 358   100 cents
# 359   frequency
# 360   "high" pitch
# 361   least one model
# 362   overtones
# 363   time
# 364   a4
# 365   the higher frequencies
# 366   12
# 367   perceived interval
# 368   sound
# 369   theories
# 370   southampton
# 371   uk
# 372   annual southampton boat show
# 373   seven
# 374   city
# 375   120,305
# 376   sizeable polish population
# 377   lloyd's register group
# 378   most successful college american football teams
# 379   1996
# 380   great war
# 381   9th century
# 382   london
# 383   new forest
# 384   10th century
# 385   southampton
# 386   southampton city council
# 387   roughly half
# 388   2015 council elections
# 389   than 2,000
# 390   two
# 391   over a week
# 392   portsmouth
# 393   one
# 394   walls
# 395   city
# 396   importance
# 397   1888
# 398   november 2014
# 399   annual
# 400   one third
# 401   annual southampton boat show
# 402   population
# 403   12th century
# 404   latter half of the 20th century
# 405   october 2014
# 406   hamtun
# 407   15th century
# 408   1940s
# 409   southampton's largest retail centre
# 410   english
# 411   house tower
# 412   24
# 413   2004
# 414   two
# 415   first half of the 20th century
# 416   1964
# 417   worst behaved secondary schools
# 418   part
# 419   four
# 420   1840
# 421   1862
# 422   city council
# 423   western docks
# 424   space
# 425   1417
# 426   western docks
# 427   1339
# 428   202
# 429   1976
# 430   city
# 431   presence
# 432   centre
# 433   1968
# 434   port
# 435   hampshire
# 436   1066
# 437   british gas
# 438   west quay
# 439   royston smith
# 440
# 441   parts
# 442   eastleigh
# 443   princess alexandra dock
# 444   vast majority
# 445   bournemouth symphony orchestra
# 446   queen mary
# 447   2,300
# 448   early may
# 449   uni-link
# 450   cent
# 451   third ferry
# 452   university of southampton
# 453   13th century
# 454   provide
# 455   1966
# 456   hampshire
# 457   west quay
# 458   headquarters
# 459   city
# 460   portswood, banister park
# 461   local train services
# 462   two
# 463   uk
# 464   solent
# 465   p&o cruises
# 466   27 june 1640
# 467   college
# 468   9th century
# 469   1339
# 470   1233
# 471   university hospital southampton nhs foundation trust
# 472   biggest operator
# 473   4.2
# 474   1959
# 475   354
# 476   government figures
# 477   m27
# 478   coast
# 479   hanover buildings
# 480   city
# 481   december 2007
# 482   12th century
# 483   traffic congestion
# 484   southampton
# 485   2004
# 486   1233
# 487   1959
# 488   three fire stations
# 489   southampton docks
# 490   24
# 491   m27
# 492   southampton's largest retail centre
# 493   13th century
# 676   river test and river itchen
# 677   1996 and 2004
# 678   talking heads
# 679   attempt
# 680   conduit house
# 681   major uk port
# 682   supermarine spitfire
# 683   tottonians
# 684   city
# 685   northern tip
# 686   king henry's departure
# 687   france
# 688   so'ton
# 689   uk
# 690   swaythling
# 691   premier league
# 692   uk
# 693   bitterne
# 694   red funnel
# 695   1938
# 696   40,000
# 697   crimean war
# 698   previously
# 699   1862
# 700   1888
# 701   steam yacht north star
# 702   clausentum
# 703   ferry port
# 704   1879 to 1949
# 705   itchen
# 706   henry v's
# 707   1740
# 708   southampton
# 709   national lottery
# 710   eastern docks
# 711   royalists
# 712   hampshire
# 713   february 2011
# 714   119,500 males
# 715   nearly 92 %
# 716   nearly 92 %
# 717   eastern
# 718   four women
# 719   poland
# 720   ashkenazi jew's
# 721   40 %
# 722   high frequencies
# 723   however, most people
# 724   1890s
# 725   1990s
# 726   middle east
# 727   last thousand years
# 728   probability
# 729   ashkenazim
# 730   nearly 92 %
# 731   11th century
# 732   last thousand years
# 733   40 %
# 734   often
# 735   middle ages
# 736   212
# 737   certain issues
# 738   midrash
# 739   jews
# 740   several famous people
# 741   holocaust
# 742   20th century
# 743   israeli black panthers
# 744   study
# 745   estimated 8.8 million
# 746   israel
# 747   hebrew
# 748   large
# 749   roman empire
# 750   recent years
# 751   1750
# 752   ashkenazi jews
# 753   16th-century
# 754   1095
# 755   1095
# 756   elevated frequency
# 757   47.5 %
# 758   concept
# 759   uses
# 760   2,500 years ago
# 761   ancient levantine origins
# 762   middle ages
# 763   middle eastern peoples
# 764   conformity
# 765   archeological evidence
# 766   several million
# 767   ashkenazi jew
# 768   hebrew
# 769   pre-christian times
# 770   period
# 771   term
# 772   center
# 773   80
# 774   another trend
# 775   centuries later
# 776   11th century
# 777   jews
# 778   rabbinic leadership
# 779   talmud
# 780   modern-day italians
# 781   30
# 782   five thousand
# 783   brigetio
# 784   minhagim
# 785   54 % –60 %
# 786   genome-wide genetic study
# 787   fertile crescent
# 788   quarter
# 789   1095
# 790   second half of the 11th century
# 791   jerusalem
# 792   yiddish
# 793   75 %
# 794   yoma
# 795   conformity
# 796   contemporary saadia gaon
# 797   hebrew
# 798   greek historian
# 799   greek historian
# 800   1095
# 801   first
# 802   first decades
# 803   sergio dellapergola
# 804   nearly 92 %
# 805   jewish
# 806   gomer
# 807   80
# 808   jews
# 809   ashkenazi jew
# 810   2 %
# 811   91 %
# 812   upper euphrates
# 813   nusach
# 814   latin america
# 815   2002
# 816   conformity
# 817   surname hail
# 818   herodotus
# 819   many jews
# 820   first half
# 821   nusach sefard
# 822   estimated 8.8 million
# 823   genesis rabbah
# 824   religious jews
# 825   uranus
# 826   11 july neptune
# 827   largest neptunian moon
# 828   objects
# 829   difference
# 830   sun
# 831   le verrier
# 832   result
# 833   planet's distance
# 834   1.0243×1026 kg
# 835   rahab
# 836   troposphere
# 837   2007
# 838   jupiter
# 839   modern greek
# 840   uranus
# 841   johann galle
# 842   same way
# 843   william lassell
# 844   late 2020s or early 2030s
# 845   11 july 2011
# 846   gravity
# 847   le verrier
# 848   neptune's composition
# 849   200
# 850   °
# 851   , persistent methane clouds
# 852   scooter
# 853   small dark spot
# 854   voyager
# 855   high-altitude clouds
# 856   voyager
# 857   1:1 resonance
# 858   weather
# 859   1843
# 860   winds
# 861   occultation
# 862   50 %
# 863   focus
# 864   first scientifically useful observation
# 865   25 august 1989
# 866   credit
# 867   discovery
# 868   1821
# 869   0.25 %
# 870   roughly 40
# 871   upper-level clouds
# 872   sun
# 873   first and so far only object
# 874   dark spots
# 875   adams
# 876   17
# 877   le verrier ring
# 878   discovery
# 879   neptune
# 880   current most widely accepted explanation
# 881   nahuatl
# 882   2019
# 883   1:1
# 884   penultimate known planet
# 885   uranus
# 886   neptune
# 887   2006
# 888   23
# 889   high-altitude clouds
# 890   first and so far only object
# 891   14
# 892   jupiter
# 893   most heavily populated resonance
# 894   le verrier ring
# 895   sun
# 896   voyager 2's arrival
# 897   high-altitude cloud bands
# 898   neptune's atmospheric methane content
# 899   neptune
# 900   discovery
# 901   evening
# 902   december 1612
# 903   altitudes
# 904   vortex structures
# 905   neptune's more varied weather
# 906   30.1
# 907   international astronomical union
# 908   apparent backward motion
# 909   current models
# 910   1997
# 911   planetary science
# 912   400 m/s
# 913   2002 and 2003
# 914   images
# 915   1017
# 916   candidates
# 917   neptune's more varied weather
# 918   reaction
# 919   hobbes
# 920   modern term `` culture
# 921   non-material culture
# 922   citation
# 923   19th-century
# 924   terror management theory
# 925   29
# 926   united states
# 927   germany
# 928   end of the last ice age
# 929   19th-century
# 930   contrasted
# 931   terror management theory
# 932   anthropologists
# 933   1970s
# 934   around 50,000 years ago
# 935   united states
# 936   diffusion
# 937   prussian linguist
# 938   1950s and 1960s
# 939   stuart hall
# 940   élite ideal
# 941   present legislation
# 942   jefferson's metaphor
# 943   1971
# 944   nonconformists
# 945   areas
# 946   pervasive secularism
# 947   wall
# 948   may 3, 2006
# 949   still other scholars
# 950   early as the mid-17th century
# 951   religious freedom
# 952   engel
# 953   madison
# 954   december 20, 2005
# 955   william penn
# 956   two
# 957   legal scholars
# 958   still other scholars
# 959   reynolds
# 960   1776
# 961   court's decision
# 962   opponents
# 963   december
# 964   robert s. wood
# 965   u.s.
# 966   1962
# 967   court
# 968   1994
# 969   kurtzman
# 970   argue
# 971   thomas jefferson's influential virginia statute
# 972   1947
# 973   lone dissenter
# 974   central point
# 975   many early immigrant groups
# 976   third
# 977   may
# 978   jefferson
# 979   states' rights
# 980   1879
# 981   religious bigotry
# 982   one religious society
# 983   1786
# 984   religious beliefs
# 985   national motto
# 986   u.s.
# 987   ohio
# 988   2002
# 989   new england
# 990   phrase
# 991   three
# 992   answer
# 993   pledge
# 994   principle or primary effect
# 995   kurtzman
# 996   john f. kennedy
# 997   south carolina
# 998   roger williams
# 999   purpose of the display ( educating the public on american legal traditions ) was secular in nature .
# 1000   december 27, 1657
# 1001   jefferson's concept
# 1002   jefferson's statute
# 1003   eighteenth century
# 1004   required beliefs
# 2242   good arguments
# 2243   word
# 2244   earlier work
# 2245   researchers
# 2246   last two decades
# 2247   eduardo bonilla-silva
# 2248   race
# 2249   many people
# 2250   2003 paper
# 2251   system
# 2252   five
# 2253   europeans
# 2254   kaplan
# 2255   many biological anthropologists
# 2256   amerindians
# 2257   identification code
# 2258   system
# 2259   78 percent
# 2260   five
# 2261   thus, anthropologist frank livingstone's conclusion
# 2262   values
# 2263   study
# 2264   abu el-haj
# 2265   population
# 2266   mitochondrial dna
# 2267   sewall wright
# 2268   way
# 2269   1978
# 2270   researchers
# 2271   1775 treatise
# 2272   markers
# 2273   sense
# 2274   questioning
# 2275   three
# 2276   anthropologists
# 2277   one result
# 2278   last decades
# 2279   term race
# 2280   william c. boyd
# 2281   examples
# 2282   empirical reasons
# 2283   designation 'subspecies
# 2284   brazilian child
# 2285   early 20th century
# 2286   cladistics
# 2287   dean amadon
# 2288   three
# 2289
# 2290   contradictions
# 2291   similarly
# 2292   rise
# 2293   jim crow laws
# 2294   racial groups
# 2295   balanced degree
# 2296   blumenbach
# 2297   concept
# 2298   many others
# 2299   dean amadon
# 2300   european union
# 2301   than 1.8 million years ago
# 2302   eduardo bonilla-silva
# 2303   60-65 %
# 2304   example
# 2305   fixation index
# 2306   widespread popularity
# 2307   racial groups
# 2308   rather than 85%
# 2309   anthropologist norman sauer
# 2310   authors
# 2311   thousands
# 2312   19th century
# 2313   2008
# 2314   selected allele
# 2315   20th century
# 2316   scientists
# 2317   anthropologists
# 2318
# 2319   majority
# 2320   non-african groups
# 2321   last two decades of the 18th century
# 2322   clade
# 2323   racial groups
# 2324   material
# 2325   race
# 2326   united states
# 2327   selected allele
# 2328   18th century
# 2329   77
# 2330   2000 edition
# 2331   small non-representative sample
# 2332   states
# 2333   definitions
# 2334   sociological factors
# 2335   trained anthropologist
# 2336   human populations
# 2337   historically recent acceleration
# 2338   mixture
# 2339   racial discrimination
# 2340   mammalian species
# 2341   authors
# 2342   1996
# 2343   utility
# 2344   loci
# 2345   first post-classical published classification
# 2346   one-drop rule
# 2347   global distributions
# 2348   doctors
# 2349   1970s
# 2350   differences
# 2351   1996
# 2352   2007 review paper
# 2353   least three million people
# 2354   races
# 2355   early 20th century
# 2356   2001
# 2357   more realistic portrayal
# 2358   visually
# 2359   19th century
# 2360   race
# 2361   english language
# 2362   considerable suffering
# 2363   term
# 2364   england
# 2365   cladistics
# 2366   concept
# 2367   , therefore fst values
# 2368   replaced
# 2369   same geographical location
# 2370   2007 review paper
# 2371   homininae
# 2372   scholars
# 2373   rachel caspari
# 2374   scientists
# 2375   came
# 2376   than 1.8 million years ago
# 2377   virtually all physical anthropologists
# 2378   figure
# 2379   stanford university school of medicine
# 2380   correctly
# 2381   attempt
# 2382   era
# 2383   farm
# 2384   temple area
# 2385   evidence
# 2386   social inequality
# 2387   settlements
# 2388   neolithic societies
# 2389   southwestern united states
# 2390   era
# 2391   rhine
# 2392   era
# 2393   british isles
# 2394   mid-late neolithic
# 2395   elaborate tombs
# 2396   cultural elements
# 2557   end
# ...
# 2788   tuvalu
# 2789   also
# 2790   english
# 2791   tuvalu media department
# 2792   10 years
# 2793   eight per cent
# 2794   japan international cooperation agency
# 2795   program
# 2796   presidents
# 2797   european union
# 2798   pacific war funafuti
# 2799   trader
# 2800   eight
# 2801   funafuti
# 2802   tuvalu advocates ratification
# 2803   major international priority
# 2804   international monetary fund 2010 report
# 2805   independence
# 2806   part
# 2807   another important building
# 2808   manu
# 2809   tuvalu ship registry
# 2810   10,640
# 2811   july 2012
# 2812   palagi traders
# 2813   hearing
# 2814   new imac
# 2815   68020-powered macintosh lc
# 2816   macintosh
# 2817   2,600
# 2818   may 1998
# 2819   macintosh
# 2820   then-new imac g5
# 2821   order
# 2822   created
# 2823   macintosh project
# 2824   sold
# 2825   four years
# 2826   current mac product family
# 2827   39 advertising pages
# 2828   sales
# 2829   macintosh
# 2830   mac os x
# 2831   apple's market share
# 2832   pcs
# 2833   mac's market share
# 2834   retrofits
# 2835   use
# 2836   air
# 2837   apple
# 2838   intel
# 2839   original
# 2840   same year
# 2841   macbook
# 2842   matters
# 2843   macintosh
# 2844   may
# 2845   well
# 2846   john sculley
# 2847   one
# 2848   may
# 2849   steve jobs
# 2850   1998
# 2851   october
# 2852   macintosh
# 2853   macintosh ii
# 2854   $ 2.5 million
# 2855   steve jobs
# 2856   may 1990
# 2857   new imac
# 2858   us $ 1.5 million
# 2859   39 advertising pages
# 2860   estimated 100,000
# 2861   jef raskin
# 2862   2000
# 2863   john dvorak
# 2864   1997
# 2865   40
# 2866   macintosh platform
# 2867   august
# 2868   1989
# 2869   second generation
# 2870   change
# 2871   final macintosh design
# 2872   bluetooth
# 2873   apple
# 2874   apple
# 2875   early 2001
# 2876   primary authors
# 2877   installed base
# 2878   imac
# 2879   finally
# 2880   macintosh's minimal memory
# 2881   clarisworks
# 2882   2000
# 2883   complete office suite
# 2884   number five spot
# 2885   third-party platform virtualization software
# 2886   personal computer manufacturers
# 2887   steve jobs
# 2888   quarterly
# 2889   air
# 2890   open firmware
# 2891   new motorola 68030 processor
# 2892   models
# 2893   contrast
# 2894   steve jobs
# 2895   bill atkinson
# 2896   macintosh classic
# 2897   macintosh's market share
# 2898   discontinued power macintosh g3 , to slot between the imac g3 and the power mac g4 .
# 2899   hewlett packard
# 2900   suggestions
# 2901   october 2009
# 2902   several ultrabooks
# 2903   mavericks
# 2904   chief designer
# 2905   allan loren
# 2906   updated motorola cpus
# 2907   1985
# 2908   may 1990
# 2909   october
# 2910   open firmware
# 2911   apple
# 2912   3.36 million
# 2913   macintosh se
# 2914   macbook air
# 2915   2013
# 2916   mid-2011
# 2917   darwin
# 2918   macintosh
# 2919   april 5, 2006
# 2920   c++
# 2921   current mac models
# 2922   cube
# 2923   apple's actions
# 2924   one megabyte
# 2925   14 %
# 2926   c++
# 2927   apple
# 2928   performance advantage
# 2929   20
# 2930   2006
# 2931   time
# 2932   windows 95 operating system
# 2933   windows
# 2934   apple
# 2935   smith's design
# 2936   new imac
# 2937
# 2938   part
# 2939   third place spot
# 2940   macintosh
# 2941   imac , macbook pro , macbook air , and mac mini lines
# 2942   early 2011
# 2943   models
# 2944   materials
# 2945   component shortage
# 2946   seven years
# 2947   recent years
# 2948   two
# 2949   2006
# 2950   macintosh
# 2951   removal
# 2952   1993 powerbook 165c
# 2953   macintosh iici
# 2954   mid-2011
# 2955   october
# 2956   compaq
# 2957   jean-louis gassée
# 2958   lisa and macintosh user interfaces
# 2959   regis mckenna
# 2960   launch
# 2961   performance advantage
# 2962   update
# 2963   mac os x
# 2964   personal computer manufacturers
# 2965   ten
# 2966   macintosh
# 2967   1993
# 2968   crt
# 2969   models
# 2970   one
# 2971   glass
# 2972   9,900
# 2973   march 2006
# 2974   floppy disk drive
# 2975   apple
# 2976   56
# 2977   macintosh programmer's workshop
# 2978   1994
# 2979   floppy disk drive
# 2980   april 1984
# 2981   apple
# 2982   macs
# 2983   ten
# 2984   every macintosh
# 2985   3,195
# 2986   mac
# 2987   launch
# 2988   2011
# 2989   software business
# 2990   2.06
# 2991   virbhadra singh
# 2992   state-owned television broadcaster
# 2993   governor
# 2994   himachal
# 2995   sikhs
# 2996   kangra miniature paintings
# 2997   state
# 2998   himachal
# 2999   state
# 3000   himachal pradesh
# 3001   economy
# 3002   10th century
# 3003   hill stations
# 3004   public radio station
# 3005   1 november 1956
# 3006   himachal pradesh
# 3007   handicrafts
# 3008   virbhadra singh
# 3009   21st
# 3010   anglo-gorkha war
# 3011   superintendent
# 3012   pit-loom
# 3013   virbhadra singh
# 3014   buddhism and sikhism
# 3015   himachal pradesh
# 3016   wool
# 3017   year 1768
# 3018   hima
# 3019   hydro electric resources
# 3020   dial-up access
# 3021   mahmud ghaznavi
# 3022   citation
# 3023   citation
# 3024   technological advancements
# 3025   30 december 2007
# 3026   first
# 3027   nepal
# 3028   h.p.
# 3029   private fm stations
# 3030   18 december 1970
# 3031   state
# 3032   1.16%
# 3033   radio
# 3034   2006
# 3035   handicrafts
# 3036   1948
# 3037   muslims
# 3038   first five-year plan
# 3039   extreme variation
# 3040   others
# 3041   military settlement
# 3042   roman women
# 3043   imperial era
# 3044   human sacrifice
# 3045   security
# 3046   edict
# 3047   public festivals
# 3048   camp
# 3049   constantine
# 3050   roman women
# 3051   second edict
# 3052   famous tirade
# 3053   human sacrifice
# 3054   strong connections
# 3055   ordinary romans
# 3056   vergil
# 3057   valerian's first religious edict
# 3058   di immortales
# 3059   roman
# 3060   roman camps
# 3061   ruins
# 3062   (509–27 bc
# 3063   excessive devotion
# 3064   rome's hegemony
# 3065   end
# 3066   product
# 3067   customary offers
# 3068   product
# 3069   rome's hegemony
# 3070   relationship
# 3071   little or no civil authority
# 3072   edict
# 3073   edict
# 3074   most important camp-offering
# 3075   several days
# 3076   women
# 3077   dictator
# 3078   public festivals
# 3079   edict
# 3080   opportunities
# 3081   solution
# 3082   cult
# 3083   sporadic and sometimes brutal attempts
# 3084   punic crisis
# 3085   human sacrifice
# 3086   roman oaths
# 3087   least
# 3088   office
# 3089   jupiter latiaris
# 3090   religious dimensions
# 3091   augustus
# 3092   roman calendar
# 3093   second edict
# 3094   record
# 3095   lares and penates
# 3096   first punic war
# 3097   non-official but lawful cults
# 3098   rites
# 3099   act
# 3100   same token
# 3101   superstitio
# 3102   jupiter feretrius
# 3103   others
# 3104   vestals
# 3105   augustan settlement
# 3106   february
# 3107   hitherto unlikely source
# 3108   haruspices
# 3109   constantine
# 3110   gaul
# 3111   original meaning
# 3112   egypt
# 3113   early severan era
# 3114   roman bellona
# 3115   heretics
# 3116   last emperor
# 3117   roman calendar
# 3118   twelve tables
# 3119   rome's hegemony
# 3120   rome
# 3121   infernal gods
# 3122   great crisis
# 3123   ad 567
# 3124   imperial
# 3125   (509–27 bc
# 3126   emperor julian
# 3127   julius caesar
# 3128   very late republic
# 3129   high-status seating
# 3130   archaeology
# 3131   sacrifice
# 3132   several days
# 3133   imported mystery religions
# 3134   synagogues
# 3135   romans
# 3136   individuals
# 3137   empire
# 3138   mortal's death
# 3139   later empire
# 3140   16 bc tiberius
# 3141   julian
# 3142   popular belief deities
# 3143   treason
# 3144   record
# 3145   such spectacular displays
# 3146   ofﬁcial recognition
# 3147   harmony
# 3148   first ( 303 ad
# 3149   empire-wide ban
# 3150   successful general
# 3151   clients
# 3152   second punic war
# 3153   prayer
# 3154   addition
# 3155   funding
# 3156   attempt
# 3157   last century
# 3158   magistrates
# 3159   civil and religious law
# 3160   separate priestly caste
# 3161   303 ad
# 3162   product
# 3163   comparison
# 3164   valerian's first religious edict
# 3165   roman architect vitruvius
# 3166   rome
# 3167   decius mus
# 3168   everyday world
# 3169   presence
# 3170   regal era
# 3171   edict
# 3172   rome's intellectual elite
# 3173   state cult
# 3174   public priests
# 3175   clients
# 3176   roman religion
# 3177   devotio
# 3178   vestals
# 3179   reign
# 3180   western emperor gratian
# 3181   ordinary
# 3182   264–146
# 3183   senate
# 3184   least
# 3185   thessaly
# 3186   periods
# 3187   public religion
# 3188   mystery cult
# 3189   male priests
# 3190   roman "domestic" deities
# 3191   latin word templum
# 3192   popular cult
# 3193   public festivals
# 3194   constantine
# 3195
# 3196   ruins
# 3197   exceptional honor
# 3198   early days
# 3199   servius tullius
# 3200   rome
# 3201   myth
# 3202   participation
# 3203   first and last roman
# 3204   sacrifice
# 3205   rome's hegemony
# 3206   decius
# 3207   excessive devotion
# 3208   magistrates
# 3209   haruspicy
# 3210   hellenization
# 3211   later empire
# 3212   times
# 3213   context
# 3214   everyday world
# 3215   male priests
# 3216   law
# 3217   rome
# 3218   archaeology
# 3219   wife
# 3220   cult donations
# 3221   customary offers
# 3222   fulfillment
# 3223   household cult
# 3224   popular belief deities
# 3225   portion
# 3226   graeco-roman world
# 3227   roman poets
# 3228   rites
# 3229   gods
# 3230   vesta
# 3231   hitherto
# 3232   prodigies
# 3233   funeral and commemorative rites
# 3234   clitellates
# 3235   locomotion
# 3236   septa
# 3237   ragworms' jaws
# 3238   65 million years ago
# 3239   ragworms
# 3240   fluid
# 3241   brain
# 3242   "hairs
# 3243   clitellates
# 3244   find
# 3245   circulates
# 3246   3
# 3247   small shelly fossil cloudina
# 3248   north america
# 3249   annelids
# 3250   found
# 3251   frontmost section
# 3252   polychaetes
# 3253   cladistic research
# 3254   frontmost section
# 3255   two
# 3256   respiratory pigment
# 3257   two
# 3258   difference
# 3259   one-cell deep epidermis
# 3260   mesothelium
# 3261   two
# 3262   sea-floor
# 3263   mesothelium
# 3264   annelids
# 3265   leeches
# 3266   produce
# 3267   fertilized eggs
# 3268   thus
# 3269   two families
# 3270   cells
# 3271   leeches
# 3272   locomotion
# 3273   oligochaetes
# 3274   1997
# 3275   annelids
# 3276   polychaetes
# 3277   frontmost section
# 3278   very mobile and active polychaetes
# 3279   protostomes
# 3280   oligochaetes
# 3281   brain
# 3282   australia
# 3283   rest care
# 3284   northern hardwood forests
# 3285   ediacaran
# 3286   two
# 3287   vertebrates
# 3288   brain
# 3289   15 %
# 3290   enables
# 3291   2008
# 3292   30 ad
# 3293   fossils
# 3294   marine polychaetes ' predation
# 3295   clitellates
# 3296   charles darwin's book
# 3297   leeches
# 3298   vertebrates
# 3299   mid-19th century
# 3300   1964
# 3301   states
# 3302   contemporary u.s. courts
# 3303   authority
# 3304   contemporary u.s. courts
# 3305   american federalism
# 3306   contract
# 3307   public laws
# 3308   reason
# 3309   282,000
# 3310   contract
# 3311   states
# 3312   constitution
# 3313   chevron deference
# 3314   states
# 3315   constitution
# 3316   dual-sovereign system
# 3317   way
# 3318   criminal law
# 3319   mccarran-ferguson act
# 3320   english
# 3321   20th-century american tort law
# 3322   reason
# 3323   constitution
# 3324   u.s. law
# 3325   law
# 3326   traditional common law pleading
# 3327   american law institute
# 3328   principle
# 3329   eighteen
# 3330   english common law
# 3331   american civil procedure
# 3332   u.s.
# 3333   18th and 19th centuries
# 3334   united states
# 3335   282,000
# 3336   law
# 3337   united states constitution
# 3338   federal courts
# 3339   many statutes
# 3340   felony convictions
# 3341   eighteen
# 3342   eighteenth century
# 3343   constitution
# 3344   handful
# 3345   prosecution
# 3346   difficult question
# 3347   contemporary english cases
# 3348   writ
# 3349   constitution
# 3350   several legal scholars
# 3351   principle
# 3352   federal constitution
# 3353   states
# 3354   transactions
# 3355   other major implication
# 3356   18th and 19th centuries
# 3357   law
# 3358   u.s.
# 3359   president
# 3360   1964
# 3361   states
# 3362   public laws
# 3363   tort law
# 3364   constitution
# 3365   federal courts
# 3366   united states
# 3367   turn
# 3368   subsequent statute
# 3369   1963
# 3370   eighteen
# 3371   indeed
# 3372   citations
# 3373   282,000
# 3374   end
# 3375   traditional common law pleading
# 3376   turn
# 3377   congress
# 3378   reception statutes
# 3379   federal criminal law
# 3380   scope
# 3381   roger j. traynor
# 3382   u.s.
# 3383   u.s.
# 3384   american civil procedure
# 3385   states
# 3386   supreme court
# 3387   crimes
# 3388   19th century
# 3389   chevron
# 3390   eighteen
# 3391   nineteenth century
# 3392   congress
# 3393   federal agencies
# 3394   decades
# 3395   romanian
# 3396   ming dynasty
# 3559   1962
# 3560   255
# 3561   vladimir lenin
# 3562   1920s
# 3563   little red book
# 3564   first 20th-century artists
# 3565   renaissance
# 3566   nature
# 3567   2000
# 3568   christmas
# 3569   rubia plant
# 3570   communist party
# 3571   neolithic period
# 3572   example
# 3573   red
# 3574   romans
# 3575   even more money
# 3576   even more money
# 3577   red lac
# 3578   19th century
# 3579   red hair
# 3580   red stripes
# 3581   fall
# 3582   famous hymn
# 3583   national symbols
# 3584   1960
# 3585   red coloration
# 3586   1966
# 3587   middle ages
# 3588
# 3589   abbe suger
# 3590   manchu rulers
# 3591   1888
# 3592   first 20th-century
# 3593   1920s
# 3594   red stripes
# 3595   1870
# 3596   face
# 3597   red color
# 3598   color
# 3599   five years
# 3600   red sky
# 3601   zhou
# 3602   red
# 3603   red
# 3604   october
# 3605   vincent van gogh
# 3606   one to two percent
# 3607   silver
# 3608   most famous works
# 3609   chinese cultural traditions
# 3610   egyptians
# 3611   coccus
# 3612   cincinnati red stockings
# 3613   fourth and fifth
# 3614   highways
# 3615   1920
# 3616   one popular color
# 3617   one popular color
# 15

# %% [markdown]
# #  准确率测试

# %%
with open('training.json') as json_data:
    train = json.load(json_data)
    
case_count = 0
empty_count = 0
# test = [test[17]]
for test_case in train:
    question = test_case['question']
    docid = test_case['docid']
    correct_answer = test_case['text']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)
    

    # TFIDF
    doc_term_freqs = {}
    for (id, raw_doc) in enumerate(raw_docs):
        term_freqs = extract_term_freqs(raw_doc)
        doc_term_freqs[id] = term_freqs
    M = len(doc_term_freqs)

    doc_freqs = compute_doc_freqs(doc_term_freqs)

    vsm_inverted_index = defaultdict(list)
    for docid, term_freqs in doc_term_freqs.items():
        N = sum(term_freqs.values())
        length = 0

        # find tf*idf values and accumulate sum of squares
        tfidf_values = []
        for term, count in term_freqs.items():
            tfidf = float(count) / N * log(M / float(doc_freqs[term]))
            tfidf_values.append((term, tfidf))
            length += tfidf ** 2

        # normalise documents by length and insert into index
        length = length ** 0.5
        for term, tfidf in tfidf_values:
            # inversion of the indexing, term -> (doc_id, score)
            vsm_inverted_index[term].append([docid, tfidf / length])

    for term, docids in vsm_inverted_index.items():
        docids.sort()

    terms = extract_term_freqs(question) 
    results = query_vsm(terms, vsm_inverted_index)
    
    
#     tokenized_sentence = []
#     for each_sentence in raw_docs:
#         filter_stop_word = []
#         sentence_as_words = nltk.word_tokenize(each_sentence)
#         for each_word in sentence_as_words:
#             if each_word not in stop:
#                 filter_stop_word.append(each_word)
        
#         tokenized_sentence.append(filter_stop_word)
        
#     bm25Model = bm25.BM25(tokenized_sentence)
#     average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
#     query = []
#     for word in nltk.word_tokenize(question):
#         if word not in stop:
#             query.append(word)
        
#     scores = bm25Model.get_scores(query,average_idf)
#     bm25_dic = Counter()
    
#     sentence_id = 0
#     for each_score in scores:
#         bm25_dic[sentence_id] = each_score
#         sentence_id += 1
#     results = bm25_dic.most_common(4)


    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    qtype = ''

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of sentence
    for token in doc:
        if 'nsubj' in token.dep_:
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            dobj = lemmatize(strip_punctuation(token.text))

    # for noun (phrase) questions, get answer dependency
    for chunk in doc.noun_chunks:
        if qword in chunk.text:
            dep = chunk.root.dep_
            head = lemmatize(strip_punctuation(chunk.root.head.text))
            head_dep = chunk.root.head.dep_

    # determine answer type
    if 'stand for' in question or 'abbreviat' in question:
        qtype = 'abrv'

    elif qword in ['who',"who's",'whom','whose']:
        qtype = 'who'

    elif qword == 'when':
        qtype = 'when'

    elif qword in ['where',"where's"]:
        qtype = 'where'

    elif qword in ['how',"how's"]:
        if next_token == 'much':
            qtype = 'MONEY'
        elif next_token == 'many':
            qtype = 'CARDINAL'
        elif next_token == 'long':
            qtype = 'DATE'
        elif next_token in ['far','big','wide','deep','tall','high','fast','heavy']:
            qtype = 'QUANTITY'
        elif next_token in ['old','young']:
            qtype = 'DATE'
        elif next_token in ['does','did','do','have','has','had','should',
                              'can','could','will','would','must']:
            if dobj != '':
                qtype = 'adj'
            else:
                qtype = 'verb'

    elif qword in ['what', "what's", 'which']:
        if 'year'in tokens or \
                'day' in tokens or \
                'month' in tokens or \
                'era' in tokens or \
                'age' in tokens or \
                'century' in tokens or \
                'week' in tokens or \
                'period' in tokens or \
                'dynasty' in tokens:
            qtype = 'DATE'

        elif 'company' in tokens or \
                'organization' in tokens or \
                'organisation' in tokens or \
                'corporation' in tokens or \
                'institution' in tokens or \
                'university' in tokens or \
                'corporation' in tokens or \
                'association' in tokens or \
                'union' in tokens or \
                'agency' in tokens:
            qtype = 'ORG'

        elif 'city' in tokens or \
                'country' in tokens or \
                'state' in tokens or \
                'province' in tokens or \
                'county' in tokens:
            qtype = 'GPE'

        elif 'place' in tokens or \
                'river' in tokens or \
                'mountain' in tokens or \
                'ocean' in tokens or \
                'region' in tokens or \
                'area' in tokens or \
                'sea' in tokens or \
                'lake' in tokens or \
                'continent' in tokens or \
                'location' in tokens or \
                'forest' in tokens or \
                'jungle' in tokens:
            qtype = 'LOC'

        elif 'nationality' in tokens:
            qtype = 'NORP'

        elif 'building' in tokens or \
            'airport' in tokens or \
            'highway' in tokens or \
            'bridge' in tokens or \
            'harbour' in tokens or \
            'harbor' in tokens or \
            'port' in tokens or \
            'dam' in tokens:
            qtype = 'FACILITY'

        elif 'hurricane' in tokens or \
            'battle' in tokens or \
            'war' in tokens:
            qtype = 'EVENT'

        elif 'book' in tokens or \
            'novel' in tokens or \
            'song' in tokens or \
            'music' in tokens or \
            'painting' in tokens:
            qtype = 'WORK_OF_ART'

        elif 'language' in tokens or \
                'speak' in tokens:
            qtype = 'LANGUAGE'

        elif 'percentage' in tokens or 'percent' in tokens:
            qtype = 'PERCENT'

        elif 'value' in tokens or \
                'distance' in tokens or \
                'size' in tokens or \
                'length' in tokens or \
                'depth' in tokens or \
                'height' in tokens or \
                'density' in tokens or \
                'speed' in tokens or \
                'weight' in tokens or \
                'area' in tokens or \
                'temperature' in tokens or \
                'volume' in tokens:
            qtype = 'QUANTITY'

        elif 'number' in tokens:
            qtype = 'CARDINAL'

        elif 'price' in tokens:
            qtype = 'MONEY'

        elif 'name' in tokens:
            qtype = 'NE'

        else:
            # what...do type question
            tokens.remove(next_token)
            if 'do' in tokens:
                qtype = 'verb'
            else:
                qtype = 'noun'

    elif qword == 'why':
        qtype = 'why'

    elif qword in CLOSED_QUESTION_WORDS:
        qtype = 'closed'

        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            prev1 = tokens[index - 1]
            next1 = tokens[index + 1]
            tag_tokens = nltk.pos_tag(tokens)

            tag = tag_tokens[index - 1][1]

            # if answer is a noun
            if tag in ['NN', 'NNP', 'NNS', 'NNPS']:
                for chunk in doc.noun_chunks:
                    if prev1 in chunk.text:
                        first = chunk.text
                    if next1 in chunk.text:
                        second = chunk.text
                closed_q_choices = (first, second)
            else:
                closed_q_choices = (prev1, next1)
        else:
            qtype = 'others'

    # re-rank the 20 sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        if qtype == 'who':
            for ent in doc.ents:
                if ent.label_ == 'PERSON':
                    score += 1

        elif qtype == 'when':
            for ent in doc.ents:
                if ent.label_ == 'TIME' or ent.label_ == "DATE":
                    score += 1

        elif qtype == 'where':
            for ent in doc.ents:
                if ent.label_ == 'GPE' or ent.label_ == "LOC":
                    score += 1

        elif qtype in ['LANGUAGE','WORK_OF_ART','EVENT','NORP','FACILITY',
                       'GPE','DATE','TIME','PERCENT','QUANTITY','CARDINAL',
                     'MONEY','PERSON','ORG','LOC']:
            for ent in doc.ents:
                if ent.label_ == qtype:
                    score += 1
                    
        elif qtype == 'NE':
            for ent in doc.ents:
                    score += 1

        elif qtype == 'adj':
            for token in doc:
                if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                    score += 1

        elif qtype == 'verb':
            for token in doc:
                if token.dep_ == 'ROOT':
                    score += 1

        elif qtype == 'closed':
            first = closed_q_choices[0]
            second = closed_q_choices[1]

            score += (first in sent) + (second in sent)

        elif qtype == 'why':
            if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.5 + (scores[id] / max_score * 0.5)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get,default=0)
    sent = raw_docs[index]
    doc = nlp(sent)

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    for token in doc:
        if 'nsubj' in token.dep_:
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_:
            sent_dobj = lemmatize(strip_punctuation(token.text))
            
    # find answer with highest score
    max_score = -1
    answer = ''
    
    if qtype == 'who':
        for np in doc.noun_chunks:
            score = 0
            
            if np in doc.ents:
                for ent in doc.ents:
                    if np.text in ent.text and ent.label_ == 'PERSON':
                            score += 3

            # find NP dependency
            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1

            if np.text.lower() == 'it':
                score = -1
                
            if score > max_score:
                max_score = score
                answer = np.text

    elif qtype == 'when':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'TIME' or ent.label_ == "DATE":
                score += 3
                
            if ent.text not in question:
                score += 1
            
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'where':
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == 'GPE' or ent.label_ == "LOC":
                score += 3

            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text
            
    elif qtype in ['LANGUAGE', 'WORK_OF_ART', 'EVENT', 'NORP', 'FACILITY',
                   'GPE', 'DATE', 'TIME', 'PERCENT', 'QUANTITY', 'CARDINAL',
                   'MONEY', 'PERSON', 'ORG', 'LOC']:
        for ent in doc.ents:
            score = 0
            
            if ent.label_ == qtype:
                score += 3
            
            if ent.text not in question:
                score += 1
                
            if qtype in ['LOC','GPE'] and ent.root.tag_ not in ['NN','NNP','NNS','NNPS']:
                score -= 2
                
            if score > max_score:
                max_score = score
                answer = ent.text
                
#                 if qtype in ['MONEY']:
#                     for token in doc:
#                         if token.text == '$':
#                             answer = '$ ' + answer
                            
                if qtype in ['PERCENT']:
                    if 'percent' in answer:
                        answer = answer[:answer.index('percent')-1]
                            
                if qtype in ['PERCENT','QUANTITY','CARDINAL','MONEY']:
                    tokens = nltk.word_tokenize(answer)
                    i = 0
                    answer = ''
                    while i < len(tokens):
                        if tokens[i].lower() in ['well','about','around','approximately', 'some']:
                            del tokens[i]
                        else:
                            if i+1 < len(tokens) and tokens[i+1] == "'s":
                                answer += tokens[i]
                            else:
                                answer += tokens[i] + ' '
                            i += 1
                    answer = answer.strip()
                    
    elif qtype == 'NE':
        for ent in doc.ents:
            score = 3
            
            if ent.text not in question:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = ent.text

    elif qtype == 'abrv':
        abrv = ''
        qdoc = nlp(question)
        for token in qdoc:
            text = token.text
            if len(text) >= 2 and text.isupper() and text.isalpha():
                abrv = text.lower()

        if abrv == '' and 'stand for' in question:
            tokens = question.lower().split(' ')
            abrv = tokens[tokens.index('stand')-1]

        if abrv != '':
            tokens = nltk.word_tokenize(sent)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    phrase = token.lower()
                    initials = phrase[0]

                    while i+k < len(tokens) and tokens[i+k][0].isupper():
                        phrase = phrase + ' ' + tokens[i+k].lower()
                        initials += tokens[i+k][0].lower()
                        k += 1

                    phrase = phrase.strip()
                    if initials == abrv:
                        answer = phrase

        else:
            tokens = nltk.word_tokenize(question)
            for (i, token) in enumerate(tokens):
                if token[0].isupper():
                    k = 1
                    initials = token[0].lower()

                    while i + k < len(tokens) and tokens[i + k][0].isupper():
                        initials += tokens[i + k][0].lower()
                        k += 1

                    if len(initials) >= 2:
                        answer = initials

    elif qtype == 'adj':
        for token in doc:
            score = 0
            
            if 'advmod' in token.dep_ or 'acomp' in token.dep_:
                score += 3

            token_dep = token.dep_
            token_head = lemmatize(strip_punctuation(token.head.text))
            token_head_dep = token.head.dep_

            if token_dep == dep:
                score += 1
            if token_head == head:
                score += 1
            if token_head_dep == head_dep:
                score += 1

            if token.text not in question:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if token.text.lower() == 'it':
                score = -1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'verb':
        for token in doc:
            score = 0

            if token.dep_ == 'ROOT':
                score += 1

            if lemmatize(strip_punctuation(token.text)) not in \
                    [lemmatize(strip_punctuation(s)) for s in nltk.word_tokenize(question)]:
                score += 1

            if strip_punctuation(token.text).strip().lower() not in stop:
                score += 1

            if score > max_score:
                max_score = score
                answer = token.text

    elif qtype == 'closed':
        first = closed_q_choices[0]
        second = closed_q_choices[1]

        # whether each option appears (and is negates)
        appear1 = False
        appear2 = False
        negate1 = False
        negate2 = False
        neg_count = 0
        tokens = nltk.word_tokenize(raw_docs[id])

        for (index, token) in enumerate(tokens):
            if token == 'not' or "n't" in token:
                neg_count += 1

                if index+1 < len(tokens):
                    if tokens[index+1] == first:
                        negate1 = True
                    if tokens[index+1] == second:
                        negate2 = True

            if token == first:
                appear1 = True
            if token == second:
                appear2 = True

        possible_answer = ''
        if appear1 and not appear2:
            if neg_count % 2 == 1:
                possible_answer = second
            else:
                possible_answer = first

        elif appear2 and not appear1:
            if neg_count % 2 == 0:
                possible_answer = second
            else:
                possible_answer = first

        elif appear1 and appear2:
            if negate1 and not negate2:
                possible_answer = second
            elif negate2 and not negate1:
                possible_answer = first
            else:
                possible_answer = second

        if possible_answer != '':
            score += 5
            if score > max_score:
                max_score = score
                answer = possible_answer

    elif qtype == 'why':

        possible_answer = ''
        score = 0

        if 'reason' in sent or 'because' in sent or 'due to' in sent or 'since' in sent or 'for' in sent:

            if 'because of' in sent:
                score += 3
                index = sent.index('because of')
                substr = sent[index+11:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break

            elif 'because' in sent:
                score += 3
                index = sent.index('because')
                substr = sent[index + 8:]
                possible_answer = substr

            elif 'due to' in sent:
                score += 3
                index = sent.index('due to')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'reason' in sent:
                score += 2
                index = sent.index('reason')
                substr = sent[index+7:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    index = substr.find('is')
                    if index != -1:
                        possible_answer = substr[index+3]
                    else:
                        index = substr.find('was')
                        if index != -1:
                            possible_answer = substr[index+4]
                        else:
                            possible_answer = sent[sent.index('reason'):]

            elif 'for' in sent:
                score += 1
                index = sent.index('for')
                substr = sent[index + 4:]
                span = nlp(substr)
                for chunk in span.noun_chunks:
                    possible_answer = chunk.text
                    break
                if possible_answer == '':
                    possible_answer = substr

            elif 'since' in sent:
                score += 1
                index = sent.index('since')
                substr = sent[index + 6:]
                possible_answer = substr

            if possible_answer != '' and score > max_score:
                answer = possible_answer
                max_score = score

    # if answer not found, find noun phrases
    if answer == '':
        for np in doc.noun_chunks:
            score = 0

            np_dep = np.root.dep_
            np_head = lemmatize(strip_punctuation(np.root.head.text))
            np_head_dep = np.root.head.dep_

            if np_dep == dep:
                score += 1
            if np_head == head:
                score += 1
            if np_head_dep == head_dep:
                score += 1

            if np.text not in question:
                score += 1

            if strip_punctuation(np.text).strip().lower() not in stop:
                score += 1
                
            if score > max_score:
                max_score = score
                answer = np.text
                
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    if correct_answer != answer.strip().lower():
        print('Support: ',sent)
        print(question)
        print('Correct: ',correct_answer)
        print('predicted: ',answer)
        print('\n')

    case_count += 1
    if answer == '':
        empty_count += 1
    
csvFile.close()
print(empty_count)
# Out:
# Support:  A change of several tens of micrograms in one kilogram is equivalent to the current uncertainty in the value of the Planck constant in SI units.
# A kilogram could be definined as having a Planck constant of what value?
# Correct:  6966662606895999999♠6.62606896×10−34 j⋅s
# predicted:  several tens
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# What is the shape of the object that establishes the base unit of the kilogram?
# Correct:  cylinder
# predicted:  Planck constant
#
#
# Support:  In modern terms, if J is the total angular momentum of a system with rotational invariance, and Jz the angular momentum measured along any given direction, these quantities can only take on the values where the uncertainty is given as the standard deviation of the measured value from its expected value.
# What example is given as another paired relationship of uncertainly related to standard deviation?
# Correct:  time vs. energy
# predicted:  modern terms
#
#
# Support:  It is defined in terms of the reduced Planck constant, the elementary charge and the electron mass, all of which depend on the Planck constant: the final dependence on h1/2 (r2 > 0.995) can be found by expanding the variables.
# What does the Planck Constant refer to?
# Correct:  quantum of action
# predicted:  r2
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# What scientist first studied black body radiation?
# Correct:  kirchhoff
# predicted:  Max Planck
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# Who helped to give the correct quantization rules for electrons in 1926?
# Correct:  schrödinger
# predicted:  energy
#
#
# Support:  Classical statistical mechanics requires the existence of h (but does not define its value).
# What is required to exist in classical statistics mechanics?
# Correct:  h
# predicted:  Classical statistical mechanics
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# How much energy is contained in the light to which human eyes are most sensitive?
# Correct:  7005216000000000000♠216 kj/mol
# predicted:  555
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# What is frequency also known as in science?
# Correct:  f
# predicted:  colour
#
#
# Support:  It was first observed by Alexandre Edmond Becquerel in 1839, although credit is usually reserved for Heinrich Hertz, who published the first thorough investigation in 1887.
# Who published the first thorough investigation of the photoelectric effect?
# Correct:  heinrich hertz
# predicted:  Alexandre Edmond Becquerel
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# What is the term used when photoelectrons act virtually at the same time?
# Correct:  multiphoton effect
# predicted:  kinetic energy
#
#
# Support:  The Bohr magneton and the nuclear magneton are units which are used to describe the magnetic properties of the electron and atomic nuclei respectively.
# What is the unit of magentic properties of atomic nuclei?
# Correct:  nuclear magneton
# predicted:  Bohr magneton
#
#
# Support:  In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.
# Who discovered an association between the value E and quantum energy?
# Correct:  einstein
# predicted:  minimal energy increment
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# At about what wavelength of light are human eyes most sensitive?
# Correct:  555 nanometres
# predicted:  example
#
#
# Support:  The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.
# What is required for the electromagnetic field to come to thermal equilibrium?
# Correct:  hot atoms
# predicted:  electromagnetic field
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# Who received the Nobel Prize in 1921 for his work on the photoelectric effect?
# Correct:  einstein
# predicted:  Robert Andrews Millikan
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# What assumption that black-body radiation is what leads to an accurate prediction?
# Correct:  thermal
# predicted:  total amount
#
#
# Support:  That is a very small amount of energy in terms of everyday experience, but everyday experience is not concerned with individual photons any more than with individual atoms or molecules.
# What term describes a small amount of element?
# Correct:  quantum
# predicted:  very small amount
#
#
# Support:  In many cases, such as for monochromatic light or for atoms, this quantum of action also implies that only certain energy levels are allowed, and values in between are forbidden.
# Regarding atoms, what are values in between certain energy levels considered by the Planck constant?
# Correct:  forbidden
# predicted:  quantum
#
#
# Support:  Equivalently, the smallness of the Planck constant reflects the fact that everyday objects and systems are made of a large number of particles.
# What are common things like furniture and stationary objects actually made of?
# Correct:  particles
# predicted:  smallness
#
#
# Support:  Prior to Einstein's paper, electromagnetic radiation such as visible light was considered to behave as a wave: hence the use of the terms "frequency" and "wavelength" to characterise different types of radiation.
# Before Einstein, electromagnetic radiation was considered to behave as what?
# Correct:  a wave
# predicted:  visible light
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# What color of light is the human eye most sensitive to?
# Correct:  green
# predicted:  example
#
#
# Support:  The black-body problem was revisited in 1905, when Rayleigh and Jeans (on the one hand) and Einstein (on the other hand) independently proved that classical electromagnetism could never account for the observed spectrum.
# Einstein and what other two individuals revisited the black-body problem in 1905?
# Correct:  rayleigh and jeans
# predicted:  Jeans
#
#
# Support:  Instead, it must be some multiple of a very small quantity, the "quantum of action", now called the Planck constant.
# Which scientist associated the Planck constant with a quantum five years after Planck's recognition?
# Correct:  einstein
# predicted:  multiple
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# What is the frequency of the light to which the human eye is most sensitive?
# Correct:  7014540000000000000♠540 thz
# predicted:  example
#
#
# Support:  These proofs are commonly known as the "ultraviolet catastrophe", a name coined by Paul Ehrenfest in 1911.
# What name did Paul Ehrenfest give to the proofs from Einstein and Rayleigh & Jeans?
# Correct:  the `` ultraviolet catastrophe ''
# predicted:  1911
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# What measurement is deemed most important to redefine in terms of physical constants?
# Correct:  the kilogram
# predicted:  Planck constant
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# What is the energy transferred by a wave in a given time called?
# Correct:  intensity
# predicted:  energy
#
#
# Support:  In addition, there are two methods of measuring the value, a "low-field" method and a "high-field" method, and the conversion factors are different in the two cases.
# What method was was used to obtain the measurement?
# Correct:  watt-balance measurement
# predicted:  addition
#
#
# Support:  The Planck constant is a leading contender to form the basis of the new definition, although not the only one.
# Using Planck constant values from these effects would lead to what logical issue?
# Correct:  a circular argument
# predicted:  new definition
#
#
# Support:  Possible new definitions include "the mass of a body at rest whose equivalent energy equals the energy of photons whose frequencies sum to 7050135639273999999♠135639274×1042 Hz", or simply "the kilogram is defined so that the Planck constant equals 6966662606895999999♠6.62606896×10−34 J⋅s".
# The mass of a resting body with what energy would be equal to a kilogram?
# Correct:  7050135639273999999♠135639274×1042 hz
# predicted:  body
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# What does the kinetic energy of a photoelectron depend on?
# Correct:  the frequency
# predicted:  kinetic energy
#
#
# Support:  It was eventually called the photon.
# What was later termed the photon?
# Correct:  the light quantum
# predicted:
#
#
# Support:  The X-ray crystal density method is primarily a method for determining the Avogadro constant NA but as the Avogadro constant is related to the Planck constant it also determines a value for h. The principle behind the method is to determine NA as the ratio between the volume of the unit cell of a crystal, measured by X-ray crystallography, and the molar volume of the substance.
# What element is used typically to establish Avogadro's constant?
# Correct:  crystals of silicon
# predicted:  X-ray crystal density method
#
#
# Support:  There are a number of other such pairs of physically measurable values which obey a similar rule.
#  What measurable value obeys a similar rule of angular momentum?
# Correct:  time vs. energy
# predicted:  number
#
#
# Support:  Other waves, such as sound or the waves crashing against a seafront, also have their own intensity.
# What other types of wave besides light has its own intensity?
# Correct:  sound
# predicted:  waves
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# What do scientists assume black body radiation is?
# Correct:  thermal
# predicted:  Max Planck
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# What frequency does green light with a wavelength of 555 nanmetres have?
# Correct:  7014540000000000000♠540 thz
# predicted:  example
#
#
# Support:  The either-or nature of uncertainty forces measurement attempts to choose between trade offs, and given that they are quanta, the trade offs often take the form of either-or (as in Fourier analysis), rather than the compromises and gray areas of time series analysis.
# What type of analysis fits the either-or nature of the uncertainty?
# Correct:  fourier analysis
# predicted:  uncertainty forces measurement
#
#
# Support:  Eventually, following upon Planck's discovery, it was recognized that physical action cannot take on an arbitrary value.
# After Planck's findings, what was determined could not take on an arbitrary value?
# Correct:  physical action
# predicted:  Planck
#
#
# Support:  The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.
# Electromagnetic fields obey what laws?
# Correct:  laws of motion
# predicted:  electromagnetic field
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# Which light wavelength is the human eye most sensitive to?
# Correct:  555 nanometres
# predicted:  example
#
#
# Support:  They contributed greatly (along with Einstein's work on the photoelectric effect) to convincing physicists that Planck's postulate of quantized energy levels was more than a mere mathematical formalism.
# Einstein's photoelectric effect work was rewards as opposed to his work on what other topic?
# Correct:  relativity
# predicted:  photoelectric effect
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# What is the reduced Planck constant also known as?
# Correct:  the quantity
# predicted:  Bohr
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# What type of radiation was Planck studying in the late 19th century?
# Correct:  black-body
# predicted:  last years of the nineteenth century
#
#
# Support:  To make Planck's law, which correctly predicts blackbody emissions, it was necessary to multiply the classical expression by a complex factor that involves h in both the numerator and the denominator.
# In making Planck's law, what was in both the numerator and denominator of the formula that was used?
# Correct:  h
# predicted:
#
#
# Support:  It is defined in terms of the reduced Planck constant, the elementary charge and the electron mass, all of which depend on the Planck constant: the final dependence on h1/2 (r2 > 0.995) can be found by expanding the variables.
# What is the Planck constant formerly known as?
# Correct:  quantum of action
# predicted:  r2
#
#
# Support:  The result is that green light of wavelength 555 nm has an energy of 7005216000000000000♠216 kJ/mol, a typical energy of everyday life.
# How much energy does a green light of wavelength 555 nm contain?
# Correct:  7005216000000000000♠216 kj/mol
# predicted:  7005216000000000000
#
#
# Support:  It is defined in terms of the reduced Planck constant, the elementary charge and the electron mass, all of which depend on the Planck constant: the final dependence on h1/2 (r2 > 0.995) can be found by expanding the variables.
# Who introduced the reduced Planck constant?
# Correct:  bohr
# predicted:  h1/2
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# What scientist used matrix mechanics to bring electron behavior in line with the Bohr model?
# Correct:  heisenberg
# predicted:  electrons
# Support:  The Rayleigh–Jeans law makes close predictions for a narrow range of values at one limit of temperatures, but the results diverge more and more strongly as temperatures increase.
# What rule predicted narrow range of energy values at lower temperatures?
# Correct:  the rayleigh–jeans
# predicted:  Rayleigh–Jeans law
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# What alloy is the base unit of the kilogram made from?
# Correct:  platinum–iridium
# predicted:  Planck constant
#
#
# Support:  If the object is black, meaning it absorbs all the light that hits it, then its thermal light emission is maximized.
# What is maximized as a result of a black object absorbing all the light that hits it?
# Correct:  thermal light emission
# predicted:  object
#
#
# Support:  An amount of light compatible with everyday experience is the energy of one mole of photons; its energy can be computed by multiplying the photon energy by the Avogadro constant, NA ≈ 7023602200000000000♠6.022×1023 mol−1.
# What is the energy of a photon?
# Correct:  6981358000000000000♠3.58×10−19 j
# predicted:  amount
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# What color is hotter than "red hot"?
# Correct:  white hot
# predicted:  colour
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# Planck studied what problem posed originally by Kirchhoff?
# Correct:  black-body radiation
# predicted:  last years
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# What is the name for the amount of energy transfered by a wave in a given time?
# Correct:  intensity
# predicted:  energy
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# Einstein's paper on the photoelectric effect earned him the Nobel Prize in what year?
# Correct:  1921
# predicted:  1905
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# Who helped to give the correct quantization rules for electrons in 1925?
# Correct:  heisenberg
# predicted:  energy
#
#
# Support:  However, the energy account of the photoelectric effect didn't seem to agree with the wave description of light.
# What portion of the photoelectric effect was in disagreement with the believed description of light behavior?
# Correct:  the energy account
# predicted:  energy account
#
#
# Support:  The hot object in equilibrium with light absorbs just as much light as it emits.
# What law describes the changes in light emitted by a hot object?
# Correct:  stefan–boltzmann law
# predicted:  hot object
#
#
# Support:  Prior to Einstein's paper, electromagnetic radiation such as visible light was considered to behave as a wave: hence the use of the terms "frequency" and "wavelength" to characterise different types of radiation.
# Prior to Einstein's work, light behavior was modeled as what?
# Correct:  a wave
# predicted:  visible light
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# How many years prior to Planck's study had the scientific community first discussed black body radiation?
# Correct:  forty
# predicted:  First
#
#
# Support:  The hot object in equilibrium with light absorbs just as much light as it emits.
# What does a hot object in equilibrium absorb as much as it emits?
# Correct:  light
# predicted:  hot object
#
#
# Support:  It is well known that hot objects glow, and that hotter objects glow brighter than cooler ones.
# Cooler objects glow less than objects that are what?
# Correct:  hotter
# predicted:
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# What kind of prediction does the assumption that black body radiation is thermal lead to?
# Correct:  accurate
# predicted:  assumption
#
#
# Support:  The CODATA value quoted here is based on three watt-balance measurements of KJ2RK and one inter-laboratory determination of the molar volume of silicon, but is mostly determined by a 2007 watt-balance measurement made at the U.S. National Institute of Standards and Technology (NIST).
# One other measure involved the molar volume of what element?
# Correct:  silicon
# predicted:  three watt
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# What rule predicts that emitted energy increases with temperature?
# Correct:  the stefan–boltzmann law
# predicted:  Stefan
#
#
# Support:  Global wind power installations increased by 35,800 MW in 2010, bringing total installed capacity up to 194,400 MW, a 22.5% increase on the 158,700 MW installed at the end of 2009.
# Global wind power installations increased by how much in 2010?
# Correct:  35,800 mw
# predicted:  35,800
#
#
# Support:  According to a 2011 projection by the International Energy Agency, solar power plants may produce most of the world's electricity within 50 years, significantly reducing the emissions of greenhouse gases that harm the environment.
# Which group projected that solar plant may produce most of the world's electricity within 50 years?
# Correct:  international energy agency
# predicted:  2011 projection
#
#
# Support:  The company ceased all business activity, filed for Chapter 11 bankruptcy, and laid-off nearly all of its employees in early September 2011.
# What company filed for Chapter 11 bankruptcy?
# Correct:  solyndra
# predicted:  early September 2011
#
#
# Support:  The incentive to use 100% renewable energy, for electricity, transport, or even total primary energy supply globally, has been motivated by global warming and other ecological as well as economic concerns.
# What motivated the incentive to use 100 percent renewable energy?
# Correct:  global warming
# predicted:  100 %
#
#
# Support:  In 2011, additions included 41 gigawatt (GW) of new wind power capacity, 30 GW of PV, 25 GW of hydro-electricity, 6 GW of biomass, 0.5 GW of CSP, and 0.1 GW of geothermal power.
# How many hydroelectricity plants are larger than 10 GW?
# Correct:  three
# predicted:  41
#
#
# Support:  Jacobson says that energy costs with a wind, solar, water system should be similar to today's energy costs.
# Who stated that energy costs with a wind, solar, water system should be similar to today's energy costs?
# Correct:  mark z. jacobson
# predicted:  Jacobson
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# Photovoltaic and solar-thermal plants may meet how much of the world's energy needs by 2060?
# Correct:  half
# predicted:  2060 – and half
#
#
# Support:  Solar thermal power stations include the 354 megawatt (MW) Solar Energy Generating Systems power plant in the USA, Solnova Solar Power Station (Spain, 150 MW), Andasol solar power station (Spain, 100 MW), Nevada Solar One (USA, 64 MW), PS20 solar power tower (Spain, 20 MW), and the PS10 solar power tower (Spain, 11 MW).
# Where is the PS20 solar power tower located?
# Correct:  spain
# predicted:  USA
#
#
# Support:  Solar electricity consumption increased by 58 percent, to 93 terawatt-hours (TWh).
# In 2012, solar electricity consumption increased by what percentage?
# Correct:  58 percent
# predicted:  58
# Support:  Use of wind power in 2012 increased by 18.1 percent, to 521.3 TWh.
# Use of wind power in 2012 increased by what percentage?
# Correct:  18.1 percent
# predicted:  18.1
#
#
# Support:  Based on REN21's 2014 report, renewables contributed 19 percent to our energy consumption and 22 percent to our electricity generation in 2012 and 2013, respectively.
# Renewables contributed what percentage to our electricity generation?
# Correct:  22 percent
# predicted:  19
#
#
# Support:  The group is to be co-chaired by Kandeh Yumkella, the chair of UN Energy and director general of the UN Industrial Development Organisation, and Charles Holliday, chairman of Bank of America".
# Who was the UN under-secretary in 2011?
# Correct:  achim steiner
# predicted:  Kandeh Yumkella
#
#
# Support:  In 2011, UN under-secretary general Achim Steiner said: "The continuing growth in this core segment of the green economy is not happening by chance.
# Who is Achim Steiner?
# Correct:  un under-secretary general
# predicted:  UN under-secretary general Achim Steiner
#
#
# Support:  It involves lowering income taxes while raising levies on environmentally destructive activities, in order to create a more responsive market.
# What involves lowering income taxes while raising levies?
# Correct:  tax shifting
# predicted:  environmentally destructive activities
#
#
# Support:  Other developed countries with defined national or regional targets include Australia, Canada, Israel, Japan, Korea, New Zealand, Norway, Singapore, Switzerland, and some US States.
# Name one outher country with defined national or regional target?
# Correct:  australia
# predicted:  developed countries
#
#
# Support:  Barriers to implementing the renewable energy plan are seen to be "primarily social and political, not technological or economic".
# What is a barrier to implementing the renewable energy plan?
# Correct:  social and political
# predicted:  Barriers
#
#
# Support:  The California Valley Solar Ranch (CVSR) is a 250 megawatt (MW) solar photovoltaic power plant, which is being built by SunPower in the Carrizo Plain, northeast of California Valley.
# Who is building The Califoria Valley Solar Ranch?
# Correct:  sunpower
# predicted:  California Valley Solar Ranch
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by what year?
# Correct:  2060
# predicted:  2060 – and half
#
#
# Support:  Nearly all the gasoline sold in the United States today is mixed with 10 percent ethanol, a mix known as E10, and motor vehicle manufacturers already produce vehicles designed to run on much higher ethanol blends.
# Nearly all gasoline sold in the U.S. is mixed with what percentage of ethanol?
# Correct:  10 percent
# predicted:  10
#
#
# Support:  It is the most widely used form of renewable energy, accounting for 16 percent of global electricity generation – 3,427 terawatt-hours of electricity production in 2010, and is expected to increase about 3.1% each year for the next 25 years.
# Hydroelectricity accounts for what percentage of global electricity generation?
# Correct:  hydroelectricity
# predicted:  16
#
#
# Support:  Ford, DaimlerChrysler, and GM are among the automobile companies that sell flexible-fuel cars, trucks, and minivans that can use gasoline and ethanol blends ranging from pure gasoline up to 85% ethanol (E85).
# Name one company that sells flexible-fuel cars?
# Correct:  gm
# predicted:  Ford
#
#
# Support:  Geothermal power capacity grew from around 1 GW in 1975 to almost 10 GW in 2008.
# What was the geothermal capacity in 2008?
# Correct:  10 gw
# predicted:  Geothermal power capacity
#
#
# Support:  Based on REN21's 2014 report, renewables contributed 19 percent to our energy consumption and 22 percent to our electricity generation in 2012 and 2013, respectively.
# Renewables contributed what percentage to our energy consumption?
# Correct:  19 percent
# predicted:  19
#
#
# Support:  In terms of specific examples, the Internet was the result of publicly funded links among computers in government laboratories and research institutes.
# What was the result of publicly funded links among computers in government labs and reserach institutes?
# Correct:  the internet
# predicted:  terms
#
#
# Support:  As of 2011[update], there have been substantial reductions in the cost of solar and wind technologies: Renewable energy is also the most economic solution for new grid-connected capacity in areas with good resources.
# As of what year have there been substantial reductions in the cost of solar and wind technologies?
# Correct:  2011
# predicted:  solar and wind technologies
#
#
# Support:  The 370 MW Ivanpah Solar Power Facility, located in California's Mojave Desert, is the world's largest solar-thermal power plant project currently under construction.
# Where is the Ivanpah Solar Power Facility located?
# Correct:  california 's mojave desert
# predicted:  California
#
#
# Support:  The PV industry has seen drops in module prices since 2008.
# The PV industry has seen drops in module prices since what year?
# Correct:  2008
# predicted:  since 2008
#
#
# Support:  As of 2012, renewable energy accounts for about half of new nameplate electrical capacity installed and costs are continuing to fall.
# As of 2012, what accounts for about half of new nameplate electrical capacity?
# Correct:  renewable energy
# predicted:  renewable energy accounts
#
#
# Support:  It is the most widely used form of renewable energy, accounting for 16 percent of global electricity generation – 3,427 terawatt-hours of electricity production in 2010, and is expected to increase about 3.1% each year for the next 25 years.
# What is the most widely used form of renewable energy?
# Correct:  hydroelectricity
# predicted:  16 percent
#
#
# Support:  Wind power accounts for approximately 19% of electricity generated in Denmark, 9% in Spain and Portugal, and 6% in Germany and the Republic of Ireland.
# In Spain, wind power accounts for what percentage of electricity generated?
# Correct:  9 %
# predicted:  19 %
#
#
# Support:  United Nations' Secretary-General Ban Ki-moon has said that "renewable energy has the ability to lift the poorest nations to new levels of prosperity".
# Ban Ki-moon states that renewable energy has the ability to lift the poorest nations to new levels of prosperity?
# Correct:  renewable energy
# predicted:  United Nations' Secretary-General Ban Ki-moon
#
#
# Support:  In some countries, geothermal power accounts for a significant share of the total electricity supply, such as in the Philippines, where geothermal represented 17 percent of the total power mix at the end of 2008.
# In the Phillipines, geothermal represented what percentage of the total power mix at the end of 2008?
# Correct:  17 percent
# predicted:  17
#
#
# Support:  According to the directive the EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed and therefore a "guarantee of origin" must be issued (article 15).
# What states that EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed?
# Correct:  res directive
# predicted:  directive
#
#
# Support:  Innovation has helped, but the main driver of reduced costs has been market expansion.
# What is the main driver of reduced costs?
# Correct:  market expansion
# predicted:  Innovation
#
#
# Support:  Geothermal power capacity grew from around 1 GW in 1975 to almost 10 GW in 2008.
# What was the geothermal capacity in 1975?
# Correct:  1 gw
# predicted:  Geothermal power capacity
#
#
# Support:  A 2011 IEA report said: "A portfolio of renewable energy technologies is becoming cost-competitive in an increasingly broad range of circumstances, in some cases providing investment opportunities without the need for specific economic support," and added that "cost reductions in critical technologies, such as wind and solar, are set to continue."
# What group stated that "cost reductions in critical technologies, such as wind and solar, are set to continue?"
# Correct:  iea
# predicted:  2011 IEA report
#
#
# Support:  As of 2011[update], there have been substantial reductions in the cost of solar and wind technologies: Renewable energy is also the most economic solution for new grid-connected capacity in areas with good resources.
# What is the most economic solution for new grid-connected capacity in areas with good resources?
# Correct:  renewable energy
# predicted:  substantial reductions
# Support:  As of July 2012, the largest photovoltaic (PV) power plants in the world are the Agua Caliente Solar Project (USA, 247 MW), Charanka Solar Park (India, 214 MW), Golmud Solar Park (China, 200 MW), Perovo Solar Park (Russia 100 MW), Sarnia Photovoltaic Power Plant (Canada, 97 MW), Brandenburg-Briest Solarpark (Germany 91 MW), Solarpark Finow Tower (Germany 84.7 MW), Montalto di Castro Photovoltaic Power Station (Italy, 84.2 MW), Eggebek Solar Park (Germany 83.6 MW), Senftenberg Solarpark (Germany 82 MW), Finsterwalde Solar Park (Germany, 80.7 MW), Okhotnykovo Solar Park (Russia, 80 MW), Lopburi Solar Farm (Thailand 73.16 MW), Rovigo Photovoltaic Power Plant (Italy, 72 MW), and the Lieberose Photovoltaic Park (Germany, 71.8 MW).
# Where is the Agua Caliente Solar Project located?
# Correct:  usa
# predicted:  India
#
#
# Support:  The group is to be co-chaired by Kandeh Yumkella, the chair of UN Energy and director general of the UN Industrial Development Organisation, and Charles Holliday, chairman of Bank of America".
# Who is chairman of Bank of America?
# Correct:  charles holliday
# predicted:  Kandeh Yumkella
#
#
# Support:  Spielberg prefers working with production members with whom he has developed an existing working relationship.
# What show did Spielberg work with Rodat on?
# Correct:  falling skies
# predicted:  production members
#
#
# Support:  Spielberg stated he made Indiana Jones a Boy Scout in honor of his experience in Scouting.
# When did Spielberg join the Boy Scouts?
# Correct:  1958
# predicted:  Indiana Jones
#
#
# Support:  The archaeologist and adventurer hero Indiana Jones was played by Harrison Ford (whom Lucas had previously cast in his Star Wars films as Han Solo).
# Who was responsible for Star Wars?
# Correct:  george lucas
# predicted:  Harrison Ford
#
#
# Support:  It will be filmed in early 2017 for release at the end of that year, before Ready Player One is completed and released in 2018.
# When was 'Men In Black' released?
# Correct:  1997
# predicted:  early 2017
#
#
# Support:  It will be filmed in early 2017 for release at the end of that year, before Ready Player One is completed and released in 2018.
# When was 'The Dig' released?
# Correct:  1995
# predicted:  early 2017
#
#
# Support:  He was later given the opportunity to make a short film for theatrical release, the 26-minute, 35mm, Amblin', which he wrote and directed.
# What short film did Spielberg make for theatrical release?
# Correct:  amblin
# predicted:  opportunity
#
#
# Support:  Studio vice president Sidney Sheinberg was impressed by the film, which had won a number of awards, and offered Spielberg a seven-year directing contract.
# What was Sidney Sheinberg's position with Universal?
# Correct:  vice president
# predicted:  Studio vice president Sidney Sheinberg
#
#
# Support:  It was released just four days after The Adventures of Tintin, on December 25, 2011.
# When was Adventures of Tintin released in the US?
# Correct:  december 21 , 2011
# predicted:  four days
#
#
# Support:  It will be filmed in early 2017 for release at the end of that year, before Ready Player One is completed and released in 2018.
# When was 'Skullmonkeys' released?
# Correct:  1997
# predicted:  early 2017
#
#
# Support:  Studio producers Richard D. Zanuck and David Brown offered Spielberg the director's chair for Jaws, a thriller-horror film based on the Peter Benchley novel about an enormous killer shark.
# What film did Richard D. Zanuck and David Brown offer Steven Spielberg to direct?
# Correct:  jaws
# predicted:  Studio producers
#
#
# Support:  He has also criticized the use of cut scenes in games, calling them intrusive, and feels making story flow naturally into the gameplay is a challenge for future game developers.
# How does Spielberg feel about cutscenes in games?
# Correct:  intrusive
# predicted:  criticized
#
#
# Support:  Spielberg also produced the Don Bluth animated features, An American Tail and The Land Before Time, which were released by Universal Studios.
# Which studios produced Spielberg's 'War of the Worlds'?
# Correct:  paramount and dreamworks
# predicted:  Don Bluth animated features
#
#
# Support:  the Extra-Terrestrial (1982), and Jurassic Park (1993)—achieved box office records, originated and came to epitomize the blockbuster film.
# When did Jurassic Park come out?
# Correct:  1993
# predicted:  1982
#
#
# Support:  His next directorial feature was the Raiders prequel Indiana Jones and the Temple of Doom.
# When did 'Temple of Doom' debut?
# Correct:  1984
# predicted:  Raiders
#
#
# Support:  Despite the film's ultimate, enormous success, it was nearly shut down due to delays and budget over-runs.
# What was the budget for 'Robopocalypse'?
# Correct:  $ 200 million
# predicted:  film's ultimate , enormous success
#
#
# Support:  In 1997, the American Film Institute listed it among the 10 Greatest American Films ever Made (#9) which moved up to (#8) when the list was remade in 2007.
# Where did the American Film Institute rank 'Schindler's List' in 1997?
# Correct:  # 9
# predicted:  10
#
#
# Support:  I made it and got my merit badge.
# When was Spielberg's merit badge launched?
# Correct:  1989
# predicted:  merit badge
#
#
# Support:  In 1987, as China began opening to Western capital investment, Spielberg shot the first American film in Shanghai since the 1930s, an adaptation of J. G. Ballard's autobiographical novel Empire of the Sun, starring John Malkovich and a young Christian Bale.
# Until the 1980s, when had an American film last been shot in Shanghai?
# Correct:  the 1930s
# predicted:  1987
#
#
# Support:  The film was written by E.T.
# Who wrote the music for 'Into the West'?
# Correct:  geoff zanelli
# predicted:  E.T.
#
#
# Support:  Special praise of this film by the influential British critic Dilys Powell was highly significant to Spielberg's career.
# Which British critic praised 'Duel'?
# Correct:  dilys powell
# predicted:  Special praise
#
#
# Support:  Spielberg stated he made Indiana Jones a Boy Scout in honor of his experience in Scouting.
# What was Indy's rank in Boy Scouts when shown in a movie?
# Correct:  life scout
# predicted:  Spielberg
#
#
# Support:  Spielberg also said he suffered from acts of anti-Semitic prejudice and bullying: "In high school, I got smacked and kicked around.
# What kind of prejudice did Spielberg have to deal with in High school?
# Correct:  anti-semitic
# predicted:  acts
#
#
# Support:  For instance, he has cast Richard Dreyfuss in several films: Jaws, Close Encounters of the Third Kind, and Always.
# Who did Spielberg get money from to film Close Encounters?
# Correct:  his father
# predicted:  Richard Dreyfuss
#
#
# Support:  Special praise of this film by the influential British critic Dilys Powell was highly significant to Spielberg's career.
# What British critic helped boost Steven Spielberg's career?
# Correct:  dilys powell
# predicted:  Special praise
#
#
# Support:  This theme is arguably the most autobiographical aspect of Spielberg's films, since Spielberg himself was affected by his parents' divorce as a child and by the absence of his father.
# Which of Spielberg's parents liked sci-fi?
# Correct:  his father
# predicted:  theme
#
#
# Support:  :294 They lived together for four years, but the stresses of their professional careers took a toll on their relationship.
# When did Spielberg and Irving get back together?
# Correct:  1984
# predicted:  four years
#
#
# Support:  It was set for release on April 25, 2014, with Anne Hathaway and Chris Hemsworth set to star, but Spielberg postponed production indefinitely in January 2013, just before it had been set to begin.
# How far in the future was 'Robopocalypse' set?
# Correct:  15–20 years
# predicted:  April 25 , 2014
#
#
# Support:  It was released just four days after The Adventures of Tintin, on December 25, 2011.
# Where did Adventures of Tintin debut?
# Correct:  brussels , belgium
# predicted:  four days
#
#
# Support:  Spielberg was also a co-producer of the 1987 film *batteries not included.
# What was Spielberg's role on 'Batteries Not Included'?
# Correct:  co-producer
# predicted:  co-producer of the 1987 film
#
#
# Support:  It became the biggest film at the box office in 1981, and the recipient of numerous Oscar nominations including Best Director (Spielberg's second nomination) and Best Picture (the second Spielberg film to be nominated for Best Picture).
# How many Oscar nominations did 'Munich' get?
# Correct:  five
# predicted:  1981
#
#
# Support:  The film, based on the novel of the same name written by Michael Morpurgo and published in 1982, follows the long friendship between a British boy and his horse Joey before and during World War I – the novel was also adapted into a hit play in London which is still running there, as well as on Broadway.
# How long was 'Amblin'?
# Correct:  26-minute
# predicted:  1982
# Support:  Spielberg also produced the Don Bluth animated features, An American Tail and The Land Before Time, which were released by Universal Studios.
# Which studio produced 'Super 8'?
# Correct:  paramount pictures
# predicted:  Spielberg
#
#
# Support:  It was on this project that Spielberg also met his future wife, actress Kate Capshaw.
# What was Spielberg's future wife's career?
# Correct:  actress
# predicted:  project
#
#
# Support:  For cinematography, Allen Daviau, a childhood friend and cinematographer, shot the early Spielberg film Amblin and most of his films up to Empire of the Sun; Janusz Kamiński who has shot every Spielberg film since Schindler's List (see List of film director and cinematographer collaborations); and the film editor Michael Kahn who has edited every film directed by Spielberg from Close Encounters to Munich (except E.T.
# Which childhood friend worked on Spielberg's films?
# Correct:  allen daviau
# predicted:  cinematography
#
#
# Support:  Spielberg first met actress Amy Irving in 1976 at the suggestion of director Brian De Palma, who knew he was looking for an actress to play in Close Encounters.
# Who introduced Irving to Spielberg?
# Correct:  brian de palma
# predicted:  Amy Irving
#
#
# Support:  The archaeologist and adventurer hero Indiana Jones was played by Harrison Ford (whom Lucas had previously cast in his Star Wars films as Han Solo).
# Who played Indiana Jones's father?
# Correct:  sean connery
# predicted:  Harrison Ford
#
#
# Support:  Drawing from his own experiences in Scouting, Spielberg helped the Boy Scouts of America develop a merit badge in cinematography in order to help promote filmmaking as a marketable skill.
# What Boy Scout merit badge did Spielberg help develop?
# Correct:  cinematography
# predicted:  own experiences
#
#
# Support:  An example of this is his production relationship with Kathleen Kennedy who has served as producer on all his major films from E.T.
# Which film did Kathleen Kennedy first work with Spielberg on?
# Correct:  e.t . the extra-terrestrial
# predicted:  example
#
#
# Support:  The BFG is set to premiere out of competition at the Cannes Film Festival in May 2016, before its wide release in the US on July 1, 2016.
# In what month is Cannes held?
# Correct:  may
# predicted:  May 2016
#
#
# Support:  Schindler's List earned Spielberg his first Academy Award for Best Director (it also won Best Picture).
# What did Spielberg first win Best Director for?
# Correct:  schindler 's list
# predicted:  Schindler's List
#
#
# Support:  It will be filmed in early 2017 for release at the end of that year, before Ready Player One is completed and released in 2018.
# When was 'Bridge of Spies' released?
# Correct:  october 16 , 2015
# predicted:  early 2017
#
#
# Support:  Spielberg next directed the historical drama film Lincoln, starring Daniel Day-Lewis as United States President Abraham Lincoln and Sally Field as Mary Todd Lincoln.
# Who played Mary Todd Lincoln in 'Lincoln'?
# Correct:  sally field
# predicted:  Spielberg
#
#
# Support:  Spielberg's debut full-length feature film was The Sugarland Express, about a married couple who are chased by police as the couple tries to regain custody of their baby.
# How did Steven Spielberg's film "The Sugarland Express" do in the box office?
# Correct:  poorly
# predicted:  debut
#
#
# Support:  I made it and got my merit badge.
# What film did Spielberg make to earn a merit badge?
# Correct:  the last gunfight
# predicted:  merit badge
#
#
# Support:  It will be filmed in early 2017 for release at the end of that year, before Ready Player One is completed and released in 2018.
# When was The Neverhood released?
# Correct:  1996
# predicted:  early 2017
#
#
# Support:  He has been associated with composer John Williams since 1974, who composed music for all save five of Spielberg's feature films.
# What composer has Steven Spielberg been associated with since 1974?
# Correct:  john williams
# predicted:  composer John Williams
#
#
# Support:  In spite of this, Temple of Doom is rated PG by the MPAA, even though it is the darkest and, possibly, most violent Indy film.
# What rating did 'Temple of Doom' receive?
# Correct:  pg
# predicted:  spite
#
#
# Support:  The film was released in North American theaters on December 21, 2011, in Digital 3D and IMAX.
# When will 'The BFG' be in most theaters?
# Correct:  july 1 , 2016
# predicted:  December 21, 2011
#
#
# Support:  Spielberg stated he made Indiana Jones a Boy Scout in honor of his experience in Scouting.
# Who made Spielberg a knight?
# Correct:  jacques chirac
# predicted:  Spielberg
#
#
# Support:  In a career spanning more than four decades, Spielberg's films have covered many themes and genres.
# Who is naive in 'Catch Me if You Can'?
# Correct:  frank
# predicted:  career
#
#
# Support:  Spielberg played many of LucasArts adventure games, including the first Monkey Island games.
# What was the first video game Spielberg played?
# Correct:  pong
# predicted:  LucasArts
#
#
# Support:  It became the biggest film at the box office in 1981, and the recipient of numerous Oscar nominations including Best Director (Spielberg's second nomination) and Best Picture (the second Spielberg film to be nominated for Best Picture).
# How many Oscar nominations did 'Bridge of Spies' get?
# Correct:  six
# predicted:  1981
#
#
# Support:  The film was written by E.T.
# Who wrote 'The BFG'?
# Correct:  roald dahl
# predicted:  E.T.
#
#
# Support:  It is the first non-Pixar film to win the award since the category was first introduced.
# ...
# Correct:  1964
# predicted:  registered Republicans
#
#
# Support:  Prominent theatre companies in Oklahoma include, in the capital city, Oklahoma City Theatre Company, Carpenter Square Theatre, Oklahoma Shakespeare in the Park, and CityRep.
# What is the 2nd-largest company in Oklahoma?
# Correct:  williams companies
# predicted:  Oklahoma City Theatre Company
#
#
# Support:  With 39,000 acres (158 km2), the Tallgrass Prairie Preserve in north-central Oklahoma is the largest protected area of tallgrass prairie in the world and is part of an ecosystem that encompasses only 10 percent of its former land area, once covering 14 states.
# What part of Oklahoma is the Tallgrass Prairie Preserve in?
# Correct:  north-central
# predicted:  39,000 acres
#
#
# Support:  Following the 2000 census, the Oklahoma delegation to the U.S. House of Representatives was reduced from six to five representatives, each serving one congressional district.
# How many US House reps did Oklahoma have before the 2000 census?
# Correct:  six
# predicted:  six to five
#
#
# Support:  More than 12,000 miles (19,000 km) of roads make up the state's major highway skeleton, including state-operated highways, ten turnpikes or major toll roads, and the longest drivable stretch of Route 66 in the nation.
# Oklahoma has the longest drivable stretch of what famous highway?
# Correct:  route 66
# predicted:  than 12,000 miles
#
#
# Support:  Ancestors of the Wichita and Caddo lived in what is now Oklahoma.
# Ancestors of which tribes lived in Oklahoma?
# Correct:  wichita and caddo
# predicted:  Wichita
#
#
# Support:  In terms of traffic, R. L. Jones Jr. (Riverside) Airport in Tulsa is the state's busiest airport, with 335,826 takeoffs and landings in 2008.
# When did France sell Oklahoma's land to the US?
# Correct:  1803
# predicted:  2008
#
#
# Support:  The name was settled upon statehood, Oklahoma Territory and Indian Territory were merged and Indian was dropped from the name.
# What was the Thunder's previous name?
# Correct:  seattle supersonics
# predicted:  Oklahoma Territory
#
#
# Support:  Oklahoma has four primary mountain ranges: the Ouachita Mountains, the Arbuckle Mountains, the Wichita Mountains, and the Ozark Mountains.
# In which direction do the Ozark mountains get higher?
# Correct:  eastward
# predicted:  Oklahoma
#
#
# Support:  This means the state of Oklahoma produces an average of 38,278 degree-holders per completions component (i.e.
# What does Oklahoma mean?
# Correct:  red people
# predicted:  state
#
#
# Support:  Over a twenty-year period ending in 1950, the state saw its only historical decline in population, dropping 6.9 percent as impoverished families migrated out of the state after the Dust Bowl.
# When did the Dust Bowl begin?
# Correct:  1930s
# predicted:  twenty-year
#
#
# Support:  While the state ranked eighth for installed wind energy capacity in 2011, it is at the bottom of states in usage of renewable energy, with 94 percent of its electricity being generated by non-renewable sources in 2009, including 25 percent from coal and 46 percent from natural gas.
# How much of Oklahoma's electricity comes from non-renewable sources?
# Correct:  94 percent
# predicted:  eighth
#
#
# Support:  Oklahoma's judicial branch consists of the Oklahoma Supreme Court, the Oklahoma Court of Criminal Appeals, and 77 District Courts that each serves one county.
# How many district courts does Oklahoma have?
# Correct:  77
# predicted:  one
#
#
# Support:  The state's lowest point is on the Little River near its far southeastern boundary near the town of Idabel, OK, which dips to 289 feet (88 m) above sea level.
# How many feet above sea level is Oklahoma's lowest point?
# Correct:  289
# predicted:  Little River
#
#
# Support:  Mid-summer (July and August) represents a secondary dry season over much of Oklahoma, with long stretches of hot weather with only sporadic thunderstorm activity not uncommon many years.
# Which season is the most dry in Oklahoma?
# Correct:  winter
# predicted:  Mid-summer (July
#
#
# Support:  Oklahoma later became the de facto name for Oklahoma Territory, and it was officially approved in 1890, two years after the area was opened to white settlers.
# When was the name Oklahoma suggested?
# Correct:  1866
# predicted:  1890
#
#
# Support:  With 39,000 acres (158 km2), the Tallgrass Prairie Preserve in north-central Oklahoma is the largest protected area of tallgrass prairie in the world and is part of an ecosystem that encompasses only 10 percent of its former land area, once covering 14 states.
# The Tallgrass Prairie Preserve is the largest protected tallgrass prairie in what area?
# Correct:  the world
# predicted:  39,000 acres
#
#
# Support:  Tulsa eventually became known as the "Oil Capital of the World" for most of the 20th century and oil investments fueled much of the state's early economy.
# What type of investments were important in early Oklahoma?
# Correct:  oil
# predicted:  Tulsa
#
#
# Support:  Following the 2000 census, the Oklahoma delegation to the U.S. House of Representatives was reduced from six to five representatives, each serving one congressional district.
# How many US House reps did Oklahoma have after the 2000 census?
# Correct:  five
# predicted:  six to five
#
#
# Support:  Regular LPGA tournaments are held at Cedar Ridge Country Club in Tulsa, and major championships for the PGA or LPGA have been played at Southern Hills Country Club in Tulsa, Oak Tree Country Club in Oklahoma City, and Cedar Ridge Country Club in Tulsa.
# What kind of tournaments does Cedar Ridge Country Club host?
# Correct:  lpga
# predicted:  Tulsa
#
#
# Support:  With an educational system made up of public school districts and independent private institutions, Oklahoma had 638,817 students enrolled in 1,845 public primary, secondary, and vocational schools in 533 school districts as of 2008[update].
# How many public universities does Oklahoma have?
# Correct:  eleven
# predicted:  638,817
#
#
# Support:  Norman is also host to the Medieval Fair of Norman, which has been held annually since 1976 and was Oklahoma's first medieval fair.
# Where was Oklahoma's first medieval fair?
# Correct:  norman
# predicted:  Oklahoma
#
#
# Support:  The name Oklahoma comes from the Choctaw phrase okla humma, literally meaning red people.
# What language does the name Oklahoma come from?
# Correct:  choctaw
# predicted:  Oklahoma
#
#
# Support:  The state is divided into 77 counties that govern locally, each headed by a three-member council of elected commissioners, a tax assessor, clerk, court clerk, treasurer, and sheriff.
# How many county commissioners does each Oklahoma county have?
# Correct:  three
# predicted:  77
#
#
# Support:  Partial plains interrupted by small, sky island mountain ranges like the Antelope Hills and the Wichita Mountains dot southwestern Oklahoma; transitional prairie and oak savannahs cover the central portion of the state.
# What part of Oklahoma has oak savannahs?
# Correct:  central
# predicted:  Partial plains
#
#
# Support:  As an example, on November 11, 1911, the temperature at Oklahoma City reached 83 °F (28 °C) in the afternoon (the record high for that date), then an Arctic cold front of unprecedented intensity slammed across the state, causing the temperature to crash 66 degrees, down to 17 °F (−8 °C) at midnight (the record low for that date); thus, both the record high and record low for November 11 were set on the same date.
# What was Oklahoma's record high temperature?
# Correct:  120 °f
# predicted:  66 degrees
#
#
# Support:  The Oklahoman, based in Oklahoma City, is the largest newspaper in the state and 54th-largest in the nation by circulation, with a weekday readership of 138,493 and a Sunday readership of 202,690.
# How many people read the Sunday issue of The Oklahoman?
# Correct:  202,690
# predicted:  138,493
#
#
# Support:  Oklahoma i/ˌoʊkləˈhoʊmə/ (Cherokee: Asgaya gigageyi / ᎠᏍᎦᏯ ᎩᎦᎨᏱ; or translated ᎣᎦᎳᎰᎹ (òɡàlàhoma), Pawnee: Uukuhuúwa, Cayuga: Gahnawiyoˀgeh) is a state located in the South Central United States.
# What is the Pawnee name for Oklahoma?
# Correct:  uukuhuúwa
# predicted:  Cherokee
# Support:  In 2010, the state had the nation's third highest number of bridges classified as structurally deficient, with nearly 5,212 bridges in disrepair, including 235 National Highway System Bridges.
# How many national highway bridges in Oklahoma were found to be deficient in 2010?
# Correct:  235
# predicted:  nearly 5,212
#
#
# Support:  In descending order of population, Oklahoma's largest cities in 2010 were: Oklahoma City (579,999, +14.6%), Tulsa (391,906, −0.3%), Norman (110,925, +15.9%), Broken Arrow (98,850, +32.0%), Lawton (96,867, +4.4%), Edmond (81,405, +19.2%), Moore (55,081, +33.9%), Midwest City (54,371, +0.5%), Enid (49,379, +5.0%), and Stillwater (45,688, +17.0%).
# What is Oklahoma's 2nd-largest city?
# Correct:  tulsa
# predicted:  Oklahoma City
#
#
# Support:  Mid-summer (July and August) represents a secondary dry season over much of Oklahoma, with long stretches of hot weather with only sporadic thunderstorm activity not uncommon many years.
# How much of Oklahoma's electricity comes from coal?
# Correct:  25 percent
# predicted:  Mid-summer ( July and August
#
#
# Support:  Fifth is Vietnamese, spoken by 11,330 people, or about 0.4% of the population, many of whom live in the Asia District of Oklahoma City.
# How many counties are in Oklahoma?
# Correct:  77
# predicted:  11,330
#
#
# Support:  Norman is also host to the Medieval Fair of Norman, which has been held annually since 1976 and was Oklahoma's first medieval fair.
# When did the Medieval Fair of Norman begin?
# Correct:  1976
# predicted:  annually
#
#
# Support:  The House passed HCR 1024, which will change the state motto from "Labor Omnia Vincit" to "Oklahoma-In God We Trust!"
# What was Oklahoma's state motto, before the state House bill might change it?
# Correct:  labor omnia vincit
# predicted:  HCR
#
#
# Support:  Other languages include French with 8,258 speakers (0.3%), Chinese with 6,413 (0.2%), Korean with 3,948 (0.1%), Arabic with 3,265 (0.1%), other Asian languages with 3,134 (0.1%), Tagalog with 2,888 (0.1%), Japanese with 2,546 (0.1%), and African languages with 2,546 (0.1%).
# What is Oklahoma's fourth most popular language?
# Correct:  german
# predicted:  Arabic
#
#
# Support:  Oklahoma is the nation's third-largest producer of natural gas, fifth-largest producer of crude oil, and has the second-greatest number of active drilling rigs, and ranks fifth in crude oil reserves.
# How does Oklahoma's crude oil reserves rank among states?
# Correct:  fifth
# predicted:
#
#
# Support:  The semi-arid high plains in the state's northwestern corner harbor few natural forests; the region has a rolling to flat landscape with intermittent canyons and mesa ranges like the Glass Mountains.
# What is an example of a mesa range?
# Correct:  glass mountains
# predicted:  semi-arid high plains
#
#
# Support:  Oklahoma i/ˌoʊkləˈhoʊmə/ (Cherokee: Asgaya gigageyi / ᎠᏍᎦᏯ ᎩᎦᎨᏱ; or translated ᎣᎦᎳᎰᎹ (òɡàlàhoma), Pawnee: Uukuhuúwa, Cayuga: Gahnawiyoˀgeh) is a state located in the South Central United States.
# What is the Cayuga name for Oklahoma?
# Correct:  gahnawiyoˀgeh
# predicted:  Cherokee
#
#
# Support:  Although registered Republicans were a minority in the state until 2015, starting in 1952, Oklahoma has been carried by Republican presidential candidates in all but one election (1964).
# Oklahoma was the only state where which presidential candidate won no counties twice?
# Correct:  barack obama
# predicted:  Oklahoma
#
#
# Support:  Spanning the southern and eastern parts of the United States, the area is known for politically and socially conservative views, even though Oklahoma has more voters registered with the Democratic Party than with any other party.
# What political party has the most members in Oklahoma?
# Correct:  democratic
# predicted:  southern and eastern parts
#
#
# Support:  Oklahoma's centennial celebration was named the top event in the United States for 2007 by the American Bus Association, and consisted of multiple celebrations saving with the 100th anniversary of statehood on November 16, 2007.
# What organization said Oklahoma's centennial was the top event in the US that year?
# Correct:  american bus association
# predicted:  2007
#
#
# Support:  The Oklahoma City Museum of Art contains the most comprehensive collection of glass sculptures by artist Dale Chihuly in the world, and Oklahoma City's National Cowboy and Western Heritage Museum documents the heritage of the American Western frontier.
# What kind of art did Dale Chinuly make?
# Correct:  glass sculptures
# predicted:  Oklahoma City Museum
#
#
# Support:  Oklahoma is located in a humid subtropical region.
# What natural-disaster-based nickname does Oklahoma's region have?
# Correct:  tornado alley
# predicted:  Oklahoma
#
#
# Support:  Fifth is Vietnamese, spoken by 11,330 people, or about 0.4% of the population, many of whom live in the Asia District of Oklahoma City.
# How many people lived in Stillwater in 2010?
# Correct:  45,688
# predicted:  11,330
#
#
# Support:  Describing the Arab Spring (2010- ), sociologist Philip N. Howard quoted an activist's succinct description that organizing the political unrest involved using "Facebook to schedule the protests, Twitter to coordinate, and YouTube to tell the world."
# An activist in the Arab spring said they were using youtube to do what?
# Correct:  tell the world
# predicted:  quoted
#
#
# Support:  Assuming pre-roll advertisements on half of videos, a YouTube partner would earn 0.5 X $7.60 X 55% = $2.09 per 1000 views in 2013.
# What was the highest earning youtube partner video producer?
# Correct:  $ 12 million
# predicted:  pre-roll advertisements
#
#
# Support:  2015 also saw the announcement of a premium YouTube service titled YouTube Red, which provides users with both ad-free content as well as the ability to download videos among other features.
# What was the original title of youtube red?
# Correct:  music key
# predicted:  announcement
#
#
# Support:  In 2014 YouTube said that 300 hours of new videos were uploaded to the site every minute, three times more than one year earlier and that around three quarters of the material comes from outside the U.S.
# How much content on youtube comes from outside the US?
# Correct:  around three quarters
# predicted:  2014
#
#
# Support:  All YouTube users can upload videos up to 15 minutes each in duration.
# As of 2010 what is the maximum length of a video a user can upload given the proper authority?
# Correct:  unlimited
# predicted:  YouTube
#
#
# Support:  According to TubeMogul, in 2013 a pre-roll advertisement on YouTube (one that is shown before the video starts) cost advertisers on average $7.60 per 1000 views.
# What type of videos did youtube officially start supporting in July 2009?
# Correct:  3d
# predicted:  TubeMogul
#
#
# Support:  YouTube has cited the effectiveness of Content ID as one of the reasons why the site's rules were modified in December 2010 to allow some users to upload videos of unlimited length.
# What happened to the sites rules in Dec. 2010?
# Correct:  were modified
# predicted:  YouTube
#
#
# Support:  YouTube relies on its users to flag the content of videos as inappropriate, and a YouTube employee will view a flagged video to determine whether it violates the site's terms of service.
# Youtube depends on who to flag inappropriate videos?
# Correct:  users
# predicted:  YouTube
#
#
# Support:  YouTube Red was originally announced on November 12, 2014, as "Music Key", a subscription music streaming service, and was intended to integrate with and replace the existing Google Play Music "All Access" service.
# When was youtube red originally announced?
# Correct:  november 12 , 2014
# predicted:  November 12, 2014
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-70cfb009fdfb> in <module>()
#     208         else:
#     209             # what...do type question
# --> 210             tokens.remove(next_token)
#     211             if 'do' in tokens:
#     212                 qtype = 'verb'
#
# ValueError: list.remove(x): x not in list
