# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer
import csv
from gensim.summarization import bm25

OPEN_QUESTION_WORDS = ['what', 'who', 'whose', 'whom', 'where', 'when', 'why', 'how',
                       'which', "what's", "who's", "where's", "how's"]
CLOSED_QUESTION_WORDS = ['is', 'are', 'am', 'was', 'were', 'do', 'does,', 'did', 'can',
                         'could', 'will', 'would', 'shall', 'should', 'have', 'has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('testing.json') as json_data:
    test = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)


def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)


def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma


def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += tfs[term]
    return dfs


def query_vsm(query, index, k=10):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'


# length of longest same sequences of keywords
def get_overlap(sent1, sent2):
    tokens1 = []
    tokens2 = []

    for token in nltk.word_tokenize(strip_punctuation(sent1.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens1.append(lemma)

    for token in nltk.word_tokenize(strip_punctuation(sent2.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens2.append(lemma)

    max = 0
    for i in range(len(tokens1)):
        for j in range(len(tokens2)):

            if tokens1[i] == tokens2[j]:
                length = 1

                ii = i + 1
                jj = j + 1
                while ii < len(tokens1) and jj < len(tokens2) and \
                        tokens1[ii] == tokens2[jj]:
                    ii += 1
                    jj += 1
                    length += 1

                if length > max:
                    max = length

    return max


csvFile = open("low.csv", "w")
writer = csv.writer(csvFile)
header = ['id','answer']
writer.writerow(header)

case_count = 0
# test = [test[17]]
for test_case in test:
    question = test_case['question']
    docid = test_case['docid']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)

    # TFIDF
#     doc_term_freqs = {}
#     for (id, raw_doc) in enumerate(raw_docs):
#         term_freqs = extract_term_freqs(raw_doc)
#         doc_term_freqs[id] = term_freqs
#     M = len(doc_term_freqs)

#     doc_freqs = compute_doc_freqs(doc_term_freqs)

#     vsm_inverted_index = defaultdict(list)
#     for docid, term_freqs in doc_term_freqs.items():
#         N = sum(term_freqs.values())
#         length = 0

#         # find tf*idf values and accumulate sum of squares
#         tfidf_values = []
#         for term, count in term_freqs.items():
#             tfidf = float(count) / N * log(M / float(doc_freqs[term]))
#             tfidf_values.append((term, tfidf))
#             length += tfidf ** 2

#         # normalise documents by length and insert into index
#         length = length ** 0.5
#         for term, tfidf in tfidf_values:
#             # inversion of the indexing, term -> (doc_id, score)
#             vsm_inverted_index[term].append([docid, tfidf / length])

#     for term, docids in vsm_inverted_index.items():
#         docids.sort()

#     terms = extract_term_freqs(question)
#     results = query_vsm(terms, vsm_inverted_index)



    tokenized_sentence = []
    for each_sentence in raw_docs:
        filter_stop_word = []
        sentence_as_words = nltk.word_tokenize(each_sentence)
        for each_word in sentence_as_words:
            if each_word not in stop:
                filter_stop_word.append(each_word)
        
        tokenized_sentence.append(filter_stop_word)
        
    bm25Model = bm25.BM25(tokenized_sentence)
    average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
    query = []
    for word in nltk.word_tokenize(question):
        if word not in stop:
            query.append(word)
        
    scores = bm25Model.get_scores(query,average_idf)
    bm25_dic = Counter()
    
    sentence_id = 0
    for each_score in scores:
        bm25_dic[sentence_id] = each_score
        sentence_id += 1
    results = bm25_dic.most_common(3)



    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    target = [] # target dep

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''
    attr = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of question
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            dobj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'attr' and token.head.dep_ == 'ROOT':
            attr = lemmatize(strip_punctuation(token.text))

    # determine answer dependency
    if qword in ['who', "who's", 'whom', 'whose']:
        for chunk in doc.noun_chunks:
            if qword in chunk.text:
                target = [chunk.root.dep_]

    elif qword in ['where', "where's", 'when']:
        target = ['advmod','prep']

    elif qword in ['how', "how's"]:
        if next_token in ['much', 'many','long','far', 'big', 'wide', 'deep', 'tall', 'high', 'fast', 'heavy','old', 'young']:
            target = ['attr']
        
        elif next_token in ['does', 'did', 'do', 'have', 'has', 'had', 'should',
                            'can', 'could', 'will', 'would', 'must']:
            if dobj != '':
                target = ['advmod', 'acomp']
            else:
                target = ['ROOT']

    elif qword in ['what', "what's", 'which']:
        # what...do type question
        tokens.remove(next_token)
        if 'do' in tokens:
            target = ['ROOT']
        else:
            for chunk in doc.noun_chunks:
                if qword in chunk.text:
                    target = [chunk.root.dep_]

    elif qword == 'why':
        target = ['mark','prep']

    elif qword in CLOSED_QUESTION_WORDS:
        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            
            # dep of phrase before and after 'or'
            prev = tokens[index - 1]
            for chunk in doc.noun_chunks:
                if prev in chunk.text:
                    target = [chunk.root.dep_]
            
            if target == []:
                for token in doc:
                    if prev in token.text:
                        target = [token.dep_]

     # re-rank the sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        for token in doc:
            if token.dep_ in target:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.3 + (scores[id] / max_score * 0.7)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get)
    sent = raw_docs[index]
    doc = nlp(sent)
                   
    # find answer with highest score from the highest ranking sentence
    max_score = -1
    answer = ''

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    sent_attr = ''
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_dobj = lemmatize(strip_punctuation(token.text))
        if 'attr' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_attr = lemmatize(strip_punctuation(token.text))

    score = 0
    if nsubj == sent_nsubj:
        score += 1
        if ROOT == sent_ROOT:
            score += 1
            if dobj == sent_dobj:
                score += 1
            if attr == sent_attr:
                score += 1

    max_score = -1
    answer = ''
    if target == ['ROOT'] or target == ['attr'] or target == ['advmod','acomp']:
        for token in doc:
            if token.dep_ in target:
                score += 1

                if token.text not in question:
                    score += 1

                if strip_punctuation(token.text).lower() in stop:
                    score = -1

                if token.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    answer = token.text

    elif target == ['mark','prep'] or target == ['advmod','prep']:
        for token in doc:
            if token.dep_ in target:
                score += 1

                if token.text not in question:
                    score += 1

                if strip_punctuation(token.text).lower() in stop:
                    score = -1

                if token.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    substr = sent[sent.index(token.text):]
                    tokens = nltk.word_tokenize(substr)
                    del tokens[0]
                    for token in tokens:
                        if token in punc:
                            break
                        answer += token+' '

    else:
        for chunk in doc.noun_chunks:
            if chunk.root.dep_ in target:
                score += 1

                if chunk.text not in question:
                    score += 1

                if strip_punctuation(chunk.text).lower() in stop:
                    score = -1

                if chunk.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    answer = chunk.text
        
    # default answer
    if answer == '':
        for chunk in doc.noun_chunks:
            if chunk.text not in stop and chunk.text not in question:
                answer = chunk.text
        
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    answer = answer.strip().lower()
    answer_result = []
    answer_result.append(case_count)
    answer_result.append(answer)
    writer.writerow(answer_result)
    print(case_count,' ',answer)
    case_count += 1
    
csvFile.close()
# Out:
# 0   combination
# 1   capabilities
# 2   process
# 3   mac
# 4   released in september 2008
# 5   95 %
# 6   user
# 7   history
# 8   september
# 9   sir tim berners-lee
# 10   consumer choice
# 11   industry's first browser war
# 12   merely "web browsers
# 13   consumer choice
# 14   browser extensions
# 15   entire browser market
# 16   reduces consumer choice
# 17   local files
# 18   google search
# 19   web browser
# 20   file formats
# 21   reduces consumer choice
# 22   august
# 23   average person
# 24   internet explorer
# 25   form
# 26   used web browser but still had lower usage than all versions of internet explorer combined had lower usage than all versions of internet explorer combined
# 27   started his own company
# 28   open source software model
# 29   40 million phones
# 30   rapid development
# 31   url
# 32   open source software model
# 33   file systems
# 34   95 %
# 35   web browsers
# 36   started his own company
# 37   user interface
# 38   google chrome
# 39   user's consent
# 40   information resources
# 41   feed
# 42   feed
# 43   bookmarks
# 44   released in september 2008
# 45   url
# 46   average person
# 47   intended to use the world wide web be used to access information provided by web servers in private networks or files in file systems
# 48   customers
# 49   customers
# 50   web pages
# 51   users
# 52   user's default newsgroup reader
# 53   web browser
# 54   olympics
# 55   dalai lama
# 56   media
# 57   republic day celebrations
# 58   chinese
# 59   ‘caged woman’
# 60   free media
# 61   chinese
# 62   beijing citizen
# 63   western media bias
# 64   palace square
# 65
# 66   chinese
# 67   olympic flame
# 68   malaysian capital
# 69   ngunnawal people
# 70   lenovo group
# 71   palace square
# 72   very good example
# 73   chinese
# 74   own initiative
# 75   anti-china separatists
# 76   saint petersburg
# 77   large numbers
# 78   april
# 79   french capital
# 80   confusion
# 81   democracy
# 82   april 16
# 83   pro-beijing camp politicians
# 84   pressure from both directions
# 85   olympic games
# 86   funds
# 87   mobile protective ring
# 88   world ’ s worst offenders
# 89   security services
# 90   u.s.-based cable news network ( cnn
# 91   chinese media
# 92   torch
# 93   april
# 94   chinese media
# 95   torch route
# 96   torch
# 97   market
# 98   xinjiang
# 99   kind
# 100   may
# 101   charges
# 102   lake
# 103   chinese
# 104   kind
# 105   ancient olympic games
# 106   olympic torch relay
# 107   beijing citizen
# 108   chinese media
# 109   torchbearers
# 110   costanera sur
# 111   athletes
# 112   interruptions
# 113   assurances
# 114   police
# 115   chinese officials
# 116   olympic controversy
# 117   democracy
# 118   chinese
# 119   chinese
# 120   palace square
# 121   china
# 122   kind
# 123   chinese
# 124   officials
# 125   participation in the olympic cause
# 126   tibetan activists
# 127   stop
# 128   reaction
# 129   closed doors
# 130   may
# 131   april
# 132   aluminum
# 133   chinese
# 134   chief executive donald tsang
# 135   scheduled to be the starting point for the olympic torch relay in nagano
# 136   torch
# 137   chinese
# 138   police
# 139   torchbearers
# 140   april
# 141   may
# 142   pro-tibet demonstrators
# 143   concerns about pro-tibet protests
# 144   onlookers
# 145   august
# 146   torchbearers
# 147   paris
# 148   air
# 149   tensions
# 150   chinese
# 151   torchbearers
# 152   orderly and legal manner
# 153   olympics
# 154   saboteurs
# 155   tax evasion
# 156   chinese
# 157   chinese
# 158   own initiative
# 159   olympics
# 160   1964 tokyo edition
# 161   china
# 162   russia
# 163   konnie huq
# 164   counter-protesters
# 165   chinese
# 166   march
# 167   torch relays
# 168   fmr
# 169   kind
# 170   propaganda stunt
# 171   jackie chan
# 172   sikkimese
# 173   pro-tibet independent camp
# 174   kazakhstan nursultan nazarbaev
# 175   the 2008 summer olympics
# 176   people
# 177   1964 tokyo edition
# 178   stadium
# 179   olympic flame
# 180   jackie chan
# 181   mainland china route
# 182   `` lack
# 183   one dream
# 184   zenkoji monks
# 185   may
# 186   ‘caged woman’
# 187   olympics
# 188   germany
# 189   chinese
# 190   torch relay route
# 191   torch route
# 192   70 runners
# 193   bearers
# 194   regions
# 195   confusion
# 196   olympic torch relay
# 197   china
# 198   chinese
# 199   relay
# 200   thailand
# 201   handful
# 202   wan chai
# 203   anti-japanese protests
# 204   chinese
# 205   chinese
# 206   chinese
# 207   chinese
# 208   taksim square
# 209   china
# 210   route
# 211   tibet
# 212   april
# 213   dalai lama
# 214   taksim square
# 215   chan
# 216   flame
# 217   curtailed 3 km route
# 218   chinese
# 219   may
# 220   darfur
# 221   april
# 222   `` immigration reasons `` and were forced to leave hong kong
# 223   previous relays
# 224   curtailed 3 km route
# 225   novelty inflatable plastic olympic flames
# 226   chan
# 227   blog
# 228   chinese
# 229   games
# 230   chan
# 231   chinese
# 232   march
# 233   sacred torch
# 234   torchbearers
# 235   chinese
# 236   astana square
# 237   market
# 238   funds
# 239   well-coordinated plan to take the day by weight of numbers plan to take the day by weight of numbers
# 240   kazakhstan nursultan nazarbaev
# 241   chinese
# 242   london
# 243   media
# 244   torch
# 245   saint petersburg
# 246   carrefour boycott
# 247   may
# 248   borders organised several symbolic protests scaling the eiffel tower to hang a protest banner from it
# 249   april
# 250   western media coverage
# 251   "lucky cloud
# 252   chan
# 253   torchbearers
# 254   volunteers
# 255   the planned boycott more evident
# 256   city
# 257   april
# 258   mainland china route
# 259   police vehicle `` for their own protection
# 260   lovely city
# 261   relay
# 262   peace
# 263   bearers
# 264   western media bias
# 265   chinese
# 266   strong personal reasons
# 267   west
# 268   chinese
# 269   april
# 270   olympic torch relay
# 271   macau
# 272   ancient links
# 273   torch relay
# 274   comments
# 275   protests
# 276   china's recent crackdown
# 277   orderly and legal manner
# 278   taksim square
# 279   relay
# 280   narisa chakrabongse, green world foundation (gwf) chairwoman
# 281   torchbearers
# 282   paralympic games
# 283   jackie chan
# 284   funds
# 285   chinese
# 286   city
# 287   chinese embassy
# 288   notre dame cathedral
# 289   kind
# 290   police
# 291   china
# 292   costanera sur
# 293   confiscating tibetan flags from demonstrators
# 294   syrian actress sulaf fawakherji
# 295   except on the trocadéro on the trocadéro
# 296   olympics
# 297   8 lanterns
# 298   "one world
# 299   said
# 300   nagano leg
# 301   green party officials
# 302   chinese
# 303   success
# 304   nagano leg
# 305   half-an-hour
# 306   buenos aires
# 307   trocadéro
# 308   china
# 309   china's human rights record
# 310   regions
# 311   global perspective
# 312   orchidbbs.com and cyberctm.com internet forums
# 313   dalai lama
# 314   san francisco
# 315   april
# 316   route
# 317   lovely city
# 318
# 319   casino tycoon stanley ho
# 320   concerns
# 321   chinese
# 322   olympic controversy
# 323   chinese
# 324   april
# 325   1964 tokyo edition
# 326   journey
# 327   ngunnawal people
# 328   2 inches
# 329   chinese
# 330   torch relay
# 331   april 16
# 332   thailand
# 333   kazakhstan nursultan nazarbaev
# 334   supposed to carry the torch around islamabad islamabad to security concerns regarding `` militant threats or anti-china protests ''
# 335   8 lanterns
# 336   security concerns
# 337   april
# 338   chinese
# 339   human rights
# 340   april
# 341   relay
# 342   2,000 and 10,000 chinese supporters
# 343   blog
# 344   april
# 345   "lucky cloud
# 346   olympic flame
# 347   xinhua
# 348   chinese sources
# 349   french capital
# 350   1964 tokyo edition
# 351   8 lanterns
# 352   coverage
# 353   temperaments
# 354   16 to 16,000 hz
# 355   frequency
# 356   number
# 357   specific pitch
# 358   100 cents
# 359   wave
# 360   slower oscillation
# 361   pitch
# 362   frequencies
# 363   musical tuning
# 364   temperaments
# 365   total spectrum
# 366   number
# 367   a880
# 368   instrument
# 369   pitch
# 370   southampton
# 371   nine miles
# 372   600 exhibitors
# 373   single day
# 374   marinas
# 375   city's population
# 376   estimates
# 377   specially developed site
# 378   eastleigh
# 379   services
# 380   pows
# 381   medieval southampton
# 382   midlands
# 383   river test
# 384   medieval southampton
# 385   southampton
# 386   16 wards
# 387   cyclists
# 388   city
# 389   physical bullying
# 390   watermark westquay
# 391   600 exhibitors
# 392   mixed race
# 393   one
# 394   walls
# 395   354 local authorities
# 396   single day
# 397   southampton town
# 398   november
# 399   september
# 400   elections
# 401   600 exhibitors
# 402   city's largest employers
# 403   evidence
# 404   petrochemicals
# 405   westquay park
# 406   hampton
# 407   bath house
# 408   pre-war era
# 409   handsome width
# 410   city
# 411   first purpose-built artillery fortification
# 412   galleries
# 413   melody
# 414   large ships
# 415   uk
# 416   changed to hampshire in 1959 although the county had been commonly known as hampshire or hantscire for centuries
# 417   worst behaved secondary schools
# 418   boys
# 419   sotonians
# 420   south western railway company
# 421   22,000 students
# 422   westquay park
# 423   programme
# 424   contemporary art installations
# 425   england
# 426   programme
# 427   town
# 428   202 crimes
# 429   96.1 °
# 430   aviation
# 431   depth
# 432   city's buildings
# 433   southampton container terminals
# 434   29 june
# 435   new county council
# 436   normandy
# 437   united kingdom
# 438   uk
# 439   city
# 440   city
# 441   area
# 442   flights
# 443   marina
# 444   city
# 445   southampton
# 446   queen mary
# 447   guildhall
# 448   four-year term
# 449   road
# 450   16.2 percent
# 451   southampton water
# 452   southampton
# 453   dates
# 454   provide
# 455   eight years
# 456   hampshire ceremonial county
# 457   tide
# 458   3 july
# 459   professional athletes
# 460   southampton
# 461   local train services
# 462   guildhall
# 463   home to one of the most successful college american football teams in the uk to one of the most successful college american football teams in the uk
# 464   portsmouth
# 465   headquarters
# 466   town
# 467   adult learners
# 468   medieval southampton
# 469   town
# 470   last remains
# 471   city
# 472   pound tree road
# 473   regional economy
# 474   centuries
# 475   354 local authorities
# 476   higher crime rate
# 477   city
# 478   dance music's top acts
# 479   this
# 480   1980s popstar howard jones
# 481   three queens
# 482   wool
# 483   bargate
# 484   running mate
# 485   104 decibels
# 486   last remains
# 487   name
# 488   stations
# 489   luftwaffe bombing raids
# 490   galleries
# 491   western docks and city centre
# 492   spencer
# 493   13th century
# 494   england
# 495
# 496   large ships
# 497   £100m development
# 498   wool
# 499   29 june
# 500   health and education sector
# 501   southampton central
# 502   age range
# 503   council estates
# 504   southampton central railway station
# 505   health and education sector
# 506   high street
# 507   north
# 508   city
# 509   current and 578th sherriff
# 510   health and education sector
# 511   city's primary producing theatre
# 512   portsmouth
# 513   student population
# 514   south korea
# 515   river
# 516
# 517   transit models
# 518   st. denys
# 519   13 june
# 520   plc
# 521   one
# 522   retail park
# 523   physical or verbal assaults
# 524   eastern docks
# 525   web
# 526   1
# 527   southampton
# 528   1960s
# 529   vicinity
# 530   oxford
# 531   16 wards
# 532   plymouth
# 533   industrial revolution
# 534   large ships
# 535   next few decades
# 536   exchange
# 537   pre-war era
# 538   itchen
# 539   populous
# 540   england
# 541   south korea
# 542   government
# 543   centre
# 544   anglo-saxons
# 545   hampshire constabulary
# 546   rms titanic
# 547   one
# 548   castle way
# 549   southampton
# 550   single day
# 551   southampton docks company
# 552   city
# 553   water supply system
# 554   city
# 555   aviation
# 556   pows
# 557   crimean war
# 558   shops
# 559   racing took place at banister court stadium in the pre-war era
# 560   town quay
# 561   southampton and district sunday football league
# 562   close second
# 563   pre-war era
# 564   galleries
# 565   figure
# 566   terminus
# 567   buildings
# 568   aviation
# 569   surviving embankment
# 570   authority
# 571   water supply system
# 572   blue plaque
# 573   castle way
# 574   swedish home products retailer ikea
# 575   uk
# 576   south korea
# 577   2003 fa cup
# 578   city centre
# 579
# 580
# 581   last three years
# 582   103-year-old former stadium
# 583   22,000 students
# 584   several container terminals
# 585   22,267
# 586   time low
# 587   charter
# 588   industrial revolution
# 589   southampton
# 590   city's population
# 591   southampton
# 592   stations
# 593   oxford
# 594   high street
# 595   16 wards
# 596   one
# 597   previously the coast
# 598   different police forces recording methodologies
# 599   total number
# 600   good quality beach
# 601   1992 local government act
# 602   residents
# 603   men's fitness magazine
# 604   one
# 605   1992 local government act
# 606   fortifications
# 607   langstone
# 608   estimated population
# 609   council leisure executives
# 610   space
# 611   adult learners
# 612   linda norris
# 613   passenger services
# 614   mixed race
# 615   town
# 616   large ships
# 617   25+26 hen
# 618   local governance organisational changes
# 619   first dock
# 620   one
# 621   test estuaries
# 622   city centre
# 623   water supply system
# 624   thousands
# 625   fortifications
# 626   london
# 627   town
# 628   southampton
# 629   river
# 630   1
# 631   rivers test
# 632   london
# 633   buildings
# 634   workers
# 635   southampton's ocean village marina
# 636   96.1 °
# 637   monaco
# 638   petrochemicals
# 639   europe
# 640   hampton
# 641   96.1 °
# 642   water supply system
# 643   solent sky
# 644   normandy
# 645   urban area
# 646   last remains
# 647   time low
# 648   city
# 649   11 other additional leisure venures
# 650   single day
# 651   united kingdom
# 652   population
# 653   petrochemicals
# 654   recession
# 655   number
# 656   high street
# 657   portsmouth and gosport areas
# 658   dance music's top acts
# 659   road
# 660   may
# 661   westquay park
# 662   spencer
# 663   22,267
# 664   ponds
# 665   enterprise
# 666   top flight
# 667
# 668   city
# 669   1980s popstar howard jones
# 670   further education college
# 671   city
# 672   köppen cfb
# 673   previously the coast
# 674   strong higher education sector
# 675   boys’ and girls’ teams
# 676   river
# 677   england
# 678   dance music's top acts
# 679   hill lane area
# 680   medieval water supply system
# 681   country
# 682   1930s
# 683   city
# 684   estimated population
# 685   last ice age
# 686   high street
# 687   south korea
# 688   name
# 689   96.1 °
# 690   hampshire constabulary
# 691   southampton and district sunday football league
# 692   bus services
# 693   town
# 694   red funnel
# 695   boys’ and girls’ teams
# 696   industry
# 697   city
# 698   run
# 699   22,000 students
# 700   new county council
# 701   shops
# 702   bath house
# 703   waterfront
# 704   tram system
# 705   river
# 706   henry v's famous warship hms grace dieu
# 707
# 708   st. denys
# 709   numerous private investors
# 710   eastern docks
# 711   town
# 712   hampshire ceremonial county
# 713   february
# 714   117,400 females
# 715   world jewry
# 716   jews
# 717   central europe
# 718   1st and 2nd centuries ce
# 719   present-day belarus
# 720   same ethnic group
# 721   1st and 2nd centuries ce
# 722   high frequencies
# 723   syrian jewish community
# 724   france was wracked by the dreyfus affair in the 1890s
# 725   efforts
# 726   the middle east
# 727   ashkenazi
# 728   central and eastern europe
# 729   levant
# 730   world jewry
# 731   world's jews
# 732   ashkenazi
# 733   40 %
# 734   often
# 735   orleans
# 736   212 ce
# 737   orthodox jews
# 738   german lands
# 739   ashkenazi woman who marries a sephardi or mizrahi man is expected to take on sephardic practice and the children inherit a sephardic identity
# 740   vladimir ashkenazy
# 741   number
# 742   ashkenazi jewish ancestry
# 743   moroccan jew
# 744   assumed geographical source population
# 745   holocaust
# 746   halakhic matters
# 747   secular lives
# 748   artisans
# 749   roman empire
# 750   kabbalah
# 751   1750
# 752   ashkenazi jews
# 753   11th century
# 754   12th century
# 755   12th century
# 756   ashkenazi jews
# 757   therefore 35–36%
# 758   yiddish language
# 759   uses
# 760   eventually eastern europe
# 761   ancient levantine origins
# 762   two distinct jewish populations
# 763   general european population
# 764   canaan
# 765   artisans
# 766   eventually eastern europe
# 767   ashkenazi jew
# 768   yiddish
# 769   pre-christian times
# 770   christianity
# 771   siddur ( prayer book
# 772   present-day belarus
# 773   origin
# 774   ashkenazi origin
# 775   area
# 776   world's jews
# 777   jews
# 778   life-style
# 779   sound
# 780   modern-day italians
# 781   ashkenazi jews
# 782   european genetic substructure
# 783   large number
# 784   minhagim
# 785   ashkenazi jews
# 786
# 787   genetic overlap
# 788   ashkenazi jewish ancestry
# 789   12th century
# 790   halakhic questions
# 791   rescued jews in palestine and carried them back to worms to repay the favor
# 792   yiddish
# 793   implies
# 794   northwestern syria
# 795   canaan
# 796   central europe
# 797   daily life
# 798   invading persians
# 799   invading persians
# 800   local christian rulers
# 801   nations
# 802   east european ashkenazim
# 803   sephardic and mizrahi jews
# 804   percentage
# 805   money lending
# 806   nations
# 807   origin
# 808   levant
# 809   jewishness
# 810   ashkenazi jewish ancestry
# 811   yiddish speakers
# 812   cimmerians
# 813   siddur ( prayer book
# 814   distinct geographic locales
# 815   host community
# 816   canaan
# 817   vladimir ashkenazy
# 818   invading persians
# 819   free peoples
# 820   germany
# 821   lubavitch hasidim
# 822   holocaust
# 823   german lands
# 824   minhagim
# 825   data
# 826   at its exact discovery position in relation to the sun
# 827   neptune,[e
# 828   pluto
# 829   deeper atmospheric processes
# 830   north pole
# 831   french bureau des longitudes
# 832   result
# 833   position
# 834   jupiter
# 835   (נפטון
# 836   upper cloud
# 837   warmer
# 838   methane
# 839   solar system
# 840   sun
# 841   urbain le verrier
# 842   neptune's gravity
# 843   neptune
# 844   late 2020s
# 845   discovery in 1846
# 846   jupiter
# 847   french bureau des longitudes
# 848   2008 lc18
# 849   resonance
# 850   resembles uranus in its magnetosphere
# 851   tropopause layer
# 852   great dark spot
# 853   galileo's small telescope
# 854   moon titan
# 855   opaque cloud deck
# 856   kuiper belt object
# 857   1:1 resonance
# 858   ultraviolet radiation
# 859   data
# 860   planet's rotation
# 861   only spacecraft
# 862   much energy
# 863   largest moon triton
# 864   empirical observation
# 865   25 august
# 866   convincing astronomers
# 867   french bureau des longitudes
# 868   neptune's neighbour uranus
# 869   neptune,[e
# 870   roughly 40 earth years
# 871   temperature
# 872   earth
# 873   2008 lc18
# 874   the equator or possibly through some other unknown mechanism through some other unknown mechanism
# 875   discovery
# 876   mass
# 877   one much less substantial than that of saturn less substantial than that of saturn substantial than that of saturn
# 878   part
# 879   upper cloud
# 880   kuiper belt
# 881   solar system
# 882   kuiper belt object
# 883   1:1 resonance
# 884   sun
# 885   small apparent size
# 886   own gravity
# 887   solar system
# 888   le verrier
# 889   altitude
# 890   fixed star
# 891   example
# 892   planetary ring system
# 893   2:3 resonance
# 894   one much less substantial than that of saturn less substantial than that of saturn substantial than that of saturn
# 895   gaseous protoplanetary disc
# 896   sideways rotation
# 897   cloud deck
# 898   neptune's colour
# 899   south than the great dark spot
# 900   kuiper belt
# 901   became the penultimate known planet for a 20-year period between 1979 and 1999 when pluto 's elliptical orbit brought it closer to the sun than neptune
# 902   arose during the months leading up to the voyager 2 encounter in 1989 reveal the presence of clouds moving even faster than those that had initially been detected by voyager 2
# 903   troposphere
# 904   vortex structures
# 905   uranus is due in part to its higher internal heating
# 906   satellite
# 907   earth
# 908   outer planet
# 909   formation
# 910   useful observation of neptune from ground-based telescopes using adaptive optics
# 911   hot , dense fluid
# 912   poles
# 913
# 914   1989 pbs all-night program
# 915   satellite
# 916   atmosphere
# 917   higher internal heating
# 918   unpredictable and highly diverse forms
# 919   contrast
# 920   man's natural perfection
# 921   two types
# 922   cultural change
# 923   people's essential nature
# 924   larger brain
# 925   29 ways
# 926   cultural studies
# 927   (weltanschauung
# 928   many cultural innovations
# 929   people's essential nature
# 930   nature
# 931   larger brain
# 932   symbolically encoded experiences
# 933   international intellectual movement
# 934   expression of the conflict between european elites and non-elites
# 935   taylor
# 936   new ideas
# 937   kant's and herder's interests
# 938   the influence first of richard hoggart
# 939   director
# 940   haute cuisine
# 941   present legislation
# 942   u.s. supreme court
# 943   kurtzman
# 944   england
# 945   constitution
# 946   private sphere
# 947   wall
# 948   public property
# 949   word religion
# 950   bondage
# 951   america
# 952   participation
# 953   language
# 954   mercer county that the continued display of the ten commandments as part of a larger display on american legal traditions in a kentucky courthouse was allowed
# 955   churches
# 956   modern establishment clause
# 957   anti-federalists
# 958   word religion
# 959   u.s.
# 960   public office
# 961   absolute sense
# 962   established church
# 963   nature
# 964   religions
# 965   religion
# 966   prayer or religious recitations in public schools
# 967
# 968   grumet
# 969   god
# 970   argue
# 971   taxes
# 972   board of education
# 973   constitution
# 974   religious observance
# 975   germany
# 976   religion
# 977   public office
# 978   separation
# 979   14th amendment
# 980   united states as an authoritative declaration of the scope and effect of the
# 981   spiritual and secular worlds
# 982   religious principles
# 983   rights
# 984   constitution
# 985   nature
# 986   blaine amendments
# 987   particular religion
# 988   students were not compelled to recite it
# 989   state
# 990   persecution
# 991   `` lemon test
# 992   religious dimension
# 993   newdow
# 994   one
# 995   court
# 996   god
# 997   it could preempt the religious clauses in the state constitutions
# 998   churches
# 999   mercer county that the continued display of the ten commandments as part of a larger display on american legal traditions in a kentucky courthouse was allowed
# 1000   peter stuyvesant
# 1001   establishment clause jurisprudence
# 1002   taxes
# 1003   eighteenth century
# 1004   punishments
# 1005   united states
# 1006   roman catholics
# 1007   scholars
# 1008   watkins
# 1009   said
# 1010   virginia
# 1011   daughter
# 1012
# 1013   public funds
# 1014   churches
# 1015   god
# 1016   separation
# 1017   tile
# 1018   hagia sophia
# 1019   beautiful mosaic pavement
# 1020   one solsternus
# 1021   abd al-malik ibn marwan
# 1022   original mosaic decoration
# 1023   5th century
# 1024   justinian's reign
# 1025   pompeii
# 1026   taddeo zuccari
# 1027   17th-century drawings
# 1028   kiev
# 1029   tribune
# 1030   beautiful mosaic pavement
# 1031   remains
# 1032   whose sail
# 1033   french invader
# 1034   12th–13th centuries
# 1035   building
# 1036   wall mosaics have not survived in the region because of the destruction of buildings but the st. catherine 's monastery is exceptional
# 1037   robot
# 1038   church
# 1039   creation process
# 1040   texas interstate highways
# 1041   destroyed
# 1042   contemporary palace decoration
# 1043   human figure
# 1044   arta
# 1045   rebuilt abbey church
# 1046   specific connotations
# 1047   mosaic floors
# 1048   samaritan synagogue
# 1049   mosaic artwork
# 1050   destroyed in 1922
# 1051   jordan
# 1052   santa maria maggiore
# 1053   decidedly byzantine character
# 1054   lazarium
# 1055   later date
# 1056   constantinople
# 1057   life
# 1058   high artistic quality
# 1059   byzantine emperor
# 1060   unesco world heritage site
# 1061   exarchate
# 1062   apse
# 1063   taddeo zuccari
# 1064   5th century
# 1065   ascension
# 1066   mosaic floor
# 1067   traditional byzantine pattern
# 1068   site
# 1069   rule
# 1070   later date
# 1071   galla placidia
# 1072   thessaloniki
# 1073   hagia irene in constantinople
# 1074   moorish spain
# 1075   lusosphere
# 1076   river mureş in present-day romania
# 1077   samu
# 1078   church
# 1079   ravenna
# 1080   17th century
# 1081   black slave
# 1082   technical skill
# 1083   ancient rome
# 1084   jordan
# 1085   constantine monomachos
# 1086   roman and early christian mosaic art
# 1087   constantine monomachos
# 1088   constantine monomachos
# 1089   called saint sophia cathedral
# 1090   dura-europos
# 1091   georgia
# 1092   wooden panel
# 1093   constantinople
# 1094   precious , miniature mosaic icons
# 1095   lusosphere
# 1096   river mureş in present-day romania
# 1097   interesting fusion
# 1098   santa constanza
# 1099   arab caliphate
# 1100   late roman mosaic art
# 1101   8th century
# 1102   novel reinvention
# 1103   martorana church
# 1104   long braided hair and rosy cheeks
# 1105   giotto di bondone
# 1106   another more simple geometric mosaic floor
# 1107   early 4th century
# 1108   papal gifts
# 1109   rams
# 1110   model
# 1111   1143 even more byzantine although important parts were later demolished more byzantine although important parts were later demolished demolished
# 1112   549
# 1113   most prominent artist
# 1114   specific connotations
# 1115   ancient kastron mefaa
# 1116   umayyad caliph
# 1117
# 1118   mortuary chapel
# 1119   laterano
# 1120   rebuilt abbey church
# 1121   christian interpretations
# 1122   beautiful mosaic pavement
# 1123   libyan town
# 1124   apse
# 1125   arab caliphate
# 1126   jewish month
# 1127   high artistic quality mosaics
# 1128   early 4th century
# 1129   sant'apollinare nuovo
# 1130   higher accuracy
# 1131   18th century
# 1132   robot
# 1133   high-ranking officials
# 1134   constantine monomachos
# 1135   holy land
# 1136   rams
# 1137   constantine monomachos
# 1138   misleading impression
# 1139   umm ar-rasas
# 1140   santa pudenziana
# 1141   rams
# 1142   6th century
# 1143   figures
# 1144   5th century
# 1145   seems that it was not until the christian era that figural wall mosaics became a major form of artistic expression
# 1146   bowl
# 1147   jerusalem
# 1148   monreale
# 1149   st. catherine's monastery
# 1150   either side
# 1151   constantine monomachos
# 1152   coarser work
# 1153   important place of pilgrimage
# 1154   late roman mosaic art
# 1155   idolatry
# 1156   3rd millennium bc
# 1157   period
# 1158   creation process
# 1159   elaborate, golden mosaics
# 1160   wisdom
# 1161   roman and early christian mosaic art
# 1162   important place of pilgrimage
# 1163   lusosphere
# 1164   found at pompeii and neighbouring sites
# 1165   demonstration
# 1166   lusosphere
# 1167   hagia sophia
# 1168   portal
# 1169   3rd century bc
# 1170   constantine monomachos
# 1171   early 4th century
# 1172   tunis
# 1173   ava
# 1174   16 languages
# 1175   united kingdom
# 1176   yangon (rangoon
# 1177   group's name
# 1178   period
# 1179   50 million tons
# 1180   18th century
# 1181   external expansion
# 1182   disaster
# 1183   world's longest-running ongoing civil wars
# 1184   uk
# 1185   ayutthaya
# 1186   entire irrawaddy valley
# 1187   minority cultures
# 1188   myanmar
# 1189   country
# 1190   general saw maung
# 1191   population [ citation
# 1192   history
# 1193   total perimeter
# 1194   military rule
# 1195   british colony
# 1196   group's name
# 1197   protected areas
# 1198   first time
# 1199   group's name
# 1200   united kingdom
# 1201   lay people
# 1202   yangon
# 1203   arbitrary violence
# 1204   united kingdom
# 1205   lay people
# 1206   400,000 years ago
# 1207   territories
# 1208   united kingdom
# 1209   16th century
# 1210   region
# 1211   18th century
# 1212   yangon (rangoon
# 1213   world war ii
# 1214   siam
# 1215   country
# 1216   particular idea
# 1217   adopted the term intellectual property in their new combined title
# 1218   united states
# 1219   example
# 1220   rhetoric
# 1221   practice
# 1222   ip protection
# 1223   end
# 1224   trillion
# 1225   claim
# 1226   copyright
# 1227   automobile
# 1228   monopolies in the form of copyright extensions
# 1229   confusion
# 1230   confusion
# 1231   granted patent
# 1232   registration
# 1233   ever-changing nature
# 1234   granted patent
# 1235   patent holder
# 1236   gnu gpl
# 1237   federal crime
# 1238   member states
# 1239   law
# 1240   et inventeurs
# 1241   many jurisdictions
# 1242   scarcity
# 1243   ever-changing nature
# 1244   applicability
# 1245   october 1845 massachusetts circuit court ruling
# 1246   criminal law
# 1247   specific technological problem
# 1248   ip protection
# 1249   adopted the term intellectual property in their new combined title
# 1250   trademark
# 1251   knowledge
# 1252   industry
# 1253   industry
# 1254   referring
# 1255   ideas
# 1256   intellectual property
# 1257   member states
# 1258   united states
# 1259   member states
# 1260   america invents act
# 1261   ten or fifteen years
# 1262   incarceration and fines
# 1263   (98/84/eec
# 1264   trademarks
# 1265   a social product
# 1266   october 1845 massachusetts circuit court ruling
# 1267   example
# 1268   adopted the term intellectual property in their new combined title
# 1269   luxury
# 1270   business method patents
# 1271   trademarks
# 1272   motion picture association
# 1273   business finance
# 1274   other party
# 1275   millions
# 1276   life-saving medicines
# 1277   written form
# 1278   business method patents
# 1279   intellectual-property rights
# 1280   written form
# 1281   property rights
# 1282   copyright extensions
# 1283   criminal law
# 1284   average readers
# 1285
# 1286   eastern orthodox christians
# 1287   harbor
# 1288   proper
# 1289   independence war
# 1290   gyumri
# 1291   dispute
# 1292   russia
# 1293   william howard russell
# 1294   crete
# 1295   previous war
# 1296   attack
# 1297   charlemagne
# 1298   giurgiu
# 1299   giurgiu
# 1300   withdrawal
# 1301   baltic was [ when
# 1302   june
# 1303   turkish province
# 1304   principalities
# 1305   vienna
# 1306   artillery units
# 1307   sevastopol
# 1308   orders
# 1309   baltic was [ when
# 1310   åland islands
# 1311   russian resistance
# 1312   war
# 1313   smaller vessels
# 1314   13 november
# 1315   turks
# 1316   william howard russell
# 1317   equipment
# 1318   reform
# 1319   encircled the city to the south
# 1320   negotiation
# 1321   baltic was [ when
# 1322   , re-appointed stratford canning
# 1323   whole russian army
# 1324   war
# 1325   war
# 1326   batum
# 1327   disease
# 1328   6000 men
# 1329   bulgaria
# 1330   alexander ii
# 1331   russia
# 1332   newly invented blockade mines
# 1333   kept
# 1334   time
# 1335   shallow water
# 1336   malakoff
# 1337   operations
# 1338   north
# 1339   6 january
# 1340   alfred nobel
# 1341   parliament
# 1342   baltic was [ when
# 1343   epirus
# 1344   italy
# 1345   orders
# 1346   russian resistance
# 1347   part
# 1348   french
# 1349   western powers
# 1350   second-class citizens
# 1351   30 january
# 1352   mediterranean sea
# 1353   åland islands
# 1354   alexander ii
# 1355   compromise
# 1356   hills
# 1357   attack
# 1358   greek orthodox church
# 1359   kadikoi
# 1360   outside military or financial support
# 1361   two days
# 1362   st. martin-in-the-field in which 1,500 people gathered to protest against the war by pelting buses
# 1363   disease
# 1364   army
# 1365   western powers
# 1366   two days
# 1367   casus belli
# 1368   russians
# 1369   russian resistance
# 1370   austrians
# 1371   forgotten theatre
# 1372   baltic was [ when
# 1373   280,000 men
# 1374   worldwide attention
# 1375   village
# 1376   turkish province
# 1377   russian military aid
# 1378   roger fenton
# 1379   june
# 1380   orders
# 1381   february
# 1382   declared war
# 1383   franco-prussian war
# 1384   roger fenton
# 1385   interest
# 1386   battle
# 1387   problems to the south and the heavy artillery was brought ashore with batteries and connecting trenches built so that by 10 october some batteries were ready and by 17 october—when the bombardment commenced—126 guns were firing
# 1388   heavy casualties
# 1389   winter clothing
# 1390   "the charge
# 1391   finally
# 1392   turks
# 1393   united kingdom
# 1394   british hq
# 1395   war
# 1396   september
# 1397   north
# 1398   practice
# 1399   black sea
# 1400   calafat
# 1401   march
# 1402   russian resistance
# 1403   british army forces
# 1404   28 june
# 1405   hills
# 1406   baltic was [ when
# 1407   odessa harbour
# 1408   crimean peninsula
# 1409   marani
# 1410   credited[by
# 1411   siege
# 1412   kars road
# 1413   ottoman empire
# 1414   franco-prussian war
# 1415   28 june
# 1416   silistra
# 1417   hungarian revolution
# 1418   london convention
# 1419   principalities
# 1420   roger fenton
# 1421   duplicitous french and ottoman diplomacy
# 1422   oltenița
# 1423   many different interpretations
# 1424   large body
# 1425   region
# 1426   odessa harbour
# 1427   protection
# 1428   sevastopol
# 1429   snow balls
# 1430   rostov
# 1431   6000 men
# 1432   russian fleet
# 1433   giurgiu
# 1434   same turk army
# 1435   ottoman expense
# 1436   austrian foreign minister count karl von buol
# 1437   june
# 1438   erzerum
# 1439   europe
# 1440   british
# 1441   austrian foreign minister count karl von buol
# 1442   syria
# 1443   ottoman empire
# 1444   130–43
# 1445   kamishevaya bay
# 1446   point
# 1447   smaller vessels
# 1448   turkish landing
# 1449   europe
# 1450   february
# 1451   russian fleet
# 1452   calamita bay
# 1453   hostilities
# 1454   sinop
# 1455   seven columns
# 1456   ottoman military forces
# 1457   greek orthodox church
# 1458   tsarist russia
# 1459   wallachia
# 1460   ended by the treaty of paris
# 1461   austrian foreign minister count karl von buol
# 1462   number of their artillery units
# 1463   allies
# 1464   south
# 1465   crete
# 1466   cholok river border
# 1467   orthodox church's hierarchy
# 1468   shore
# 1469   280,000 men
# 1470   battle
# 1471   late july
# 1472   sukhum kale
# 1473   few hours
# 1474
# 1475   russia
# 1476   malakoff
# 1477   village
# 1478   village
# 1479   palestine
# 1480   appreciable value
# 1481   30 march
# 1482   special guardian
# 1483   alexandropol (november
# 1484   russian resistance
# 1485   french emperor
# 1486   saint petersburg
# 1487   duplicitous french and ottoman diplomacy
# 1488   danube
# 1489   treaty
# 1490   nitroglycerin
# 1491   french
# 1492   forgotten theatre
# 1493   village
# 1494   , re-appointed stratford canning
# 1495   rapid communications
# 1496   village
# 1497   imperial examination
# 1498   other `` mean '' people
# 1499   father
# 1500   ming military to get them to defect to the qing
# 1501   manchukuo
# 1502   a revolt by han in liaodong in 1623
# 1503   gapsin coup
# 1504   chinese zodiacal system
# 1505   kangxi emperor
# 1506   power
# 1507   time
# 1508   power
# 1509   manchu homeland
# 1510   viceroys
# 1511   early 17th century
# 1512   foreign legation quarter
# 1513   wore it in the form of a top-knot
# 1514   campaign
# 1515   fujian
# 1516   jahangir khoja
# 1517   instead
# 1518   chinese zodiacal system
# 1519   prior military experience
# 1520   chinese military
# 1521   population
# 1522   dorgon
# 1523   collection
# 1524   compensation for their expenses in invading china and execution of complicit officials
# 1525   beijing
# 1526   beijing
# 1527   eight banners
# 1528   authoritative reference
# 1529   hybrid
# 1530   the massive amount of han chinese soldiers which were absorbed into the eight banners by both capture and defection
# 1531   throne
# 1532   russia
# 1533   eight banners
# 1534   manchu people
# 1535   wu's concubine chen yuanyuan
# 1536   nomadic people
# 1537   prior military experience
# 1538   watershed
# 1539   nanjing
# 1540   lucrative since they were direct
# 1541   silver
# 1542   qing rulers `` bloodiest civil war of all time
# 1543   the person of the emperor
# 1544   crown
# 1545   death of the shunzhi emperor and the accession of his son
# 1546   power
# 1547   provinces
# 1548   20 million people
# 1549   wu's concubine chen yuanyuan
# 1550   maritime trade
# 1551   eight han banners
# 1552   part
# 1553   late ming dynasty
# 1554   first two han banners
# 1555   eight han banners
# 1556   hubei and hunan provinces
# 1557   ming dynasty
# 1558   brought him in close contact with the khorchin mongol domains on the plains of mongolia
# 1559   xinjiang
# 1560   small anglo-french coalition force numbering 25,000
# 1561   february
# 1562   beijing
# 1563   loyal officers
# 1564   bang bo
# 1565   dynasty
# 1566   manchuria
# 1567   population
# 1568   internal administration
# 1569   "bondservants
# 1570   a revolt by han in liaodong in 1623
# 1571   hundred days ' reform
# 1572   han banners
# 1573   chinese emperor
# 1574   private chinese merchants
# 1575   brought him in close contact with the khorchin mongol domains on the plains of mongolia
# 1576   jesus christ
# 1577   traditional confucian values
# 1578   own cabinet
# 1579   central government institution
# 1580   many newly surrendered ming officials
# 1581   opium trade
# 1582   qing court
# 1583   earlier dynasties
# 1584   soviet union
# 1585   fujian
# 1586   watershed
# 1587   taiping and nian rebellions
# 1588   social standing
# 1589   units
# 1590   published books
# 1591   dynasty
# 1592   primary military forces
# 1593   taiping and nian rebellions
# 1594   bodhisattva manjusri
# 1595   tungning
# 1596   period
# 1597   professional foreign service
# 1598   fujian
# 1599   eight years
# 1600   northeast
# 1601   killed in the dzungar–qing war
# 1602   early 17th century
# 1603   throne
# 1604   hubei and hunan provinces
# 1605   smallpox
# 1606   could allow yuan to step into the position of president of the republic of china
# 1607   qing dynasty
# 1608   great wall
# 1609   manchu ancestry
# 1610   war
# 1611   corpse
# 1612   conquests
# 1613   country
# 1614   beijing
# 1615   population growth
# 1616   beijing
# 1617   smallpox
# 1618   indochina
# 1619   han civilians
# 1620   day
# 1621   provinces
# 1622   mean ( or ignoble ) people
# 1623   ming dynasty
# 1624   74,000 and 100,000 people
# 1625   100 million to 300 million people
# 1626   aisin gioro relatives
# 1627   early 17th century
# 1628   base
# 1629   authoritative reference
# 1630   fief
# 1631   officials
# 1632   little evidence
# 1633   and b categories
# 1634   kangxi emperor
# 1635   20 million people
# 1636   father
# 1637   beginning
# 1638   beleaguered central government
# 1639   manchu culture
# 1640   successor
# 1641   many newly surrendered ming officials
# 1642   warlord factionalism
# 1643   80%
# 1644   chinese military
# 1645   summer palace
# 1646   top-knot
# 1647   kingdom
# 1648   dorgon
# 1649   immediate predecessor's capital
# 1650   qing military establishment
# 1651   throne
# 1652   revolt
# 1653   rehe
# 1654   fujian
# 1655   manchu ancestry
# 1656   mirror
# 1657   put to shame by the better performance of the han chinese green standard army
# 1658   silver
# 1659   beijing
# 1660   harsher
# 1661   proceeded with directions from empress dowager longyu
# 1662   japan
# 1663   diplomatic and strategic problems
# 1664   square emblem
# 1665   ming
# 1666   collection
# 1667   five
# 1668   revolt
# 1669   instruction
# 1670   imperial examination
# 1671   manchu masters
# 1672   many of the plans stayed in place
# 1673   tribute nation
# 1674   nomadic people
# 1675   chongzhen emperor
# 1676   fuzhou
# 1677   pescadores
# 1678   taken over its immediate predecessor 's capital
# 1679   qing
# 1680   warlord factionalism
# 1681   manchus
# 1682   qing dynasty
# 1683   smallpox
# 1684   chinese history
# 1685   first two han banners
# 1686   indochina
# 1687   qing dynasty
# 1688   later jin
# 1689   modern chinese state
# 1690   watershed
# 1691   northeast
# 1692   size
# 1693   resign from the banner rolls or striking their names off
# 1694   death
# 1695   beijing
# 1696   jiaozhou bay
# 1697   emergency army
# 1698   country
# 1699   manchuria
# 1700   gapsin coup
# 1701   local french diplomats
# 1702   xinjiang
# 1703   chongzhen emperor
# 1704   early 19th century
# 1705   officials
# 1706   lucrative since they were direct
# 1707   father
# 1708   allied
# 1709   eight banners
# 1710   issuing edicts in favor of banning them from 1740–1776
# 1711   color
# 1712   mass civil disorder
# 1713   confucian family values
# 1714   in what was called the tongzhi restoration
# 1715   jurchen aisin gioro clan
# 1716   provinces
# 1717   manchu people
# 1718   power
# 1719   ground
# 1720   manchus drew up the treaty of kyakhta
# 1721   wanted to go ... ... in the arrow war
# 1722   killed in the dzungar–qing war
# 1723   dynasty great qing
# 1724   chinese history
# 1725   october
# 1726   qing dynasty
# 1727   comparable benefits
# 1728   civil time
# 1729   standard time
# 1730   theatre owners
# 1731   solar time
# 1732   older time stamps
# 1733   energy crisis
# 1734   next year
# 1735   standard time
# 1736   clock
# 1737   older timestamps
# 1738   example
# 1739   rural areas
# 1740   time zone and natural discrepancies
# 1741   modern idea
# 1742   utc clocks
# 1743   summer
# 1744   later date
# 1745   twice yearly time shifts
# 1746   systems
# 1747   favor
# 1748   adjust
# 1749   forms
# 1750   tended
# 1751   "winter" time
# 1752   tz=':america/new_york
# 1753   example
# 1754   ordered
# 1755   clocks
# 1756   spattering
# 1757   united states
# 1758   2007 united states extension
# 1759   farming
# 1760   western australia
# 1761   crime
# 1762   us dst extensions
# 1763   draft legislation
# 1764   `` s
# 1765   its effects on residential lighting
# 1766   germany
# 1767   belarus
# 1768   computer clocks
# 1769   base
# 1770   skew
# 1771   modern idea
# 1772   daylight
# 1773   daylight time
# 1774   standard time
# 1775   time zone names
# 1776   skin cancer
# 1777   daylight hours
# 1778   pundits
# 1779   work
# 1780   several political issues
# 1781   lists
# 1782   later years
# 1783   sleep patterns
# 1784   negative dst
# 1785   draft legislation
# 1786   individuals
# 1787   spring
# 1788   daylight time
# 1789   effect
# 1790   electricity
# 1791   1970s energy crisis
# 1792   eastern european time
# 1793   corporate information technologists
# 1794   outdoor exercise
# 1795   utc-based unix time
# 1796   spattering
# 1797   evening dinner
# 1798   suggested
# 1799   d.c.'s violent crime rate
# 1800   many editors
# 1801   motivation
# 1802   year
# 1803   new york
# 1804   dark
# 1805   spring
# 1806   1898 paper
# 1807   system
# 1808   year
# 1809   changing dates
# 1810   war
# 1811   equatorial brazil
# 1812   disadvantages
# 1813   dst
# 1814   filesystem
# 1815   around $1.7 billion usd
# 1816   complexity
# 1817   railroads
# 1818   ordinary dst
# 1819   daylight
# 1820   time zone differences
# 1821   primary use
# 1822   labor
# 1823   typical `` nine-to-five '' workday
# 1824   standard time
# 1825   idaho potatoes
# 1826   methodology
# 1827   many enactments
# 1828   value
# 1829   gregorian calendar
# 1830   peacetime
# 1831   feature
# 1832   many countries
# 1833   dst
# 1834   clock
# 1835   result
# 1836   draft legislation
# 1837   methodology
# 1838   ordinary system maintenance
# 1839   24:00 local time
# 1840   workday activities
# 1841   northern regions
# 1842   sunrise
# 1843   winter
# 1844   single studies
# 1845   typical `` nine-to-five '' workday
# 1846   golf industry revenues
# 1847   adopt
# 1848   uses
# 1849   evening dinner
# 1850   autumn transition
# 1851   single studies
# 1852   standardize
# 1853   dual-time zone arrangement
# 1854   dst
# 1855   complexity
# 1856   average
# 1857   favor
# 1858   little impact
# 1859   problems
# 1860   utc-based unix time
# 1861   ordinary system maintenance
# 1862   increase
# 1863   use
# 1864   committee
# 1865   older timestamps
# 1866   end
# 1867   confusion
# 1868   seasonal vaccinations
# 1869   30 april
# 1870   single studies
# 1871   daylight
# 1872   winter solstice
# 1873   rules
# 1874   file
# 1875   canadian location
# 1876   energy-consumption study
# 1877   term summer time
# 1878   help
# 1879   repeals
# 1880   state law
# 1881   heating and candle season
# 1882   your honor
# 1883   genre
# 1884   80s glam metal
# 1885   "misirlou
# 1886   rock
# 1887   spaghetti incident
# 1888   who
# 1889   solo lead instrument
# 1890   top ten album school
# 1891   spaghetti incident
# 1892   "misirlou
# 1893   album-oriented radio
# 1894   6 million copies
# 1895   double platinum ballbreaker
# 1896   uk singles chart
# 1897   rock drummer keith moon
# 1898   coverdale's or deep purple's catalogue
# 1899   spaghetti incident
# 1900   spaghetti incident
# 1901   us
# 1902   van halen iii
# 1903   five million copies
# 1904   dr. feelgood
# 1905   popularity
# 1906   lead guitarist eddie van halen
# 1907   tensions
# 1908   ac/dc
# 1909   double live album
# 1910   lead guitarist eddie van halen
# 1911   rolling stones
# 1912   nine weeks
# 1913   several other countries
# 1914   hard rock and heavy metal sound
# 1915   highly successful recording careers
# 1916   distortion
# 1917   album worldwide
# 1918   commercial success
# 1919   performances
# 1920   `` hair band '' predecessors
# 1921   1993 covers
# 1922   early 1990s material
# 1923   guitar solos
# 1924   lead guitars
# 1925   guns n' roses' original lineup
# 1926   1970s
# 1927   two styles
# 1928   decade
# 1929   five weeks
# 1930   commercial pinnacle
# 1931   hard rock act
# 1932   mötley crüe
# 1933   decade
# 1934   decade
# 1935   australia's wolfmother
# 1936   double platinum-certified album crush
# 1937   number
# 1938   rolling stones
# 1939   boston's "amanda
# 1940   number
# 1941   destruction
# 1942   isp
# 1943   access isps
# 1944   new `` net neutrality '' regulations
# 1945   adoption
# 1946   wholesale isp
# 1947   services
# 1948   possible solution
# 1949   world wide web
# 1950   world wide web
# 1951   wireless networking
# 1952   intelligence agencies
# 1953   internet access
# 1954   mail boxes
# 1955   universities
# 1956   net neutrality
# 1957   advertiser
# 1958   mode
# 1959   net neutrality
# 1960   broadband
# 1961   isp
# 1962   united states constitution
# 1963   others
# 1964   same concept
# 1965   new `` net neutrality '' regulations
# 1966   large amounts
# 1967   charge
# 1968   physical server operation
# 1969   lawrence, kansas
# 1970   ku football
# 1971   2014 u.s. news & world report `` best graduate schools '' edition
# 1972   navy commission
# 1973   lawrence, kansas
# 1974   royal blue
# 1975   less than forty acres
# 1976   one
# 1977   kansas
# 1978   rural health care
# 1979   architecture
# 1980   lawrence, kansas
# 1981   development
# 1982   nation
# 1983   world report's 2016 rankings
# 1984   university
# 1985   attend
# 1986   kansas
# 1987   kansas
# 1988   kjhk radio
# 1989   rural health care
# 1990   national universities
# 1991   nation
# 1992   students
# 1993   lawrence, kansas
# 1994   underwent a
# 1995   strategic communication
# 1996   civil and environmental engineering
# 1997   matthew porubsky
# 1998   team
# 1999   operations
# 2000   overland park
# 2001   campus community center
# 2002   former dean james green
# 2003   lawrence, kansas
# 2004   team
# 2005   editing
# 2006   lawrence
# 2007   rural health care
# 2008   first union
# 2009   accounting
# 2010   u.s
# 2011   university
# 2012   regents
# 2013   fall semester
# 2014   average age
# 2015   engineering
# 2016   average age
# 2017   lawrence, kansas
# 2018   public university
# 2019   greater university
# 2020   former kansas governor charles l. robinson
# 2021   broadcast
# 2022   kansas city
# 2023   orange bowl
# 2024   january
# 2025   additional fees
# 2026   school
# 2027   early lynx text based web browser
# 2028   espn regional television
# 2029   new locker room
# 2030   community health
# 2031   founded in 1891
# 2032   salina
# 2033   field
# 2034   kansas board
# 2035   royal blue
# 2036   department's budget
# 2037   students
# 2038   prestigious hearst foundation national writing competition
# 2039   three ncaa tournament championships
# 2040   strategic communication
# 2041   main campus
# 2042   early lynx text based web browser
# 2043   women's outdoor track
# 2044   public university
# 2045   college
# 2046   former dean james green
# 2047   average age
# 2048   students
# 2049   npr-affiliated radio station
# 2050   january
# 2051   fall semester
# 2052   kansas city
# 2053   matthew porubsky
# 2054   development
# 2055   team
# 2056   team
# 2057   land
# 2058   main campus
# 2059   2014 u.s. news & world report `` best graduate schools '' edition
# 2060   cbbc
# 2061   `` footprint
# 2062   a-nis
# 2063   introduced ceefax
# 2064   a-nis
# 2065   uk
# 2066   british broadcasting corporation
# 2067   bbc vision
# 2068   britain's most iconic and beloved television programmes
# 2069
# 2070   first teletext service
# 2071   first teletext service
# 2072   september
# 2073   used two systems
# 2074   tv viewers
# 2075   radar programme
# 2076   following night
# 2077   horizon
# 2078   september
# 2079   london
# 2080   air
# 2081   brookmans park
# 2082
# 2083   produce a number of programmes that are shown across the uk
# 2084   end
# 2085   bbc's london transmitter
# 2086   a-nis
# 2087   world's largest television production companies
# 2088   high audience ratings
# 2089   aired on bbc one
# 2090
# 2091   australia
# 2092   patrick kielty
# 2093   bbc known as bbc vision for a few years in the early 21st century
# 2094   brookmans park
# 2095   programme
# 2096   bafta award
# 2097   problem
# 2098   first teletext service
# 2099   september
# 2100   current affairs
# 2101
# 2102   niche programming
# 2103
# 2104   april
# 2105   horizon
# 2106   british television set
# 2107
# 2108   cbbc
# 2109   bbc vision
# 2110   a-nis
# 2111   13 february
# 2112   first teletext service
# 2113
# 2114   april
# 2115   bbc two
# 2116
# 2117   resumed on 1 october 1936
# 2118   production
# 2119   [original research
# 2120   24-hour , worldwide news coverage
# 2121   technology
# 2122   vhf band
# 2123   bbc continued until june 1932
# 2124   bafta award
# 2125   changes in the format of the bbc television news
# 2126   television
# 2127   brookmans park
# 2128   september
# 2129
# 2130
# 2131   saturday
# 2132   television
# 2133   overseas broadcasters
# 2134   six-year-old son
# 2135   niche programming
# 2136
# ...
# 2926   system
# 2927   apple
# 2928   compaq
# 2929   iici
# 2930   first macbook pro
# 2931   frogdesign
# 2932   microsoft's formerly separate ms-dos and windows products
# 2933   mac os gui
# 2934   a bad condition
# 2935   raskin
# 2936   october
# 2937   adventurous mac users
# 2938   macs
# 2939   third place
# 2940   audio equipment manufacturer
# 2941   first macbook pro
# 2942   mac users
# 2943   macintosh clones
# 2944   materials
# 2945   apple's margins
# 2946   seven years
# 2947   more than 30 percent increase
# 2948   macbook ( 2015 version
# 2949
# 2950   platforms
# 2951   support document
# 2952   640 x 400-pixel resolution
# 2953   25 mhz
# 2954   9.3%
# 2955   6 percent
# 2956   third place
# 2957   prices
# 2958   macintosh group's own ideas
# 2959   macintosh
# 2960   product's creation
# 2961   top pc manufacturer
# 2962   controversial `` rip , mix , burn '' advertising campaign
# 2963   increasing problem
# 2964   choice
# 2965   new computer
# 2966   dell
# 2967   latest cpu technology
# 2968   high voltage
# 2969   apple's system
# 2970   fewer than 100,000 pcs
# 2971   macbook pro
# 2972   macintosh iifx
# 2973   windows-only software on macs at near native speed
# 2974   external third-party hardware
# 2975   apple
# 2976   one
# 2977   software
# 2978   , co
# 2979   external third-party hardware
# 2980   january
# 2981
# 2982   i/o processing
# 2983   ashton-tate
# 2984   imac g4
# 2985   price
# 2986   ten months
# 2987   all-in-one computer
# 2988   mac pro
# 2989   software business
# 2990   q4
# 2991   25 december
# 2992   state-owned television broadcaster
# 2993   governor
# 2994   difficult terrain
# 2995   25%
# 2996   kangra miniature paintings
# 2997   toilet
# 2998   himachal emerged as the 18th state of the indian union
# 2999   handicrafts
# 3000   himachal pradesh
# 3001   third-fastest growing economy
# 3002   10th century
# 3003   state
# 3004   public radio station
# 3005   1 november
# 3006   25%
# 3007   handicrafts
# 3008   chief minister
# 3009   22nd place
# 3010   british india
# 3011   district
# 3012   40%
# 3013   shimla
# 3014   sikhism
# 3015   abundant natural beauty
# 3016   wool
# 3017   year
# 3018   india
# 3019   hydro electric resources
# 3020   providers
# 3021   10th century
# 3022   indian states
# 3023   10.5%
# 3024   technological advancements
# 3025   30 december
# 3026   himachal
# 3027   year
# 3028   h.p.
# 3029   shimla
# 3030   25 january
# 3031   goal
# 3032   live in towns and cities and constitute 1.16
# 3033   tv
# 3034   sundernagar
# 3035   increased
# 3036   the rest of india
# 3037   population
# 3038   himachal
# 3039   great variation
# 3040   plebeians
# 3041   concordia
# 3042   side
# 3043   provincial cursus honorum
# 3044   haruspex
# 3045   emperor
# 3046   mutual toleration
# 3047   office
# 3048   images
# 3049   first council
# 3050   cult observances
# 3051   rome's traditional gods
# 3052   fact
# 3053   men
# 3054   fertile victims
# 3055   advance
# 3056   vesta
# 3057   heavenly intercessor
# 3058   di immortales
# 3059   revolt
# 3060   life
# 3061   ancient roman culture
# 3062   republican pontifices
# 3063   daily life
# 3064   calendar
# 3065   augustus
# 3066   communal meal
# 3067   food
# 3068   heavenly intercessor
# 3069   roman religious law
# 3070   individual romans
# 3071   even "pagan" emperors
# 3072   christians
# 3073   jews
# 3074   major , set battle
# 3075   february
# 3076   general symbolic value
# 3077   concordia
# 3078   start
# 3079   provincial cursus honorum
# 3080   princeps
# 3081   christian terms
# 3082   augustus
# 3083   186 bc
# 3084   roman bacchus
# 3085   general symbolic value
# 3086   centralised legal requirement
# 3087   particularly
# 3088   de facto consular prerogative
# 3089   rome's inclusive hegemony
# 3090   religious dimensions
# 3091   reform
# 3092   religious observances
# 3093   second edict
# 3094   record
# 3095   home
# 3096   purpose
# 3097   occasion
# 3098   men
# 3099   roman gladiator
# 3100   roman military
# 3101   superstitio
# 3102   pomerium
# 3103   very early era
# 3104   rome's female priesthood
# 3105   roman society
# 3106   christian era
# 3107   persecution
# 3108   particularly the liver
# 3109   heavenly intercessor
# 3110   blight and red mildew
# 3111   building
# 3112   "private" diviners
# 3113   princeps
# 3114   pontiffs
# 3115   local traditions
# 3116   emperor
# 3117   cult observances
# 3118   ad
# 3119   roman religious law
# 3120   individual romans
# 3121   roman military aristocrat
# 3122   gods
# 3123   celebrated and appeased at the parentalia
# 3124   stipulated period
# 3125   divination
# 3126   romanitas
# 3127   roman politics
# 3128   imperial cult
# 3129   theatres
# 3130   very early era
# 3131   lesser deities
# 3132   life
# 3133   laws
# 3134   julius caesar
# 3135   roman art
# 3136   darkness
# 3137   concordia
# 3138   mortal's death
# 3139   different local traditions
# 3140   death
# 3141   roman empire
# 3142   cult
# 3143   christians
# 3144   record
# 3145   such spectacular displays
# 3146   general symbolic value
# 3147   major , set battle
# 3148   purpose
# 3149   men
# 3150   remus
# 3151   destiny
# 3152   allies
# 3153   human affairs
# 3154   equivalent
# 3155   funding
# 3156   rights
# 3157   polymath varro
# 3158   roman gladiator
# 3159   family
# 3160   separate priestly caste
# 3161   edict
# 3162   communal meal
# 3163   comparison
# 3164   state counterparts
# 3165   building
# 3166   far greater problem
# 3167   same name
# 3168   return
# 3169   ancient roman culture
# 3170   public festivals
# 3171   edict
# 3172   apotheosized mortals
# 3173   rule
# 3174   assistants
# 3175   destiny
# 3176   virtually monarchic powers
# 3177   underworld gods
# 3178   vestals
# 3179   augustus
# 3180   elite classes
# 3181   justified
# 3182   rome
# 3183   clients
# 3184   later
# 3185   country's peril
# 3186   general symbolic value
# 3187   augur
# 3188   subversive activity
# 3189   office
# 3190   vesta
# 3191   architecture
# 3192   popular cult
# 3193   bar kokhba revolt
# 3194   first council
# 3195   roman camps
# 3196   ritual
# 3197   public profile
# 3198   auspices
# 3199   annually elected magistrates
# 3200   convenient scapegoats
# 3201   rome's founding
# 3202   values
# 3203   divine monarchy
# 3204   event
# 3205   roughly forty annual religious festivals
# 3206   fate
# 3207   divine knowledge
# 3208   general symbolic value
# 3209   senate
# 3210   greek influences
# 3211   traditional festivals
# 3212   values
# 3213   superstitio
# 3214   order
# 3215   office
# 3216   law
# 3217   religious observances
# 3218   very early era
# 3219   household's cult
# 3220   own communities
# 3221   alms
# 3222   empire
# 3223   assistants
# 3224   limited capacity
# 3225   vesta's flame
# 3226   persian priests
# 3227   model
# 3228   bona dea
# 3229   gods
# 3230   vesta's flame
# 3231   officially
# 3232   misfortune
# 3233   religious context
# 3234   leeches
# 3235   locomotion
# 3236   obvious signs
# 3237   strength
# 3238   tertiary period
# 3239   natural populations
# 3240   infections
# 3241   ganglia
# 3242   capabilities
# 3243   maturity
# 3244   serve
# 3245   circulates
# 3246   outgroups
# 3247   cnidarian
# 3248   native earthworms are thought to have been killed by the glaciers and the worms currently found in those areas are all introduced from other areas found in those areas are all introduced from other areas
# 3249   vertical mesenteries
# 3250   found
# 3251   scientists' current knowledge
# 3252   arthropods' eyes
# 3253   cladistic research
# 3254   scientists' current knowledge
# 3255   animals
# 3256   blood plasma
# 3257   lower one
# 3258   metanephridia
# 3259   outermost skin layer
# 3260   infections
# 3261   metanephridia
# 3262   maturity
# 3263   body
# 3264   use protonephridia
# 3265   dubious practise of blood-letting have come from china around 30 ad 30 ad 30 ad throughout europe
# 3266   produce
# 3267   trochophore larvae
# 3268   thus
# 3269   dead and decaying matter
# 3270   spiral determinate cleavage
# 3271   incomplete in annelids that are semi-sessile or that do not move by peristalsis or by movements of parapodia – for example some move by whipping movements of the body
# 3272   locomotion
# 3273   hatchlings
# 3274   anatomical structures
# 3275   segmentation
# 3276   lives
# 3277   scientists' current knowledge
# 3278   the prostomium the peristomium
# 3279   nemerteans
# 3280   hatchlings
# 3281   another pair
# 3282   annelid
# 3283   cocoon
# 3284   ecological diversity
# 3285   europe
# 3286   septa
# 3287   muscle fibers
# 3288   ganglia
# 3289   worms ' total weight
# 3290   enables
# 3291   polychaetes
# 3292   dubious practise of blood-letting have come from china around 30 ad 30 ad 30 ad throughout europe
# 3293   situations
# 3294   jurassic
# 3295   whose best-known members
# 3296   soil fertility
# 3297   cocoon
# 3298   deuterostomes
# 3299   gap
# 3300   adopted a slightly different version of the greenman rule in section 402a of the restatement different version of the greenman rule in section 402a of the restatement
# 3301   minor crimes
# 3302   common carriers
# 3303   authority
# 3304   common carriers
# 3305   constitution
# 3306   one state
# 3307   legal statutory citation
# 3308   reasoning
# 3309   272,795 new cases
# 3310   become
# 3311   local ordinances
# 3312   constitution
# 3313   chevron doctrine
# 3314   federal judiciary
# 3315   federal judiciary
# 3316   constitution
# 3317   court's jurisdiction
# 3318   one state
# 3319   mccarran-ferguson act
# 3320   presence of reception statutes
# 3321   warranty
# 3322   reasoning
# 3323   federal judiciary
# 3324   one state
# 3325   federal government
# 3326   20th century
# 3327   others
# 3328   supreme court
# 3329   number
# 3330   common carriers
# 3331   settlement
# 3332   evolution
# 3333   mail
# 3334   accepted that the founding fathers of the united states
# 3335   slip law
# 3336   federal government
# 3337   constitution
# 3338   constitution
# 3339   federal regulations
# 3340   substantial fine
# 3341   american reports
# 3342   individual judges
# 3343   interstate commerce
# 3344   laws
# 3345   infractions
# 3346   stare decisis
# 3347   contemporary english cases
# 3348   police brutality
# 3349   interstate commerce
# 3350   includes the power to decide the precedential effect of those cases and controversies
# 3351   supreme court
# 3352   federal constitutional rights
# 3353   local ordinances
# 3354   uniform commercial code
# 3355   gap
# 3356   mail
# 3357   federal government
# 3358   others
# 3359   slip law
# 3360   adopted a slightly different version of the greenman rule in section 402a of the restatement different version of the greenman rule in section 402a of the restatement
# 3361   united states
# 3362   legal statutory citation
# 3363   private parties
# 3364   constitution
# 3365   case
# 3366   state level
# 3367   supreme court
# 3368   subsequent statute
# 3369   yuba power products
# 3370   published volumes
# 3371   grant
# 3372   american people
# 3373   272,795 new cases
# 3374   session laws
# 3375   20th century
# 3376   west publishing
# 3377   territories
# 3378   others
# 3379   federal government
# 3380   scope
# 3381   warranty
# 3382   science
# 3383   others
# 3384   settlement
# 3385   local ordinances
# 3386   supreme court
# 3387   torts
# 3388   disappeared during the 19th century as american courts developed their own principles to resolve the legal problems of the american people
# 3389   carry the force of law as long as they are based on a reasonable interpretation of the relevant statutes
# 3390   american reports
# 3391   kozinski's analysis
# 3392   congress
# 3393   regulations
# 3394   decades
# 3395   two countries
# 3396   capital
# 3397   latin-derived florentine tuscan language
# 3398   subject
# 3399   language
# 3400   university
# 3401   closely related dialects
# 3402   companies' names
# 3403   languages
# 3404   regional dialect
# 3405   ukraine
# 3406   different languages
# 3407   different english dialects
# 3408   familiar environment
# 3409   dialekt mit an armey un flot
# 3410   german dialects
# 3411   qur'an
# 3412   fact
# 3413   linguistic phenomena
# 3414   major involvement
# 3415   separate languages
# 3416   hidden or latent language
# 3417   arabic dialects
# 3418   politically motivated `` absurdity
# 3419   italian national identity
# 3420   inter-dialect unintelligibility
# 3421   mutual intelligibility
# 3422   class
# 3423   ukrainian bolsheviks
# 3424   spoken varieties
# 3425   mutual unintelligibility
# 3426   language
# 3427   latin script
# 3428   yiddish speaker
# 3429   south
# 3430   german-speaking countries
# 3431   own right
# 3432   english language
# 3433   pure sicilian language variant
# 3434   language
# 3435   institutions
# 3436   another language
# 3437   language
# 3438   ukrainian bolsheviks
# 3439   standard average european
# 3440   two dialects
# 3441   question
# 3442   languages
# 3443   tyke
# 3444   prosody
# 3445   major dialect groups
# 3446   german dialectology
# 3447   latin-derived florentine tuscan language
# 3448   ausbau language
# 3449   regional dialect
# 3450   became regarded as subordinate `` dialects '' to italian with lack of education or provincialism
# 3451   sardinia
# 3452   a language
# 3453   language—"everybody
# 3454   "être
# 3455   term accent
# 3456   jamaican people
# 3457   influence
# 3458   numerous other varieties
# 3459   language
# 3460   south
# 3461   languages
# 3462   italian military
# 3463   language
# 3464   latin-derived florentine tuscan language
# 3465   yivo bleter
# 3466   inter-dialect unintelligibility
# 3467   "être
# 3468   beijing
# 3469   literacy rates
# 3470   politically motivated `` absurdity
# 3471   english language
# 3472   english
# 3473   traditional regional varieties
# 3474   wealth
# 3475   red
# 3476   orange and opposite violet
# 3477   open coffin
# 3478   ten horns
# 3479   little attention
# 3480   skin color
# 3481   christian faith
# 3482   brilliant new red
# 3483   one to two percent
# 3484   red flags
# 3485   danger
# 3486   men
# 3487   four sides
# 3488   oldest professional baseball team
# 3489   kermes dye
# 3490   achievement
# 3491   orange and opposite violet
# 3492   invention of the ruby laser in 1960
# 3493   beam
# 3494   whose predominant colors
# 3495   power
# 3496   red flags
# 3497   sick people
# 3498   rubia tinctorum plant
# 3499   used by romans
# 3500   ten horns
# 3501   repression
# 3502   professional sport and multiplayer video games
# 3503   spain
# 3504   gathered
# 3505   important religious symbolism
# 3506   crowd
# 3507   orange and opposite violet
# 3508   st. george's cross
# 3509
# 3510   christ
# 3511   blood pressure
# 3512   neolithic cave-burial
# 3513   schools
# 3514   little attention
# 3515   game
# 3516   virgin mary
# 3517   bright red
# 3518   1869
# 3519   five other colors
# 3520   clothes
# 3521   german nationalism
# 3522   madder plant
# 3523   magnificent red
# 3524   traditional patchwork quilt
# 3525   `` achievement '' context
# 3526   important religious symbolism
# 3527   christ
# 3528   virtual death sentence
# 3529   four sides
# 3530   day
# 3531   path
# 3532   socialist revolutionaries
# 3533   flamengo
# 3534   most visible color
# 3535   (originally redd hede
# 3536   messages
# 3537   color
# 3538   professional sport and multiplayer video games
# 3539   red paint
# 3540   rubia tinctorum plant
# 3541   1869
# 3542   ten horns
# 3543   black screen
# 3544   ten horns
# 3545   color
# 3546   vertebrates
# 3547   television
# 3548   red flag
# 3549   red
# 3550   rubia tinctorum plant
# 3551   certain herbs
# 3552   orange and opposite violet
# 3553   bright red
# 3554   s.l.
# 3555   red jerseys
# 3556   german nationalism
# 3557   known as alizarin
# 3558   more radical parties
# 3559   christ
# 3560   maximum intensity
# 3561   franco-prussian war
# 3562   colors
# 3563   prc
# 3564   emotions
# 3565   rubia tinctorum plant
# 3566   vertebrates
# 3567   "blue states
# 3568   modern-day turkey
# 3569   artisans
# 3570   rural middle class
# 3571   kermes dye
# 3572   television
# 3573   orange and opposite violet
# 3574   red shawl
# 3575   related insect
# 3576   related insect
# 3577   india
# 3578   pan-slavic connotations
# 3579   four sides
# 3580   red jerseys
# 3581   plant
# 3582   rouget de lisle
# 3583   `` red sun
# 3584   extremely inexpensive laser pointers
# 3585   red coloration
# 3586   prc
# 3587   red costumes
# 3588   color
# 3589   copper
# 3590   gold
# 3591   brother
# 3592   emotions
# 3593   colors
# 3594   red shawl
# 3595   french workers
# 3596   testosterone
# 3597   roughly 620–740 nanometres
# 3598   relatively low levels
# 3599   vertebrates
# 3600   eye
# 3601   zhou , han , jin , song and ming dynasties , red
# 3602   additive primary colors
# 3603   important role
# 3604   event
# 3605   vincent van gogh
# 3606   relatively low levels
# 3607   magnificent red
# 3608   mansions
# 3609   money
# 3610   alizarin crimson
# 3611   coccus
# 3612   oldest professional baseball team
# 3613   bright red
# 3614   highways
# 3615   power
# 3616   rouge d'adrinople
# 3617   rouge d'adrinople

# %% [markdown]
# # Train set test

# %%
import nltk
import json
import spacy
from nltk.corpus import stopwords
from math import log
from collections import defaultdict, Counter
from string import punctuation
from nltk.stem.wordnet import WordNetLemmatizer
import csv
from gensim.summarization import bm25

OPEN_QUESTION_WORDS = ['what', 'who', 'whose', 'whom', 'where', 'when', 'why', 'how',
                       'which', "what's", "who's", "where's", "how's"]
CLOSED_QUESTION_WORDS = ['is', 'are', 'am', 'was', 'were', 'do', 'does,', 'did', 'can',
                         'could', 'will', 'would', 'shall', 'should', 'have', 'has',
                         'had']

# Stop words
stop = set(stopwords.words('english'))

lmtz = WordNetLemmatizer()

with open('training.json') as json_data:
    train = json.load(json_data)

with open('documents.json') as json_data:
    documents = json.load(json_data)

# Spacy toolkit
nlp = spacy.load('en_core_web_sm')

punc = set(punctuation)


def strip_punctuation(s):
    return ''.join(c for c in s if c not in punc)


def lemmatize(token):
    lemma = lmtz.lemmatize(token, 'v')
    if lemma == token:
        lemma = lmtz.lemmatize(token, 'n')
    return lemma


def extract_term_freqs(doc):
    tfs = {}
    for token in nltk.word_tokenize(doc):
        lemma = lemmatize(token.lower())
        if lemma not in stop and lemma.isalpha():
            tfs[lemma] = tfs.get(lemma, 0) + 1
    return tfs


def compute_doc_freqs(doc_term_freqs):
    dfs = Counter()
    for tfs in doc_term_freqs.values():
        for term in tfs.keys():
            dfs[term] += tfs[term]
    return dfs


def query_vsm(query, index, k=10):
    accumulator = Counter()
    for term in query:
        postings = index[term]
        for docid, weight in postings:
            accumulator[docid] += weight
    return accumulator.most_common(k)


# Find the question word
def get_qword(question):
    tokens = nltk.word_tokenize(question.lower())
    for token in tokens:
        if token in OPEN_QUESTION_WORDS:
            return token
    for token in tokens:
        if token in CLOSED_QUESTION_WORDS:
            return token
    return 'others'


# length of longest same sequences of keywords
def get_overlap(sent1, sent2):
    tokens1 = []
    tokens2 = []

    for token in nltk.word_tokenize(strip_punctuation(sent1.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens1.append(lemma)

    for token in nltk.word_tokenize(strip_punctuation(sent2.lower())):
        lemma = lemmatize(token)
        if lemma not in stop:
            tokens2.append(lemma)

    max = 0
    for i in range(len(tokens1)):
        for j in range(len(tokens2)):

            if tokens1[i] == tokens2[j]:
                length = 1

                ii = i + 1
                jj = j + 1
                while ii < len(tokens1) and jj < len(tokens2) and \
                        tokens1[ii] == tokens2[jj]:
                    ii += 1
                    jj += 1
                    length += 1

                if length > max:
                    max = length

    return max


case_count = 0
# test = [test[17]]
for test_case in train:
    question = test_case['question']
    docid = test_case['docid']
    correct_answer = test_case['text']

    # Convert doc into one string, then tokenize sentences
    corpus = ''
    for para in documents[docid]['text']:
        corpus += para + ' '

    # sentence as a document
    raw_docs = nltk.sent_tokenize(corpus)

    # TFIDF
#     doc_term_freqs = {}
#     for (id, raw_doc) in enumerate(raw_docs):
#         term_freqs = extract_term_freqs(raw_doc)
#         doc_term_freqs[id] = term_freqs
#     M = len(doc_term_freqs)

#     doc_freqs = compute_doc_freqs(doc_term_freqs)

#     vsm_inverted_index = defaultdict(list)
#     for docid, term_freqs in doc_term_freqs.items():
#         N = sum(term_freqs.values())
#         length = 0

#         # find tf*idf values and accumulate sum of squares
#         tfidf_values = []
#         for term, count in term_freqs.items():
#             tfidf = float(count) / N * log(M / float(doc_freqs[term]))
#             tfidf_values.append((term, tfidf))
#             length += tfidf ** 2

#         # normalise documents by length and insert into index
#         length = length ** 0.5
#         for term, tfidf in tfidf_values:
#             # inversion of the indexing, term -> (doc_id, score)
#             vsm_inverted_index[term].append([docid, tfidf / length])

#     for term, docids in vsm_inverted_index.items():
#         docids.sort()

#     terms = extract_term_freqs(question)
#     results = query_vsm(terms, vsm_inverted_index)



    tokenized_sentence = []
    for each_sentence in raw_docs:
        filter_stop_word = []
        sentence_as_words = nltk.word_tokenize(each_sentence)
        for each_word in sentence_as_words:
            if each_word not in stop:
                filter_stop_word.append(each_word)
        
        tokenized_sentence.append(filter_stop_word)
        
    bm25Model = bm25.BM25(tokenized_sentence)
    average_idf = sum(map(lambda k: float(bm25Model.idf[k]), bm25Model.idf.keys())) / len(bm25Model.idf.keys())
    
    query = []
    for word in nltk.word_tokenize(question):
        if word not in stop:
            query.append(word)
        
    scores = bm25Model.get_scores(query,average_idf)
    bm25_dic = Counter()
    
    sentence_id = 0
    for each_score in scores:
        bm25_dic[sentence_id] = each_score
        sentence_id += 1
    results = bm25_dic.most_common(3)



    # Step 2
    # Analyse question type
    qword = get_qword(question)

    # the word after question word, such as 'what value', 'which gender'
    next_token = ''

    target = [] # target dep

    # dependency parsing
    dep = ''

    # head word
    head = ''

    # head dependency
    head_dep = ''

    # subject, root, object
    nsubj = ''
    ROOT = ''
    dobj = ''
    attr = ''

    # yes or no questions have two options
    closed_q_choices = ('', '')

    doc = nlp(question)

    tokens = nltk.word_tokenize(question.lower())

    # get next word
    if qword in tokens:
        if tokens.index(qword) < len(tokens) - 1:
            next_token = tokens[tokens.index(qword) + 1]

    # get structure of question
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            dobj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'attr' and token.head.dep_ == 'ROOT':
            attr = lemmatize(strip_punctuation(token.text))

    # determine answer dependency
    if qword in ['who', "who's", 'whom', 'whose']:
        for chunk in doc.noun_chunks:
            if qword in chunk.text:
                target = [chunk.root.dep_]

    elif qword in ['where', "where's", 'when']:
        target = ['advmod','prep']

    elif qword in ['how', "how's"]:
        if next_token in ['much', 'many','long','far', 'big', 'wide', 'deep', 'tall', 'high', 'fast', 'heavy','old', 'young']:
            target = ['attr']
        
        elif next_token in ['does', 'did', 'do', 'have', 'has', 'had', 'should',
                            'can', 'could', 'will', 'would', 'must']:
            if dobj != '':
                target = ['advmod', 'acomp']
            else:
                target = ['ROOT']

    elif qword in ['what', "what's", 'which']:
        # what...do type question
        tokens.remove(next_token)
        if 'do' in tokens:
            target = ['ROOT']
        else:
            for chunk in doc.noun_chunks:
                if qword in chunk.text:
                    target = [chunk.root.dep_]

    elif qword == 'why':
        target = ['mark','prep']

    elif qword in CLOSED_QUESTION_WORDS:
        # answer is one of the 'or' options in the question
        if 'or' in tokens:
            index = tokens.index('or')
            
            # dep of phrase before and after 'or'
            prev = tokens[index - 1]
            for chunk in doc.noun_chunks:
                if prev in chunk.text:
                    target = [chunk.root.dep_]
            
            if target == []:
                for token in doc:
                    if prev in token.text:
                        target = [token.dep_]

     # re-rank the sentences
    scores = {}
    for id, _ in results:
        sent = raw_docs[id]
        doc = nlp(sent)

        score = get_overlap(sent, question)

        for token in doc:
            if token.dep_ in target:
                score += 1

        scores[id] = score

    rank = {}
    for id, sim in results:
        max_score = scores[max(scores, key=scores.get)]
        if max_score != 0:
            rank[id] = sim * 0.3 + (scores[id] / max_score * 0.7)
        else:
            rank[id] = sim
    
    # sentence with highest rank
    index = max(rank, key=rank.get)
    sent = raw_docs[index]
    doc = nlp(sent)
                   
    # find answer with highest score from the highest ranking sentence
    max_score = -1
    answer = ''

    # find sentence structure
    sent_nsubj = ''
    sent_ROOT = ''
    sent_dobj = ''
    sent_attr = ''
    for token in doc:
        if 'nsubj' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_nsubj = lemmatize(strip_punctuation(token.text))
        if token.dep_ == 'ROOT':
            sent_ROOT = lemmatize(strip_punctuation(token.text))
        if 'dobj' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_dobj = lemmatize(strip_punctuation(token.text))
        if 'attr' in token.dep_ and token.head.dep_ == 'ROOT':
            sent_attr = lemmatize(strip_punctuation(token.text))

    score = 0
    if nsubj == sent_nsubj:
        score += 1
        if ROOT == sent_ROOT:
            score += 1
            if dobj == sent_dobj:
                score += 1
            if attr == sent_attr:
                score += 1

    max_score = -1
    answer = ''
    if target == ['ROOT'] or target == ['attr'] or target == ['advmod','acomp']:
        for token in doc:
            if token.dep_ in target:
                score += 1

                if token.text not in question:
                    score += 1

                if strip_punctuation(token.text).lower() in stop:
                    score = -1

                if token.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    answer = token.text

    elif target == ['mark','prep'] or target == ['advmod','prep']:
        for token in doc:
            if token.dep_ in target:
                score += 1

                if token.text not in question:
                    score += 1

                if strip_punctuation(token.text).lower() in stop:
                    score = -1

                if token.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    substr = sent[sent.index(token.text):]
                    tokens = nltk.word_tokenize(substr)
                    del tokens[0]
                    for token in tokens:
                        if token in punc:
                            break
                        answer += token+' '

    else:
        for chunk in doc.noun_chunks:
            if chunk.root.dep_ in target:
                score += 1

                if chunk.text not in question:
                    score += 1

                if strip_punctuation(chunk.text).lower() in stop:
                    score = -1

                if chunk.text.lower() == 'it':
                    score = -1

                if score > max_score:
                    max_score = score
                    answer = chunk.text
        
    # default answer
    if answer == '':
        for chunk in doc.noun_chunks:
            if chunk.text not in stop and chunk.text not in question:
                answer = chunk.text
        
    a = nltk.word_tokenize(answer)
    if len(a) > 0 and a[0].lower() in stop:
        del a[0]
        answer = ''
        for i in range(len(a)):
            if i+1 < len(a) and a[i+1] == "'s":
                answer += a[i]
            else:
                answer += a[i] + ' '
        
    if correct_answer != answer.strip().lower():
        print('Support: ',sent)
        print('***')
        print('Question: ',question)
        print('***')
        print('Correct: ',correct_answer)
        print('***')
        print('predicted: ',answer.strip().lower())
        print('\n')

    case_count += 1
# Out:
# Support:  A change of several tens of micrograms in one kilogram is equivalent to the current uncertainty in the value of the Planck constant in SI units.
# ***
# Question:  A kilogram could be definined as having a Planck constant of what value?
# ***
# Correct:  6966662606895999999♠6.62606896×10−34 j⋅s
# ***
# predicted:  si units
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# ***
# Question:  What is the shape of the object that establishes the base unit of the kilogram?
# ***
# Correct:  cylinder
# ***
# predicted:  fundamental physical constants
#
#
# Support:  In modern terms, if J is the total angular momentum of a system with rotational invariance, and Jz the angular momentum measured along any given direction, these quantities can only take on the values where the uncertainty is given as the standard deviation of the measured value from its expected value.
# ***
# Question:  What example is given as another paired relationship of uncertainly related to standard deviation?
# ***
# Correct:  time vs. energy
# ***
# predicted:  expected value
#
#
# Support:  It is defined in terms of the reduced Planck constant, the elementary charge and the electron mass, all of which depend on the Planck constant: the final dependence on h1/2 (r2 > 0.995) can be found by expanding the variables.
# ***
# Question:  What does the Planck Constant refer to?
# ***
# Correct:  quantum of action
# ***
# predicted:  variables
#
#
# Support:  Niels Bohr introduced the first quantized model of the atom in 1913, in an attempt to overcome a major shortcoming of Rutherford's classical model.
# ***
# Question:  When was the first quantized model of the atom introduced?
# ***
# Correct:  1913
# ***
# predicted:  rutherford's classical model
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# ***
# Question:  What scientist first studied black body radiation?
# ***
# Correct:  kirchhoff
# ***
# predicted:  associated electromagnetic wave
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  Who helped to give the correct quantization rules for electrons in 1926?
# ***
# Correct:  schrödinger
# ***
# predicted:  angular momentum
#
#
# Support:  Classical statistical mechanics requires the existence of h (but does not define its value).
# ***
# Question:  What is required to exist in classical statistics mechanics?
# ***
# Correct:  h
# ***
# predicted:  value
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  How much energy is contained in the light to which human eyes are most sensitive?
# ***
# Correct:  7005216000000000000♠216 kj/mol
# ***
# predicted:  hz
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What is frequency also known as in science?
# ***
# Correct:  f
# ***
# predicted:  temperature
#
#
# Support:  It was first observed by Alexandre Edmond Becquerel in 1839, although credit is usually reserved for Heinrich Hertz, who published the first thorough investigation in 1887.
# ***
# Question:  When was the photoelectric effect first observed?
# ***
# Correct:  1839
# ***
# predicted:  observed by alexandre edmond becquerel in 1839
#
#
# Support:  These proofs are commonly known as the "ultraviolet catastrophe", a name coined by Paul Ehrenfest in 1911.
# ***
# Question:  When did Paul Ehrenfest come up with the name "ultraviolet catastrophe"?
# ***
# Correct:  1911
# ***
# predicted:  known as the `` ultraviolet catastrophe ''
#
#
# Support:  It was first observed by Alexandre Edmond Becquerel in 1839, although credit is usually reserved for Heinrich Hertz, who published the first thorough investigation in 1887.
# ***
# Question:  Who first observed the photoelectric effect?
# ***
# Correct:  alexandre edmond becquerel
# ***
# predicted:  first thorough investigation
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# ***
# Question:  What is the term used when photoelectrons act virtually at the same time?
# ***
# Correct:  multiphoton effect
# ***
# predicted:  higher kinetic energy
#
#
# Support:  The Bohr magneton and the nuclear magneton are units which are used to describe the magnetic properties of the electron and atomic nuclei respectively.
# ***
# Question:  What is the unit of magentic properties of atomic nuclei?
# ***
# Correct:  nuclear magneton
# ***
# predicted:  electron and atomic nuclei
#
#
# Support:  In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.
# ***
# Question:  Who discovered an association between the value E and quantum energy?
# ***
# Correct:  einstein
# ***
# predicted:  electromagnetic wave
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  At about what wavelength of light are human eyes most sensitive?
# ***
# Correct:  555 nanometres
# ***
# predicted:  hz
#
#
# Support:  It was first observed by Alexandre Edmond Becquerel in 1839, although credit is usually reserved for Heinrich Hertz, who published the first thorough investigation in 1887.
# ***
# Question:  Who first observed the photoelectric effect?
# ***
# Correct:  alexandre edmond becquerel
# ***
# predicted:  first thorough investigation
#
#
# Support:  The very first Solvay Conference in 1911 was devoted to "the theory of radiation and quanta".
# ***
# Question:  When was the first Solvay Conference held?
# ***
# Correct:  1911
# ***
# predicted:  quanta
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# ***
# Question:  Who received the Nobel Prize in 1921 for his work on the photoelectric effect?
# ***
# Correct:  einstein
# ***
# predicted:  robert andrews millikan
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What assumption that black-body radiation is what leads to an accurate prediction?
# ***
# Correct:  thermal
# ***
# predicted:  total amount
#
#
# Support:  That is a very small amount of energy in terms of everyday experience, but everyday experience is not concerned with individual photons any more than with individual atoms or molecules.
# ***
# Question:  What term describes a small amount of element?
# ***
# Correct:  quantum
# ***
# predicted:  molecules
#
#
# Support:  In many cases, such as for monochromatic light or for atoms, this quantum of action also implies that only certain energy levels are allowed, and values in between are forbidden.
# ***
# Question:  Regarding atoms, what are values in between certain energy levels considered by the Planck constant?
# ***
# Correct:  forbidden
# ***
# predicted:  certain energy levels
#
#
# Support:  Prior to Einstein's paper, electromagnetic radiation such as visible light was considered to behave as a wave: hence the use of the terms "frequency" and "wavelength" to characterise different types of radiation.
# ***
# Question:  Before Einstein, electromagnetic radiation was considered to behave as what?
# ***
# Correct:  a wave
# ***
# predicted:  radiation
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What color of light is the human eye most sensitive to?
# ***
# Correct:  green
# ***
# predicted:  hz
#
#
# Support:  The black-body problem was revisited in 1905, when Rayleigh and Jeans (on the one hand) and Einstein (on the other hand) independently proved that classical electromagnetism could never account for the observed spectrum.
# ***
# Question:  Einstein and what other two individuals revisited the black-body problem in 1905?
# ***
# Correct:  rayleigh and jeans
# ***
# predicted:  einstein
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  Which scientist associated the Planck constant with a quantum five years after Planck's recognition?
# ***
# Correct:  einstein
# ***
# predicted:  angular momentum
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What type of changes in the light a hot object emits as the object's temperature changes?
# ***
# Correct:  colour
# ***
# predicted:  temperature
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What is the frequency of the light to which the human eye is most sensitive?
# ***
# Correct:  7014540000000000000♠540 thz
# ***
# predicted:  hz
#
#
# Support:  These proofs are commonly known as the "ultraviolet catastrophe", a name coined by Paul Ehrenfest in 1911.
# ***
# Question:  What name did Paul Ehrenfest give to the proofs from Einstein and Rayleigh & Jeans?
# ***
# Correct:  the `` ultraviolet catastrophe ''
# ***
# predicted:  name
#
#
# Support:  The Planck constant is given by There are a number of proposals to redefine certain of the SI base units in terms of fundamental physical constants.
# ***
# Question:  What measurement is deemed most important to redefine in terms of physical constants?
# ***
# Correct:  the kilogram
# ***
# predicted:  fundamental physical constants
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What is the energy transferred by a wave in a given time called?
# ***
# Correct:  intensity
# ***
# predicted:  energy
#
#
# Support:  The most likely reason is that the measurement uncertainty for one (or both) of the methods has been estimated too low – it is (or they are) not as precise as is currently believed – but for the time being there is no indication which method is at fault.
# ***
# Question:  What method was was used to obtain the measurement?
# ***
# Correct:  watt-balance measurement
# ***
# predicted:  fault
#
#
# Support:  Making an equation out of Planck's law that would reproduce the Rayleigh–Jeans law could not be done by changing the values of h, of the Boltzmann constant, or of any other constant or variable in the equation.
# ***
# Question:  Using Planck constant values from these effects would lead to what logical issue?
# ***
# Correct:  a circular argument
# ***
# predicted:  equation
#
#
# Support:  Possible new definitions include "the mass of a body at rest whose equivalent energy equals the energy of photons whose frequencies sum to 7050135639273999999♠135639274×1042 Hz", or simply "the kilogram is defined so that the Planck constant equals 6966662606895999999♠6.62606896×10−34 J⋅s".
# ***
# Question:  The mass of a resting body with what energy would be equal to a kilogram?
# ***
# Correct:  7050135639273999999♠135639274×1042 hz
# ***
# predicted:  j⋅s
#
#
# Support:  In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.
# ***
# Question:  What is considered the minimal energy increment of a hypothetical oscillator?
# ***
# Correct:  value e
# ***
# predicted:  electromagnetic wave
#
#
# Support:  This kinetic energy (for each photoelectron) is independent of the intensity of the light, but depends linearly on the frequency; and if the frequency is too low (corresponding to a photon energy that is less than the work function of the material), no photoelectrons are emitted at all, unless a plurality of photons, whose energetic sum is greater than the energy of the photoelectrons, acts virtually simultaneously (multiphoton effect)  Assuming the frequency is high enough to cause the photoelectric effect, a rise in intensity of the light source causes more photoelectrons to be emitted with the same kinetic energy, rather than the same number of photoelectrons to be emitted with higher kinetic energy.
# ***
# Question:  What does the kinetic energy of a photoelectron depend on?
# ***
# Correct:  the frequency
# ***
# predicted:  higher kinetic energy
#
#
# Support:  It was eventually called the photon.
# ***
# Question:  What was later termed the photon?
# ***
# Correct:  the light quantum
# ***
# predicted:
#
#
# Support:  The X-ray crystal density method is primarily a method for determining the Avogadro constant NA but as the Avogadro constant is related to the Planck constant it also determines a value for h. The principle behind the method is to determine NA as the ratio between the volume of the unit cell of a crystal, measured by X-ray crystallography, and the molar volume of the substance.
# ***
# Question:  What element is used typically to establish Avogadro's constant?
# ***
# Correct:  crystals of silicon
# ***
# predicted:  substance
#
#
# Support:  There are a number of other such pairs of physically measurable values which obey a similar rule.
# ***
# Question:   What measurable value obeys a similar rule of angular momentum?
# ***
# Correct:  time vs. energy
# ***
# predicted:  physically measurable values
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What other types of wave besides light has its own intensity?
# ***
# Correct:  sound
# ***
# predicted:  given time
#
#
# Support:  First recognized in 1900 by Max Planck, it was originally the proportionality constant between the minimal increment of energy, E, of a hypothetical electrically charged oscillator in a cavity that contained black body radiation, and the frequency, f, of its associated electromagnetic wave.
# ***
# Question:  What do scientists assume black body radiation is?
# ***
# Correct:  thermal
# ***
# predicted:  associated electromagnetic wave
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  What frequency does green light with a wavelength of 555 nanmetres have?
# ***
# Correct:  7014540000000000000♠540 thz
# ***
# predicted:  hz
#
#
# Support:  The either-or nature of uncertainty forces measurement attempts to choose between trade offs, and given that they are quanta, the trade offs often take the form of either-or (as in Fourier analysis), rather than the compromises and gray areas of time series analysis.
# ***
# Question:  What type of analysis fits the either-or nature of the uncertainty?
# ***
# Correct:  fourier analysis
# ***
# predicted:  time series analysis
#
#
# Support:  The electromagnetic field obeys laws of motion similarly to a mass on a spring, and can come to thermal equilibrium with hot atoms.
# ***
# Question:  Electromagnetic fields obey what laws?
# ***
# Correct:  laws of motion
# ***
# predicted:  hot atoms
#
#
# Support:  For example, green light with a wavelength of 555 nanometres (the approximate wavelength to which human eyes are most sensitive) has a frequency of 7014540000000000000♠540 THz (7014540000000000000♠540×1012 Hz).
# ***
# Question:  Which light wavelength is the human eye most sensitive to?
# ***
# Correct:  555 nanometres
# ***
# predicted:  hz
#
#
# Support:  They contributed greatly (along with Einstein's work on the photoelectric effect) to convincing physicists that Planck's postulate of quantized energy levels was more than a mere mathematical formalism.
# ***
# Question:  Einstein's photoelectric effect work was rewards as opposed to his work on what other topic?
# ***
# Correct:  relativity
# ***
# predicted:  mere mathematical formalism
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  What is the reduced Planck constant also known as?
# ***
# Correct:  the quantity
# ***
# predicted:  angular momentum
#
#
# Support:  Max Planck received the 1918 Nobel Prize in Physics "in recognition of the services he rendered to the advancement of Physics by his discovery of energy quanta".
# ***
# Question:  In what year did Planck receive the Nobel Prize in Physics for his discovery of energy quanta?
# ***
# Correct:  1918
# ***
# predicted:  energy
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  What type of radiation was Planck studying in the late 19th century?
# ***
# Correct:  black-body
# ***
# predicted:  kirchhoff
#
#
# Support:  To make Planck's law, which correctly predicts blackbody emissions, it was necessary to multiply the classical expression by a complex factor that involves h in both the numerator and the denominator.
# ***
# Question:  In making Planck's law, what was in both the numerator and denominator of the formula that was used?
# ***
# Correct:  h
# ***
# predicted:  denominator
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  What is the Planck constant formerly known as?
# ***
# Correct:  quantum of action
# ***
# predicted:  angular momentum
#
#
# Support:  The result is that green light of wavelength 555 nm has an energy of 7005216000000000000♠216 kJ/mol, a typical energy of everyday life.
# ***
# Question:  How much energy does a green light of wavelength 555 nm contain?
# ***
# Correct:  7005216000000000000♠216 kj/mol
# ***
# predicted:  everyday life
#
#
# Support:  Nevertheless, Wilhelm Wien discovered the mathematical relationship between the peaks of the curves at different temperatures, by using the principle of adiabatic invariance.
# ***
# Question:  Who discovered the mathematical relationship between peaks and curves of light at different temperatures?
# ***
# Correct:  wilhelm wien
# ***
# predicted:  adiabatic invariance
#
#
# Support:  Bohr solved this paradox with explicit reference to Planck's work: an electron in a Bohr atom could only have certain defined energies En Bohr also introduced the quantity , now known as the reduced Planck constant, as the quantum of angular momentum.
# ***
# Question:  Who introduced the reduced Planck constant?
# ***
# Correct:  bohr
# ***
# predicted:  angular momentum
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  What scientist used matrix mechanics to bring electron behavior in line with the Bohr model?
# ***
# Correct:  heisenberg
# ***
# predicted:  angular momentum
#
#
# Support:  The Rayleigh–Jeans law makes close predictions for a narrow range of values at one limit of temperatures, but the results diverge more and more strongly as temperatures increase.
# ***
# Question:  What rule predicted narrow range of energy values at lower temperatures?
# ***
# Correct:  the rayleigh–jeans
# ***
# predicted:  results
#
#
# Support:  The most urgent unit on the list for redefinition is the kilogram, whose value has been fixed for all science (since 1889) by the mass of a small cylinder of platinum–iridium alloy kept in a vault just outside Paris.
# ***
# Question:  What alloy is the base unit of the kilogram made from?
# ***
# Correct:  platinum–iridium
# ***
# predicted:  paris
#
#
# Support:  To make Planck's law, which correctly predicts blackbody emissions, it was necessary to multiply the classical expression by a complex factor that involves h in both the numerator and the denominator.
# ***
# Question:  What does Planck's law correctly predict?
# ***
# Correct:  blackbody emissions
# ***
# predicted:  denominator
#
#
# Support:  Niels Bohr introduced the first quantized model of the atom in 1913, in an attempt to overcome a major shortcoming of Rutherford's classical model.
# ***
# Question:  Who modeled the atom in 1913, challenging Rutherford's model?
# ***
# Correct:  niels bohr
# ***
# predicted:  rutherford's classical model
#
#
# Support:  The CODATA value quoted here is based on three watt-balance measurements of KJ2RK and one inter-laboratory determination of the molar volume of silicon, but is mostly determined by a 2007 watt-balance measurement made at the U.S. National Institute of Standards and Technology (NIST).
# ***
# Question:  The value quoted here for the Planck constant is based on a measurement in what year?
# ***
# Correct:  2007
# ***
# predicted:  standards
#
#
# Support:  Each photon has an energy E = hf = 6981358000000000000♠3.58×10−19 J.
# ***
# Question:  What is the energy of a photon?
# ***
# Correct:  6981358000000000000♠3.58×10−19 j
# ***
# predicted:  j.
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What color is hotter than "red hot"?
# ***
# Correct:  white hot
# ***
# predicted:  temperature
#
#
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  Planck studied what problem posed originally by Kirchhoff?
# ***
# Correct:  black-body radiation
# ***
# predicted:  planck
#
#
# Support:  The energy transferred by a wave in a given time is called its intensity.
# ***
# Question:  What is the name for the amount of energy transfered by a wave in a given time?
# ***
# Correct:  intensity
# ***
# predicted:  energy
#
#
# Support:  Einstein's 1905 paper discussing the effect in terms of light quanta would earn him the Nobel Prize in 1921, when his predictions had been confirmed by the experimental work of Robert Andrews Millikan.
# ***
# Question:  Einstein's paper on the photoelectric effect earned him the Nobel Prize in what year?
# ***
# Correct:  1921
# ***
# predicted:  robert andrews millikan
#
#
# Support:  The correct quantization rules for electrons – in which the energy reduces to the Bohr model equation in the case of the hydrogen atom – were given by Heisenberg's matrix mechanics in 1925 and the Schrödinger wave equation in 1926: the reduced Planck constant remains the fundamental quantum of angular momentum.
# ***
# Question:  Who helped to give the correct quantization rules for electrons in 1925?
# ***
# Correct:  heisenberg
# ***
# predicted:  angular momentum
#
#
# Support:  However, the energy account of the photoelectric effect didn't seem to agree with the wave description of light.
# ***
# Question:  What portion of the photoelectric effect was in disagreement with the believed description of light behavior?
# ***
# Correct:  the energy account
# ***
# predicted:  wave description
#
#
# Support:  But it was also known that the colour of the light given off by a hot object changes with the temperature, so that "white hot" is hotter than "red hot".
# ***
# Question:  What law describes the changes in light emitted by a hot object?
# ***
# Correct:  stefan–boltzmann law
# ***
# predicted:  temperature
#
#
# Support:  Niels Bohr introduced the first quantized model of the atom in 1913, in an attempt to overcome a major shortcoming of Rutherford's classical model.
# ***
# Question:  Who introduced the first quantized model of the atom?
# ***
# Correct:  niels bohr
# ***
# predicted:  rutherford's classical model
#
#
# Support:  In 1905 the value E, the minimal energy increment of a hypothetical oscillator, was theoretically associated by Einstein with a "quantum" or minimal element of the energy of the electromagnetic wave itself.
# ***
# Question:  In what year was the value E associated by Einstein with quantum theories of energy?
# ***
# Correct:  1905
# ***
# predicted:  electromagnetic wave
#
#
# Support:  Max Planck received the 1918 Nobel Prize in Physics "in recognition of the services he rendered to the advancement of Physics by his discovery of energy quanta".
# ***
# Question:  Who received the Nobel Prize in Physics in 1918?
# ***
# Correct:  max planck
# ***
# predicted:  energy
#
#
# Support:  Prior to Einstein's paper, electromagnetic radiation such as visible light was considered to behave as a wave: hence the use of the terms "frequency" and "wavelength" to characterise different types of radiation.
# ***
# Question:  Prior to Einstein's work, light behavior was modeled as what?
# ***
# Correct:  a wave
# ***
# predicted:  radiation
# Support:  In the last years of the nineteenth century, Planck was investigating the problem of black-body radiation first posed by Kirchhoff some forty years earlier.
# ***
# Question:  How many years prior to Planck's study had the scientific community first discussed black body radiation?
# ***
# Correct:  forty
# ***
# predicted:  kirchhoff
#
#
# Support:  The very first Solvay Conference in 1911 was devoted to "the theory of radiation and quanta".
# ***
# Question:  When was the first Solvay Conference held?
# ***
# Correct:  1911
# ***
# predicted:  quanta
#
#
# Support:  The hot object in equilibrium with light absorbs just as much light as it emits.
# ***
# Question:  What does a hot object in equilibrium absorb as much as it emits?
# ***
# Correct:  light
# ***
# predicted:  as much light
#
#
# Support:  It is well known that hot objects glow, and that hotter objects glow brighter than cooler ones.
# ***
# Question:  Cooler objects glow less than objects that are what?
# ***
# Correct:  hotter
# ***
# predicted:  cooler ones
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What kind of prediction does the assumption that black body radiation is thermal lead to?
# ***
# Correct:  accurate
# ***
# predicted:  definite rule
#
#
# Support:  The assumption that black-body radiation is thermal leads to an accurate prediction: the total amount of emitted energy goes up with the temperature according to a definite rule, the Stefan–Boltzmann law (1879–84).
# ***
# Question:  What rule predicts that emitted energy increases with temperature?
# ***
# Correct:  the stefan–boltzmann law
# ***
# predicted:  definite rule
#
#
# Support:  Global wind power installations increased by 35,800 MW in 2010, bringing total installed capacity up to 194,400 MW, a 22.5% increase on the 158,700 MW installed at the end of 2009.
# ***
# Question:  Global wind power installations increased by how much in 2010?
# ***
# Correct:  35,800 mw
# ***
# predicted:  end
#
#
# Support:  According to a 2011 projection by the International Energy Agency, solar power plants may produce most of the world's electricity within 50 years, significantly reducing the emissions of greenhouse gases that harm the environment.
# ***
# Question:  Which group projected that solar plant may produce most of the world's electricity within 50 years?
# ***
# Correct:  international energy agency
# ***
# predicted:  environment
#
#
# Support:  Also in 2006, the Stern Review made a strong economic case for investing in low carbon technologies now, and argued that economic growth need not be incompatible with cutting energy consumption.
# ***
# Question:  What made a strong economic case for investing in low carbon technologies?
# ***
# Correct:  stern review
# ***
# predicted:  energy consumption
#
#
# Support:  Renewable energy technologies are getting cheaper, through technological change and through the benefits of mass production and market competition.
# ***
# Question:  What is getting cheaper as a result of technilogical change?
# ***
# Correct:  renewable energy technologies
# ***
# predicted:  market competition
#
#
# Support:  Public policy determines the extent to which renewable energy (RE) is to be incorporated into a developed or developing country's generation mix.
# ***
# Question:  What determines the extent to which renewable energy is to be incorporated into a country's generation mix?
# ***
# Correct:  public policy
# ***
# predicted:  developed or developing country's generation mix
#
#
# Support:  A number of events in 2006 pushed renewable energy up the political agenda, including the US mid-term elections in November, which confirmed clean energy as a mainstream issue.
# ***
# Question:  In what year did a number of events push renewable energy up the political agenda?
# ***
# Correct:  2006
# ***
# predicted:  mainstream issue
#
#
# Support:  The company ceased all business activity, filed for Chapter 11 bankruptcy, and laid-off nearly all of its employees in early September 2011.
# ***
# Question:  What company filed for Chapter 11 bankruptcy?
# ***
# Correct:  solyndra
# ***
# predicted:  early september
#
#
# Support:  Worldwide investment in solar power in 2012 was $140.4 billion, an 11 percent decline from 2011, and wind power investment was down 10.1 percent, to $80.3 billion.
# ***
# Question:  How much was the worldwide investment in solar power in 2012?
# ***
# Correct:  $ 140.4 billion
# ***
# predicted:  billion
#
#
# Support:  The incentive to use 100% renewable energy, for electricity, transport, or even total primary energy supply globally, has been motivated by global warming and other ecological as well as economic concerns.
# ***
# Question:  What motivated the incentive to use 100 percent renewable energy?
# ***
# Correct:  global warming
# ***
# predicted:  economic concerns
#
#
# Support:  There are now three hydroelectricity plants larger than 10 GW: the Three Gorges Dam in China, Itaipu Dam across the Brazil/Paraguay border, and Guri Dam in Venezuela.
# ***
# Question:  How many hydroelectricity plants are larger than 10 GW?
# ***
# Correct:  three
# ***
# predicted:  plants
#
#
# Support:  Jacobson says that energy costs with a wind, solar, water system should be similar to today's energy costs.
# ***
# Question:  Who stated that energy costs with a wind, solar, water system should be similar to today's energy costs?
# ***
# Correct:  mark z. jacobson
# ***
# predicted:  jacobson
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# ***
# Question:  Photovoltaic and solar-thermal plants may meet how much of the world's energy needs by 2060?
# ***
# Correct:  half
# ***
# predicted:  remaining generation
#
#
# Support:  Setting national renewable energy targets can be an important part of a renewable energy policy and these targets are usually defined as a percentage of the primary energy and/or electricity generation mix.
# ***
# Question:  Setting national renewable energy targets can be an important part of what?
# ***
# Correct:  renewable energy policy
# ***
# predicted:  primary energy and/or electricity generation mix
#
#
# Support:  Solar thermal power stations include the 354 megawatt (MW) Solar Energy Generating Systems power plant in the USA, Solnova Solar Power Station (Spain, 150 MW), Andasol solar power station (Spain, 100 MW), Nevada Solar One (USA, 64 MW), PS20 solar power tower (Spain, 20 MW), and the PS10 solar power tower (Spain, 11 MW).
# ***
# Question:  Where is the PS20 solar power tower located?
# ***
# Correct:  spain
# ***
# predicted:  11 mw
#
#
# Support:  Solar electricity consumption increased by 58 percent, to 93 terawatt-hours (TWh).
# ***
# Question:  In 2012, solar electricity consumption increased by what percentage?
# ***
# Correct:  58 percent
# ***
# predicted:  93 terawatt-hours
#
#
# Support:  Use of wind power in 2012 increased by 18.1 percent, to 521.3 TWh.
# ***
# Question:  Use of wind power in 2012 increased by what percentage?
# ***
# Correct:  18.1 percent
# ***
# predicted:  521.3 twh
#
#
# Support:  Setting national renewable energy targets can be an important part of a renewable energy policy and these targets are usually defined as a percentage of the primary energy and/or electricity generation mix.
# ***
# Question:  Renewables contributed what percentage to our electricity generation?
# ***
# Correct:  22 percent
# ***
# predicted:  national renewable energy targets
#
#
# Support:  In 2011, UN under-secretary general Achim Steiner said: "The continuing growth in this core segment of the green economy is not happening by chance.
# ***
# Question:  Who was the UN under-secretary in 2011?
# ***
# Correct:  achim steiner
# ***
# predicted:  chance
#
#
# Support:  First-generation biomass technologies can be economically competitive, but may still require deployment support to overcome public acceptance and small-scale issues.
# ***
# Question:  What can be economically competetive but may still require deployment support?
# ***
# Correct:  first-generation biomass technologies
# ***
# predicted:  small-scale issues
#
#
# Support:  Renewables are becoming increasingly economic in both developing and developed countries.
# ***
# Question:  What is becoming increasingly economic in both developing and devloped countries?
# ***
# Correct:  renewables
# ***
# predicted:  developing and developed countries
#
#
# Support:  In 2011, UN under-secretary general Achim Steiner said: "The continuing growth in this core segment of the green economy is not happening by chance.
# ***
# Question:  Who is Achim Steiner?
# ***
# Correct:  un under-secretary general
# ***
# predicted:  chance
#
#
# Support:  It involves lowering income taxes while raising levies on environmentally destructive activities, in order to create a more responsive market.
# ***
# Question:  What involves lowering income taxes while raising levies?
# ***
# Correct:  tax shifting
# ***
# predicted:  more responsive market
# Support:  Wind power accounts for approximately 19% of electricity generated in Denmark, 9% in Spain and Portugal, and 6% in Germany and the Republic of Ireland.
# ***
# Question:  In Denmark, wind power accounts for what percentage of electricity generated?
# ***
# Correct:  19 %
# ***
# predicted:  ireland
#
#
# Support:  Other developed countries with defined national or regional targets include Australia, Canada, Israel, Japan, Korea, New Zealand, Norway, Singapore, Switzerland, and some US States.
# ***
# Question:  Name one outher country with defined national or regional target?
# ***
# Correct:  australia
# ***
# predicted:  us states
#
#
# Support:  Barriers to implementing the renewable energy plan are seen to be "primarily social and political, not technological or economic".
# ***
# Question:  What is a barrier to implementing the renewable energy plan?
# ***
# Correct:  social and political
# ***
# predicted:  barriers
#
#
# Support:  The 230 MW Antelope Valley Solar Ranch is a First Solar photovoltaic project which is under construction in the Antelope Valley area of the Western Mojave Desert, and due to be completed in 2013.
# ***
# Question:  Who is building The Califoria Valley Solar Ranch?
# ***
# Correct:  sunpower
# ***
# predicted:  western mojave desert
#
#
# Support:  The group is to be co-chaired by Kandeh Yumkella, the chair of UN Energy and director general of the UN Industrial Development Organisation, and Charles Holliday, chairman of Bank of America".
# ***
# Question:  Who is chair of UN Energy?
# ***
# Correct:  kandeh yumkella
# ***
# predicted:  america
#
#
# Support:  The IEA has said: "Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by 2060 – and half of all energy needs – with wind, hydropower and biomass plants supplying much of the remaining generation".
# ***
# Question:  Photovoltaic and solar-thermal plants may meet most of the world's demand for electricity by what year?
# ***
# Correct:  2060
# ***
# predicted:  remaining generation
#
#
# Support:  Nearly all the gasoline sold in the United States today is mixed with 10 percent ethanol, a mix known as E10, and motor vehicle manufacturers already produce vehicles designed to run on much higher ethanol blends.
# ***
# Question:  Nearly all gasoline sold in the U.S. is mixed with what percentage of ethanol?
# ***
# Correct:  10 percent
# ***
# predicted:  much higher ethanol blends
#
#
# Support:  Setting national renewable energy targets can be an important part of a renewable energy policy and these targets are usually defined as a percentage of the primary energy and/or electricity generation mix.
# ***
# Question:  Hydroelectricity accounts for what percentage of global electricity generation?
# ***
# Correct:  hydroelectricity
# ***
# predicted:  primary energy and/or electricity generation mix
#
#
# Support:  Ford, DaimlerChrysler, and GM are among the automobile companies that sell flexible-fuel cars, trucks, and minivans that can use gasoline and ethanol blends ranging from pure gasoline up to 85% ethanol (E85).
# ***
# Question:  Name one company that sells flexible-fuel cars?
# ***
# Correct:  gm
# ***
# predicted:  e85
#
#
# Support:  In some countries, geothermal power accounts for a significant share of the total electricity supply, such as in the Philippines, where geothermal represented 17 percent of the total power mix at the end of 2008.
# ***
# Question:  What was the geothermal capacity in 2008?
# ***
# Correct:  10 gw
# ***
# predicted:  end
#
#
# Support:  Lester Brown states that the market "does not incorporate the indirect costs of providing goods or services into prices, it does not value nature's services adequately, and it does not respect the sustainable-yield thresholds of natural systems".
# ***
# Question:  Who believes that the market does not value nature's service adequately?
# ***
# Correct:  lester brown
# ***
# predicted:  natural systems
#
#
# Support:  As of 2012, renewable energy plays a major role in the energy mix of many countries globally.
# ***
# Question:  How many countries now have renewable energy policies?
# ***
# Correct:  144
# ***
# predicted:  energy mix
#
#
# Support:  Based on REN21's 2014 report, renewables contributed 19 percent to our energy consumption and 22 percent to our electricity generation in 2012 and 2013, respectively.
# ***
# Question:  Renewables contributed what percentage to our energy consumption?
# ***
# Correct:  19 percent
# ***
# predicted:  electricity generation
#
#
# Support:  Dedicated energy crops, such as switchgrass, are also promising cellulose sources that can be sustainably produced in many regions.
# ***
# Question:  What is a promising cellulose source that can be sustainably produced in many regions?
# ***
# Correct:  dedicated energy crops
# ***
# predicted:  cellulose sources
#
#
# Support:  In terms of specific examples, the Internet was the result of publicly funded links among computers in government laboratories and research institutes.
# ***
# Question:  What was the result of publicly funded links among computers in government labs and reserach institutes?
# ***
# Correct:  the internet
# ***
# predicted:  research institutes
#
#
# Support:  As of 2011[update], there have been substantial reductions in the cost of solar and wind technologies: Renewable energy is also the most economic solution for new grid-connected capacity in areas with good resources.
# ***
# Question:  As of what year have there been substantial reductions in the cost of solar and wind technologies?
# ***
# Correct:  2011
# ***
# predicted:  good resources
#
#
# Support:  The 370 MW Ivanpah Solar Power Facility, located in California's Mojave Desert, is the world's largest solar-thermal power plant project currently under construction.
# ***
# Question:  Where is the Ivanpah Solar Power Facility located?
# ***
# Correct:  california 's mojave desert
# ***
# predicted:  construction
#
#
# Support:  The PV industry has seen drops in module prices since 2008.
# ***
# Question:  The PV industry has seen drops in module prices since what year?
# ***
# Correct:  2008
# ***
# predicted:  module prices
#
#
# Support:  As of 2012, renewable energy accounts for about half of new nameplate electrical capacity installed and costs are continuing to fall.
# ***
# Question:  As of 2012, what accounts for about half of new nameplate electrical capacity?
# ***
# Correct:  renewable energy
# ***
# predicted:  renewable energy accounts
#
#
# Support:  It is the most widely used form of renewable energy, accounting for 16 percent of global electricity generation – 3,427 terawatt-hours of electricity production in 2010, and is expected to increase about 3.1% each year for the next 25 years.
# ***
# Question:  What is the most widely used form of renewable energy?
# ***
# Correct:  hydroelectricity
# ***
# predicted:  next 25 years
#
#
# Support:  Wind power accounts for approximately 19% of electricity generated in Denmark, 9% in Spain and Portugal, and 6% in Germany and the Republic of Ireland.
# ***
# Question:  In Spain, wind power accounts for what percentage of electricity generated?
# ***
# Correct:  9 %
# ***
# predicted:  ireland
#
#
# Support:  United Nations' Secretary-General Ban Ki-moon has said that "renewable energy has the ability to lift the poorest nations to new levels of prosperity".
# ***
# Question:  Ban Ki-moon states that renewable energy has the ability to lift the poorest nations to new levels of prosperity?
# ***
# Correct:  renewable energy
# ***
# predicted:  united nations' secretary-general ban ki-moon
#
#
# Support:  As a share of total investment in power plants, wind and solar PV grew from 14% in 2000 to over 60% in 2012.
# ***
# Question:  How much was the total investment in renewable energy in 2012?
# ***
# Correct:  $ 244 billion
# ***
# predicted:  60 %
#
#
# Support:  According to the directive the EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed and therefore a "guarantee of origin" must be issued (article 15).
# ***
# Question:  What states that EU Member States must ensure that the origin of electricity produced from renewables can be guaranteed?
# ***
# Correct:  res directive
# ***
# predicted:  article
#
#
# Support:  Analysts expect the market to triple by 2030.
# ***
# Question:  Analysts expect the market to triple by what year?
# ***
# Correct:  2030
# ***
# predicted:
#
#
# Support:  Geothermal power capacity grew from around 1 GW in 1975 to almost 10 GW in 2008.
# ***
# Question:  What was the geothermal capacity in 1975?
# ***
# Correct:  1 gw
# ***
# predicted:  almost 10 gw
#
#
# Support:  A 2011 IEA report said: "A portfolio of renewable energy technologies is becoming cost-competitive in an increasingly broad range of circumstances, in some cases providing investment opportunities without the need for specific economic support," and added that "cost reductions in critical technologies, such as wind and solar, are set to continue."
# ***
# Question:  What group stated that "cost reductions in critical technologies, such as wind and solar, are set to continue?"
# ***
# Correct:  iea
# ***
# predicted:  specific economic support
# Support:  Hydropower is produced in 150 countries, with the Asia-Pacific region generating 32 percent of global hydropower in 2010.
# ***
# Question:  Hydropower is produced in how many countries?
# ***
# Correct:  150
# ***
# predicted:  global hydropower
#
#
# Support:  Crop residues (such as corn stalks, wheat straw and rice straw), wood waste, and municipal solid waste are potential sources of cellulosic biomass.
# ***
# Question:  What are potential sources of cellulosic biomass?
# ***
# Correct:  crop residues
# ***
# predicted:  municipal solid waste
#
#
# Support:  The $1.00/W installed cost, is often regarded in the PV industry as marking the achievement of grid parity for PV.
# ***
# Question:  What cost is often regarded as marking the achievment of grid parity for PV?
# ***
# Correct:  $ 1.00/w installed cost
# ***
# predicted:  achievement
#
#
# Support:  Mark Z. Jacobson, professor of civil and environmental engineering at Stanford University and director of its Atmosphere and Energy Program says producing all new energy with wind power, solar power, and hydropower by 2030 is feasible and existing energy supply arrangements could be replaced by 2050.
# ***
# Question:  Jacobson says producing all new energy with wind power, solar power and hydropower is feasible by what year?
# ***
# Correct:  2030
# ***
# predicted:  wind power
#
#
# Support:  Energy regulators often have authority to carry out a number of functions that have implications for the financial feasibility of renewable energy projects.
# ***
# Question:  Who has the authority to carry out a number of functions that havae implications for the feasiblity of renewable energy projects?
# ***
# Correct:  energy regulators
# ***
# predicted:  financial feasibility
#
#
# Support:  The Blythe Solar Power Project is a 500 MW photovoltaic station under construction in Riverside County, California.
# ***
# Question:  Where is the Agua Caliente Solar Project located?
# ***
# Correct:  usa
# ***
# predicted:  california
#
#
# Support:  Spielberg directed 2015's Bridge of Spies, a Cold War thriller based on the 1960 U-2 incident, and focusing on James B. Donovan's negotiations with the Soviets for the release of pilot Gary Powers after his aircraft was shot down over Soviet territory.
# ***
# Question:  Who played Donovan in 'Bridge of Spies'?
# ***
# Correct:  tom hanks
# ***
# predicted:  soviet territory
#
#
# Support:  He developed the series with Robert Rodat and is credited as an executive producer.
# ***
# Question:  What show did Spielberg work with Rodat on?
# ***
# Correct:  falling skies
# ***
# predicted:  executive producer
#
#
# Support:  Drawing from his own experiences in Scouting, Spielberg helped the Boy Scouts of America develop a merit badge in cinematography in order to help promote filmmaking as a marketable skill.
# ***
# Question:  When did Spielberg join the Boy Scouts?
# ***
# Correct:  1958
# ***
# predicted:  marketable skill
#
#
# Support:  The archaeologist and adventurer hero Indiana Jones was played by Harrison Ford (whom Lucas had previously cast in his Star Wars films as Han Solo).
# ***
# Question:  Who was responsible for Star Wars?
# ***
# Correct:  george lucas
# ***
# predicted:  han solo
#
#
# Support:  He served as an executive producer for the 1997 film Men in Black, and its sequels, Men in Black II and Men in Black III.
# ***
# Question:  When was 'Men In Black' released?
# ***
# Correct:  1997
# ***
# predicted:  black iii
#
#
# Support:  In 1989, he brought the concept of The Dig to LucasArts.
# ***
# Question:  When was 'The Dig' released?
# ***
# Correct:  1995
# ***
# predicted:  lucasarts
#
#
# Support:  Studio vice president Sidney Sheinberg was impressed by the film, which had won a number of awards, and offered Spielberg a seven-year directing contract.
# ***
# Question:  What was Sidney Sheinberg's position with Universal?
# ***
# Correct:  vice president
# ***
# predicted:  seven-year directing contract
#
#
# Support:  It was released just four days after The Adventures of Tintin, on December 25, 2011.
# ***
# Question:  When was Adventures of Tintin released in the US?
# ***
# Correct:  december 21 , 2011
# ***
# predicted:  december
#
#
# ...
# ***
# Question:  What seige did these victories lead to?
# ***
# Correct:  siege of metz
# ***
# predicted:  2 september
#
#
# Support:  As the autumn storms of the North Sea forced the return of more of the French ships, the blockade of the north German ports diminished and in September 1870 the French navy abandoned the blockade for the winter.
# ***
# Question:  The autumn storms of what sea forced the return of yet more French ships?
# ***
# Correct:  the north sea
# ***
# predicted:  winter
#
#
# Support:  Despite odds of four to one, the III Corps launched a risky attack.
# ***
# Question:  What odds were at stake for the attack launched by the III Corps?
# ***
# Correct:  four to one
# ***
# predicted:  risky attack
#
#
# Support:  The casualties were horrible, especially for the attacking Prussian forces.
# ***
# Question:  In what type of neighborhoods did the occur especially?
# ***
# Correct:  working-class neighbourhoods
# ***
# predicted:  attacking prussian forces
#
#
# Support:  More recent histories, based on studies of the number buried in Paris cemeteries and in mass graves after the fall of the Commune, put the number killed at between 6,000 and 10,000.
# ***
# Question:  What did most Prussians fall under?
# ***
# Correct:  french chassepot rifles
# ***
# predicted:  number
#
#
# Support:  Other countries quickly discerned the advantages given to the Germans by their military system, and adopted many of their innovations, particularly the General Staff, universal conscription and highly detailed mobilization systems.
# ***
# Question:  Who reformed the low numbers of troops by implementing universal conscription?
# ***
# Correct:  marshal adolphe niel
# ***
# predicted:  highly detailed mobilization systems
#
#
# Support:  The Battle of Spicheren, on 5 August, was the second of three critical French defeats.
# ***
# Question:  Which battle was the second of three key French losses?
# ***
# Correct:  battle of spicheren
# ***
# predicted:  three critical french defeats
# Support:  Firing a contact-detonated shell, the Krupp gun had a longer range and a higher rate of fire than the French bronze muzzle loading cannon, which relied on faulty time fuses.
# ***
# Question:  What type of shell did the Krupp weapon fire?
# ***
# Correct:  a contact-detonated shell
# ***
# predicted:  faulty time fuses
#
#
# Support:  A pre-war plan laid out by the late Marshal Niel called for a strong French offensive from Thionville towards Trier and into the Prussian Rhineland.
# ***
# Question:  From Thionville towards Trier, what was the final destination of the offensive?
# ***
# Correct:  the prussian rhineland
# ***
# predicted:  prussian rhineland
#
#
# Support:  General Frossard's II Corps and Marshal Bazaine's III Corps crossed the German border on 2 August, and began to force the Prussian 40th Regiment of the 16th Infantry Division from the town of Saarbrücken with a series of direct attacks.
# ***
# Question:  What town were the III Corps able to capture?
# ***
# Correct:  vionville
# ***
# predicted:  direct attacks
#
#
# Support:  On 18 August, the battle began when at 08:00 Moltke ordered the First and Second Armies to advance against the French positions.
# ***
# Question:  On what date did the battle begin?
# ***
# Correct:  18 august
# ***
# predicted:  french positions
#
#
# Support:  In January 1871, Gambetta forced Faidherbe to march his army beyond the fortresses and engage the Prussians in open battle.
# ***
# Question:  Who commanded the French army at the battle of Worth?
# ***
# Correct:  general macmahon
# ***
# predicted:  open battle
#
#
# Support:  During the fighting, the Communards killed c. 500 people, including the Archbishop of Paris, and burned down many government buildings, including the Tuileries Palace and the Hotel de Ville.
# ***
# Question:  What type of buildings were especially targeted to be burned down?
# ***
# Correct:  government buildings
# ***
# predicted:  hotel de ville
#
#
# Support:  When the war had begun, European public opinion heavily favored the Germans; many Italians attempted to sign up as volunteers at the Prussian embassy in Florence and a Prussian diplomat visited Giuseppe Garibaldi in Caprera.
# ***
# Question:  In which city did many Italians attempt to proffer their services to the Prussian embassy?
# ***
# Correct:  florence
# ***
# predicted:  caprera
#
#
# Support:  German tactics emphasised encirclement battles like Cannae and using artillery offensively whenever possible.
# ***
# Question:  German tactics relied on what type of battle strategy?
# ***
# Correct:  encirclement battles
# ***
# predicted:  cannae
#
#
# Support:  During the fighting, the Communards killed c. 500 people, including the Archbishop of Paris, and burned down many government buildings, including the Tuileries Palace and the Hotel de Ville.
# ***
# Question:  How many were killed by the Communards?
# ***
# Correct:  500 people
# ***
# predicted:  hotel de ville
#
#
# Support:  The Crown Prince of Prussia's 3rd army had, on the quick reaction of his Chief of Staff General von Blumenthal, drawn reinforcements which brought its strength up to 140,000 troops.
# ***
# Question:  What was the estimated number of troops in Prussia's 3rd Army?
# ***
# Correct:  140,000 troops
# ***
# predicted:  to 140,000 troops
#
#
# Support:  The French Army of the Rhine, commanded by Marshal François-Achille Bazaine, numbering about 183 infantry battalions, 104 cavalry squadrons, backed by 520 heavy cannons, totaling 112,800 officers and men, dug in along high ground with their southern left flank at the town of Rozerieulles, and their northern right flank at St. Privat.
# ***
# Question:  Who commanded the French Army of the Rhine?
# ***
# Correct:  marshal françois-achille bazaine
# ***
# predicted:  st. privat
#
#
# Support:  By 12:00, General Manstein opened up the battle before the village of Amanvillers with artillery from the 25th Infantry Division.
# ***
# Question:  Which general opened the battle with artillery from the 25th Infantry Division?
# ***
# Correct:  general manstein
# ***
# predicted:  amanvillers
#
#
# Support:  Bismarck honoured the armistice, by allowing train loads of food into Paris and withdrawing Prussian forces to the east of the city, prior to a full withdrawal once France agreed to pay a five billion franc war indemnity.
# ***
# Question:  To hounour the armistice, Bismarck allowed train loads of what into Paris?
# ***
# Correct:  food
# ***
# predicted:  full withdrawal
#
#
# Support:  When the news arrived at Paris of the surrender at Sedan of Napoleon III and 80,000 men, the Second Empire was overthrown by a popular uprising in Paris, which forced the proclamation of a Provisional Government and a Third Republic by general Trochu, Favre and Gambetta at Paris on 4 September, the new government calling itself the Government of National Defence.
# ***
# Question:  Which empire was overthrown by a popular uprising in Paris?
# ***
# Correct:  the second empire
# ***
# predicted:  national defence
#
#
# Support:  The events of the Franco-Prussian War had great influence on military thinking over the next forty years.
# ***
# Question:  The events of the Franco-Prussian War had great influence on what?
# ***
# Correct:  military thinking
# ***
# predicted:  next forty years
#
#
# Support:  General De Wimpffen, the commander of the French V Corps in reserve, hoped to launch a combined infantry and cavalry attack against the Prussian XI Corps.
# ***
# Question:  Who commanded the French V Corps in reserve?
# ***
# Correct:  general de wimpffen
# ***
# predicted:  prussian xi corps
#
#
# Support:  The attackers had an initial superiority of numbers, a broad deployment which made envelopment highly likely but the effectiveness of French Chassepot rifle-fire inflicted costly repulses on infantry attacks, until the French infantry had been extensively bombarded by the Prussian artillery.
# ***
# Question:  What weapon once again increased the effectiveness of the infantry attacks?
# ***
# Correct:  french chassepot
# ***
# predicted:  prussian artillery
#
#
# Support:  While the French army under General MacMahon engaged the German 3rd Army at the Battle of Wörth, the German 1st Army under Steinmetz finished their advance west from Saarbrücken.
# ***
# Question:  Which German divisison did MacMahon engage?
# ***
# Correct:  german 3rd army
# ***
# predicted:  saarbrücken
#
#
# Support:  When the war began, the French government ordered a blockade of the North German coasts, which the small North German navy (Norddeutsche Bundesmarine) with only five ironclads could do little to oppose.
# ***
# Question:  The small North German navy had how many ironclads at their disposal?
# ***
# Correct:  only five
# ***
# predicted:  five ironclads
#
#
# Support:  The Treaty of Frankfurt of 10 May 1871 gave Germany most of Alsace and some parts of Lorraine, which became the Imperial territory of Alsace-Lorraine (Reichsland Elsaß-Lothringen).The German conquest of France and the unification of Germany upset the European balance of power, that had existed since the Congress of Vienna in 1815 and Otto von Bismarck maintained great authority in international affairs for two decades.
# ***
# Question:  The Treaty of Frankfurt gave Germany which Imperial territory?
# ***
# Correct:  alsace-lorraine
# ***
# predicted:  two decades
#
#
# Support:  Spotting a blockade-runner became unwelcome because of the question du charbon; pursuit of Prussian ships quickly depleted the coal reserves of the French ships.
# ***
# Question:  In pursuing Prussian ships, what resource was quickly depleted?
# ***
# Correct:  coal reserves
# ***
# predicted:  french ships
#
#
# Support:  When the war had begun, European public opinion heavily favored the Germans; many Italians attempted to sign up as volunteers at the Prussian embassy in Florence and a Prussian diplomat visited Giuseppe Garibaldi in Caprera.
# ***
# Question:  At the start of the war, which country did European public opinion champion?
# ***
# Correct:  the germans
# ***
# predicted:  volunteers
#
#
# Support:  Because the reserves had not arrived, Frossard erroneously believed that he was in grave danger of being outflanked as German soldiers under General von Glume were spotted in Forbach.
# ***
# Question:  Which town was the site of General von Steinmetz's grave error?
# ***
# Correct:  spicheren
# ***
# predicted:  forbach
#
#
# Support:  As the autumn storms of the North Sea forced the return of more of the French ships, the blockade of the north German ports diminished and in September 1870 the French navy abandoned the blockade for the winter.
# ***
# Question:  How many ships was the French navy able to dispatch to sea?
# ***
# Correct:  470
# ***
# predicted:  winter
#
#
# Support:  Marshal MacMahon, now closest to Wissembourg, spread his four divisions over 20 miles (32 km) to react to any Prussian invasion.
# ***
# Question:  Which marshal was closest to Wissembourg?
# ***
# Correct:  marshal macmahon
# ***
# predicted:  prussian invasion
# Support:  President Trochu resigned on 25 January and was replaced by Favre, who signed the surrender two days later at Versailles, with the armistice coming into effect at midnight.
# ***
# Question:  On what date did president Trochu resign?
# ***
# Correct:  25 january
# ***
# predicted:  midnight
#
#
# Support:  On 19 July 1870 a declaration of war was sent to the Prussian government.
# ***
# Question:  On which date did France issue a declaration of war to the Prussian government?
# ***
# Correct:  19 july 1870
# ***
# predicted:  19 july
#
#
# Support:  More recent histories, based on studies of the number buried in Paris cemeteries and in mass graves after the fall of the Commune, put the number killed at between 6,000 and 10,000.
# ***
# Question:  What was the number of French prisoners?
# ***
# Correct:  4,420
# ***
# predicted:  commune
#
#
# Support:  On 10 October, hostilities began between German and French republican forces near Orléans.
# ***
# Question:  On which date did hostilities between the German and French troops begin near Orleans?
# ***
# Correct:  10 october
# ***
# predicted:  orléans
#
#
# Support:  The Prussian guns typically opened fire at a range of 2–3 kilometres (1.2–1.9 mi), beyond the range of French artillery or the Chassepot rifle.
# ***
# Question:  What was the typical range that Prussian guns could fire?
# ***
# Correct:  2–3 kilometres
# ***
# predicted:  chassepot rifle
#
#
# Support:  The Hohenzollern prince's candidacy was withdrawn under French diplomatic pressure, but Otto von Bismarck goaded the French into declaring war by altering a telegram sent by William I.
# ***
# Question:  Who goaded the French into war by editing a telegram sent by William I?
# ***
# Correct:  otto von bismarck
# ***
# predicted:  william i.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c608b2f1bc59> in <module>()
#     296     for id, _ in results:
#     297         sent = raw_docs[id]
# --> 298         doc = nlp(sent)
#     299
#     300         score = get_overlap(sent, question)
#
# /anaconda3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     278         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
#     279         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad),
# --> 280                                          drop=drop)
#     281         if bp_layer is None:
#     282             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /anaconda3/lib/python3.6/site-packages/thinc/api.py in uniqued_fwd(X, drop)
#     370         uniq_keys, ind, inv, counts = numpy.unique(keys, return_index=True,
#     371                                                     return_inverse=True,
# --> 372                                                     return_counts=True)
#     373         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
#     374         Y_uniq, bp_Y_uniq = layer.begin_update(X_uniq, drop=drop)
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     298         if return_counts:
#     299             idx = np.concatenate(np.nonzero(flag) + ([ar.size],))
# --> 300             ret += (np.diff(idx),)
#     301     return ret
#     302
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in diff(a, n, axis)
#    1942     slice2 = tuple(slice2)
#    1943
# -> 1944     op = not_equal if a.dtype == np.bool_ else subtract
#    1945     for _ in range(n):
#    1946         a = op(a[slice1], a[slice2])
#
# KeyboardInterrupt:
